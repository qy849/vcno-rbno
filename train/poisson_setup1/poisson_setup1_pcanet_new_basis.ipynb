# %%
import os
import sys
import argparse

import numpy as np
import matplotlib.pyplot as plt

import torch

import dolfinx
import dolfinx.fem.petsc
import ufl


from mpi4py import MPI
import basix.ufl

repo_path = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(repo_path)

from data_generation.differential_equations import PoissonSetup1LeastSquares
from utils import load_yaml, load_pkl, load_npy, format_elapsed_time, timing, plot_complex_valued_function, plot_real_valued_function
from utils import evaluate_expression, print_model_size


from scifem import create_real_functionspace

import torch
import torch.nn as nn
import torch.nn.init as init
import numpy as np
from petsc4py import PETSc
import scifem


from utils import project, norm_L2, convert_petsc_mat_to_torch_sparse_coo_tensor, print_model_size
from typing import Optional
import pickle
from tqdm import tqdm
import einops
from models import ResNet1d, MLP
# Out:
# ----------------------------------------
# 2025-12-19 14:26:49 - Start Program
# ----------------------------------------

# %%
mesh_config_path= repo_path + "/configs/poisson_setup1/config_data/config_mesh.yaml"
function_space_config_path= repo_path + "/configs/poisson_setup1/config_data/config_function_space.yaml"
output_reduced_basis_config_path= repo_path + "/configs/poisson_setup1/config_data/config_output_reduced_basis.yaml"
train_dataset_path = repo_path + "/results/poisson_setup1/train_dataset"
test_dataset_path = repo_path + "/results/poisson_setup1/test_dataset"
model_train_outputs_path = repo_path + "/results/poisson_setup1/model_train_outputs/pcanet_new_basis"
model_test_outputs_path = repo_path + "/results/poisson_setup1/model_test_outputs/pcanet_new_basis"

mesh_args = load_yaml(mesh_config_path)
function_space_args = load_yaml(function_space_config_path)
output_reduced_basis_args = load_yaml(output_reduced_basis_config_path)
poisson_least_squares = PoissonSetup1LeastSquares(mesh_args, function_space_args)

# %%
p_dof = load_npy(train_dataset_path+'/p_dof.npy')
p_vertex_values = load_npy(train_dataset_path+'/p_vertex_values.npy')
sigma_u_dof = load_npy(train_dataset_path+'/sigma_u_dof.npy')
sigma_vertex_values = load_npy(train_dataset_path+'/sigma_vertex_values.npy')
u_vertex_values = load_npy(train_dataset_path+'/u_vertex_values.npy')

# %%
print("p_dof shape: ", p_dof.shape)
print("p_vertex_values shape: ", p_vertex_values.shape)
print("sigma_u_dof shape: ", sigma_u_dof.shape)
print("sigma_vertex_values shape: ", sigma_vertex_values.shape)
print("u_vertex_values shape: ", u_vertex_values.shape)
# Out:
# p_dof shape:  (5000, 32768)
# p_vertex_values shape:  (5000, 16641)
# sigma_u_dof shape:  (5000, 230401)
# sigma_vertex_values shape:  (5000, 16641, 2)
# u_vertex_values shape:  (5000, 16641, 1)

# %%
mesh = poisson_least_squares.mesh
Vh = poisson_least_squares.Vh

# %%
torch_dtype = {
    'float16': torch.float16,
    'float32': torch.float32,
    'float64': torch.float64,
}

# %%
# num_k_fc = len(k_dof)
# num_sigma_u_fc = len(sigma_u_dof)

# k_vertex_values = np.zeros((num_k_fc, num_vertices))
# u_vertex_values = np.zeros((num_sigma_u_fc, num_vertices, 1))
# sigma_vertex_values = np.zeros((num_sigma_u_fc, num_vertices, 2))

# image_k_vertex_values = np.zeros((num_k_fc, mesh_args['num_y']+1, mesh_args['num_x']+1))
# image_u_vertex_values = np.zeros((num_sigma_u_fc, 1, mesh_args['num_y']+1, mesh_args['num_x']+1))
# image_sigma_vertex_values = np.zeros((num_sigma_u_fc, 2, mesh_args['num_y']+1, mesh_args['num_x']+1))

# dolfinx_mesh_coords = mesh.geometry.x[:,:2]
# num_vertices = len(dolfinx_mesh_coords)
# num_x, num_y = mesh_args['num_x'], mesh_args['num_y']
# x = np.linspace(0, mesh_args['upper_right_x'], num_x+1)
# y = np.linspace(0, mesh_args['upper_right_y'], num_y+1)
# image_mesh_coords = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
# perm = [np.where((image_mesh_coords == row).all(axis=1))[0][0] for row in dolfinx_mesh_coords]

# CG_element = basix.ufl.element('CG', 'triangle', 1)
# Vh['CG1'] = dolfinx.fem.functionspace(mesh, CG_element)

# %%
# for i in tqdm(range(num_k_fc), desc="Evaluating k on grid points"):
#     k = dolfinx.fem.Function(Vh['CG1'])
#     k.x.array[:] = k_dof[i]
#     k_vertex_values[i][perm] = k.x.array[:][scifem.vertex_to_dofmap(Vh['CG1'])]
#     image_k_vertex_values[i] = k_vertex_values[i].reshape(num_x+1, num_y+1).T

# %%
num_p_fc = len(p_dof)
num_x, num_y = mesh_args['num_x'], mesh_args['num_y']
image_p_vertex_values = np.zeros((num_p_fc, num_y+1, num_x+1))
for i in tqdm(range(num_p_fc)):
    image_p_vertex_values[i,:,:] = p_vertex_values[i].reshape(num_x+1, num_y+1).T
# Out:
# 100%|██████████| 5000/5000 [00:02<00:00, 2391.66it/s]

# %%
# num_sigma_fc = len(sigma_vertex_values)
# image_sigma_vertex_values = np.zeros((num_sigma_fc, 2, mesh_args['num_y']+1, mesh_args['num_x']+1))
# for i in tqdm(range(num_sigma_fc)):
#     image_sigma_vertex_values[i, 0, :, :] = sigma_vertex_values[i, :, 0].reshape(num_x+1, num_y+1).T
#     image_sigma_vertex_values[i, 1, :, :] = sigma_vertex_values[i, :, 1].reshape(num_x+1, num_y+1).T

# num_u_fc = len(u_vertex_values)
# image_u_vertex_values = np.zeros((num_u_fc, 1, mesh_args['num_y']+1, mesh_args['num_x']+1))
# for i in tqdm(range(num_u_fc)):
#     image_u_vertex_values[i, 0, :, :] = u_vertex_values[i, :, 0].reshape(num_x+1, num_y+1).T

# %%
# for i in tqdm(range(num_sigma_u_fc), desc="Evaluating sigma_u on grid points"):
#     sigma_u_fc = dolfinx.fem.Function(Vh['sigma_u'])
#     sigma_u_fc.x.array[:] = sigma_u_dof[i]
#     sigma_fc = sigma_u_fc.sub(0).collapse()
#     u_fc = sigma_u_fc.sub(1).collapse()

#     sigma_grid_evals = evaluate_expression(mesh, sigma_fc, mesh.geometry.x)[1]
#     u_grid_evals = evaluate_expression(mesh, u_fc, mesh.geometry.x)[1]

#     sigma_vertex_values[i, perm, 0] = sigma_grid_evals[:, 0]
#     sigma_vertex_values[i, perm, 1] = sigma_grid_evals[:, 1]
#     u_vertex_values[i, perm, 0] = u_grid_evals[:, 0]
 
#     image_sigma_vertex_values[i, 0, :, :] = sigma_vertex_values[i, :, 0].reshape(num_x+1, num_y+1).T
#     image_sigma_vertex_values[i, 1, :, :] = sigma_vertex_values[i, :, 1].reshape(num_x+1, num_y+1).T
#     image_u_vertex_values[i, 0, :, :] = u_vertex_values[i, :, 0].reshape(num_x+1, num_y+1).T

# np.save(train_dataset_path+'/image_k_vertex_values.npy', image_k_vertex_values)
# np.save(train_dataset_path+'/image_u_vertex_values.npy', image_u_vertex_values)
# np.save(train_dataset_path+'/image_sigma_vertex_values.npy', image_sigma_vertex_values)

# %%
# image_k_vertex_values = load_npy(train_dataset_path+'/image_k_vertex_values.npy')
# image_u_vertex_values = load_npy(train_dataset_path+'/image_u_vertex_values.npy')
# image_sigma_vertex_values = load_npy(train_dataset_path+'/image_sigma_vertex_values.npy')

# %%
num_sigma_u_fc = len(sigma_u_dof)
image_u_vertex_values = np.zeros((num_sigma_u_fc, 1, mesh_args['num_y']+1, mesh_args['num_x']+1))
image_sigma_vertex_values = np.zeros((num_sigma_u_fc, 2, mesh_args['num_y']+1, mesh_args['num_x']+1))
for i in tqdm(range(num_sigma_u_fc)):
    image_sigma_vertex_values[i, 0, :, :] = sigma_vertex_values[i, :, 0].reshape(num_x+1, num_y+1).T
    image_sigma_vertex_values[i, 1, :, :] = sigma_vertex_values[i, :, 1].reshape(num_x+1, num_y+1).T
    image_u_vertex_values[i, 0, :, :] = u_vertex_values[i, :, 0].reshape(num_x+1, num_y+1).T
# Out:
# 100%|██████████| 5000/5000 [00:06<00:00, 800.50it/s]

# %%
# image_k_vertex_values = load_npy(train_dataset_path+'/image_k_vertex_values.npy').reshape(num_k_fc, mesh_args['num_x']+1, mesh_args['num_y']+1).transpose(0, 2, 1)
# image_u_vertex_values = load_npy(train_dataset_path+'/image_u_vertex_values.npy').reshape(num_sigma_u_fc, mesh_args['num_x']+1, mesh_args['num_y']+1, 1).transpose(0, 2, 1, 3)
# image_sigma_vertex_values = load_npy(train_dataset_path+'/image_sigma_vertex_values.npy').reshape(num_sigma_u_fc, mesh_args['num_x']+1, mesh_args['num_y']+1, 2).transpose(0, 2, 1, 3)

# %%
sample_index = 1000
plt.imshow(image_p_vertex_values[sample_index], extent=(0, mesh_args['upper_right_x'], 0, mesh_args['upper_right_y']), origin='lower', cmap='turbo')
plt.title("p vertex values")
plt.colorbar()
plt.show()

x = mesh.geometry.x[:, 0]
y = mesh.geometry.x[:, 1]
p = dolfinx.fem.Function(Vh['p'])
p.x.array[:] = p_dof[sample_index]
plt.tricontourf(x, y, evaluate_expression(mesh, p, mesh.geometry.x)[1][:, 0], cmap='turbo', levels=100)
plt.colorbar()
plt.title('Random parameter function p')
plt.show()



sigma_u = dolfinx.fem.Function(Vh['sigma_u'])
sigma_u.x.array[:] = sigma_u_dof[sample_index]
sigma = sigma_u.sub(0).collapse()
u = sigma_u.sub(1).collapse()


plt.imshow(image_u_vertex_values[sample_index, 0, :, :], extent=(0, mesh_args['upper_right_x'], 0, mesh_args['upper_right_y']), origin='lower', cmap='turbo')
plt.title("u vertex values")
plt.colorbar()
plt.show()

plt.tricontourf(x, y, evaluate_expression(mesh, u, mesh.geometry.x)[1][:, 0], cmap='turbo', levels=100)
plt.colorbar()
plt.show()


plt.imshow(image_sigma_vertex_values[sample_index, 0, :, :], extent=(0, mesh_args['upper_right_x'], 0, mesh_args['upper_right_y']), origin='lower', cmap='turbo')
plt.title("sigma_1 vertex values")
plt.colorbar()
plt.show()  

plt.tricontourf(x, y, evaluate_expression(mesh, sigma, mesh.geometry.x)[1][:, 0], cmap='turbo', levels=100)
plt.colorbar()
plt.show()

plt.imshow(image_sigma_vertex_values[sample_index, 1, :, :], extent=(0, mesh_args['upper_right_x'], 0, mesh_args['upper_right_y']), origin='lower', cmap='turbo')
plt.title("sigma_2 vertex values")
plt.colorbar()
plt.show()

plt.tricontourf(x, y, evaluate_expression(mesh, sigma, mesh.geometry.x)[1][:, 1], cmap='turbo', levels=100)
plt.colorbar()
plt.show()

# %%
# pod_basis_dof = np.load(train_dataset_path+'/pod_basis_dof.npy')[:,:output_reduced_basis_args['num_basis']]
# pod_coeff_labels = np.load(train_dataset_path+'/pod_coeff_labels.npy')[:,:output_reduced_basis_args['num_basis']]

# %%
# quadratic_weight = torch.tensor(np.load(train_dataset_path+'/quadratic_weight.npy'), dtype=torch_dtype['float64'])
# linear_weight = torch.tensor(np.load(train_dataset_path+'/linear_weight.npy'), dtype=torch_dtype['float64'])
# bias = torch.tensor(np.load(train_dataset_path+'/bias.npy'), dtype=torch_dtype['float64'])

# %%
device = torch.device('cuda:1')

# %%
def compute_pod_basis(snapshot: np.ndarray, num_basis: int, weight: np.ndarray = None) -> tuple[np.ndarray, np.ndarray]:
    """
    Compute POD basis using NumPy.

    Parameters:
        snapshot: (num_samples, num_dof) complex or real ndarray
        num_basis: number of POD modes to extract
        weight: (num_dof, num_dof) ndarray, optional

    Returns:
        sqrt_eigvals: (num_basis,) ndarray of sqrt of top eigenvalues
        pod_basis: (num_dof, num_basis) ndarray of POD modes
    """
    num_samples, num_dof = snapshot.shape
    assert num_basis < num_dof

    if weight is None:
        C = snapshot @ snapshot.T
    else:
        C = snapshot @ weight @ snapshot.T

    eigvals, eigvecs = np.linalg.eigh(C)  # ascending order
    eigvals = eigvals[-num_basis:]
    eigvecs = eigvecs[:, -num_basis:]


    # Sort eigenvalues and eigenvectors in descending order
    # Note that np.flip is not in-place, need to mannually copy to accelerate the following computation
    eigvals = np.flip(eigvals, axis=0).copy() 
    eigvecs = np.flip(eigvecs, axis=1).copy()

    temp = snapshot.T @ eigvecs
    pod_basis = np.zeros((num_dof, num_basis), dtype=snapshot.dtype)
    for i in range(num_basis):
        pod_basis[:, i] = temp[:, i] / np.sqrt(eigvals[i])

    return np.sqrt(eigvals), pod_basis

# %%
num_samples_for_constructing_pod_basis = output_reduced_basis_args['num_evals']
num_input_basis = 20
num_output_basis = 128 

p_eigvals, p_pod_basis = compute_pod_basis(einops.rearrange(image_p_vertex_values[:num_samples_for_constructing_pod_basis], 'b h w -> b (h w)'), num_basis=num_input_basis)
image_sigma_u_vertex_values = np.concatenate((image_sigma_vertex_values, image_u_vertex_values), axis=1)

sigma_eigvals, sigma_pod_basis = compute_pod_basis(einops.rearrange(image_sigma_vertex_values[:num_samples_for_constructing_pod_basis], 'b c h w -> b (c h w)'), num_basis=num_output_basis)
u_eigvals, u_pod_basis = compute_pod_basis(einops.rearrange(image_u_vertex_values[:num_samples_for_constructing_pod_basis], 'b c h w -> b (c h w)'), num_basis=num_output_basis)
sigma_u_eigvals, sigma_u_pod_basis = compute_pod_basis(einops.rearrange(image_sigma_u_vertex_values[:num_samples_for_constructing_pod_basis], 'b c h w -> b (c h w)'), num_basis=num_output_basis)

# %%
pod_basis_dof = np.load(train_dataset_path+'/hdiv_h1_pod_basis_dof.npy')[:,:output_reduced_basis_args['num_basis']]
reference_reduced_minimizers = np.load(train_dataset_path+'/reference_reduced_minimizers.npy')[:,:output_reduced_basis_args['num_basis']]

# %%
reduced_p = einops.rearrange(image_p_vertex_values, 'b h w -> b (h w)') @ p_pod_basis
# reduced_sigma = einops.rearrange(image_sigma_vertex_values, 'b c h w -> b (c h w)') @ sigma_pod_basis
# reduced_u = einops.rearrange(image_u_vertex_values, 'b c h w -> b (c h w)') @ u_pod_basis
# reduced_sigma_u = einops.rearrange(image_sigma_u_vertex_values, 'b c h w -> b (c h w)') @ sigma_u_pod_basis

# %%
# reconstructed_sigma_u = einops.rearrange(reduced_sigma_u @ sigma_u_pod_basis.T, 'b (c h w) -> b c h w', c=3, h=129, w=129)

# temp= 0 
# for i in range(10):
#     temp += np.sum((reconstructed_sigma_u[i] - image_sigma_u_vertex_values[i])**2)**(1/2) / np.sum(image_sigma_u_vertex_values[i]**2)**(1/2)
# temp /= 10

# print(temp)

# %%
# reconstructed_p = einops.rearrange(reduced_p @ p_pod_basis.T, 'b (h w) -> b h w', h=129, w=129)

# temp= 0 
# for i in range(10):
#     temp += np.sum((reconstructed_p[i] - image_p_vertex_values[i])**2)**(1/2) / np.sum(image_p_vertex_values[i]**2)**(1/2)
# temp /= 10

# print(temp)

# %%
reduced_p_tensor = torch.tensor(reduced_p, dtype=torch_dtype['float32'])
reference_reduced_minimizers_tensor = torch.tensor(reference_reduced_minimizers, dtype=torch_dtype['float32'])
# reduced_u_tensor = torch.tensor(reduced_u, dtype=torch_dtype['float32'])
# reduced_sigma_tensor = torch.tensor(reduced_sigma, dtype=torch_dtype['float32'])
# reduced_sigma_u_tensor = torch.tensor(reduced_sigma_u, dtype=torch_dtype['float32'])
print(f'reduced_p_tensor shape: {reduced_p_tensor.shape}')
print(f'reference_reduced_minimizers_tensor shape: {reference_reduced_minimizers_tensor.shape}')
# print(f'reduced_u_tensor shape: {reduced_u_tensor.shape}')
# print(f'reduced_sigma_tensor shape: {reduced_sigma_tensor.shape}')
# print(f'reduced_sigma_u_tensor shape: {reduced_sigma_u_tensor.shape}')
# Out:
# reduced_p_tensor shape: torch.Size([5000, 20])
# reference_reduced_minimizers_tensor shape: torch.Size([5000, 128])

# %%
# image_k_vertex_values_tensor = torch.tensor(image_k_vertex_values, dtype=torch_dtype['float32'])
# image_u_vertex_values_tensor = torch.tensor(image_u_vertex_values, dtype=torch_dtype['float32'])
# image_sigma_vertex_values_tensor = torch.tensor(image_sigma_vertex_values, dtype=torch_dtype['float32'])
# image_sigma_u_vertex_values_tensor = torch.cat((image_sigma_vertex_values_tensor, image_u_vertex_values_tensor), dim=1)
# image_sigma_u_vertex_values_tensor = image_sigma_u_vertex_values_tensor.permute(0, 3, 1, 2)

# %%
# image_k_vertex_values_tensor = torch.tensor(image_k_vertex_values, dtype=torch_dtype['float32'])
# image_u_vertex_values_tensor = torch.tensor(image_u_vertex_values, dtype=torch_dtype['float32'])
# image_sigma_vertex_values_tensor = torch.tensor(image_sigma_vertex_values, dtype=torch_dtype['float32'])
# image_sigma_u_vertex_values_tensor = torch.cat((image_sigma_vertex_values_tensor, image_u_vertex_values_tensor), dim=-1)
# image_sigma_u_vertex_values_tensor = image_sigma_u_vertex_values_tensor.permute(0, 3, 1, 2)

# %%
# from neuralop.models import FNO

# %%
# class ModifiedFNO(nn.Module):
#     def __init__(self, num_basis):
#         super().__init__()
#         self.num_basis = num_basis
#         self.FNO = FNO(
#             n_modes=(32, 32), 
#             hidden_channels=128, 
#             in_channels=1, 
#             out_channels=1,
#             n_layers=4,
#         )
#         self.linear = nn.Linear(81*81, self.num_basis)
#         self.loss_record = None

#     def forward(self, p):
#         y = self.FNO(p)
#         y = y.view(-1, 81*81)
#         y = self.linear(y)
#         return y

# %%
class BatchIndicesIterator:
    def __init__(self, start: int, end: int, batch_size: int, shuffle: bool=True):
        self.start = start
        self.end = end
        if  self.start >= self.end:
            raise ValueError(f'The start index {self.start} must be less than the end index {self.end}.')
        self.batch_size = batch_size
        self.shuffle = shuffle

        self.indices = torch.arange(start, end)
        self.num_indices = len(self.indices)
        self.current_index = 0

        if self.shuffle:
            self.indices = self.indices[torch.randperm(self.num_indices)]

    def __iter__(self):
        return self

    def __next__(self):
        if self.current_index >= self.end - self.start:
            if self.shuffle:
                self.indices = self.indices[torch.randperm(self.num_indices)]
            self.current_index = 0
            raise StopIteration

        batch_indices = self.indices[self.current_index:self.current_index + self.batch_size]
        self.current_index += self.batch_size
        return batch_indices

# %%
def pretty_print_loss(loss_dict):
    formatted_loss = {key: value.item() for key, value in loss_dict.items()}
    print(', '.join(f"'{key}': {value}" for key, value in formatted_loss.items()))

# %%
class RelativeL2Loss(nn.Module):
    def __init__(self, eps=1e-10, reduction='sum'):
        super().__init__()
        self.eps = eps
        self.reduction = reduction

    def l2_norm(self, x):
        if x.dim() == 2:
            return torch.sum(x**2, dim=1)**(1/2)
        elif x.dim() == 3:
            return torch.sum(x**2, dim=(1,2))**(1/2)
        elif x.dim() == 4:
            return torch.sum(x**2, dim=(1,2,3))**(1/2)
        else:
            raise ValueError('Unsupported tensor shape')

    def forward(self, outputs, labels):
        diff = outputs - labels
        loss = self.l2_norm(diff) / (self.l2_norm(labels) + self.eps)
        if self.reduction == 'sum':
            return torch.sum(loss, dim=0)
        else:
            return torch.mean(loss, dim=0)

# %%
# class AddSpatialCoordinates(nn.Module):
#     def __init__(self, num_x: int, num_y: int): 
#         super().__init__()
#         self.num_x, self.num_y = (num_x, num_y)
#         self.x = np.linspace(0, 1, num_x)
#         self.y = np.linspace(0, 1, num_y)
#         self.x_coor, self.y_coor = np.meshgrid(self.x, self.y)
#         self.x_coor = torch.from_numpy(self.x_coor).to(dtype=torch.float32)
#         self.y_coor = torch.from_numpy(self.y_coor).to(dtype=torch.float32)

#     def forward(self, inputs):
#         repeat_x_coor = self.x_coor.repeat(inputs.shape[0],1,1)
#         repeat_y_coor = self.y_coor.repeat(inputs.shape[0],1,1)
#         outputs = torch.stack((inputs, repeat_x_coor, repeat_y_coor), dim=1)
#         return outputs

#     def to(self, device):
#         self.x_coor = self.x_coor.to(device)
#         self.y_coor = self.y_coor.to(device)
#         return self

# %%
# add_spatial_coordinates = AddSpatialCoordinates(num_x+1, num_y+1)
# add_spatial_coordinates = add_spatial_coordinates.to(device)

# %%
# model = FNO(
#     n_modes=(32, 32), 
#     hidden_channels=128, 
#     in_channels=3, 
#     out_channels=3,
#     n_layers=4,
# )

# model = model.to(device)

# %%
# model = ResNet1d(
#     input_dim=num_input_basis,
#     output_dim=num_output_basis,
#     hidden_dim=num_output_basis,
#     hidden_depth=5,
#     activation="relu",
#     init_func="kaiming_normal"
# )

model = MLP(
    input_dim=num_input_basis,
    output_dim=num_output_basis
)

_, _ = print_model_size(model)
model = model.to(device)
# Out:
# Total number of model parameters: 4350080 (~16.59 MiB)

# %%
relative_l2_loss = RelativeL2Loss(reduction='mean')
l2_loss = nn.MSELoss(reduction='mean')

# %%
iterations = 3000
num_train = output_reduced_basis_args['num_evals']
num_valid = 500

batch_size = {
    'train': num_train,
    'valid': num_valid
}

# %%
print(f'num_train: {num_train}')
# Out:
# num_train: 500

# %%
input_scaler_statistics = {
    'mean': reduced_p_tensor[:num_train].mean(dim=0).to(device),
    'std': reduced_p_tensor[:num_train].std(dim=0).to(device)
}
# output_scaler_statistics = {
#     'mean': reduced_sigma_u_tensor[:num_train].mean(dim=0).to(device),
#     'std': reduced_sigma_u_tensor[:num_train].std(dim=0).to(device)
# }

output_scaler_statistics = {
    'mean': reference_reduced_minimizers_tensor[:num_train].mean(dim=0).to(device),
    'std': reference_reduced_minimizers_tensor[:num_train].std(dim=0).to(device)
}

# %%
loss_history = {
    'train': [],
    'valid': []
}
valid_start_index = 4500

train_batch_indices_iterator = BatchIndicesIterator(start=0, end=num_train, batch_size=batch_size['train'], shuffle=True)
valid_batch_indices_iterator = BatchIndicesIterator(start=valid_start_index, end=valid_start_index + num_valid, batch_size=batch_size['valid'], shuffle=False)

print(f'num_training_samples: {num_train}')
# optimizer = SOAP(params=model.parameters(), lr = 5e-3, betas=(.95, .95), weight_decay=.01, precondition_frequency=5)  
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.01)  
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.9)

best_val_loss = float('inf')
best_model_path = os.path.join(model_train_outputs_path, f"best_model_params_{num_train}.pth")
best_model_iterations = []  

counter = 0 
while counter < iterations:
    for batch_indices in train_batch_indices_iterator:
        input_ = reduced_p_tensor[batch_indices].to(device)
        input_ = (input_ - input_scaler_statistics['mean']) / input_scaler_statistics['std']
        output = model(input_) 
        # label_sigma = reduced_sigma_tensor[batch_indices].to(device)
        # label_u = reduced_u_tensor[batch_indices].to(device)
        label = reference_reduced_minimizers_tensor[batch_indices].to(device)
        label = (label - output_scaler_statistics['mean']) / output_scaler_statistics['std']
        # loss = relative_l2_loss(output, label) 
        loss = l2_loss(output, label)
        # loss = l2_loss(output[:, :num_output_basis], label_sigma) + l2_loss(output[:, num_output_basis:], label_u)
        loss /= len(batch_indices)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        counter += 1
        print('')
        print(f'Iteration: {counter}')
        print(f'Train loss: {loss.item()}')
        loss_history['train'].append(loss.item())

        with torch.no_grad():
            model.eval()
            valid_loss = 0.0
            for valid_batch_indices in valid_batch_indices_iterator:
                valid_input = reduced_p_tensor[valid_batch_indices].to(device)
                valid_input = (valid_input - input_scaler_statistics['mean']) / input_scaler_statistics['std']
                valid_output = model(valid_input)
                # valid_label_sigma = reduced_sigma_tensor[valid_batch_indices].to(device)
                # valid_label_u = reduced_u_tensor[valid_batch_indices].to(device)
                valid_label = reference_reduced_minimizers_tensor[valid_batch_indices].to(device)
                valid_label = (valid_label - output_scaler_statistics['mean']) / output_scaler_statistics['std']
                # valid_loss += (relative_l2_loss(valid_output, valid_label).item())
                valid_loss = l2_loss(valid_output, valid_label).item()
                # valid_loss += (l2_loss(valid_output[:, :num_output_basis], valid_label_sigma) + l2_loss(valid_output[:, num_output_basis:], valid_label_u)).item()
            valid_loss /= num_valid
            loss_history['valid'].append(valid_loss)
            print(f'Valid loss: {valid_loss}')
            if valid_loss < best_val_loss:
                best_val_loss = valid_loss
                torch.save(model.state_dict(), best_model_path)
                best_model_iterations.append(counter)
                print(f"New best model saved at iteration {counter} with validation loss {best_val_loss:.6f}")

    lr_scheduler.step()

# Save training history and final model
loss_history = {key: np.array(value) for key, value in loss_history.items()}
np.save(os.path.join(model_train_outputs_path, f'loss_history_{num_train}.npy'), loss_history)
torch.save(model.state_dict(), os.path.join(model_train_outputs_path, f"latest_model_params_{num_train}.pth"))
# Out:
# num_training_samples: 500
#
# Iteration: 1
# Train loss: 0.0020720346365123987
# Valid loss: 0.0027453906536102296
# New best model saved at iteration 1 with validation loss 0.002745
#
# Iteration: 2
# Train loss: 0.0021382446866482496
# Valid loss: 0.0025477614402770994
# New best model saved at iteration 2 with validation loss 0.002548
#
# Iteration: 3
# Train loss: 0.0019152788445353508
# Valid loss: 0.002477184534072876
# New best model saved at iteration 3 with validation loss 0.002477
#
# Iteration: 4
# Train loss: 0.0018439794657751918
# Valid loss: 0.0024457011222839354
# New best model saved at iteration 4 with validation loss 0.002446
#
# Iteration: 5
# Train loss: 0.0018136841244995594
# Valid loss: 0.00241996169090271
# New best model saved at iteration 5 with validation loss 0.002420
#
# Iteration: 6
# Train loss: 0.0017750223632901907
# Valid loss: 0.0024197032451629638
#
# Iteration: 2982
# Train loss: 8.148326458012889e-09
# Valid loss: 0.0022505972385406495
#
# Iteration: 2983
# Train loss: 8.14746492494578e-09
# Valid loss: 0.0022505974769592286
#
# Iteration: 2984
# Train loss: 8.146613161841287e-09
# Valid loss: 0.002250597715377808
#
# Iteration: 2985
# Train loss: 8.145782715018868e-09
# Valid loss: 0.0022505979537963865
#
# Iteration: 2986
# Train loss: 8.144936280984894e-09
# Valid loss: 0.0022505979537963865
#
# Iteration: 2987
# Train loss: 8.14411649230351e-09
# Valid loss: 0.0022505979537963865
#
# Iteration: 2988
# Train loss: 8.14326028830692e-09
# Valid loss: 0.0022505981922149657
#
# Iteration: 2989
# Train loss: 8.1424298414845e-09
# Valid loss: 0.002250598430633545
#
# Iteration: 2990
# Train loss: 8.141609164624697e-09
# Valid loss: 0.002250598430633545
#
# Iteration: 2991
# Train loss: 8.140759177877044e-09
# Valid loss: 0.002250598669052124
#
# Iteration: 2992
# Train loss: 8.139931395589883e-09
# Valid loss: 0.002250598669052124
#
# Iteration: 2993
# Train loss: 8.139071638879614e-09
# Valid loss: 0.002250598907470703
#
# Iteration: 2994
# Train loss: 8.13825540291191e-09
# Valid loss: 0.002250598907470703
#
# Iteration: 2995
# Train loss: 8.137388540774282e-09
# Valid loss: 0.0022505991458892823
#
# Iteration: 2996
# Train loss: 8.136550988524505e-09
# Valid loss: 0.0022505991458892823
#
# Iteration: 2997
# Train loss: 8.135716100809987e-09
# Valid loss: 0.0022505991458892823
#
# Iteration: 2998
# Train loss: 8.134858120456556e-09
# Valid loss: 0.0022505993843078614
#
# Iteration: 2999
# Train loss: 8.13404632538095e-09
# Valid loss: 0.0022505996227264406
#
# Iteration: 3000
# Train loss: 8.13318923320594e-09
# Valid loss: 0.0022505996227264406

# %%
# model = ResNet1d(
#     input_dim=num_input_basis,
#     output_dim=num_output_basis,
#     hidden_dim=num_output_basis,
#     hidden_depth=5,
#     activation="relu",
#     init_func="kaiming_normal"
# )

model = MLP(
    input_dim=num_input_basis,
    output_dim=num_output_basis
)

state_dict = torch.load(os.path.join(model_train_outputs_path, f"best_model_params_{num_train}.pth"), weights_only=False)
model.load_state_dict(state_dict)
model = model.to(device)

# %%
counter_indices = np.arange(1, len(loss_history['train'])+1)
plt.loglog(counter_indices, loss_history['train'], label='Training Loss', color='blue')
plt.loglog(counter_indices, loss_history['valid'], label='Validation Loss', color='orange')
plt.plot(counter_indices[-1], loss_history['train'][-1], 'bo', markersize=5, label='Final training loss')  # blue dot on last point
plt.plot(best_model_iterations[-1], loss_history['valid'][best_model_iterations[-1]-1], 'go', markersize=5, label='Lowest validation loss')  # red dot for best model iteration
plt.plot(best_model_iterations, [loss_history['valid'][i-1] for i in best_model_iterations], 'gx', markersize=2, label='Best model saved')  # green dots for best model iterations
# Annotate the last value
plt.annotate(f'{loss_history['train'][-1]:.2e}',
             xy=(counter_indices[-1], loss_history['train'][-1]),
             xytext=(-20, 20),
             textcoords='offset points',
             color='red',
             fontsize=8,
             arrowprops=dict(arrowstyle='->', color='red', lw=0.5))

plt.annotate(f'{loss_history['valid'][best_model_iterations[-1]-1]:.2e}',
                xy=(best_model_iterations[-1], loss_history['valid'][best_model_iterations[-1]-1]),
                xytext=(-20, 20),
                textcoords='offset points',
                color='red',
                fontsize=8,
                arrowprops=dict(arrowstyle='->', color='red', lw=0.5))

plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title(f'Loss history (num_train: {num_train} | num_valid: {num_valid})')
plt.legend()
plt.savefig(os.path.join(model_train_outputs_path, f'loss_history_{num_train}.png'), dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
num_test = 500

test_p_dof = load_npy(test_dataset_path+'/p_dof.npy')[:num_test]
test_p_vertex_values = load_npy(test_dataset_path+'/p_vertex_values.npy')[:num_test]
test_sigma_u_dof = load_npy(test_dataset_path+'/sigma_u_dof.npy')[:num_test]
test_sigma_vertex_values = load_npy(test_dataset_path+'/sigma_vertex_values.npy')[:num_test]
test_u_vertex_values = load_npy(test_dataset_path+'/u_vertex_values.npy')[:num_test]
test_sigma_u_dof = torch.tensor(test_sigma_u_dof)

# %%
# test_k_vertex_values = np.zeros((num_test, num_vertices))
# test_image_k_vertex_values = np.zeros((num_test, mesh_args['num_y']+1, mesh_args['num_x']+1))
# for i in range(num_test):
#     k = dolfinx.fem.Function(Vh['CG1'])
#     k.x.array[:] = test_k_dof[i]
#     test_k_vertex_values[i][perm] = k.x.array[:][scifem.vertex_to_dofmap(Vh['CG1'])]
#     test_image_k_vertex_values[i] = test_k_vertex_values[i].reshape(num_x+1, num_y+1).T

# %%
test_image_p_vertex_values = np.zeros((num_test, mesh_args['num_y']+1, mesh_args['num_x']+1))
for i in tqdm(range(num_test)):
    test_image_p_vertex_values[i,:,:] = test_p_vertex_values[i].reshape(num_x+1, num_y+1).T
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 21545.05it/s]

# %%
test_reduced_p = einops.rearrange(test_image_p_vertex_values, 'b h w -> b (h w)') @ p_pod_basis

# %%
test_reduced_p_tensor = torch.tensor(test_reduced_p, dtype=torch_dtype['float32']).to(device)
test_batch_indices_iterator = BatchIndicesIterator(start=0, end=num_test, batch_size=20, shuffle=False)

# %%
# %%time
with torch.no_grad():
    model.eval()
    test_reduced_sigma_u_pred = []
    for batch_indices in test_batch_indices_iterator:
        batch_input = test_reduced_p_tensor[batch_indices]
        batch_input = (batch_input - input_scaler_statistics['mean']) / input_scaler_statistics['std']
        batch_output = model(batch_input)
        batch_output = (batch_output * output_scaler_statistics['std']) + output_scaler_statistics['mean']
        test_reduced_sigma_u_pred.append(batch_output)
    test_reduced_sigma_u_pred = torch.cat(test_reduced_sigma_u_pred, dim=0)

test_reduced_sigma_u_pred = test_reduced_sigma_u_pred.cpu().numpy().astype(np.float64)
# test_sigma_u_vertex_values_pred = einops.rearrange(test_reduced_sigma_u_pred @ sigma_u_pod_basis.T, 'b (c h w) -> b c h w', c=3, h=num_y+1, w=num_x+1)
# Out:
# CPU times: user 23.2 ms, sys: 12.8 ms, total: 36 ms
# Wall time: 33.7 ms

# %%
test_pred = test_reduced_sigma_u_pred @ pod_basis_dof.T

# %%
dolfinx_mesh_coords = mesh.geometry.x[:,:2]
num_x, num_y = mesh_args['num_x'], mesh_args['num_y']
x = np.linspace(0, mesh_args['upper_right_x'], num_x+1)
y = np.linspace(0, mesh_args['upper_right_y'], num_y+1)
image_mesh_coords = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
perm = [np.where((image_mesh_coords == row).all(axis=1))[0][0] for row in dolfinx_mesh_coords]

# %%
Vh_CG1_sigma1, Vh_CG1_sigma1_map = Vh['CG1_vector'].sub(0).collapse()
Vh_CG1_sigma2, Vh_CG1_sigma2_map = Vh['CG1_vector'].sub(1).collapse()

Vh_sigma, Vh_sigma_map = Vh['sigma_u'].sub(0).collapse()
Vh_u, Vh_u_map = Vh['sigma_u'].sub(1).collapse()

Vh_CG1_sigma, Vh_CG1_sigma_map = Vh['CG1_vector_scalar'].sub(0).collapse()
Vh_CG1_u, Vh_CG1_u_map = Vh['CG1_vector_scalar'].sub(1).collapse()

# %%
# from utils import project_Hdiv, project_H1

# %%
# test_CG1_sigma_fc_pred_list = []
# test_CG1_u_fc_pred_list = []
# num_dof = test_sigma_u_dof.shape[1]

# test_pred = np.zeros((num_test, num_dof))
# for i in tqdm(range(num_test)):
#     test_CG1_sigma1_fc_pred = dolfinx.fem.Function(Vh['CG1'])
#     test_CG1_sigma2_fc_pred = dolfinx.fem.Function(Vh['CG1'])
#     test_CG1_u_fc_pred = dolfinx.fem.Function(Vh['CG1'])

#     test_CG1_sigma_fc_pred = dolfinx.fem.Function(Vh['CG1_vector'])
#     test_CG1_sigma1_fc_pred.x.array[:] = test_sigma_u_vertex_values_pred[i, 0, :, :].reshape(-1, order='F')[scifem.dof_to_vertexmap(Vh['CG1'])][perm]
#     test_CG1_sigma2_fc_pred.x.array[:] = test_sigma_u_vertex_values_pred[i, 1, :, :].reshape(-1, order='F')[scifem.dof_to_vertexmap(Vh['CG1'])][perm]
#     test_CG1_u_fc_pred.x.array[:] = test_sigma_u_vertex_values_pred[i, 2, :, :].reshape(-1, order='F')[scifem.dof_to_vertexmap(Vh['CG1'])][perm]

#     test_CG1_sigma_fc_pred.x.array[Vh_CG1_sigma1_map] = test_CG1_sigma1_fc_pred.x.array[:]
#     test_CG1_sigma_fc_pred.x.array[Vh_CG1_sigma2_map] = test_CG1_sigma2_fc_pred.x.array[:]

#     # test_sigma_u_fc_pred = dolfinx.fem.Function(Vh['sigma_u'])

#     # test_sigma_fc_pred_reconstruct = dolfinx.fem.Function(Vh['sigma'])
#     # test_u_fc_pred_reconstruct = dolfinx.fem.Function(Vh['u'])

#     # project_Hdiv(test_sigma_fc_pred, test_sigma_fc_pred_reconstruct)
#     # project_H1(test_u_fc_pred, test_u_fc_pred_reconstruct)

#     # test_sigma_u_fc_pred.x.array[Vh_sigma_map] = test_sigma_fc_pred_reconstruct.x.array[:]
#     # test_sigma_u_fc_pred.x.array[Vh_u_map] = test_u_fc_pred_reconstruct.x.array[:]


#     test_CG1_sigma_u_fc_pred = dolfinx.fem.Function(Vh['CG1_vector_scalar'])
#     test_CG1_sigma_u_fc_pred.x.array[np.sort(Vh_CG1_sigma_map)] = test_CG1_sigma_fc_pred.x.array[:]
#     test_CG1_sigma_u_fc_pred.x.array[np.sort(Vh_CG1_u_map)] = test_CG1_u_fc_pred.x.array[:]

#     test_sigma_u_fc_pred = poisson_least_squares.project_Hdiv_H1(test_CG1_sigma_u_fc_pred)
#     test_pred[i] = test_sigma_u_fc_pred.x.array[:]

#     test_CG1_sigma_fc_pred_list.append(test_CG1_sigma_fc_pred)
#     test_CG1_u_fc_pred_list.append(test_CG1_u_fc_pred)

# %%
# test_CG1_sigma_fc_label_list = []
# test_CG1_u_fc_label_list = []
# for i in tqdm(range(num_test)):
#     test_CG1_u_fc_label = dolfinx.fem.Function(Vh['CG1'])
#     test_CG1_u_fc_label.x.array[:] = test_u_vertex_values[i, :, 0][perm]

#     test_CG1_sigma1_fc_label = dolfinx.fem.Function(Vh['CG1'])
#     test_CG1_sigma1_fc_label.x.array[:] = test_sigma_vertex_values[i, :, 0][perm]

#     test_CG1_sigma2_fc_label = dolfinx.fem.Function(Vh['CG1'])
#     test_CG1_sigma2_fc_label.x.array[:] = test_sigma_vertex_values[i, :, 1][perm]


#     test_CG1_sigma_fc_label = dolfinx.fem.Function(Vh['CG1_vector'])
#     test_CG1_sigma_fc_label.x.array[:] = np.stack([test_CG1_sigma1_fc_label.x.array, test_CG1_sigma2_fc_label.x.array], axis=1).reshape(-1)

#     test_CG1_sigma_fc_label_list.append(test_CG1_sigma_fc_label)
#     test_CG1_u_fc_label_list.append(test_CG1_u_fc_label)

# %%
compute_squared_L2_norm = poisson_least_squares.compute_squared_L2_norm
compute_squared_hdiv_h1_norm = poisson_least_squares.compute_squared_hdiv_h1_norm

# %%
sigma_u_norm_dict = {
    'squared_L2': np.zeros(num_test),
    'avg_squared_L2': 0.0,
    'cg1_squared_L2': np.zeros(num_test),
    'avg_cg1_squared_L2': 0.0,
    'squared_hdiv_h1': np.zeros(num_test),
    'avg_squared_hdiv_h1': 0.0,
    'cg1_squared_hdiv_h1': np.zeros(num_test),
    'avg_cg1_squared_hdiv_h1': 0.0
}

# %%
# CG1_l2_err_dict = {
#     'sigma': [],
#     'u': [],
#     'sigma_u': []
# }

# CG1_rel_l2_err_dict = {
#     'sigma': [],
#     'u': [],
#     'sigma_u': []
# }

# for i in range(num_test):
#     test_CG1_sigma_fc_pred = test_CG1_sigma_fc_pred_list[i]
#     test_CG1_u_fc_pred = test_CG1_u_fc_pred_list[i]
#     test_CG1_sigma_fc_label = test_CG1_sigma_fc_label_list[i]
#     test_CG1_u_fc_label = test_CG1_u_fc_label_list[i]

#     CG1_sigma_l2_err = compute_L2_norm(test_CG1_sigma_fc_label - test_CG1_sigma_fc_pred)
#     CG1_u_l2_err = compute_L2_norm(test_CG1_u_fc_label - test_CG1_u_fc_pred)
#     CG1_sigma_u_l2_err = np.sqrt(CG1_sigma_l2_err ** 2 + CG1_u_l2_err ** 2)

#     CG1_sigma_rel_l2_err = CG1_sigma_l2_err / compute_L2_norm(test_CG1_sigma_fc_label)
#     CG1_u_rel_l2_err = CG1_u_l2_err / compute_L2_norm(test_CG1_u_fc_label)
#     CG1_sigma_u_rel_l2_err = np.sqrt((CG1_sigma_l2_err ** 2 + CG1_u_l2_err ** 2) / (compute_L2_norm(test_CG1_u_fc_label) ** 2 + compute_L2_norm(test_CG1_sigma_fc_label) ** 2))

#     CG1_l2_err_dict['sigma'].append(CG1_sigma_l2_err)
#     CG1_l2_err_dict['u'].append(CG1_u_l2_err)
#     CG1_l2_err_dict['sigma_u'].append(CG1_sigma_u_l2_err)

#     CG1_rel_l2_err_dict['sigma'].append(CG1_sigma_rel_l2_err)
#     CG1_rel_l2_err_dict['u'].append(CG1_u_rel_l2_err)
#     CG1_rel_l2_err_dict['sigma_u'].append(CG1_sigma_u_rel_l2_err)

#     print(f'sample {i}:')
#     print(f'CG1 sigma rel l2 error: {CG1_sigma_rel_l2_err}')
#     print(f'CG1 u rel l2 error: {CG1_u_rel_l2_err}')
#     print(f'CG1 sigma u rel L2 error: {CG1_sigma_u_rel_l2_err}')
#     print("")

# CG1_l2_err_dict['sigma'] = np.array(CG1_l2_err_dict['sigma'])
# CG1_l2_err_dict['u'] = np.array(CG1_l2_err_dict['u'])
# CG1_l2_err_dict['sigma_u'] = np.array(CG1_l2_err_dict['sigma_u'])
# CG1_rel_l2_err_dict['sigma'] = np.array(CG1_rel_l2_err_dict['sigma'])
# CG1_rel_l2_err_dict['u'] = np.array(CG1_rel_l2_err_dict['u'])
# CG1_rel_l2_err_dict['sigma_u'] = np.array(CG1_rel_l2_err_dict['sigma_u'])

# print(f'avg CG1 sigma L2 error (std): {CG1_l2_err_dict["sigma"].mean():.2e} ({CG1_l2_err_dict["sigma"].std():.2e})')
# print(f'avg CG1 u L2 error (std): {CG1_l2_err_dict["u"].mean():.2e} ({CG1_l2_err_dict["u"].std():.2e})')
# print(f'avg CG1 sigma u L2 error (std): {CG1_l2_err_dict["sigma_u"].mean():.2e} ({CG1_l2_err_dict["sigma_u"].std():.2e})')
# print(f'avg CG1 sigma rel L2 error (std): {CG1_rel_l2_err_dict["sigma"].mean():.2e} ({CG1_rel_l2_err_dict["sigma"].std():.2e})')
# print(f'avg CG1 u rel L2 error (std): {CG1_rel_l2_err_dict["u"].mean():.2e} ({CG1_rel_l2_err_dict["u"].std():.2e})')
# print(f'avg CG1 sigma u rel L2 error (std): {CG1_rel_l2_err_dict["sigma_u"].mean():.2e} ({CG1_rel_l2_err_dict["sigma_u"].std():.2e})')

# %%
# for i in tqdm(range(num_test)):
#     test_CG1_sigma_fc_label = test_CG1_sigma_fc_label_list[i]
#     test_CG1_u_fc_label = test_CG1_u_fc_label_list[i] 
#     sigma_u_norm_dict['cg1_squared_L2'][i] = compute_squared_L2_norm(test_CG1_sigma_fc_label) + compute_squared_L2_norm(test_CG1_u_fc_label)
# sigma_u_norm_dict['avg_cg1_squared_L2'] = np.mean(sigma_u_norm_dict['cg1_squared_L2'])

# %%
for i in tqdm(range(num_test)):
    sigma_u_label_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_label_fc.x.array[:] = test_sigma_u_dof[i] 
    sigma_u_norm_dict['squared_L2'][i] = compute_squared_L2_norm(sigma_u_label_fc)
sigma_u_norm_dict['avg_squared_L2'] = np.mean(sigma_u_norm_dict['squared_L2'])
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 167.89it/s]

# %%
# for i in tqdm(range(num_test)):
#     test_CG1_sigma_fc_label = test_CG1_sigma_fc_label_list[i]
#     test_CG1_u_fc_label = test_CG1_u_fc_label_list[i]
#     sigma_u_norm_dict['cg1_squared_hdiv_h1'][i] = compute_squared_hdiv_h1_norm(test_CG1_sigma_fc_label, test_CG1_u_fc_label)
# sigma_u_norm_dict['avg_cg1_squared_hdiv_h1'] = np.mean(sigma_u_norm_dict['cg1_squared_hdiv_h1'])

# %%
for i in tqdm(range(num_test)):
    sigma_u_label_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_label_fc.x.array[:] = test_sigma_u_dof[i]
    sigma_label_fc = sigma_u_label_fc.sub(0).collapse()
    u_label_fc = sigma_u_label_fc.sub(1).collapse()
    sigma_u_norm_dict['squared_hdiv_h1'][i] = compute_squared_hdiv_h1_norm(sigma_label_fc, u_label_fc)
sigma_u_norm_dict['avg_squared_hdiv_h1'] = np.mean(sigma_u_norm_dict['squared_hdiv_h1'])
# Out:
# 100%|██████████| 500/500 [00:07<00:00, 69.11it/s]

# %%
print(f"Average squared L2 norm of sigma_u: {sigma_u_norm_dict['avg_squared_L2']:.2e}")
print(f"Average squared H(div)xH1 norm of sigma_u: {sigma_u_norm_dict['avg_squared_hdiv_h1']:.2e}")
print(f'Average CG1 squared L2 norm of sigma_u: {sigma_u_norm_dict["avg_cg1_squared_L2"]:.2e}')
print(f'Average CG1 squared H(div)xH1 norm of sigma_u: {sigma_u_norm_dict["avg_cg1_squared_hdiv_h1"]:.2e}')
# Out:
# Average squared L2 norm of sigma_u: 2.54e-01
# Average squared H(div)xH1 norm of sigma_u: 1.43e+00
# Average CG1 squared L2 norm of sigma_u: 0.00e+00
# Average CG1 squared H(div)xH1 norm of sigma_u: 0.00e+00

# %%
sigma_u_error_dict = {
    'squared_L2': np.zeros(num_test),
    'relative_squared_L2': np.zeros(num_test),
    'cg1_squared_L2': np.zeros(num_test),
    'relative_cg1_squared_L2': np.zeros(num_test),

    'squared_hdiv_h1': np.zeros(num_test),
    'relative_squared_hdiv_h1': np.zeros(num_test),
    'cg1_squared_hdiv_h1': np.zeros(num_test),
    'relative_cg1_squared_hdiv_h1': np.zeros(num_test)
}

# %%
# for i in tqdm(range(num_test)):
#     test_CG1_sigma_label_fc = test_CG1_sigma_fc_label_list[i]
#     test_CG1_u_label_fc = test_CG1_u_fc_label_list[i]

#     test_CG1_sigma_pred_fc = test_CG1_sigma_fc_pred_list[i]
#     test_CG1_u_pred_fc = test_CG1_u_fc_pred_list[i] 

#     sigma_u_error_dict['cg1_squared_L2'][i] = compute_squared_L2_norm(test_CG1_sigma_label_fc - test_CG1_sigma_pred_fc) + compute_squared_L2_norm(test_CG1_u_label_fc - test_CG1_u_pred_fc)
#     sigma_u_error_dict['relative_cg1_squared_L2'][i] = sigma_u_error_dict['cg1_squared_L2'][i] / sigma_u_norm_dict['avg_cg1_squared_L2']

#     sigma_u_error_dict['cg1_squared_hdiv_h1'][i] = compute_squared_hdiv_h1_norm(test_CG1_sigma_label_fc - test_CG1_sigma_pred_fc, test_CG1_u_label_fc - test_CG1_u_pred_fc)
#     sigma_u_error_dict['relative_cg1_squared_hdiv_h1'][i] = sigma_u_error_dict['cg1_squared_hdiv_h1'][i] / sigma_u_norm_dict['avg_cg1_squared_hdiv_h1']

# %%
for i in tqdm(range(num_test)):
    sigma_u_label_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_label_fc.x.array[:] = test_sigma_u_dof[i]
    sigma_label_fc = sigma_u_label_fc.sub(0).collapse()
    u_label_fc = sigma_u_label_fc.sub(1).collapse()

    sigma_u_pred_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_pred_fc.x.array[:] = test_pred[i]
    sigma_pred_fc = sigma_u_pred_fc.sub(0).collapse()
    u_pred_fc = sigma_u_pred_fc.sub(1).collapse()

    sigma_u_error_dict['squared_L2'][i] = compute_squared_L2_norm(sigma_u_label_fc - sigma_u_pred_fc)
    sigma_u_error_dict['relative_squared_L2'][i] = sigma_u_error_dict['squared_L2'][i] / sigma_u_norm_dict['avg_squared_L2']

    sigma_u_error_dict['squared_hdiv_h1'][i] = compute_squared_hdiv_h1_norm(sigma_label_fc - sigma_pred_fc, u_label_fc - u_pred_fc)
    sigma_u_error_dict['relative_squared_hdiv_h1'][i] = sigma_u_error_dict['squared_hdiv_h1'][i] / sigma_u_norm_dict['avg_squared_hdiv_h1']
# Out:
# 100%|██████████| 500/500 [00:18<00:00, 27.66it/s]

# %%
sigma_u_error_dict['bochner_L2'] = np.sqrt(np.mean(sigma_u_error_dict['squared_L2']))
sigma_u_error_dict['relative_bochner_L2'] = np.sqrt(np.mean(sigma_u_error_dict['relative_squared_L2']))
sigma_u_error_dict['bochner_hdiv_h1'] = np.sqrt(np.mean(sigma_u_error_dict['squared_hdiv_h1']))
sigma_u_error_dict['relative_bochner_hdiv_h1'] = np.sqrt(np.mean(sigma_u_error_dict['relative_squared_hdiv_h1']))

sigma_u_error_dict['std_L2'] = np.std(np.sqrt(sigma_u_error_dict['squared_L2']))
sigma_u_error_dict['std_relative_L2'] = np.std(np.sqrt(sigma_u_error_dict['relative_squared_L2']))
sigma_u_error_dict['std_hdiv_h1'] = np.std(np.sqrt(sigma_u_error_dict['squared_hdiv_h1']))
sigma_u_error_dict['std_relative_hdiv_h1'] = np.std(np.sqrt(sigma_u_error_dict['relative_squared_hdiv_h1']))

sigma_u_error_dict['cg1_bochner_L2'] = np.sqrt(np.mean(sigma_u_error_dict['cg1_squared_L2']))
sigma_u_error_dict['relative_cg1_bochner_L2'] = np.sqrt(np.mean(sigma_u_error_dict['relative_cg1_squared_L2']))
sigma_u_error_dict['std_cg1_L2'] = np.std(np.sqrt(sigma_u_error_dict['cg1_squared_L2']))
sigma_u_error_dict['std_relative_cg1_L2'] = np.std(np.sqrt(sigma_u_error_dict['relative_cg1_squared_L2']))

sigma_u_error_dict['cg1_bochner_hdiv_h1'] = np.sqrt(np.mean(sigma_u_error_dict['cg1_squared_hdiv_h1']))
sigma_u_error_dict['relative_cg1_bochner_hdiv_h1'] = np.sqrt(np.mean(sigma_u_error_dict['relative_cg1_squared_hdiv_h1']))
sigma_u_error_dict['std_cg1_hdiv_h1'] = np.std(np.sqrt(sigma_u_error_dict['cg1_squared_hdiv_h1']))
sigma_u_error_dict['std_relative_cg1_hdiv_h1'] = np.std(np.sqrt(sigma_u_error_dict['relative_cg1_squared_hdiv_h1']))

# %%
print(f'sigma_u relative Bochner L2 error (std): {sigma_u_error_dict["relative_bochner_L2"]:.2e} ({sigma_u_error_dict["std_relative_L2"]:.2e})')
print(f'sigma_u relative Bochner H(div) x H1 error (std): {sigma_u_error_dict["relative_bochner_hdiv_h1"]:.2e} ({sigma_u_error_dict["std_relative_hdiv_h1"]:.2e})')
print(f'sigma_u relative CG1 Bochner L2 error (std): {sigma_u_error_dict["relative_cg1_bochner_L2"]:.2e} ({sigma_u_error_dict["std_relative_cg1_L2"]:.2e})')
print(f'sigma_u relative CG1 Bochner H(div) x H1 error (std): {sigma_u_error_dict["relative_cg1_bochner_hdiv_h1"]:.2e} ({sigma_u_error_dict["std_relative_cg1_hdiv_h1"]:.2e})')
# Out:
# sigma_u relative Bochner L2 error (std): 1.23e-01 (2.52e-02)
# sigma_u relative Bochner H(div) x H1 error (std): 8.39e-02 (1.65e-02)
# sigma_u relative CG1 Bochner L2 error (std): 0.00e+00 (0.00e+00)
# sigma_u relative CG1 Bochner H(div) x H1 error (std): 0.00e+00 (0.00e+00)

# %%
np.save(os.path.join(model_test_outputs_path, "sigma_u_error_dict.npy"), sigma_u_error_dict)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
def plot_ref_pred_diff(x, y, ref_f_grid_evals, pred_f_grid_evals, diff_f_grid_evals, variable_name, 
                        levels=100, 
                        ref_pred_format='%.3f',
                        ref_pred_colorbar_pad=0.02, 
                        diff_colorbar_pad=0.01,
                        tick_labelsize=15,  # NEW: control tick font size
                        colorbar_labelsize=15):  # NEW: control colorbar tick font size

    vmin = min(ref_f_grid_evals.min(), pred_f_grid_evals.min())
    vmax = max(ref_f_grid_evals.max(), pred_f_grid_evals.max())

    fig, axs = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

    # Reference
    cf0 = axs[0].tricontourf(x, y, ref_f_grid_evals, levels=levels, cmap='turbo', vmin=vmin, vmax=vmax)
    axs[0].set_title(fr'Reference {variable_name}', fontsize=18)
    axs[0].tick_params(axis='both', which='major', labelsize=tick_labelsize)
    axs[0].set_xticklabels([])
    axs[0].set_yticklabels([])


    # Prediction
    cf1 = axs[1].tricontourf(x, y, pred_f_grid_evals, levels=levels, cmap='turbo', vmin=vmin, vmax=vmax)
    axs[1].set_title(fr'Prediction {variable_name}', fontsize=18)
    axs[1].tick_params(axis='both', which='major', labelsize=tick_labelsize)
    axs[1].set_xticklabels([])
    axs[1].set_yticklabels([])

    # Shared colorbar for first two subplots
    cbar_shared = fig.colorbar(cf1, ax=[axs[0], axs[1]], format=ref_pred_format, pad=ref_pred_colorbar_pad)
    cbar_shared.ax.tick_params(labelsize=colorbar_labelsize)  # Increase colorbar ticks
    cbar_shared.locator = ticker.MaxNLocator(nbins=5)
    cbar_shared.update_ticks()

    # Difference plot (independent colorbar)
    cf2 = axs[2].tricontourf(x, y, diff_f_grid_evals, levels=levels, cmap='turbo')
    axs[2].set_title(fr'Difference {variable_name}', fontsize=18)
    axs[2].tick_params(axis='both', which='major', labelsize=tick_labelsize)
    axs[2].set_xticklabels([])
    axs[2].set_yticklabels([])

    cbar_diff = fig.colorbar(cf2, ax=axs[2], pad=diff_colorbar_pad)
    cbar_diff.ax.tick_params(labelsize=colorbar_labelsize)  # Increase colorbar ticks
    cbar_diff.formatter = ticker.ScalarFormatter(useMathText=True)
    cbar_diff.formatter.set_scientific(True)
    cbar_diff.formatter.set_powerlimits((-2, 2))
    cbar_diff.locator = ticker.MaxNLocator(nbins=5)
    cbar_diff.update_ticks()

    cbar_diff.ax.yaxis.get_offset_text().set_fontsize(colorbar_labelsize)

    # Remove ticks on x and y axes if needed
    for ax in axs:
        ax.tick_params(left=False, bottom=False)

    return fig

# %%
for i in range(3):
    # plt.figure(figsize=(6, 5))  # Optional: larger figure size
    img = plt.imshow(test_image_p_vertex_values[i,:,:],
                     extent=[0, 1, 0, 1], origin='lower', cmap='turbo')

    cbar = plt.colorbar()
    cbar.ax.tick_params(labelsize=16)  # Increase colorbar tick labels

    plt.title('parameter (setup 1)', fontsize=20)
    # plt.xticks(fontsize=16)
    # plt.yticks(fontsize=16)

    plt.savefig(os.path.join(model_test_outputs_path, f'test_p_{i}.png'),
                dpi=300, bbox_inches='tight')
    plt.close()

# %%
for test_sample_index in range(3):
    pred_sigma_u_fc = dolfinx.fem.Function(Vh['sigma_u'])
    pred_sigma_u_fc.x.array[:] = test_pred[test_sample_index]
    pred_sigma_fc = pred_sigma_u_fc.sub(0).collapse()
    pred_u_fc = pred_sigma_u_fc.sub(1).collapse()

    ref_sigma_u_fc = dolfinx.fem.Function(Vh['sigma_u'])
    ref_sigma_u_fc.x.array[:] = test_sigma_u_dof[test_sample_index]
    ref_sigma_fc = ref_sigma_u_fc.sub(0).collapse()
    ref_u_fc = ref_sigma_u_fc.sub(1).collapse()


    pred_sigma_grid_evals = evaluate_expression(mesh, pred_sigma_fc, mesh.geometry.x)[1]
    pred_u_grid_evals = evaluate_expression(mesh, pred_u_fc, mesh.geometry.x)[1]


    ref_sigma_grid_evals = evaluate_expression(mesh, ref_sigma_fc, mesh.geometry.x)[1]
    ref_u_grid_evals = evaluate_expression(mesh, ref_u_fc, mesh.geometry.x)[1]


    diff_sigma_grid_evals = pred_sigma_grid_evals - ref_sigma_grid_evals
    diff_u_grid_evals = pred_u_grid_evals - ref_u_grid_evals

    x = mesh.geometry.x[:, 0]
    y = mesh.geometry.x[:, 1]


    fig = plot_ref_pred_diff(x, y, ref_u_grid_evals[:,0], pred_u_grid_evals[:,0], diff_u_grid_evals[:,0], r'$u^{\circ}$',
                            levels=100,
                            ref_pred_format='%.3f',
                            ref_pred_colorbar_pad=0.01,
                            diff_colorbar_pad=-0.01)
    fig.savefig(os.path.join(model_test_outputs_path, f'u_ref_pred_diff_{test_sample_index}.png'), dpi=300, bbox_inches='tight')


    fig = plot_ref_pred_diff(x, y, ref_sigma_grid_evals[:,0], pred_sigma_grid_evals[:, 0], diff_sigma_grid_evals[:, 0], r'$\sigma_1^{\circ}$', 
                            levels=100,
                            ref_pred_format='%.1f',
                            ref_pred_colorbar_pad=0.01, 
                            diff_colorbar_pad=-0.01)
    fig.savefig(os.path.join(model_test_outputs_path, f'sigma_1_ref_pred_diff_{test_sample_index}.png'), dpi=300, bbox_inches='tight')


    fig = plot_ref_pred_diff(x, y, ref_sigma_grid_evals[:,1], pred_sigma_grid_evals[:, 1], diff_sigma_grid_evals[:, 1], r'$\sigma_2^{\circ}$', 
                            levels=100,
                            ref_pred_format='%.1f',
                            ref_pred_colorbar_pad=0.01, 
                            diff_colorbar_pad=-0.01)
    fig.savefig(os.path.join(model_test_outputs_path, f'sigma_2_ref_pred_diff_{test_sample_index}.png'), dpi=300, bbox_inches='tight')

# %%
compute_physical_loss_1 = poisson_least_squares.compute_physical_loss_1
compute_physical_loss_2 = poisson_least_squares.compute_physical_loss_2

# %%
residual_loss_dict = {
    'loss_1': np.zeros(num_test),
    'loss_2': np.zeros(num_test),
    'total_loss': np.zeros(num_test),
    'sqrt_total_loss': np.zeros(num_test)
}
for test_index in range(num_test): 
    pred_fc = dolfinx.fem.Function(Vh['sigma_u'])
    pred_fc.x.array[:] = test_pred[test_index]
    pred_sigma_fc = pred_fc.sub(0).collapse()
    pred_u_fc = pred_fc.sub(1).collapse()

    p_fc = dolfinx.fem.Function(Vh['p'])
    p_fc.x.array[:] = test_p_dof[test_index]

    residual_loss_1 = compute_physical_loss_1(pred_sigma_fc, pred_u_fc, p_fc)
    residual_loss_2 = compute_physical_loss_2(pred_sigma_fc, pred_u_fc, p_fc)

    residual_loss = residual_loss_1 + residual_loss_2

    sqrt_residual_loss = np.sqrt(residual_loss)

    residual_loss_dict['loss_1'][test_index] = residual_loss_1
    residual_loss_dict['loss_2'][test_index] = residual_loss_2
    residual_loss_dict['total_loss'][test_index] = residual_loss
    residual_loss_dict['sqrt_total_loss'][test_index] = sqrt_residual_loss
    print(f'Test sample {test_index}:')
    print(f'Residual loss 1: {residual_loss_1} | Residual loss 2: {residual_loss_2}')
    print(f'Total residual loss: {residual_loss} | Sqrt residual loss: {sqrt_residual_loss}')

    print("")
# Out:
# Test sample 0:
# Residual loss 1: 0.022370693127679978 | Residual loss 2: 4.846902349841295e-05
# Total residual loss: 0.022419162151178392 | Sqrt residual loss: 0.14973029804010407
#
# Test sample 1:
# Residual loss 1: 0.11297989801787368 | Residual loss 2: 7.379091547620845e-05
# Total residual loss: 0.1130536889333499 | Sqrt residual loss: 0.3362345742682479
#
# Test sample 2:
# Residual loss 1: 0.010672406055624153 | Residual loss 2: 9.424906254168162e-06
# Total residual loss: 0.010681830961878322 | Sqrt residual loss: 0.10335294365366823
#
# Test sample 3:
# Residual loss 1: 0.012854936453633321 | Residual loss 2: 3.092379011593025e-05
# Total residual loss: 0.01288586024374925 | Sqrt residual loss: 0.11351590304335886
#
# Test sample 4:
# Residual loss 1: 0.034700141620549144 | Residual loss 2: 5.8272250169765045e-05
# Total residual loss: 0.03475841387071891 | Sqrt residual loss: 0.18643608521613755
#
# Test sample 5:
# Residual loss 1: 0.04940460684940247 | Residual loss 2: 6.324812314582196e-05
# Total residual loss: 0.04946785497254829 | Sqrt residual loss: 0.22241370230394594
#
# Test sample 6:
# Residual loss 1: 0.007568651300314075 | Residual loss 2: 7.634867204039852e-06
# Total residual loss: 0.007576286167518115 | Sqrt residual loss: 0.08704186445336586
#
# Test sample 7:
# Residual loss 1: 0.013814892244244146 | Residual loss 2: 2.06849351585365e-05
# Total residual loss: 0.013835577179402682 | Sqrt residual loss: 0.11762473030533452
#
# Test sample 8:
# Residual loss 1: 0.06750571216212778 | Residual loss 2: 1.1861588739241293e-05
# Total residual loss: 0.06751757375086702 | Sqrt residual loss: 0.25984143963361006
#
# Test sample 9:
# Residual loss 1: 0.1045947685145675 | Residual loss 2: 4.827128256722775e-05
# Total residual loss: 0.10464303979713473 | Sqrt residual loss: 0.3234857644427877
#
# Test sample 10:
# Residual loss 1: 0.015498314781635146 | Residual loss 2: 2.8996110560196152e-05
# Total residual loss: 0.015527310892195343 | Sqrt residual loss: 0.12460863088965926
#
# Test sample 11:
# Residual loss 1: 0.018530563810789377 | Residual loss 2: 8.956030587969157e-05
# Total residual loss: 0.01862012411666907 | Sqrt residual loss: 0.13645557561590904
#
# Test sample 12:
# Residual loss 1: 0.009274957586104662 | Residual loss 2: 1.1026468723117977e-07
# Total residual loss: 0.009275067850791893 | Sqrt residual loss: 0.09630715368440651
#
# Test sample 13:
# Residual loss 1: 0.016807236292123873 | Residual loss 2: 1.0267086069474417e-05
# Total residual loss: 0.01681750337819335 | Sqrt residual loss: 0.1296823171376628
#
# Test sample 14:
# Residual loss 1: 0.07642018797572994 | Residual loss 2: 1.0961652862730283e-05
# Total residual loss: 0.07643114962859267 | Sqrt residual loss: 0.27646184117992245
#
# Test sample 15:
# Residual loss 1: 0.027608500486305292 | Residual loss 2: 5.663670554207495e-05
# Total residual loss: 0.027665137191847367 | Sqrt residual loss: 0.166328401639189
#
# Test sample 16:
# Residual loss 1: 0.0670141244394275 | Residual loss 2: 3.6077677298986335e-06
# Total residual loss: 0.0670177322071574 | Sqrt residual loss: 0.2588778325912773
#
# Test sample 17:
# Residual loss 1: 0.011708331951238292 | Residual loss 2: 6.407901465196096e-06
# Total residual loss: 0.011714739852703488 | Sqrt residual loss: 0.10823465181125445
#
# Test sample 18:
# Residual loss 1: 0.016149639925568296 | Residual loss 2: 3.1232724041427306e-05
# Total residual loss: 0.016180872649609723 | Sqrt residual loss: 0.12720405909250587
#
# Test sample 19:
# Residual loss 1: 0.018753379888215196 | Residual loss 2: 1.0356580912159144e-06
# Total residual loss: 0.018754415546306413 | Sqrt residual loss: 0.1369467617225994
#
# Test sample 20:
# Residual loss 1: 0.0082030278295573 | Residual loss 2: 2.875936850916819e-06
# Total residual loss: 0.008205903766408217 | Sqrt residual loss: 0.0905864436127626
#
# Test sample 21:
# Residual loss 1: 0.03071498821831511 | Residual loss 2: 6.281796013375977e-05
# Total residual loss: 0.03077780617844887 | Sqrt residual loss: 0.17543604583565167
#
# Test sample 22:
# Residual loss 1: 0.009990766897705441 | Residual loss 2: 2.7560667509806876e-05
# Total residual loss: 0.010018327565215248 | Sqrt residual loss: 0.10009159587705278
#
# Test sample 23:
# Residual loss 1: 0.009979260980810473 | Residual loss 2: 0.00011008856392854827
# Total residual loss: 0.01008934954473902 | Sqrt residual loss: 0.10044575423948501
#
# Test sample 24:
# Residual loss 1: 0.041112636964688615 | Residual loss 2: 1.4423133062853715e-05
# Total residual loss: 0.04112706009775147 | Sqrt residual loss: 0.2027980771549658
#
# Test sample 25:
# Residual loss 1: 0.021824579169413855 | Residual loss 2: 4.993163993758149e-05
# Total residual loss: 0.021874510809351436 | Sqrt residual loss: 0.14790034080201248
#
# Test sample 26:
# Residual loss 1: 0.012176092432845018 | Residual loss 2: 1.9903773371263323e-06
# Total residual loss: 0.012178082810182145 | Sqrt residual loss: 0.11035435111576772
#
# Test sample 27:
# Residual loss 1: 0.017380493340044916 | Residual loss 2: 1.6138227223355905e-05
# Total residual loss: 0.017396631567268273 | Sqrt residual loss: 0.1318962909534164
#
# Test sample 28:
# Residual loss 1: 0.010231764573460686 | Residual loss 2: 1.9894497106985503e-06
# Total residual loss: 0.010233754023171384 | Sqrt residual loss: 0.10116201867880743
#
# Test sample 29:
# Residual loss 1: 0.028198248028789737 | Residual loss 2: 1.1851743629604183e-06
# Total residual loss: 0.028199433203152695 | Sqrt residual loss: 0.16792686861593262
#
# Test sample 30:
# Residual loss 1: 0.03224665158098988 | Residual loss 2: 1.1659696807023353e-05
# Total residual loss: 0.03225831127779691 | Sqrt residual loss: 0.17960598898087143
#
# Test sample 31:
# Residual loss 1: 0.03050836355144822 | Residual loss 2: 1.4491308872280936e-06
# Total residual loss: 0.03050981268233545 | Sqrt residual loss: 0.17467058333427368
#
# Test sample 32:
# Residual loss 1: 0.023138934929511516 | Residual loss 2: 2.6406685181207813e-05
# Total residual loss: 0.023165341614692723 | Sqrt residual loss: 0.15220164787114732
#
# Test sample 33:
# Residual loss 1: 0.08685800678032515 | Residual loss 2: 7.764128836275592e-06
# Total residual loss: 0.08686577090916144 | Sqrt residual loss: 0.2947299966226061
#
# Test sample 34:
# Residual loss 1: 0.03535002869422823 | Residual loss 2: 2.3594604813716702e-05
# Total residual loss: 0.035373623299041944 | Sqrt residual loss: 0.18807876886837052
#
# Test sample 35:
# Residual loss 1: 0.008907816804504946 | Residual loss 2: 1.1758844820040587e-07
# Total residual loss: 0.008907934392953147 | Sqrt residual loss: 0.09438185415085437
#
# Test sample 36:
# Residual loss 1: 0.07988174192037664 | Residual loss 2: 2.501330213762615e-05
# Total residual loss: 0.07990675522251427 | Sqrt residual loss: 0.28267782937916136
#
# Test sample 37:
# Residual loss 1: 0.03274801112212557 | Residual loss 2: 1.6074600462440145e-06
# Total residual loss: 0.03274961858217181 | Sqrt residual loss: 0.18096855688812852
#
# Test sample 38:
# Residual loss 1: 0.09172977386663335 | Residual loss 2: 1.8088171880892284e-05
# Total residual loss: 0.09174786203851425 | Sqrt residual loss: 0.302899095473252
#
# Test sample 39:
# Residual loss 1: 0.02057315841536294 | Residual loss 2: 1.3360306973322625e-05
# Total residual loss: 0.020586518722336262 | Sqrt residual loss: 0.14348002900172643
#
# Test sample 40:
# Residual loss 1: 0.05788461247388408 | Residual loss 2: 1.483309417878151e-05
# Total residual loss: 0.05789944556806286 | Sqrt residual loss: 0.2406230362373122
#
# Test sample 41:
# Residual loss 1: 0.026074752343991675 | Residual loss 2: 4.647379055041665e-06
# Total residual loss: 0.026079399723046716 | Sqrt residual loss: 0.16149117537205157
#
# Test sample 42:
# Residual loss 1: 0.03786029438981982 | Residual loss 2: 1.048803377600155e-06
# Total residual loss: 0.037861343193197415 | Sqrt residual loss: 0.19457991467054717
#
# Test sample 43:
# Residual loss 1: 0.03901136894399703 | Residual loss 2: 4.4186835447297605e-10
# Total residual loss: 0.039011369385865385 | Sqrt residual loss: 0.19751296004532307
#
# Test sample 44:
# Residual loss 1: 0.02082621525667827 | Residual loss 2: 2.375470694644029e-05
# Total residual loss: 0.02084996996362471 | Sqrt residual loss: 0.14439518677443758
#
# Test sample 45:
# Residual loss 1: 0.027751622135197645 | Residual loss 2: 1.2902813551395156e-07
# Total residual loss: 0.027751751163333158 | Sqrt residual loss: 0.1665885685253738
#
# Test sample 46:
# Residual loss 1: 0.0074293323655516726 | Residual loss 2: 2.5242799098172117e-05
# Total residual loss: 0.007454575164649845 | Sqrt residual loss: 0.08633988165760852
#
# Test sample 47:
# Residual loss 1: 0.05789026810707522 | Residual loss 2: 1.183449094532709e-05
# Total residual loss: 0.05790210259802055 | Sqrt residual loss: 0.24062855732024108
#
# Test sample 48:
# Residual loss 1: 0.026798203358752326 | Residual loss 2: 2.0973311121608942e-05
# Total residual loss: 0.026819176669873934 | Sqrt residual loss: 0.163765615041357
#
# Test sample 49:
# Residual loss 1: 0.022136915318036427 | Residual loss 2: 1.5868426586628947e-05
# Total residual loss: 0.022152783744623056 | Sqrt residual loss: 0.14883811254051516
#
# Test sample 50:
# Residual loss 1: 0.005758133326620428 | Residual loss 2: 1.7819977940308936e-05
# Total residual loss: 0.005775953304560737 | Sqrt residual loss: 0.07599969279254185
#
# Test sample 51:
# Residual loss 1: 0.0222854855353907 | Residual loss 2: 6.277465117484351e-06
# Total residual loss: 0.022291763000508186 | Sqrt residual loss: 0.149304263169235
#
# Test sample 52:
# Residual loss 1: 0.07087522735812896 | Residual loss 2: 2.018711131024331e-05
# Total residual loss: 0.0708954144694392 | Sqrt residual loss: 0.2662619283139052
#
# Test sample 53:
# Residual loss 1: 0.016457468477102288 | Residual loss 2: 4.495529924682495e-06
# Total residual loss: 0.016461964007026972 | Sqrt residual loss: 0.12830418546184288
#
# Test sample 54:
# Residual loss 1: 0.03336856471423383 | Residual loss 2: 1.993354111315506e-07
# Total residual loss: 0.03336876404964496 | Sqrt residual loss: 0.18267119107742458
#
# Test sample 55:
# Residual loss 1: 0.020240638756494008 | Residual loss 2: 1.8558365378343376e-05
# Total residual loss: 0.020259197121872352 | Sqrt residual loss: 0.14233480643142896
#
# Test sample 56:
# Residual loss 1: 0.020260059751328663 | Residual loss 2: 2.00470933738014e-09
# Total residual loss: 0.020260061756038 | Sqrt residual loss: 0.14233784372414104
#
# Test sample 57:
# Residual loss 1: 0.015639496397130193 | Residual loss 2: 4.382385756989827e-08
# Total residual loss: 0.015639540220987763 | Sqrt residual loss: 0.1250581473594894
#
# Test sample 58:
# Residual loss 1: 0.032659511389718426 | Residual loss 2: 2.6450552234937984e-05
# Total residual loss: 0.03268596194195336 | Sqrt residual loss: 0.18079259371432604
#
# Test sample 59:
# Residual loss 1: 0.043703292636513465 | Residual loss 2: 2.111206791279898e-07
# Total residual loss: 0.04370350375719259 | Sqrt residual loss: 0.20905382980752252
#
# Test sample 60:
# Residual loss 1: 0.04323609829362588 | Residual loss 2: 6.853643898822214e-05
# Total residual loss: 0.0433046347326141 | Sqrt residual loss: 0.20809765672062264
#
# Test sample 61:
# Residual loss 1: 0.1053728886659102 | Residual loss 2: 2.1418460117545112e-05
# Total residual loss: 0.10539430712602775 | Sqrt residual loss: 0.3246448938856543
#
# Test sample 62:
# Residual loss 1: 0.013609570343804575 | Residual loss 2: 5.99087501078621e-06
# Total residual loss: 0.013615561218815362 | Sqrt residual loss: 0.1166857369982097
#
# Test sample 63:
# Residual loss 1: 0.011407664976397964 | Residual loss 2: 6.066789067773751e-06
# Total residual loss: 0.011413731765465738 | Sqrt residual loss: 0.10683506805101842
#
# Test sample 64:
# Residual loss 1: 0.009284993269359252 | Residual loss 2: 6.094317037583497e-06
# Total residual loss: 0.009291087586396836 | Sqrt residual loss: 0.09639028782194208
#
# Test sample 65:
# Residual loss 1: 0.0068475692666577865 | Residual loss 2: 2.544330578543082e-05
# Total residual loss: 0.006873012572443217 | Sqrt residual loss: 0.08290363425353087
#
# Test sample 66:
# Residual loss 1: 0.013064251725589431 | Residual loss 2: 5.04287761241272e-06
# Total residual loss: 0.013069294603201845 | Sqrt residual loss: 0.11432101557982174
#
# Test sample 67:
# Residual loss 1: 0.01836004000450758 | Residual loss 2: 9.042113759367961e-05
# Total residual loss: 0.01845046114210126 | Sqrt residual loss: 0.13583247454898723
#
# Test sample 68:
# Residual loss 1: 0.012932342154977265 | Residual loss 2: 0.00012529602923084303
# Total residual loss: 0.013057638184208109 | Sqrt residual loss: 0.11427002312158735
#
# Test sample 69:
# Residual loss 1: 0.060842119807508255 | Residual loss 2: 4.807807171324725e-05
# Total residual loss: 0.0608901978792215 | Sqrt residual loss: 0.24675939268692793
#
# Test sample 70:
# Residual loss 1: 0.026140192670209804 | Residual loss 2: 1.1786565630540375e-07
# Total residual loss: 0.02614031053586611 | Sqrt residual loss: 0.16167965405661316
#
# Test sample 71:
# Residual loss 1: 0.012383164268016967 | Residual loss 2: 2.0863836384347404e-05
# Total residual loss: 0.012404028104401313 | Sqrt residual loss: 0.11137337251067381
#
# Test sample 72:
# Residual loss 1: 0.022240237692410594 | Residual loss 2: 2.0108514168575873e-07
# Total residual loss: 0.02224043877755228 | Sqrt residual loss: 0.14913228616752403
#
# Test sample 73:
# Residual loss 1: 0.01763280042243837 | Residual loss 2: 4.793704712733522e-07
# Total residual loss: 0.017633279792909642 | Sqrt residual loss: 0.13279036031621289
#
# Test sample 74:
# Residual loss 1: 0.031377258240403764 | Residual loss 2: 2.8314226714757926e-09
# Total residual loss: 0.03137726107182644 | Sqrt residual loss: 0.17713627824877218
#
# Test sample 75:
# Residual loss 1: 0.029602198287538756 | Residual loss 2: 9.65189520414033e-06
# Total residual loss: 0.029611850182742896 | Sqrt residual loss: 0.1720809407887547
#
# Test sample 76:
# Residual loss 1: 0.009988898352033952 | Residual loss 2: 2.4707252307684136e-06
# Total residual loss: 0.00999136907726472 | Sqrt residual loss: 0.09995683607069963
#
# Test sample 77:
# Residual loss 1: 0.033896650235214064 | Residual loss 2: 3.149279387569361e-06
# Total residual loss: 0.03389979951460163 | Sqrt residual loss: 0.18411898195080711
#
# Test sample 78:
# Residual loss 1: 0.014761756607930682 | Residual loss 2: 2.1054884048827973e-05
# Total residual loss: 0.01478281149197951 | Sqrt residual loss: 0.12158458574991943
#
# Test sample 79:
# Residual loss 1: 0.025522814535859927 | Residual loss 2: 4.041988611289939e-06
# Total residual loss: 0.025526856524471217 | Sqrt residual loss: 0.15977126313724635
#
# Test sample 80:
# Residual loss 1: 0.017427918566960132 | Residual loss 2: 3.0725487703342493e-06
# Total residual loss: 0.017430991115730467 | Sqrt residual loss: 0.13202647884318686
#
# Test sample 81:
# Residual loss 1: 0.01567173742753105 | Residual loss 2: 0.00011143908648077555
# Total residual loss: 0.015783176514011826 | Sqrt residual loss: 0.12563111284236808
#
# Test sample 82:
# Residual loss 1: 0.020620995843552474 | Residual loss 2: 2.1735935855324673e-07
# Total residual loss: 0.020621213202911028 | Sqrt residual loss: 0.14360088162302845
#
# Test sample 83:
# Residual loss 1: 0.015938876887122158 | Residual loss 2: 1.6504453247792684e-05
# Total residual loss: 0.015955381340369952 | Sqrt residual loss: 0.12631461253699017
#
# Test sample 84:
# Residual loss 1: 0.0050308776061116535 | Residual loss 2: 1.536684559976105e-06
# Total residual loss: 0.00503241429067163 | Sqrt residual loss: 0.0709395114916337
#
# Test sample 85:
# Residual loss 1: 0.038710480705071104 | Residual loss 2: 3.975705309880793e-06
# Total residual loss: 0.03871445641038099 | Sqrt residual loss: 0.19675989533027555
#
# Test sample 86:
# Residual loss 1: 0.01732061868839022 | Residual loss 2: 2.3635184348989297e-05
# Total residual loss: 0.017344253872739208 | Sqrt residual loss: 0.13169758491612216
#
# Test sample 87:
# Residual loss 1: 0.09498493295094892 | Residual loss 2: 3.4060023276443727e-09
# Total residual loss: 0.09498493635695125 | Sqrt residual loss: 0.3081962627238547
#
# Test sample 88:
# Residual loss 1: 0.03795002087128228 | Residual loss 2: 1.0750447275421836e-05
# Total residual loss: 0.037960771318557705 | Sqrt residual loss: 0.1948352414697036
#
# Test sample 89:
# Residual loss 1: 0.007333466160204473 | Residual loss 2: 2.8632965951218304e-05
# Total residual loss: 0.007362099126155691 | Sqrt residual loss: 0.08580267551863223
#
# Test sample 90:
# Residual loss 1: 0.020863037638843354 | Residual loss 2: 2.5525297554042924e-06
# Total residual loss: 0.02086559016859876 | Sqrt residual loss: 0.14444926503308614
#
# Test sample 91:
# Residual loss 1: 0.010242095859884448 | Residual loss 2: 4.596862779425811e-06
# Total residual loss: 0.010246692722663873 | Sqrt residual loss: 0.10122594886027926
#
# Test sample 92:
# Residual loss 1: 0.01221256256926677 | Residual loss 2: 6.9064958402169955e-06
# Total residual loss: 0.012219469065106988 | Sqrt residual loss: 0.11054170735567181
#
# Test sample 93:
# Residual loss 1: 0.011811355654874194 | Residual loss 2: 1.7424056900789753e-08
# Total residual loss: 0.011811373078931094 | Sqrt residual loss: 0.10868014114331603
#
# Test sample 94:
# Residual loss 1: 0.00963726103443586 | Residual loss 2: 2.763503790891705e-07
# Total residual loss: 0.009637537384814949 | Sqrt residual loss: 0.09817095998723324
#
# Test sample 95:
# Residual loss 1: 0.033251136131235086 | Residual loss 2: 4.178170002795275e-06
# Total residual loss: 0.03325531430123788 | Sqrt residual loss: 0.1823603967456692
#
# Test sample 96:
# Residual loss 1: 0.029376688158704378 | Residual loss 2: 3.198639016700693e-06
# Total residual loss: 0.029379886797721078 | Sqrt residual loss: 0.17140562067132184
#
# Test sample 97:
# Residual loss 1: 0.017536063337428385 | Residual loss 2: 7.426823097763844e-07
# Total residual loss: 0.01753680601973816 | Sqrt residual loss: 0.13242660616257657
#
# Test sample 98:
# Residual loss 1: 0.021373237338450302 | Residual loss 2: 3.315739260647447e-07
# Total residual loss: 0.021373568912376368 | Sqrt residual loss: 0.14619702087380704
#
# Test sample 99:
# Residual loss 1: 0.0492711707500318 | Residual loss 2: 1.9451252139069166e-05
# Total residual loss: 0.04929062200217087 | Sqrt residual loss: 0.22201491391834663
#
# Test sample 100:
# Residual loss 1: 0.011441309156604074 | Residual loss 2: 1.0595180723550938e-05
# Total residual loss: 0.011451904337327625 | Sqrt residual loss: 0.10701357080916245
#
# Test sample 101:
# Residual loss 1: 0.010052750223742603 | Residual loss 2: 2.7404046368180716e-05
# Total residual loss: 0.010080154270110784 | Sqrt residual loss: 0.10039997146469108
#
# Test sample 102:
# Residual loss 1: 0.05434083978463688 | Residual loss 2: 1.068918434363154e-05
# Total residual loss: 0.05435152896898051 | Sqrt residual loss: 0.23313414372197933
#
# Test sample 103:
# Residual loss 1: 0.018369401876226116 | Residual loss 2: 4.670351599567208e-05
# Total residual loss: 0.01841610539222179 | Sqrt residual loss: 0.13570595194103238
#
# Test sample 104:
# Residual loss 1: 0.023071917014370693 | Residual loss 2: 2.6018798686902802e-05
# Total residual loss: 0.023097935813057597 | Sqrt residual loss: 0.15198005070751094
#
# Test sample 105:
# Residual loss 1: 0.03703546307111984 | Residual loss 2: 2.482151177993036e-05
# Total residual loss: 0.03706028458289977 | Sqrt residual loss: 0.19251047915087577
#
# Test sample 106:
# Residual loss 1: 0.036460490498782486 | Residual loss 2: 2.9102984333321335e-06
# Total residual loss: 0.03646340079721582 | Sqrt residual loss: 0.19095392323075172
#
# Test sample 107:
# Residual loss 1: 0.026449367469415057 | Residual loss 2: 4.15995710275782e-06
# Total residual loss: 0.026453527426517815 | Sqrt residual loss: 0.16264540395141147
#
# Test sample 108:
# Residual loss 1: 0.008976575240268186 | Residual loss 2: 2.2605113782217715e-05
# Total residual loss: 0.008999180354050404 | Sqrt residual loss: 0.09486400979323194
#
# Test sample 109:
# Residual loss 1: 0.07033863957205648 | Residual loss 2: 1.9271345831798803e-07
# Total residual loss: 0.0703388322855148 | Sqrt residual loss: 0.26521469093079064
#
# Test sample 110:
# Residual loss 1: 0.01902036671380517 | Residual loss 2: 5.066512484594217e-05
# Total residual loss: 0.019071031838651113 | Sqrt residual loss: 0.13809790671350206
#
# Test sample 111:
# Residual loss 1: 0.01827459416697177 | Residual loss 2: 6.08921585627623e-06
# Total residual loss: 0.018280683382828046 | Sqrt residual loss: 0.13520607746262017
#
# Test sample 112:
# Residual loss 1: 0.00786083582811737 | Residual loss 2: 6.135715390292926e-06
# Total residual loss: 0.007866971543507663 | Sqrt residual loss: 0.08869594998368112
#
# Test sample 113:
# Residual loss 1: 0.010102457221057692 | Residual loss 2: 1.593010589435618e-06
# Total residual loss: 0.010104050231647127 | Sqrt residual loss: 0.10051890484703425
#
# Test sample 114:
# Residual loss 1: 0.05954430088679451 | Residual loss 2: 1.0905360091995525e-07
# Total residual loss: 0.05954440994039543 | Sqrt residual loss: 0.24401723287586766
#
# Test sample 115:
# Residual loss 1: 0.0550076296064158 | Residual loss 2: 4.920004008451701e-07
# Total residual loss: 0.055008121606816646 | Sqrt residual loss: 0.23453810267591202
#
# Test sample 116:
# Residual loss 1: 0.04965991825000556 | Residual loss 2: 2.5412064991495787e-05
# Total residual loss: 0.049685330314997056 | Sqrt residual loss: 0.2229020644027261
#
# Test sample 117:
# Residual loss 1: 0.021356134995581172 | Residual loss 2: 1.7709953794603385e-07
# Total residual loss: 0.021356312095119116 | Sqrt residual loss: 0.14613798991062904
#
# Test sample 118:
# Residual loss 1: 0.07764670419103874 | Residual loss 2: 9.485389672088316e-05
# Total residual loss: 0.07774155808775962 | Sqrt residual loss: 0.2788217317350992
#
# Test sample 119:
# Residual loss 1: 0.020594285514071522 | Residual loss 2: 2.5763954220110117e-05
# Total residual loss: 0.020620049468291633 | Sqrt residual loss: 0.1435968295899726
#
# Test sample 120:
# Residual loss 1: 0.061448914576862114 | Residual loss 2: 2.552639080505632e-07
# Total residual loss: 0.06144916984077017 | Sqrt residual loss: 0.2478894306757958
#
# Test sample 121:
# Residual loss 1: 0.026269144431241925 | Residual loss 2: 5.157795526729701e-05
# Total residual loss: 0.02632072238650922 | Sqrt residual loss: 0.16223662467676409
#
# Test sample 122:
# Residual loss 1: 0.00752387465495069 | Residual loss 2: 4.6563924698644046e-08
# Total residual loss: 0.0075239212188753886 | Sqrt residual loss: 0.08674053965058892
#
# Test sample 123:
# Residual loss 1: 0.009281583684685846 | Residual loss 2: 1.1436930792822773e-06
# Total residual loss: 0.009282727377765128 | Sqrt residual loss: 0.09634691161508566
#
# Test sample 124:
# Residual loss 1: 0.11709017988576761 | Residual loss 2: 2.9609163293266367e-05
# Total residual loss: 0.11711978904906088 | Sqrt residual loss: 0.3422276859768375
#
# Test sample 125:
# Residual loss 1: 0.019778376087256615 | Residual loss 2: 2.832275265084341e-05
# Total residual loss: 0.019806698839907457 | Sqrt residual loss: 0.14073627407284683
#
# Test sample 126:
# Residual loss 1: 0.0674350460281059 | Residual loss 2: 4.183411344070409e-05
# Total residual loss: 0.06747688014154661 | Sqrt residual loss: 0.2597631231363425
#
# Test sample 127:
# Residual loss 1: 0.019033763804286723 | Residual loss 2: 6.933068392470814e-05
# Total residual loss: 0.01910309448821143 | Sqrt residual loss: 0.13821394462286152
#
# Test sample 128:
# Residual loss 1: 0.03151249738971097 | Residual loss 2: 1.3401691229033348e-05
# Total residual loss: 0.03152589908094001 | Sqrt residual loss: 0.1775553408966906
#
# Test sample 129:
# Residual loss 1: 0.07618753469418861 | Residual loss 2: 3.5360830614746776e-05
# Total residual loss: 0.07622289552480335 | Sqrt residual loss: 0.2760849425897822
#
# Test sample 130:
# Residual loss 1: 0.02412626129682962 | Residual loss 2: 4.003089413767317e-05
# Total residual loss: 0.024166292190967293 | Sqrt residual loss: 0.15545511310654048
#
# Test sample 131:
# Residual loss 1: 0.009763987687480052 | Residual loss 2: 2.445959653062131e-05
# Total residual loss: 0.009788447284010673 | Sqrt residual loss: 0.09893658213224607
#
# Test sample 132:
# Residual loss 1: 0.00575240793230959 | Residual loss 2: 2.515628317653812e-06
# Total residual loss: 0.005754923560627244 | Sqrt residual loss: 0.07586121249114888
#
# Test sample 133:
# Residual loss 1: 0.02011259642846309 | Residual loss 2: 1.1758676171580758e-05
# Total residual loss: 0.020124355104634672 | Sqrt residual loss: 0.14186033661540026
#
# Test sample 134:
# Residual loss 1: 0.04843916763709882 | Residual loss 2: 1.3385571546851124e-06
# Total residual loss: 0.04844050619425351 | Sqrt residual loss: 0.220092040279183
#
# Test sample 135:
# Residual loss 1: 0.016428380802414575 | Residual loss 2: 2.8718453478355746e-05
# Total residual loss: 0.01645709925589293 | Sqrt residual loss: 0.12828522617937316
#
# Test sample 136:
# Residual loss 1: 0.020443266125751213 | Residual loss 2: 7.529391301542218e-06
# Total residual loss: 0.020450795517052756 | Sqrt residual loss: 0.14300627789384895
#
# Test sample 137:
# Residual loss 1: 0.009739674576931482 | Residual loss 2: 4.5530197764981474e-05
# Total residual loss: 0.009785204774696464 | Sqrt residual loss: 0.09892019396815022
#
# Test sample 138:
# Residual loss 1: 0.027982674393796668 | Residual loss 2: 6.982478683674002e-05
# Total residual loss: 0.02805249918063341 | Sqrt residual loss: 0.16748880315004167
#
# Test sample 139:
# Residual loss 1: 0.035286967970442104 | Residual loss 2: 1.0486074782019142e-05
# Total residual loss: 0.03529745404522412 | Sqrt residual loss: 0.1878761667834005
#
# Test sample 140:
# Residual loss 1: 0.015114990109239295 | Residual loss 2: 1.2673691619247122e-05
# Total residual loss: 0.015127663800858542 | Sqrt residual loss: 0.1229945681762351
#
# Test sample 141:
# Residual loss 1: 0.05598759962578652 | Residual loss 2: 2.6863761146159274e-05
# Total residual loss: 0.05601446338693268 | Sqrt residual loss: 0.23667374883356346
#
# Test sample 142:
# Residual loss 1: 0.01664387066172691 | Residual loss 2: 2.9291088925473913e-05
# Total residual loss: 0.016673161750652386 | Sqrt residual loss: 0.12912459777537502
#
# Test sample 143:
# Residual loss 1: 0.026225098023682007 | Residual loss 2: 1.1923114874551718e-08
# Total residual loss: 0.02622510994679688 | Sqrt residual loss: 0.16194168687153065
#
# Test sample 144:
# Residual loss 1: 0.0384407443249393 | Residual loss 2: 0.00012163366303307963
# Total residual loss: 0.03856237798797238 | Sqrt residual loss: 0.19637305820293266
#
# Test sample 145:
# Residual loss 1: 0.02469851596702981 | Residual loss 2: 4.313053470042967e-06
# Total residual loss: 0.024702829020499854 | Sqrt residual loss: 0.15717133651050963
#
# Test sample 146:
# Residual loss 1: 0.007763111126858869 | Residual loss 2: 0.0001340407366554692
# Total residual loss: 0.007897151863514338 | Sqrt residual loss: 0.08886592070931544
#
# Test sample 147:
# Residual loss 1: 0.03007324927209121 | Residual loss 2: 0.00014975938547174186
# Total residual loss: 0.03022300865756295 | Sqrt residual loss: 0.17384765933875254
#
# Test sample 148:
# Residual loss 1: 0.04058716305240994 | Residual loss 2: 4.941413302475802e-06
# Total residual loss: 0.04059210446571242 | Sqrt residual loss: 0.20147482340409786
#
# Test sample 149:
# Residual loss 1: 0.009578238237177501 | Residual loss 2: 7.017432349411334e-06
# Total residual loss: 0.009585255669526912 | Sqrt residual loss: 0.09790431895236754
#
# Test sample 150:
# Residual loss 1: 0.015543775923695248 | Residual loss 2: 1.867633043291036e-06
# Total residual loss: 0.015545643556738539 | Sqrt residual loss: 0.12468217016373487
#
# Test sample 151:
# Residual loss 1: 0.03663165338051308 | Residual loss 2: 3.845567656058584e-05
# Total residual loss: 0.036670109057073665 | Sqrt residual loss: 0.19149440998910036
#
# Test sample 152:
# Residual loss 1: 0.030184685024790436 | Residual loss 2: 5.4011041897324655e-05
# Total residual loss: 0.030238696066687762 | Sqrt residual loss: 0.17389277174939666
#
# Test sample 153:
# Residual loss 1: 0.018097068596896478 | Residual loss 2: 2.223138127768841e-07
# Total residual loss: 0.018097290910709253 | Sqrt residual loss: 0.1345261718429141
#
# Test sample 154:
# Residual loss 1: 0.12418437844453657 | Residual loss 2: 8.759731328059904e-06
# Total residual loss: 0.12419313817586464 | Sqrt residual loss: 0.3524104683119737
#
# Test sample 155:
# Residual loss 1: 0.0044213108275731605 | Residual loss 2: 4.1159953852942354e-05
# Total residual loss: 0.004462470781426103 | Sqrt residual loss: 0.06680172738354977
#
# Test sample 156:
# Residual loss 1: 0.06548312317336084 | Residual loss 2: 7.23147306757809e-05
# Total residual loss: 0.06555543790403663 | Sqrt residual loss: 0.2560379618416703
#
# Test sample 157:
# Residual loss 1: 0.04116012382238845 | Residual loss 2: 7.810795132389383e-07
# Total residual loss: 0.04116090490190169 | Sqrt residual loss: 0.2028815045830982
#
# Test sample 158:
# Residual loss 1: 0.006444510939085648 | Residual loss 2: 1.5019459321440569e-05
# Total residual loss: 0.006459530398407089 | Sqrt residual loss: 0.08037120378846574
#
# Test sample 159:
# Residual loss 1: 0.0075968253569419116 | Residual loss 2: 4.751743471818335e-06
# Total residual loss: 0.00760157710041373 | Sqrt residual loss: 0.08718702369282788
#
# Test sample 160:
# Residual loss 1: 0.02174122541162235 | Residual loss 2: 2.9606965662648414e-05
# Total residual loss: 0.021770832377285 | Sqrt residual loss: 0.14754942350712522
#
# Test sample 161:
# Residual loss 1: 0.0229975226275172 | Residual loss 2: 1.1325439048234994e-05
# Total residual loss: 0.023008848066565436 | Sqrt residual loss: 0.15168667728764262
#
# Test sample 162:
# Residual loss 1: 0.027734994409040595 | Residual loss 2: 1.6687591122611087e-05
# Total residual loss: 0.027751682000163206 | Sqrt residual loss: 0.16658836093846174
#
# Test sample 163:
# Residual loss 1: 0.03789383807738918 | Residual loss 2: 6.501305704868249e-06
# Total residual loss: 0.03790033938309405 | Sqrt residual loss: 0.1946800949842948
#
# Test sample 164:
# Residual loss 1: 0.028319858888902903 | Residual loss 2: 3.533273049766797e-05
# Total residual loss: 0.02835519161940057 | Sqrt residual loss: 0.16838999857295733
#
# Test sample 165:
# Residual loss 1: 0.03597645404286898 | Residual loss 2: 3.6970027541072657e-07
# Total residual loss: 0.03597682374314439 | Sqrt residual loss: 0.1896755749777614
#
# Test sample 166:
# Residual loss 1: 0.1373447304546178 | Residual loss 2: 4.487030871091664e-05
# Total residual loss: 0.13738960076332873 | Sqrt residual loss: 0.37066103216190494
#
# Test sample 167:
# Residual loss 1: 0.025275895888522824 | Residual loss 2: 2.3229436231059924e-06
# Total residual loss: 0.02527821883214593 | Sqrt residual loss: 0.15899125394859281
#
# Test sample 168:
# Residual loss 1: 0.011525846005325859 | Residual loss 2: 4.630251029372191e-05
# Total residual loss: 0.011572148515619581 | Sqrt residual loss: 0.107573921168746
#
# Test sample 169:
# Residual loss 1: 0.020381823757322795 | Residual loss 2: 9.799797587352021e-05
# Total residual loss: 0.020479821733196315 | Sqrt residual loss: 0.1431077277200512
#
# Test sample 170:
# Residual loss 1: 0.08820527664905942 | Residual loss 2: 1.078444577787034e-06
# Total residual loss: 0.08820635509363721 | Sqrt residual loss: 0.296995547262307
#
# Test sample 171:
# Residual loss 1: 0.0072796496355310375 | Residual loss 2: 9.089809389417683e-08
# Total residual loss: 0.007279740533624931 | Sqrt residual loss: 0.0853213955208477
#
# Test sample 172:
# Residual loss 1: 0.0646808099916236 | Residual loss 2: 6.173529380737633e-06
# Total residual loss: 0.06468698352100433 | Sqrt residual loss: 0.2543363590228584
#
# Test sample 173:
# Residual loss 1: 0.015984784437226503 | Residual loss 2: 9.410066853987125e-06
# Total residual loss: 0.01599419450408049 | Sqrt residual loss: 0.12646815608713716
#
# Test sample 174:
# Residual loss 1: 0.019116395350269086 | Residual loss 2: 3.080185484840332e-07
# Total residual loss: 0.01911670336881757 | Sqrt residual loss: 0.13826316707213665
#
# Test sample 175:
# Residual loss 1: 0.018691498347554555 | Residual loss 2: 1.800021057848827e-05
# Total residual loss: 0.018709498558133045 | Sqrt residual loss: 0.13678266907080386
#
# Test sample 176:
# Residual loss 1: 0.02160108836089062 | Residual loss 2: 5.275898039665251e-05
# Total residual loss: 0.021653847341287273 | Sqrt residual loss: 0.14715246291274664
#
# Test sample 177:
# Residual loss 1: 0.06685030694556851 | Residual loss 2: 2.0480873776099866e-05
# Total residual loss: 0.06687078781934461 | Sqrt residual loss: 0.2585938665539935
#
# Test sample 178:
# Residual loss 1: 0.008503969905019022 | Residual loss 2: 1.0218320041576285e-05
# Total residual loss: 0.008514188225060598 | Sqrt residual loss: 0.09227235894383863
#
# Test sample 179:
# Residual loss 1: 0.01472063642215133 | Residual loss 2: 2.735238664033178e-05
# Total residual loss: 0.014747988808791662 | Sqrt residual loss: 0.12144129778947384
#
# Test sample 180:
# Residual loss 1: 0.025815002354812717 | Residual loss 2: 1.563296435304051e-08
# Total residual loss: 0.02581501798777707 | Sqrt residual loss: 0.16067052619499655
#
# Test sample 181:
# Residual loss 1: 0.04961823117495042 | Residual loss 2: 9.567046083618968e-05
# Total residual loss: 0.04971390163578661 | Sqrt residual loss: 0.22296614459551164
#
# Test sample 182:
# Residual loss 1: 0.028342202809396377 | Residual loss 2: 1.4071670454474085e-05
# Total residual loss: 0.02835627447985085 | Sqrt residual loss: 0.16839321387707656
#
# Test sample 183:
# Residual loss 1: 0.015158490546788275 | Residual loss 2: 5.369175550005465e-07
# Total residual loss: 0.015159027464343276 | Sqrt residual loss: 0.12312200235678136
#
# Test sample 184:
# Residual loss 1: 0.042738402208213844 | Residual loss 2: 1.5328774986021672e-05
# Total residual loss: 0.042753730983199865 | Sqrt residual loss: 0.2067697535501744
#
# Test sample 185:
# Residual loss 1: 0.07178616475940536 | Residual loss 2: 4.1278667225477695e-06
# Total residual loss: 0.0717902926261279 | Sqrt residual loss: 0.26793710572843005
#
# Test sample 186:
# Residual loss 1: 0.009569935279124787 | Residual loss 2: 2.6405162750220624e-05
# Total residual loss: 0.009596340441875009 | Sqrt residual loss: 0.09796091282687708
#
# Test sample 187:
# Residual loss 1: 0.010285217665950514 | Residual loss 2: 3.245208512687331e-05
# Total residual loss: 0.010317669751077388 | Sqrt residual loss: 0.10157593096338023
#
# Test sample 188:
# Residual loss 1: 0.02004035955149826 | Residual loss 2: 2.7873710030559144e-05
# Total residual loss: 0.02006823326152882 | Sqrt residual loss: 0.14166239183893806
#
# Test sample 189:
# Residual loss 1: 0.050251613966373204 | Residual loss 2: 3.630748407731667e-05
# Total residual loss: 0.05028792145045052 | Sqrt residual loss: 0.22424968550803037
#
# Test sample 190:
# Residual loss 1: 0.03342823069447905 | Residual loss 2: 8.440620852893495e-07
# Total residual loss: 0.033429074756564335 | Sqrt residual loss: 0.18283619651634722
#
# Test sample 191:
# Residual loss 1: 0.03853741726207182 | Residual loss 2: 4.3405923521788715e-05
# Total residual loss: 0.03858082318559361 | Sqrt residual loss: 0.19642001727317307
#
# Test sample 192:
# Residual loss 1: 0.009014109645802338 | Residual loss 2: 7.262474736117068e-06
# Total residual loss: 0.009021372120538456 | Sqrt residual loss: 0.09498090397831796
#
# Test sample 193:
# Residual loss 1: 0.03139033893493886 | Residual loss 2: 1.6688585140419257e-06
# Total residual loss: 0.0313920077934529 | Sqrt residual loss: 0.17717789871610087
#
# Test sample 194:
# Residual loss 1: 0.020879760766062638 | Residual loss 2: 1.339496939013623e-06
# Total residual loss: 0.02088110026300165 | Sqrt residual loss: 0.1445029420565604
#
# Test sample 195:
# Residual loss 1: 0.09764149565772726 | Residual loss 2: 1.1878036566026368e-05
# Total residual loss: 0.09765337369429328 | Sqrt residual loss: 0.312495397876982
#
# Test sample 196:
# Residual loss 1: 0.041781240606073675 | Residual loss 2: 8.908689806691544e-06
# Total residual loss: 0.04179014929588037 | Sqrt residual loss: 0.20442639089873002
#
# Test sample 197:
# Residual loss 1: 0.06551557437297846 | Residual loss 2: 0.00019844409522862063
# Total residual loss: 0.06571401846820708 | Sqrt residual loss: 0.25634745652767277
#
# Test sample 198:
# Residual loss 1: 0.018422837446491865 | Residual loss 2: 4.84109336531705e-05
# Total residual loss: 0.018471248380145036 | Sqrt residual loss: 0.13590897093328694
#
# Test sample 199:
# Residual loss 1: 0.010031925806591143 | Residual loss 2: 1.4739354370586283e-06
# Total residual loss: 0.010033399742028201 | Sqrt residual loss: 0.10016685949967784
#
# Test sample 200:
# Residual loss 1: 0.07526663986340705 | Residual loss 2: 0.00011559197852614325
# Total residual loss: 0.0753822318419332 | Sqrt residual loss: 0.27455824854105765
#
# Test sample 201:
# Residual loss 1: 0.02024114110046847 | Residual loss 2: 1.9917148946808994e-05
# Total residual loss: 0.02026105824941528 | Sqrt residual loss: 0.1423413441323893
#
# Test sample 202:
# Residual loss 1: 0.029430429274633806 | Residual loss 2: 2.191660406357908e-07
# Total residual loss: 0.02943064844067444 | Sqrt residual loss: 0.1715536313829423
#
# Test sample 203:
# Residual loss 1: 0.011839959801780223 | Residual loss 2: 3.0046884757538873e-05
# Total residual loss: 0.011870006686537761 | Sqrt residual loss: 0.10894956028611479
#
# Test sample 204:
# Residual loss 1: 0.01565989720968493 | Residual loss 2: 2.91073729921042e-06
# Total residual loss: 0.01566280794698414 | Sqrt residual loss: 0.1251511404142373
#
# Test sample 205:
# Residual loss 1: 0.019618774043574694 | Residual loss 2: 1.816289542836659e-06
# Total residual loss: 0.01962059033311753 | Sqrt residual loss: 0.14007351760099954
#
# Test sample 206:
# Residual loss 1: 0.069937193340341 | Residual loss 2: 0.00019700985776234363
# Total residual loss: 0.07013420319810335 | Sqrt residual loss: 0.2648286298686442
#
# Test sample 207:
# Residual loss 1: 0.012704459138790456 | Residual loss 2: 2.3566099434948496e-05
# Total residual loss: 0.012728025238225405 | Sqrt residual loss: 0.11281855006259124
#
# Test sample 208:
# Residual loss 1: 0.05905747045953585 | Residual loss 2: 6.97337665896636e-05
# Total residual loss: 0.05912720422612551 | Sqrt residual loss: 0.24316086080232055
#
# Test sample 209:
# Residual loss 1: 0.007972877962840593 | Residual loss 2: 0.00012464663999221264
# Total residual loss: 0.008097524602832806 | Sqrt residual loss: 0.08998624674267067
#
# Test sample 210:
# Residual loss 1: 0.024713726843054094 | Residual loss 2: 1.6903306836346923e-05
# Total residual loss: 0.02473063014989044 | Sqrt residual loss: 0.15725975375120757
#
# Test sample 211:
# Residual loss 1: 0.025412529360997697 | Residual loss 2: 3.48013789248491e-05
# Total residual loss: 0.025447330739922547 | Sqrt residual loss: 0.1595221951325976
#
# Test sample 212:
# Residual loss 1: 0.025766525431489495 | Residual loss 2: 1.8017222658932454e-05
# Total residual loss: 0.025784542654148427 | Sqrt residual loss: 0.1605756602170716
#
# Test sample 213:
# Residual loss 1: 0.013772532760464806 | Residual loss 2: 5.354172847052745e-06
# Total residual loss: 0.01377788693331186 | Sqrt residual loss: 0.11737924404813595
#
# Test sample 214:
# Residual loss 1: 0.027068460217560923 | Residual loss 2: 6.492538080020602e-08
# Total residual loss: 0.027068525142941724 | Sqrt residual loss: 0.1645251504875219
#
# Test sample 215:
# Residual loss 1: 0.10779702446498873 | Residual loss 2: 4.603665780374726e-05
# Total residual loss: 0.10784306112279247 | Sqrt residual loss: 0.328394672799046
#
# Test sample 216:
# Residual loss 1: 0.016419782828797806 | Residual loss 2: 1.0915347156242926e-05
# Total residual loss: 0.016430698175954047 | Sqrt residual loss: 0.12818228495370976
#
# Test sample 217:
# Residual loss 1: 0.031310592632835595 | Residual loss 2: 8.024035945039217e-05
# Total residual loss: 0.03139083299228599 | Sqrt residual loss: 0.1771745833698671
#
# Test sample 218:
# Residual loss 1: 0.03307719904862275 | Residual loss 2: 0.0001326746053134252
# Total residual loss: 0.03320987365393618 | Sqrt residual loss: 0.18223576392666774
#
# Test sample 219:
# Residual loss 1: 0.020841953474844462 | Residual loss 2: 1.5843272601206643e-05
# Total residual loss: 0.02085779674744567 | Sqrt residual loss: 0.14442228618688208
#
# Test sample 220:
# Residual loss 1: 0.03454605396342556 | Residual loss 2: 3.1719869121690224e-07
# Total residual loss: 0.03454637116211678 | Sqrt residual loss: 0.18586654126581464
#
# Test sample 221:
# Residual loss 1: 0.053650497684122014 | Residual loss 2: 4.004363579701681e-06
# Total residual loss: 0.05365450204770172 | Sqrt residual loss: 0.23163441464450338
#
# Test sample 222:
# Residual loss 1: 0.015843589078418523 | Residual loss 2: 2.558642641602943e-05
# Total residual loss: 0.015869175504834552 | Sqrt residual loss: 0.12597291575904143
#
# Test sample 223:
# Residual loss 1: 0.019194255681252118 | Residual loss 2: 9.880670990138468e-05
# Total residual loss: 0.0192930623911535 | Sqrt residual loss: 0.13889946864964423
#
# Test sample 224:
# Residual loss 1: 0.04654993522221834 | Residual loss 2: 2.6325624456763377e-05
# Total residual loss: 0.046576260846675106 | Sqrt residual loss: 0.21581533969269912
#
# Test sample 225:
# Residual loss 1: 0.016132813586121814 | Residual loss 2: 6.98844342604363e-05
# Total residual loss: 0.01620269802038225 | Sqrt residual loss: 0.1272898189973662
#
# Test sample 226:
# Residual loss 1: 0.014151609145974997 | Residual loss 2: 1.367374648223856e-05
# Total residual loss: 0.014165282892457236 | Sqrt residual loss: 0.11901799398602396
#
# Test sample 227:
# Residual loss 1: 0.04511145359456599 | Residual loss 2: 8.089793020821145e-06
# Total residual loss: 0.04511954338758681 | Sqrt residual loss: 0.21241361394126038
#
# Test sample 228:
# Residual loss 1: 0.10843123606259163 | Residual loss 2: 6.0142362143628244e-05
# Total residual loss: 0.10849137842473526 | Sqrt residual loss: 0.32938029453009976
#
# Test sample 229:
# Residual loss 1: 0.01591072497692179 | Residual loss 2: 5.118539881020255e-05
# Total residual loss: 0.015961910375731993 | Sqrt residual loss: 0.12634045423272783
#
# Test sample 230:
# Residual loss 1: 0.06247234140144946 | Residual loss 2: 5.031269158704492e-06
# Total residual loss: 0.06247737267060816 | Sqrt residual loss: 0.24995474124450642
#
# Test sample 231:
# Residual loss 1: 0.0991953249821124 | Residual loss 2: 3.5112103913345666e-05
# Total residual loss: 0.09923043708602575 | Sqrt residual loss: 0.3150086301770568
#
# Test sample 232:
# Residual loss 1: 0.061013579732389835 | Residual loss 2: 5.142204931199654e-05
# Total residual loss: 0.06106500178170183 | Sqrt residual loss: 0.24711333792756277
#
# Test sample 233:
# Residual loss 1: 0.02299220097007662 | Residual loss 2: 1.911111156499043e-08
# Total residual loss: 0.022992220081188185 | Sqrt residual loss: 0.1516318570788744
#
# Test sample 234:
# Residual loss 1: 0.00854726908963205 | Residual loss 2: 8.602723903007254e-06
# Total residual loss: 0.008555871813535057 | Sqrt residual loss: 0.09249795572624865
#
# Test sample 235:
# Residual loss 1: 0.011199248983747365 | Residual loss 2: 1.0173135016064294e-06
# Total residual loss: 0.01120026629724897 | Sqrt residual loss: 0.10583131057134731
#
# Test sample 236:
# Residual loss 1: 0.027909564229383784 | Residual loss 2: 1.0041813429135675e-05
# Total residual loss: 0.02791960604281292 | Sqrt residual loss: 0.1670916097319459
#
# Test sample 237:
# Residual loss 1: 0.018646815916096255 | Residual loss 2: 1.6463305759533406e-05
# Total residual loss: 0.01866327922185579 | Sqrt residual loss: 0.1366136128716893
#
# Test sample 238:
# Residual loss 1: 0.014172114118471909 | Residual loss 2: 3.77348027684608e-05
# Total residual loss: 0.01420984892124037 | Sqrt residual loss: 0.11920507087049766
#
# Test sample 239:
# Residual loss 1: 0.08350512857239226 | Residual loss 2: 6.730947051394007e-07
# Total residual loss: 0.0835058016670974 | Sqrt residual loss: 0.2889737041100754
#
# Test sample 240:
# Residual loss 1: 0.023542040960507785 | Residual loss 2: 1.3739945358667833e-06
# Total residual loss: 0.02354341495504365 | Sqrt residual loss: 0.1534386357963458
#
# Test sample 241:
# Residual loss 1: 0.019040775330077427 | Residual loss 2: 4.545748118936125e-05
# Total residual loss: 0.019086232811266788 | Sqrt residual loss: 0.13815293269151685
#
# Test sample 242:
# Residual loss 1: 0.01476361507665389 | Residual loss 2: 3.529603082566307e-06
# Total residual loss: 0.014767144679736458 | Sqrt residual loss: 0.12152014104557507
#
# Test sample 243:
# Residual loss 1: 0.038963693240255844 | Residual loss 2: 1.5839781248763122e-08
# Total residual loss: 0.038963709080037094 | Sqrt residual loss: 0.1973922720879343
#
# Test sample 244:
# Residual loss 1: 0.011735562940373341 | Residual loss 2: 1.0012410481929937e-05
# Total residual loss: 0.011745575350855271 | Sqrt residual loss: 0.10837700563705971
#
# Test sample 245:
# Residual loss 1: 0.008169553732860182 | Residual loss 2: 1.2117536059140206e-07
# Total residual loss: 0.008169674908220773 | Sqrt residual loss: 0.09038625397825033
#
# Test sample 246:
# Residual loss 1: 0.028878844246976093 | Residual loss 2: 1.7494095104255396e-05
# Total residual loss: 0.028896338342080347 | Sqrt residual loss: 0.16998923007673264
#
# Test sample 247:
# Residual loss 1: 0.058363768044781224 | Residual loss 2: 9.75428837137129e-06
# Total residual loss: 0.05837352233315259 | Sqrt residual loss: 0.2416061305785774
#
# Test sample 248:
# Residual loss 1: 0.01023019958282557 | Residual loss 2: 1.3564215059113464e-05
# Total residual loss: 0.010243763797884683 | Sqrt residual loss: 0.10121148056364299
#
# Test sample 249:
# Residual loss 1: 0.01860661559457929 | Residual loss 2: 5.9862087545979035e-05
# Total residual loss: 0.018666477682125267 | Sqrt residual loss: 0.13662531859844013
#
# Test sample 250:
# Residual loss 1: 0.06193207638063313 | Residual loss 2: 5.570832255477118e-05
# Total residual loss: 0.0619877847031879 | Sqrt residual loss: 0.24897346184520933
#
# Test sample 251:
# Residual loss 1: 0.060114278837061455 | Residual loss 2: 0.0001279170168782486
# Total residual loss: 0.0602421958539397 | Sqrt residual loss: 0.24544285659586776
#
# Test sample 252:
# Residual loss 1: 0.04589551637944657 | Residual loss 2: 1.9070585248753772e-06
# Total residual loss: 0.045897423437971444 | Sqrt residual loss: 0.2142368395910737
#
# Test sample 253:
# Residual loss 1: 0.015979176258069893 | Residual loss 2: 1.6836747062330027e-06
# Total residual loss: 0.015980859932776127 | Sqrt residual loss: 0.12641542600796837
#
# Test sample 254:
# Residual loss 1: 0.012006113328746713 | Residual loss 2: 1.362703882947337e-05
# Total residual loss: 0.012019740367576186 | Sqrt residual loss: 0.10963457651478473
#
# Test sample 255:
# Residual loss 1: 0.02449262231663776 | Residual loss 2: 2.1561215886521377e-07
# Total residual loss: 0.024492837928796626 | Sqrt residual loss: 0.15650187835549012
#
# Test sample 256:
# Residual loss 1: 0.06612974791210129 | Residual loss 2: 3.3027906533092876e-05
# Total residual loss: 0.06616277581863438 | Sqrt residual loss: 0.25722125848894056
#
# Test sample 257:
# Residual loss 1: 0.07186060800932131 | Residual loss 2: 3.601273272568161e-05
# Total residual loss: 0.071896620742047 | Sqrt residual loss: 0.26813545222899376
#
# Test sample 258:
# Residual loss 1: 0.12273070884964338 | Residual loss 2: 7.095182760079639e-06
# Total residual loss: 0.12273780403240346 | Sqrt residual loss: 0.35033955533511124
#
# Test sample 259:
# Residual loss 1: 0.05358691096948387 | Residual loss 2: 7.044999845005491e-05
# Total residual loss: 0.05365736096793392 | Sqrt residual loss: 0.2316405857528726
#
# Test sample 260:
# Residual loss 1: 0.029720648172741424 | Residual loss 2: 8.010218834567544e-06
# Total residual loss: 0.029728658391575992 | Sqrt residual loss: 0.17242000577536237
#
# Test sample 261:
# Residual loss 1: 0.017721328750287608 | Residual loss 2: 0.00012258677734420755
# Total residual loss: 0.017843915527631815 | Sqrt residual loss: 0.13358111965256098
#
# Test sample 262:
# Residual loss 1: 0.048389517382643625 | Residual loss 2: 3.356932893486209e-05
# Total residual loss: 0.04842308671157849 | Sqrt residual loss: 0.22005246354353428
#
# Test sample 263:
# Residual loss 1: 0.01394101970634644 | Residual loss 2: 5.538210701099384e-05
# Total residual loss: 0.013996401813357434 | Sqrt residual loss: 0.11830638957113615
#
# Test sample 264:
# Residual loss 1: 0.015677640756644677 | Residual loss 2: 2.71627113794146e-05
# Total residual loss: 0.01570480346802409 | Sqrt residual loss: 0.12531880731966807
#
# Test sample 265:
# Residual loss 1: 0.01109395566202442 | Residual loss 2: 1.9220474111711275e-05
# Total residual loss: 0.011113176136136133 | Sqrt residual loss: 0.10541905015762632
#
# Test sample 266:
# Residual loss 1: 0.04092041301578053 | Residual loss 2: 8.650096520510168e-07
# Total residual loss: 0.040921278025432585 | Sqrt residual loss: 0.20229008385344197
#
# Test sample 267:
# ...
#
# Test sample 411:
# Residual loss 1: 0.04744396960873289 | Residual loss 2: 9.559575155186433e-05
# Total residual loss: 0.04753956536028476 | Sqrt residual loss: 0.2180356974449018
#
# Test sample 412:
# Residual loss 1: 0.01672745685487278 | Residual loss 2: 7.479170298141344e-06
# Total residual loss: 0.01673493602517092 | Sqrt residual loss: 0.1293635807527409
#
# Test sample 413:
# Residual loss 1: 0.06109103988229877 | Residual loss 2: 4.5681705683747635e-05
# Total residual loss: 0.061136721587982515 | Sqrt residual loss: 0.24725841055054631
#
# Test sample 414:
# Residual loss 1: 0.01760746445106008 | Residual loss 2: 4.00078069208224e-08
# Total residual loss: 0.017607504458867003 | Sqrt residual loss: 0.13269327209345244
#
# Test sample 415:
# Residual loss 1: 0.038399286524363745 | Residual loss 2: 5.915884215519878e-05
# Total residual loss: 0.03845844536651894 | Sqrt residual loss: 0.19610824910370023
#
# Test sample 416:
# Residual loss 1: 0.028783743730930917 | Residual loss 2: 7.733435157521499e-05
# Total residual loss: 0.028861078082506132 | Sqrt residual loss: 0.16988548520255087
#
# Test sample 417:
# Residual loss 1: 0.026972676585700895 | Residual loss 2: 4.454843026370841e-06
# Total residual loss: 0.026977131428727267 | Sqrt residual loss: 0.1642471656642125
#
# Test sample 418:
# Residual loss 1: 0.04233650905043326 | Residual loss 2: 8.501904265264273e-06
# Total residual loss: 0.042345010954698524 | Sqrt residual loss: 0.20577903429333738
#
# Test sample 419:
# Residual loss 1: 0.06406694112290671 | Residual loss 2: 4.514403150998045e-06
# Total residual loss: 0.06407145552605771 | Sqrt residual loss: 0.2531233997995004
#
# Test sample 420:
# Residual loss 1: 0.057147700179667214 | Residual loss 2: 1.2495497690490595e-05
# Total residual loss: 0.0571601956773577 | Sqrt residual loss: 0.2390819852631262
#
# Test sample 421:
# Residual loss 1: 0.013568467051440736 | Residual loss 2: 2.6678206674072e-07
# Total residual loss: 0.013568733833507476 | Sqrt residual loss: 0.1164849081791606
#
# Test sample 422:
# Residual loss 1: 0.030004519332634948 | Residual loss 2: 6.3618862574270796e-06
# Total residual loss: 0.030010881218892376 | Sqrt residual loss: 0.1732364892824037
#
# Test sample 423:
# Residual loss 1: 0.0989194500438124 | Residual loss 2: 2.900264362535157e-06
# Total residual loss: 0.09892235030817494 | Sqrt residual loss: 0.314519236785566
#
# Test sample 424:
# Residual loss 1: 0.01958998901785868 | Residual loss 2: 5.876410754049355e-05
# Total residual loss: 0.01964875312539917 | Sqrt residual loss: 0.1401740101637931
#
# Test sample 425:
# Residual loss 1: 0.030716873018137837 | Residual loss 2: 1.87957158931113e-06
# Total residual loss: 0.030718752589727148 | Sqrt residual loss: 0.17526765985123197
#
# Test sample 426:
# Residual loss 1: 0.02710927699107921 | Residual loss 2: 2.874310656551946e-06
# Total residual loss: 0.027112151301735762 | Sqrt residual loss: 0.16465767914596563
#
# Test sample 427:
# Residual loss 1: 0.015854988192759486 | Residual loss 2: 0.0002280326445300737
# Total residual loss: 0.01608302083728956 | Sqrt residual loss: 0.1268188504808712
#
# Test sample 428:
# Residual loss 1: 0.0430317649563123 | Residual loss 2: 7.385718216781445e-05
# Total residual loss: 0.04310562213848011 | Sqrt residual loss: 0.20761893492280542
#
# Test sample 429:
# Residual loss 1: 0.025755954336175255 | Residual loss 2: 2.7675587143368205e-05
# Total residual loss: 0.025783629923318622 | Sqrt residual loss: 0.1605728181334519
#
# Test sample 430:
# Residual loss 1: 0.04268535085804187 | Residual loss 2: 2.767095244739696e-05
# Total residual loss: 0.04271302181048927 | Sqrt residual loss: 0.20667128927475453
#
# Test sample 431:
# Residual loss 1: 0.07479838561349067 | Residual loss 2: 1.289707728433221e-07
# Total residual loss: 0.07479851458426351 | Sqrt residual loss: 0.2734931710011486
#
# Test sample 432:
# Residual loss 1: 0.020098699422932544 | Residual loss 2: 4.719516409080923e-05
# Total residual loss: 0.020145894587023355 | Sqrt residual loss: 0.14193623422869636
#
# Test sample 433:
# Residual loss 1: 0.08225256608447414 | Residual loss 2: 4.740866937083446e-06
# Total residual loss: 0.08225730695141122 | Sqrt residual loss: 0.28680534679711117
#
# Test sample 434:
# Residual loss 1: 0.04933685545373251 | Residual loss 2: 8.795311325397036e-05
# Total residual loss: 0.04942480856698648 | Sqrt residual loss: 0.22231691021374528
#
# Test sample 435:
# Residual loss 1: 0.02332582863700818 | Residual loss 2: 1.1937844878747997e-08
# Total residual loss: 0.023325840574853058 | Sqrt residual loss: 0.15272799538674323
#
# Test sample 436:
# Residual loss 1: 0.024646306221133975 | Residual loss 2: 2.117369534977429e-06
# Total residual loss: 0.024648423590668954 | Sqrt residual loss: 0.15699816429076155
#
# Test sample 437:
# Residual loss 1: 0.004331258195877437 | Residual loss 2: 9.24190259370608e-09
# Total residual loss: 0.004331267437780031 | Sqrt residual loss: 0.0658123653866052
#
# Test sample 438:
# Residual loss 1: 0.029085369242095014 | Residual loss 2: 2.1140364848495116e-05
# Total residual loss: 0.02910650960694351 | Sqrt residual loss: 0.17060630002125804
#
# Test sample 439:
# Residual loss 1: 0.012421197403538333 | Residual loss 2: 7.500875289718792e-07
# Total residual loss: 0.012421947491067306 | Sqrt residual loss: 0.11145379083309506
#
# Test sample 440:
# Residual loss 1: 0.010590583092456387 | Residual loss 2: 1.1244048781949149e-06
# Total residual loss: 0.010591707497334582 | Sqrt residual loss: 0.10291602157747151
#
# Test sample 441:
# Residual loss 1: 0.03847544963104736 | Residual loss 2: 1.5905772299009203e-05
# Total residual loss: 0.03849135540334637 | Sqrt residual loss: 0.1961921389947782
#
# Test sample 442:
# Residual loss 1: 0.01892010514583727 | Residual loss 2: 2.5841597465023783e-05
# Total residual loss: 0.018945946743302293 | Sqrt residual loss: 0.13764427610076016
#
# Test sample 443:
# Residual loss 1: 0.08001385341466838 | Residual loss 2: 1.9140906682111307e-05
# Total residual loss: 0.08003299432135048 | Sqrt residual loss: 0.2829010327329161
#
# Test sample 444:
# Residual loss 1: 0.01943198908740567 | Residual loss 2: 1.8499567288453946e-06
# Total residual loss: 0.019433839044134513 | Sqrt residual loss: 0.1394053049354095
#
# Test sample 445:
# Residual loss 1: 0.16891750496375446 | Residual loss 2: 4.4042593731695756e-05
# Total residual loss: 0.16896154755748616 | Sqrt residual loss: 0.41104932496901897
#
# Test sample 446:
# Residual loss 1: 0.05565316869081027 | Residual loss 2: 9.061459433129454e-05
# Total residual loss: 0.05574378328514157 | Sqrt residual loss: 0.23610121406960527
#
# Test sample 447:
# Residual loss 1: 0.01238758047162362 | Residual loss 2: 6.315799745256429e-05
# Total residual loss: 0.012450738469076185 | Sqrt residual loss: 0.11158287713209489
#
# Test sample 448:
# Residual loss 1: 0.018286071049020254 | Residual loss 2: 0.0001441985142682533
# Total residual loss: 0.01843026956328851 | Sqrt residual loss: 0.13575812890316552
#
# Test sample 449:
# Residual loss 1: 0.05783676864808595 | Residual loss 2: 2.9358332141916475e-05
# Total residual loss: 0.05786612698022787 | Sqrt residual loss: 0.24055379227987214
#
# Test sample 450:
# Residual loss 1: 0.013023488710839562 | Residual loss 2: 4.481008686310955e-06
# Total residual loss: 0.013027969719525873 | Sqrt residual loss: 0.1141401319410744
#
# Test sample 451:
# Residual loss 1: 0.029129122432339255 | Residual loss 2: 1.0624147201118684e-07
# Total residual loss: 0.029129228673811267 | Sqrt residual loss: 0.1706728703508887
#
# Test sample 452:
# Residual loss 1: 0.07531172268631942 | Residual loss 2: 3.468463175566748e-05
# Total residual loss: 0.07534640731807508 | Sqrt residual loss: 0.27449300049013103
#
# Test sample 453:
# Residual loss 1: 0.023520516864890272 | Residual loss 2: 1.6587743781586602e-07
# Total residual loss: 0.02352068274232809 | Sqrt residual loss: 0.15336454199823402
#
# Test sample 454:
# Residual loss 1: 0.021507980169081804 | Residual loss 2: 5.587077472562095e-07
# Total residual loss: 0.02150853887682906 | Sqrt residual loss: 0.1466578974240019
#
# Test sample 455:
# Residual loss 1: 0.14209731593106337 | Residual loss 2: 1.6524855162480498e-05
# Total residual loss: 0.14211384078622585 | Sqrt residual loss: 0.3769798944058235
#
# Test sample 456:
# Residual loss 1: 0.02678170429658384 | Residual loss 2: 1.5793915761629465e-06
# Total residual loss: 0.026783283688160003 | Sqrt residual loss: 0.16365599191034835
#
# Test sample 457:
# Residual loss 1: 0.04889385693294942 | Residual loss 2: 9.93657098207776e-05
# Total residual loss: 0.048993222642770194 | Sqrt residual loss: 0.22134412719286273
#
# Test sample 458:
# Residual loss 1: 0.03134532829170001 | Residual loss 2: 1.4408766697450208e-06
# Total residual loss: 0.03134676916836975 | Sqrt residual loss: 0.17705018827544283
#
# Test sample 459:
# Residual loss 1: 0.036912567950979636 | Residual loss 2: 2.8542524401879792e-05
# Total residual loss: 0.03694111047538152 | Sqrt residual loss: 0.19220070362873679
#
# Test sample 460:
# Residual loss 1: 0.010792397706696242 | Residual loss 2: 4.500698268702767e-06
# Total residual loss: 0.010796898404964944 | Sqrt residual loss: 0.10390812482652617
#
# Test sample 461:
# Residual loss 1: 0.0035118480922189752 | Residual loss 2: 3.461294101857656e-06
# Total residual loss: 0.003515309386320833 | Sqrt residual loss: 0.059290044580189286
#
# Test sample 462:
# Residual loss 1: 0.04196139629380221 | Residual loss 2: 1.814546784348344e-05
# Total residual loss: 0.04197954176164569 | Sqrt residual loss: 0.20488909624878943
#
# Test sample 463:
# Residual loss 1: 0.04770304327123621 | Residual loss 2: 2.7706762581626723e-05
# Total residual loss: 0.04773075003381783 | Sqrt residual loss: 0.21847368270301537
#
# Test sample 464:
# Residual loss 1: 0.007180017574002777 | Residual loss 2: 7.47728683367439e-06
# Total residual loss: 0.007187494860836452 | Sqrt residual loss: 0.08477909447992737
#
# Test sample 465:
# Residual loss 1: 0.01060124854131745 | Residual loss 2: 6.552217106586606e-07
# Total residual loss: 0.010601903763028109 | Sqrt residual loss: 0.1029655464853565
#
# Test sample 466:
# Residual loss 1: 0.18590128071135176 | Residual loss 2: 3.258204810237033e-05
# Total residual loss: 0.18593386275945412 | Sqrt residual loss: 0.43120049021244644
#
# Test sample 467:
# Residual loss 1: 0.013167043870623302 | Residual loss 2: 6.505257147679597e-05
# Total residual loss: 0.013232096442100098 | Sqrt residual loss: 0.1150308499581747
#
# Test sample 468:
# Residual loss 1: 0.059290837043531684 | Residual loss 2: 8.196026930877608e-06
# Total residual loss: 0.05929903307046256 | Sqrt residual loss: 0.24351392787777573
#
# Test sample 469:
# Residual loss 1: 0.04318593634958744 | Residual loss 2: 1.5369165704426043e-05
# Total residual loss: 0.04320130551529186 | Sqrt residual loss: 0.2078492374662266
#
# Test sample 470:
# Residual loss 1: 0.03833869031689458 | Residual loss 2: 2.1207329069079393e-06
# Total residual loss: 0.03834081104980149 | Sqrt residual loss: 0.19580809750825295
#
# Test sample 471:
# Residual loss 1: 0.026375312287363076 | Residual loss 2: 3.897334399338938e-06
# Total residual loss: 0.026379209621762413 | Sqrt residual loss: 0.16241677752548353
#
# Test sample 472:
# Residual loss 1: 0.09111481204767263 | Residual loss 2: 3.094633699361736e-05
# Total residual loss: 0.09114575838466625 | Sqrt residual loss: 0.30190355808546915
#
# Test sample 473:
# Residual loss 1: 0.04266917834475631 | Residual loss 2: 4.3990790586723325e-07
# Total residual loss: 0.042669618252662175 | Sqrt residual loss: 0.2065662563262988
#
# Test sample 474:
# Residual loss 1: 0.011070376685268286 | Residual loss 2: 3.404344526564617e-06
# Total residual loss: 0.01107378102979485 | Sqrt residual loss: 0.10523203423765431
#
# Test sample 475:
# Residual loss 1: 0.01336393109520017 | Residual loss 2: 4.330192435230752e-05
# Total residual loss: 0.013407233019552477 | Sqrt residual loss: 0.11578960669918728
#
# Test sample 476:
# Residual loss 1: 0.01258948568693778 | Residual loss 2: 3.463962045303511e-08
# Total residual loss: 0.012589520326558233 | Sqrt residual loss: 0.1122030317173214
#
# Test sample 477:
# Residual loss 1: 0.0648076060465539 | Residual loss 2: 5.973951253329303e-05
# Total residual loss: 0.0648673455590872 | Sqrt residual loss: 0.2546906860469915
#
# Test sample 478:
# Residual loss 1: 0.020565502898071703 | Residual loss 2: 7.027670077607272e-06
# Total residual loss: 0.02057253056814931 | Sqrt residual loss: 0.14343127472120337
#
# Test sample 479:
# Residual loss 1: 0.01352401374183111 | Residual loss 2: 4.0346902831045985e-06
# Total residual loss: 0.013528048432114215 | Sqrt residual loss: 0.11631013899103644
#
# Test sample 480:
# Residual loss 1: 0.042250369047772726 | Residual loss 2: 1.2703106284079145e-06
# Total residual loss: 0.042251639358401136 | Sqrt residual loss: 0.2055520356464541
#
# Test sample 481:
# Residual loss 1: 0.01768258616751425 | Residual loss 2: 0.00011482805020832887
# Total residual loss: 0.017797414217722577 | Sqrt residual loss: 0.13340694966051272
#
# Test sample 482:
# Residual loss 1: 0.008139243520704812 | Residual loss 2: 6.905139693246397e-06
# Total residual loss: 0.008146148660398058 | Sqrt residual loss: 0.09025601730853217
#
# Test sample 483:
# Residual loss 1: 0.019622283521759515 | Residual loss 2: 1.576806761073114e-08
# Total residual loss: 0.019622299289827127 | Sqrt residual loss: 0.14007961768161392
#
# Test sample 484:
# Residual loss 1: 0.02201528836074232 | Residual loss 2: 1.1241139996169083e-06
# Total residual loss: 0.022016412474741936 | Sqrt residual loss: 0.1483792858681492
#
# Test sample 485:
# Residual loss 1: 0.01595785086085995 | Residual loss 2: 2.769210488136408e-06
# Total residual loss: 0.015960620071348085 | Sqrt residual loss: 0.1263353476717743
#
# Test sample 486:
# Residual loss 1: 0.006477451609605215 | Residual loss 2: 9.78797940174956e-06
# Total residual loss: 0.006487239589006964 | Sqrt residual loss: 0.08054340189616381
#
# Test sample 487:
# Residual loss 1: 0.054922973700884184 | Residual loss 2: 2.707976118038723e-06
# Total residual loss: 0.05492568167700222 | Sqrt residual loss: 0.23436228723282726
#
# Test sample 488:
# Residual loss 1: 0.03471593411099867 | Residual loss 2: 2.9883193475484964e-06
# Total residual loss: 0.03471892243034622 | Sqrt residual loss: 0.18633014364387268
#
# Test sample 489:
# Residual loss 1: 0.0713823897627768 | Residual loss 2: 2.3078115213528542e-05
# Total residual loss: 0.07140546787799033 | Sqrt residual loss: 0.26721801563141345
#
# Test sample 490:
# Residual loss 1: 0.047792416583892515 | Residual loss 2: 7.10546409007081e-06
# Total residual loss: 0.04779952204798259 | Sqrt residual loss: 0.21863101803720025
#
# Test sample 491:
# Residual loss 1: 0.0585252923176014 | Residual loss 2: 0.0001330882520334214
# Total residual loss: 0.05865838056963482 | Sqrt residual loss: 0.2421949226751767
#
# Test sample 492:
# Residual loss 1: 0.0861761617438247 | Residual loss 2: 5.919418604211606e-06
# Total residual loss: 0.08618208116242891 | Sqrt residual loss: 0.2935678476305416
#
# Test sample 493:
# Residual loss 1: 0.016964075268196967 | Residual loss 2: 6.171413869846766e-06
# Total residual loss: 0.016970246682066814 | Sqrt residual loss: 0.1302698993707557
#
# Test sample 494:
# Residual loss 1: 0.011369981575459516 | Residual loss 2: 1.0363984862822606e-05
# Total residual loss: 0.011380345560322339 | Sqrt residual loss: 0.1066787024683106
#
# Test sample 495:
# Residual loss 1: 0.018679861577181305 | Residual loss 2: 3.477833993263325e-06
# Total residual loss: 0.018683339411174567 | Sqrt residual loss: 0.13668701259144764
#
# Test sample 496:
# Residual loss 1: 0.02564890906329803 | Residual loss 2: 9.757168337969684e-06
# Total residual loss: 0.025658666231636002 | Sqrt residual loss: 0.1601832270608755
#
# Test sample 497:
# Residual loss 1: 0.009527550816582736 | Residual loss 2: 3.08362483451261e-05
# Total residual loss: 0.009558387064927863 | Sqrt residual loss: 0.09776700396825026
#
# Test sample 498:
# Residual loss 1: 0.015217925905146758 | Residual loss 2: 4.632482972896589e-07
# Total residual loss: 0.015218389153444048 | Sqrt residual loss: 0.12336283538182821
#
# Test sample 499:
# Residual loss 1: 0.025830178994993194 | Residual loss 2: 6.301568575766117e-05
# Total residual loss: 0.025893194680750856 | Sqrt residual loss: 0.1609136249071248

# %%
np.save(os.path.join(model_test_outputs_path, "residual_loss_dict.npy"), residual_loss_dict)

# %%
print(f'mean residual loss 1: {np.mean(residual_loss_dict["loss_1"]):.2e} (std: {np.std(residual_loss_dict["loss_1"]):.2e})')
print(f'mean residual loss 2: {np.mean(residual_loss_dict["loss_2"]):.2e} (std: {np.std(residual_loss_dict["loss_2"]):.2e})')
print(f'mean total residual loss: {np.mean(residual_loss_dict["total_loss"]):.2e} (std: {np.std(residual_loss_dict["total_loss"]):.2e})')
print(f'mean sqrt total residual loss: {np.mean(residual_loss_dict["sqrt_total_loss"]):.2e} (std: {np.std(residual_loss_dict["sqrt_total_loss"]):.2e})')
# Out:
# mean residual loss 1: 3.37e-02 (std: 2.66e-02)
# mean residual loss 2: 2.55e-05 (std: 3.68e-05)
# mean total residual loss: 3.38e-02 (std: 2.66e-02)
# mean sqrt total residual loss: 1.72e-01 (std: 6.48e-02)

# %%
ratio_list = []
for test_index in range(num_test):
    ratio = np.sqrt(sigma_u_error_dict['squared_hdiv_h1'])[test_index] / residual_loss_dict['sqrt_total_loss'][test_index]
    ratio_list.append(ratio)
    print(f'index: {test_index} | ratio: {ratio}')
# Out:
# index: 0 | ratio: 0.5904660845196456
# index: 1 | ratio: 0.3941669893075233
# index: 2 | ratio: 1.0371938872222926
# index: 3 | ratio: 1.2134332838027386
# index: 4 | ratio: 0.42158921796268267
# index: 5 | ratio: 0.4835892360484126
# index: 6 | ratio: 1.040987093399895
# index: 7 | ratio: 0.7876073629923104
# index: 8 | ratio: 0.47713777408480185
# index: 9 | ratio: 0.3905228564712565
# index: 10 | ratio: 0.6754149946513616
# index: 11 | ratio: 0.5533516006814359
# index: 12 | ratio: 0.8807149960058758
# index: 13 | ratio: 0.5992423869204966
# index: 14 | ratio: 0.3958695266065462
# index: 15 | ratio: 0.5092678288322843
# index: 16 | ratio: 0.580662647609692
# index: 17 | ratio: 1.0128562315851968
# index: 18 | ratio: 0.6317085134464488
# index: 19 | ratio: 0.5073988714355302
# index: 20 | ratio: 0.8653904004210412
# index: 21 | ratio: 0.7776369294467694
# index: 22 | ratio: 0.849941882070179
# index: 23 | ratio: 0.9753432346704785
# index: 24 | ratio: 0.4477841604229279
# index: 25 | ratio: 0.7056694872903975
# index: 26 | ratio: 0.7905758147771622
# index: 27 | ratio: 0.585524547355249
# index: 28 | ratio: 0.793943486644793
# index: 29 | ratio: 0.5910416869848829
# index: 30 | ratio: 0.3663461539301701
# index: 31 | ratio: 0.5957834328823022
# index: 32 | ratio: 0.7131362961787471
# index: 33 | ratio: 0.4394192617442241
# index: 34 | ratio: 0.44425177797839
# index: 35 | ratio: 0.8634595665640967
# index: 36 | ratio: 0.46752340217266297
# index: 37 | ratio: 0.6247262730270261
# index: 38 | ratio: 0.5250837247134926
# index: 39 | ratio: 0.5043643605014761
# index: 40 | ratio: 0.42246339535683153
# index: 41 | ratio: 0.5808185632450883
# index: 42 | ratio: 0.4818134996748951
# index: 43 | ratio: 0.5011090723526382
# index: 44 | ratio: 0.693979923911233
# index: 45 | ratio: 0.4405389729089976
# index: 46 | ratio: 0.8633855205264263
# index: 47 | ratio: 0.5902916872308835
# index: 48 | ratio: 0.5648531364881408
# index: 49 | ratio: 0.9173578463695876
# index: 50 | ratio: 1.1035763164649817
# index: 51 | ratio: 0.6606236641409259
# index: 492 | ratio: 0.3204763158113894
# index: 493 | ratio: 0.7393379655461932
# index: 494 | ratio: 0.8847334615268839
# index: 495 | ratio: 0.5511766641337179
# index: 496 | ratio: 0.6709925183118507
# index: 497 | ratio: 0.9096845853481816
# index: 498 | ratio: 0.707658885946708
# index: 499 | ratio: 0.6792508937823348

# %%
plt.figure(figsize=(10, 8))  # Optional: bigger figure
plt.hist(ratio_list, bins=10)

plt.xlabel('Value', fontsize=25) 
plt.ylabel('Frequency', fontsize=25)
plt.title(fr'Error / $\sqrt{{\text{{Loss}}}}$ (# test = {num_test})', fontsize=25)

plt.xticks(fontsize=23)
plt.yticks(fontsize=23)

plt.savefig(os.path.join(model_test_outputs_path, 'ratio_histogram_hdiv_h1.png'),
            dpi=300, bbox_inches='tight')
plt.close()

# %%
# cg1_residual_loss_dict = {
#     'loss_1': np.zeros(num_test),
#     'loss_2': np.zeros(num_test),
#     'total_loss': np.zeros(num_test),
#     'sqrt_total_loss': np.zeros(num_test)
# }
# for test_index in range(num_test): 
#     # pred_fc = dolfinx.fem.Function(Vh['sigma_u'])
#     # pred_fc.x.array[:] = test_pred[test_index]
#     # pred_sigma_fc = pred_fc.sub(0).collapse()
#     # pred_u_fc = pred_fc.sub(1).collapse()

#     test_CG1_sigma_pred_fc = test_CG1_sigma_fc_pred_list[test_index]
#     test_CG1_u_pred_fc = test_CG1_u_fc_pred_list[test_index]

#     p_fc = dolfinx.fem.Function(Vh['p'])
#     p_fc.x.array[:] = test_p_dof[test_index]

#     residual_loss_1 = compute_physical_loss_1(test_CG1_sigma_pred_fc, test_CG1_u_pred_fc, p_fc)
#     residual_loss_2 = compute_physical_loss_2(test_CG1_sigma_pred_fc, test_CG1_u_pred_fc, p_fc)

#     residual_loss = residual_loss_1 + residual_loss_2

#     sqrt_residual_loss = np.sqrt(residual_loss)

#     cg1_residual_loss_dict['loss_1'][test_index] = residual_loss_1
#     cg1_residual_loss_dict['loss_2'][test_index] = residual_loss_2
#     cg1_residual_loss_dict['total_loss'][test_index] = residual_loss
#     cg1_residual_loss_dict['sqrt_total_loss'][test_index] = sqrt_residual_loss
#     print(f'Test sample {test_index}:')
#     print(f'Residual loss 1: {residual_loss_1} | Residual loss 2: {residual_loss_2}')
#     print(f'Total residual loss: {residual_loss} | Sqrt residual loss: {sqrt_residual_loss}')

#     print("")

# %%
# print(f'mean CG1 residual loss 1: {np.mean(cg1_residual_loss_dict["loss_1"]):.2e} (std: {np.std(cg1_residual_loss_dict["loss_1"]):.2e})')
# print(f'mean CG1 residual loss 2: {np.mean(cg1_residual_loss_dict["loss_2"]):.2e} (std: {np.std(cg1_residual_loss_dict["loss_2"]):.2e})')
# print(f'mean CG1 total residual loss: {np.mean(cg1_residual_loss_dict["total_loss"]):.2e} (std: {np.std(cg1_residual_loss_dict["total_loss"]):.2e})')
# print(f'mean sqrt CG1 total residual loss: {np.mean(cg1_residual_loss_dict["sqrt_total_loss"]):.2e} (std: {np.std(cg1_residual_loss_dict["sqrt_total_loss"]):.2e})')
