# %%
import os
import sys
import argparse

import numpy as np
import matplotlib.pyplot as plt

import torch

import dolfinx
import dolfinx.fem.petsc
import ufl
from mpi4py import MPI
import basix.ufl

repo_path = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(repo_path)

from data_generation.differential_equations import PoissonSetup1LeastSquares
from utils import load_yaml, load_pkl, load_npy, format_elapsed_time, timing
from utils import plot_real_valued_function, plot_block_sparsity, plot_block_submatrix_sparsity

from scifem import create_real_functionspace

import torch
import torch.nn as nn
import torch.nn.init as init
import numpy as np
from petsc4py import PETSc
import scifem


from utils import project, norm_L2, convert_petsc_mat_to_torch_sparse_coo_tensor, convert_weight_to_tensor
from utils import evaluate_expression, print_model_size
from typing import Optional
import pickle
import csv

from typing import Optional
from train.train_loss import SurrogateLoss
from models import ConvolutionalNN_129x129
from train.train_utils import BatchIndicesIterator, pretty_print_loss
from train.soap import SOAP
from utils.set_seed import set_seed
import time
from tqdm import tqdm
# Out:
# ----------------------------------------
# 2025-12-09 21:06:33 - Start Program
# ----------------------------------------

# %%
set_seed(2025)

# %%
mesh_config_path= repo_path + "/configs/poisson_setup1/config_data/config_mesh.yaml"
function_space_config_path= repo_path + "/configs/poisson_setup1/config_data/config_function_space.yaml"
output_reduced_basis_config_path= repo_path + "/configs/poisson_setup1/config_data/config_output_reduced_basis.yaml"
train_dataset_path = repo_path + "/results/poisson_setup1/train_dataset"
test_dataset_path = repo_path + "/results/poisson_setup1/test_dataset"
model_train_outputs_path = repo_path + "/results/poisson_setup1/model_train_outputs/rbno_physics_loss_pod_data_loss"
model_test_outputs_path = repo_path + "/results/poisson_setup1/model_test_outputs/rbno_physics_loss_pod_data_loss"

mesh_args = load_yaml(mesh_config_path)
function_space_args = load_yaml(function_space_config_path)
output_reduced_basis_args = load_yaml(output_reduced_basis_config_path)
poisson_least_squares = PoissonSetup1LeastSquares(mesh_args, function_space_args)

# %%
p_dof = load_npy(train_dataset_path+'/p_dof.npy')
p_vertex_values = load_npy(train_dataset_path+'/p_vertex_values.npy')
sigma_u_dof = load_npy(train_dataset_path+'/sigma_u_dof.npy')

# %%
print("p_dof shape: ", p_dof.shape)
print("p_vertex_values shape: ", p_vertex_values.shape)
print("sigma_u_dof shape: ", sigma_u_dof.shape)
# Out:
# p_dof shape:  (5000, 32768)
# p_vertex_values shape:  (5000, 16641)
# sigma_u_dof shape:  (5000, 230401)

# %%
mesh = poisson_least_squares.mesh
Vh = poisson_least_squares.Vh

# %%
torch_dtype = {
    'float16': torch.float16,
    'float32': torch.float32,
    'float64': torch.float64,
}

# %%
reference_loss_list = []
num_samples_for_reference_loss = 1
for i in range(num_samples_for_reference_loss):
    p_fc = dolfinx.fem.Function(Vh['p'])  
    p_fc.x.array[:] = p_dof[i]
    weight = poisson_least_squares.compute_weight(p_fc)
    weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float64'])
    
    y = sigma_u_dof[i]
    y = torch.tensor(y, dtype=torch_dtype['float64'])
    reference_loss = torch.dot(y, weight_tensor['A00'] @ y) + 2*torch.dot(y, weight_tensor['A01'])  + weight_tensor['A11']
    print(f'reference loss: {reference_loss.item()}')
    reference_loss_list.append(reference_loss.item())

print(f"reference loss mean: {np.mean(reference_loss_list):.2e}")
print(f"reference loss std: {np.std(reference_loss_list):.2e}")
# Out:
# reference loss: 0.00010073986411485158
# reference loss mean: 1.01e-04
# reference loss std: 0.00e+00

# %%
def compute_reduced_weight(weight: dict[torch.Tensor], pod_basis_dof: torch.Tensor)-> torch.Tensor:

    quadratic_weight = pod_basis_dof.T @ weight['A00'] @ pod_basis_dof
    linear_weight = pod_basis_dof.T @ weight['A01']
    bias = weight['A11']

    reduced_weight = {'quadratic': quadratic_weight, 'linear': linear_weight, 'bias': bias}

    return reduced_weight

def compute_reduced_weight_v2(weight,  pod_basis_dof_petsc, pod_basis_dof_petsc_T) -> dict[np.ndarray]:
    """
    Compute the reduced weight using the POD basis in PETSc format.
    """
    temp = weight['A00'].matMult(pod_basis_dof_petsc)
    quadratic_weight = pod_basis_dof_petsc_T.matMult(temp)
    linear_weight = pod_basis_dof_petsc_T.createVecLeft()
    pod_basis_dof_petsc_T.mult(weight['A01'], linear_weight)
    bias = weight['A11']

    def mat_to_numpy(mat: PETSc.Mat):
        m, n = mat.getSize()
        arr = np.zeros((m, n), dtype=float)
        for i in range(m):
            for j in range(n):
                arr[i, j] = mat.getValue(i, j)
        return arr

    quadratic_weight = mat_to_numpy(quadratic_weight)
    linear_weight = linear_weight.getArray(readonly=True)
    reduced_weight = {'quadratic': quadratic_weight, 'linear': linear_weight, 'bias': bias}

    return reduced_weight

num_basis = 128

pod_basis_dof = np.load(train_dataset_path + '/hdiv_h1_pod_basis_dof.npy')[:, :num_basis]
pod_basis_dof_tensor = torch.tensor(pod_basis_dof, dtype=torch_dtype['float64'])

import numpy as np
from petsc4py import PETSc

pod_basis_dof_petsc = PETSc.Mat().createDense(size=pod_basis_dof.shape, array=pod_basis_dof, comm=PETSc.COMM_SELF)
pod_basis_dof_petsc_T = PETSc.Mat().createDense(size=(pod_basis_dof.shape[1], pod_basis_dof.shape[0]), array=pod_basis_dof.T, comm=PETSc.COMM_SELF)
pod_basis_dof_petsc.assemblyBegin()
pod_basis_dof_petsc.assemblyEnd()
pod_basis_dof_petsc_T.assemblyBegin()
pod_basis_dof_petsc_T.assemblyEnd()

# %%
# %%time
weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float64'])
reduced_weight = compute_reduced_weight(weight_tensor, pod_basis_dof_tensor)
# Out:
# CPU times: user 1.27 s, sys: 2.29 s, total: 3.56 s
# Wall time: 3.54 s

# %%
# %%time
reduced_weight_v2 = compute_reduced_weight_v2(weight, pod_basis_dof_petsc, pod_basis_dof_petsc_T)
# Out:
# CPU times: user 391 ms, sys: 111 ms, total: 501 ms
# Wall time: 493 ms

# %%
# avg_compute_reduced_weight_time = 0
# for i in range(num_samples_for_reference_loss):
#     k_fc = dolfinx.fem.Function(Vh['k'])
#     k_fc.x.array[:] = k_dof[i]
#     weight = poisson_least_squares.compute_weight_with_auxiliary_variable(k_fc, aux_sigma_u)

#     start_time = time.time()
#     reduced_weight_v2 = compute_reduced_weight_v2(weight, pod_basis_dof_petsc, pod_basis_dof_petsc_T)
#     end_time = time.time()
#     avg_compute_reduced_weight_time += (end_time - start_time)
# avg_compute_reduced_weight_time /= num_samples_for_reference_loss
# print(avg_compute_reduced_weight_time)

# %%
# ## precision = float32
# reference_loss_list = []
# num_samples_for_reference_loss = 100
# aux_sigma_u = dolfinx.fem.Function(Vh['sigma_u'])
# aux_sigma_u.x.array[:] = aux_sigma_u_dof
# for i in range(num_samples_for_reference_loss):
#     k_fc = dolfinx.fem.Function(Vh['k'])  
#     k_fc.x.array[:] = k_dof[i]
#     weight = poisson_least_squares.compute_weight_with_auxiliary_variable(k_fc, aux_sigma_u)
#     weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float32'])
    
#     y = sigma_u_dof[i] - aux_sigma_u_dof
#     y = torch.tensor(y, dtype=torch_dtype['float32'])
#     reference_loss = torch.dot(y, weight_tensor['A00'] @ y) + 2*torch.dot(y, weight_tensor['A01'])  + weight_tensor['A11']
#     print(f'reference loss: {reference_loss.item()}')
#     reference_loss_list.append(reference_loss.item())


# print(f"reference loss mean: {np.mean(reference_loss_list):.2e}")
# print(f"reference loss std: {np.std(reference_loss_list):.2e}")

# %%
# # precision = float16
# reference_loss_list = []
# num_samples_for_reference_loss = 100
# aux_sigma_u = dolfinx.fem.Function(Vh['sigma_u'])
# aux_sigma_u.x.array[:] = aux_sigma_u_dof
# for i in range(num_samples_for_reference_loss):
#     k_fc = dolfinx.fem.Function(Vh['k'])  
#     k_fc.x.array[:] = k_dof[i]
#     weight = poisson_least_squares.compute_weight_with_auxiliary_variable(k_fc, aux_sigma_u)
#     weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float16'])
    
#     y = sigma_u_dof[i] - aux_sigma_u_dof
#     y = torch.tensor(y, dtype=torch_dtype['float16'])
#     reference_loss = torch.dot(y, weight_tensor['A00'] @ y) + 2*torch.dot(y, weight_tensor['A01'])  + weight_tensor['A11']
#     print(f'reference loss: {reference_loss.item()}')
#     reference_loss_list.append(reference_loss.item())

# print(f"reference loss mean: {np.mean(reference_loss_list):.2e}")
# print(f"reference loss std: {np.std(reference_loss_list):.2e}")

# %%
# fig = plot_block_sparsity(weight_tensor, highlight_box=(10000, 12000, 10000, 12000), box_color='red', box_linewidth=3, box_alpha=0.9)
# fig.savefig(os.path.join(train_dataset_path, 'sparsity_pattern_full.png'), dpi=300, bbox_inches='tight')

# %%
# fig = plot_block_submatrix_sparsity(weight_tensor, (10000, 12000), (10000, 12000), highlight_box=(0, 100, 0, 100), box_color='red', box_linewidth=2, box_alpha=0.5)
# fig.savefig(os.path.join(train_dataset_path, 'sparsity_pattern_10000-12000.png'), dpi=300, bbox_inches='tight')

# %%
# fig = plot_block_submatrix_sparsity(weight_tensor, (10000, 10100), (10000, 10100))
# fig.savefig(os.path.join(train_dataset_path, 'sparsity_pattern_10000-10100.png'), dpi=300, bbox_inches='tight')

# %%
# for i in range(10):
#     k_fc = dolfinx.fem.Function(Vh['k'])
#     k_fc.x.array[:] = k_dof[i]
#     weight = poisson_least_squares.compute_weight_with_auxiliary_variable(k_fc, aux_sigma_u)
#     weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float64'])
    
#     y = sigma_u_dof[0] - aux_sigma_u_dof
#     y = torch.tensor(y, dtype=torch_dtype['float64'])
#     reference_loss = torch.dot(y, weight_tensor['A00'] @ y) + 2*torch.dot(y, weight_tensor['A01'])  + weight_tensor['A11']

#     if i == 0:
#         print(f'Correct reference loss: {reference_loss}')
#     else: 
#         print(f'Wrong reference loss: {reference_loss}')

# %%
pod_basis_dof = np.load(train_dataset_path+'/hdiv_h1_pod_basis_dof.npy')[:,:output_reduced_basis_args['num_basis']]
reference_reduced_minimizers = np.load(train_dataset_path+'/reference_reduced_minimizers.npy')[:,:output_reduced_basis_args['num_basis']]

# %%
# for i in range(10):
#     plt.plot(pod_basis_dof[:,i])

# %%
pod_basis_dof = torch.tensor(pod_basis_dof, dtype=torch_dtype['float64'])
reference_reduced_minimizers = torch.tensor(reference_reduced_minimizers, dtype=torch_dtype['float64'])

quadratic_weight = torch.tensor(np.load(train_dataset_path+'/hdiv_h1_quadratic_weight.npy'), dtype=torch_dtype['float64'])
linear_weight = torch.tensor(np.load(train_dataset_path+'/hdiv_h1_linear_weight.npy'), dtype=torch_dtype['float64'])
bias = torch.tensor(np.load(train_dataset_path+'/hdiv_h1_bias.npy'), dtype=torch_dtype['float64'])

# %%
reduced_weight_list = []
for i in range(len(quadratic_weight)):
    reduced_weight = {}
    reduced_weight['quadratic'] = quadratic_weight[i]
    reduced_weight['linear'] = linear_weight[i]
    reduced_weight['bias'] = bias[i]
    reduced_weight_list.append(reduced_weight)

# %%
surrogate_loss = SurrogateLoss(reduced_weight_list)

# %%
valid_start_index = 4500
reference_surrogate_loss_list = []
num_samples_for_reference_surrogate_loss = 500
for i in range(valid_start_index, valid_start_index + num_samples_for_reference_surrogate_loss):
    print(f'sample {i}:')
    reference_surrogate_loss = surrogate_loss(reference_reduced_minimizers[i], i, sub_dim=64)
    print(f'reference surrogate loss: {reference_surrogate_loss.item()}')
    reference_surrogate_loss_list.append(reference_surrogate_loss.item())
print("")
print("number of POD basi: 64")
print(f'mean reference surrogate loss: {np.mean(reference_surrogate_loss_list):.2e}')
print(f'std reference surrogate loss: {np.std(reference_surrogate_loss_list):.2e}')
# Out:
# sample 4500:
# reference surrogate loss: 0.00043160808264386397
# sample 4501:
# reference surrogate loss: 0.0008166741369290964
# sample 4502:
# reference surrogate loss: 0.00043653716075531257
# sample 4503:
# reference surrogate loss: 0.00027495829609969213
# sample 4504:
# reference surrogate loss: 0.00022582770016654763
# sample 4505:
# reference surrogate loss: 0.00018576886340060383
# sample 4506:
# reference surrogate loss: 0.00025749903907201777
# sample 4507:
# reference surrogate loss: 0.00023064808979356144
# sample 4508:
# reference surrogate loss: 0.00017224577095520388
# sample 4509:
# reference surrogate loss: 0.00014251010423005361
# sample 4510:
# reference surrogate loss: 0.00022094822162310734
# sample 4511:
# reference surrogate loss: 0.00016545408331958278
# sample 4512:
# reference surrogate loss: 0.0005317159920659176
# sample 4513:
# reference surrogate loss: 0.0003090513937227257
# sample 4514:
# reference surrogate loss: 9.764782060339705e-05
# sample 4515:
# reference surrogate loss: 0.00024325803515679034
# sample 4516:
# reference surrogate loss: 0.00013599188826907138
# sample 4517:
# reference surrogate loss: 0.00038302146549873406
# sample 4518:
# reference surrogate loss: 0.0004219192679000283
# sample 4519:
# reference surrogate loss: 0.0002812609963993573
# sample 4520:
# reference surrogate loss: 0.00037061132025684174
# sample 4521:
# reference surrogate loss: 0.00030554532843729554
# sample 4522:
# reference surrogate loss: 0.0003017966667218097
# sample 4523:
# reference surrogate loss: 0.0003392172821174988
# sample 4524:
# reference surrogate loss: 0.00039031777754905406
# sample 4525:
# reference surrogate loss: 0.0002566364128240295
# sample 4526:
# reference surrogate loss: 0.0001911935897693784
# sample 4527:
# reference surrogate loss: 0.0003676450374814344
# sample 4528:
# reference surrogate loss: 0.0005247374835251062
# sample 4529:
# reference surrogate loss: 0.00035792112106891594
# sample 4530:
# reference surrogate loss: 0.00025861663546100644
# sample 4531:
# reference surrogate loss: 0.00016243453543718367
# sample 4532:
# reference surrogate loss: 0.00036525723626001927
# sample 4533:
# reference surrogate loss: 0.0003197507163077429
# sample 4534:
# reference surrogate loss: 0.0002127133990974528
# sample 4535:
# reference surrogate loss: 0.0005912998669370673
# sample 4536:
# reference surrogate loss: 0.00012268376235535783
# sample 4537:
# reference surrogate loss: 0.0001587207430580051
# sample 4538:
# reference surrogate loss: 0.00011969556814017679
# sample 4539:
# reference surrogate loss: 0.0003460799033043749
# sample 4540:
# reference surrogate loss: 0.0008226692580981521
# sample 4541:
# reference surrogate loss: 0.00035240863431584835
# sample 4542:
# reference surrogate loss: 0.0005023504603065554
# sample 4543:
# reference surrogate loss: 0.00015935877075778926
# sample 4544:
# reference surrogate loss: 0.0002756682351183759
# sample 4545:
# reference surrogate loss: 0.00046123885228976924
# sample 4546:
# reference surrogate loss: 0.0006390945591236985
# sample 4547:
# reference surrogate loss: 0.00057073859562351
# sample 4548:
# reference surrogate loss: 0.00031649816746259773
# sample 4549:
# reference surrogate loss: 0.0002622403907126536
# sample 4550:
# reference surrogate loss: 0.00012551964574170071
# sample 4551:
# reference surrogate loss: 0.0006560895692566682
# sample 4552:
# reference surrogate loss: 0.0003398525867193136
# sample 4553:
# reference surrogate loss: 0.0011552890486794531
# sample 4554:
# reference surrogate loss: 0.00023354780077378123
# sample 4555:
# reference surrogate loss: 0.00019074597270307692
# sample 4556:
# reference surrogate loss: 0.00016366246616361657
# sample 4557:
# reference surrogate loss: 0.0004784491777380939
# sample 4558:
# reference surrogate loss: 0.0001619089920106287
# sample 4559:
# reference surrogate loss: 0.0006388879878942433
# sample 4560:
# reference surrogate loss: 0.00018636210942246656
# sample 4561:
# reference surrogate loss: 0.0007267224101836778
# sample 4562:
# reference surrogate loss: 0.0003821028083303979
# sample 4563:
# reference surrogate loss: 0.00022769683595047496
# sample 4564:
# reference surrogate loss: 0.00031155150142558874
# sample 4565:
# reference surrogate loss: 0.00022807435923111186
# sample 4566:
# reference surrogate loss: 0.00016453197660060148
# sample 4567:
# reference surrogate loss: 0.000404730535704223
# sample 4568:
# reference surrogate loss: 0.00029555934903080505
# sample 4569:
# reference surrogate loss: 0.0004952367636050781
# sample 4570:
# reference surrogate loss: 0.00038365391982941865
# sample 4571:
# reference surrogate loss: 0.0002195076637192539
# sample 4572:
# reference surrogate loss: 0.001642523744445068
# sample 4573:
# reference surrogate loss: 8.784052974819545e-05
# sample 4574:
# reference surrogate loss: 0.0002512725267562743
# sample 4575:
# reference surrogate loss: 0.00015191863694874463
# sample 4576:
# reference surrogate loss: 0.00028675773830899587
# sample 4577:
# reference surrogate loss: 0.00019965236051011637
# sample 4578:
# reference surrogate loss: 0.0002523145126207549
# sample 4579:
# reference surrogate loss: 0.0001881738481646078
# sample 4580:
# reference surrogate loss: 0.0002032817339501225
# sample 4581:
# reference surrogate loss: 0.0002226204356272632
# sample 4582:
# reference surrogate loss: 0.0005361862201944678
# sample 4583:
# reference surrogate loss: 0.00025047001268019287
# sample 4584:
# reference surrogate loss: 0.0006967087261215976
# sample 4585:
# reference surrogate loss: 0.0001916240541308678
# sample 4586:
# reference surrogate loss: 0.00021816695383036766
# sample 4587:
# reference surrogate loss: 0.0003443685478887737
# sample 4588:
# reference surrogate loss: 0.0006843254772017637
# sample 4589:
# reference surrogate loss: 0.00022772083194011472
# sample 4590:
# reference surrogate loss: 0.0005487278231290915
# sample 4591:
# reference surrogate loss: 0.0003484328750282817
# sample 4592:
# reference surrogate loss: 0.0007070352973421734
# sample 4593:
# reference surrogate loss: 0.0003877718976066369
# sample 4594:
# reference surrogate loss: 0.00033514616667429387
# sample 4595:
# reference surrogate loss: 0.0002661532371688313
# sample 4596:
# reference surrogate loss: 0.0008437891111001683
# sample 4597:
# reference surrogate loss: 0.0004133651944808747
# sample 4598:
# reference surrogate loss: 9.6728604696672e-05
# sample 4599:
# reference surrogate loss: 0.0001402246456478906
# sample 4600:
# reference surrogate loss: 0.00042810908972201744
# sample 4601:
# reference surrogate loss: 0.0002504420386599815
# sample 4602:
# reference surrogate loss: 0.0004620534325692205
# sample 4603:
# reference surrogate loss: 0.00016710891415550044
# sample 4604:
# reference surrogate loss: 0.0009552432660422383
# sample 4605:
# reference surrogate loss: 0.0002492926845174548
# sample 4606:
# reference surrogate loss: 0.00011944789637952091
# sample 4607:
# reference surrogate loss: 0.0007655740112904041
# sample 4608:
# reference surrogate loss: 0.00012220465402612568
# sample 4609:
# reference surrogate loss: 0.00042960566804794986
# sample 4610:
# reference surrogate loss: 0.00022640122046269084
# sample 4611:
# reference surrogate loss: 0.00021401659888309332
# sample 4612:
# reference surrogate loss: 0.0006854826681852444
# sample 4613:
# reference surrogate loss: 0.0004613464798839395
# sample 4614:
# reference surrogate loss: 0.00020319626263476387
# sample 4615:
# reference surrogate loss: 0.0005066530587725104
# sample 4616:
# reference surrogate loss: 0.0001932249726059876
# sample 4617:
# reference surrogate loss: 0.00016574212005293631
# sample 4618:
# reference surrogate loss: 0.0006749267024108718
# sample 4619:
# reference surrogate loss: 0.00034152917144969486
# sample 4620:
# reference surrogate loss: 0.0004284114044086351
# sample 4621:
# reference surrogate loss: 0.000128211892751251
# sample 4622:
# reference surrogate loss: 0.00045204294600620365
# sample 4623:
# reference surrogate loss: 0.0006086295733123137
# sample 4624:
# reference surrogate loss: 0.0006630031011680693
# sample 4625:
# reference surrogate loss: 0.00014268701728137323
# sample 4626:
# reference surrogate loss: 0.0002738851400689857
# sample 4627:
# reference surrogate loss: 0.0003734667830774807
# sample 4628:
# reference surrogate loss: 0.0004592762015382945
# sample 4629:
# reference surrogate loss: 0.00029080913257417684
# sample 4630:
# reference surrogate loss: 0.000174697543143143
# sample 4631:
# reference surrogate loss: 0.00038185127791656726
# sample 4632:
# reference surrogate loss: 0.00034912275976983764
# sample 4633:
# reference surrogate loss: 0.00016774710535671922
# sample 4634:
# reference surrogate loss: 0.0003620795511984909
# sample 4635:
# reference surrogate loss: 0.0009655612125103463
# sample 4636:
# reference surrogate loss: 0.0003307252483488732
# sample 4637:
# reference surrogate loss: 0.00025179671442732143
# sample 4638:
# reference surrogate loss: 0.00015961810128173326
# sample 4639:
# reference surrogate loss: 0.0005271900306538235
# sample 4640:
# reference surrogate loss: 0.0004927524114357595
# sample 4641:
# reference surrogate loss: 0.00011439745393015954
# sample 4642:
# reference surrogate loss: 0.00034726986163091667
# sample 4643:
# reference surrogate loss: 0.0003265641452152579
# sample 4644:
# reference surrogate loss: 0.0006169934800510646
# sample 4645:
# reference surrogate loss: 0.0003358837658171687
# sample 4646:
# reference surrogate loss: 0.00021445321841961906
# sample 4647:
# reference surrogate loss: 0.000970775645126043
# sample 4648:
# reference surrogate loss: 0.0001771594098938234
# sample 4649:
# reference surrogate loss: 0.0008545925412606348
# sample 4650:
# reference surrogate loss: 0.00022323609923025067
# sample 4651:
# reference surrogate loss: 0.0008056156194791164
# sample 4652:
# reference surrogate loss: 0.0008409077877191695
# sample 4653:
# reference surrogate loss: 0.0009877531406843332
# sample 4654:
# reference surrogate loss: 0.0001925723860776163
# sample 4655:
# reference surrogate loss: 0.00022100616932951844
# sample 4656:
# reference surrogate loss: 0.00035248163367063157
# sample 4657:
# reference surrogate loss: 0.0001894342803077098
# sample 4658:
# reference surrogate loss: 0.00045306477440765214
# sample 4659:
# reference surrogate loss: 0.00018429164015754118
# sample 4660:
# reference surrogate loss: 0.00029149920921045513
# sample 4661:
# reference surrogate loss: 0.000358888279645031
# sample 4662:
# reference surrogate loss: 0.000527427137228198
# sample 4663:
# reference surrogate loss: 0.00015808887297508178
# sample 4664:
# reference surrogate loss: 0.0002743104070148661
# sample 4665:
# reference surrogate loss: 0.0003089749242077833
# sample 4666:
# reference surrogate loss: 0.0001484192744445334
# sample 4667:
# reference surrogate loss: 0.00021746456149940308
# sample 4668:
# reference surrogate loss: 0.00022103583902266521
# sample 4669:
# reference surrogate loss: 0.0004219765694128963
# sample 4670:
# reference surrogate loss: 0.0006903007985847864
# sample 4671:
# reference surrogate loss: 0.00015615400243440547
# sample 4672:
# reference surrogate loss: 0.0006959393325520757
# sample 4673:
# reference surrogate loss: 0.00017596188863033824
# sample 4674:
# reference surrogate loss: 0.00035915264397634594
# sample 4675:
# reference surrogate loss: 0.00017625155573175455
# sample 4676:
# reference surrogate loss: 0.00023854898957131887
# sample 4677:
# reference surrogate loss: 0.00023591922877685967
# sample 4678:
# reference surrogate loss: 0.00025294943790288293
# sample 4679:
# reference surrogate loss: 0.00031673218353445165
# sample 4680:
# reference surrogate loss: 0.0002978131185227273
# sample 4681:
# reference surrogate loss: 0.0001341287217244691
# sample 4682:
# reference surrogate loss: 0.00039399813699203534
# sample 4683:
# reference surrogate loss: 0.000899974758850508
# sample 4684:
# reference surrogate loss: 0.0004032390007691067
# sample 4685:
# reference surrogate loss: 0.00045777980077832403
# sample 4686:
# reference surrogate loss: 0.0004158445069060157
# sample 4687:
# reference surrogate loss: 0.0016992766018673056
# sample 4688:
# reference surrogate loss: 0.000468226706912489
# sample 4689:
# reference surrogate loss: 0.00032290933435130675
# sample 4690:
# reference surrogate loss: 0.0003275730244578501
# sample 4691:
# reference surrogate loss: 0.00021886353930322677
# sample 4692:
# reference surrogate loss: 0.000373424490148766
# sample 4693:
# reference surrogate loss: 0.000285050196229264
# sample 4694:
# reference surrogate loss: 0.0005399096451161878
# sample 4695:
# reference surrogate loss: 0.000769127561802252
# sample 4696:
# reference surrogate loss: 0.0005565147831922967
# sample 4697:
# reference surrogate loss: 0.0004497507979539517
# sample 4698:
# reference surrogate loss: 0.0001800085123742079
# sample 4699:
# reference surrogate loss: 0.0003203775259101871
# sample 4700:
# reference surrogate loss: 0.00016257130830132915
# sample 4701:
# reference surrogate loss: 0.0002833938330744079
# sample 4702:
# reference surrogate loss: 0.0002349022678254098
# sample 4703:
# reference surrogate loss: 0.0008984850619622176
# sample 4704:
# reference surrogate loss: 0.00018828585619945493
# sample 4705:
# reference surrogate loss: 0.00038065639623119374
# sample 4706:
# reference surrogate loss: 0.00031224574711297137
# sample 4707:
# reference surrogate loss: 0.00015251227044354998
# sample 4708:
# reference surrogate loss: 0.0005483804803834147
# sample 4709:
# reference surrogate loss: 0.0005182511784826982
# sample 4710:
# reference surrogate loss: 0.000582584329106961
# sample 4711:
# reference surrogate loss: 0.0003106232228367034
# sample 4712:
# reference surrogate loss: 0.00016965704078497623
# sample 4713:
# reference surrogate loss: 0.00012410628087544673
# sample 4714:
# reference surrogate loss: 0.0004119349190059296
# sample 4715:
# reference surrogate loss: 0.00019673757986238272
# sample 4716:
# reference surrogate loss: 0.00020814143941660923
# sample 4717:
# reference surrogate loss: 0.00031463495979289213
# sample 4718:
# reference surrogate loss: 0.0001793047068514575
# sample 4719:
# reference surrogate loss: 0.0007424841697329931
# sample 4720:
# reference surrogate loss: 0.00015247021356179502
# sample 4721:
# reference surrogate loss: 0.0002433495367444305
# sample 4722:
# reference surrogate loss: 0.0005077972312772516
# sample 4723:
# reference surrogate loss: 0.00028900012855026525
# sample 4724:
# reference surrogate loss: 0.00040941899096491596
# sample 4725:
# reference surrogate loss: 0.0005541077132735772
# sample 4726:
# reference surrogate loss: 0.0004497488506018943
# sample 4727:
# reference surrogate loss: 0.0006665329352277816
# sample 4728:
# reference surrogate loss: 0.00016595420100973257
# sample 4729:
# reference surrogate loss: 0.0002542503151499176
# sample 4730:
# reference surrogate loss: 0.0002503043805359706
# sample 4731:
# reference surrogate loss: 0.0004528141707065281
# sample 4732:
# reference surrogate loss: 0.0004481213785281213
# sample 4733:
# reference surrogate loss: 0.00014472440313406665
# sample 4734:
# reference surrogate loss: 0.0001497748333956217
# sample 4735:
# reference surrogate loss: 0.0004763765533035702
# sample 4736:
# reference surrogate loss: 0.00028329287585182605
# sample 4737:
# reference surrogate loss: 0.0002484619954474798
# sample 4738:
# reference surrogate loss: 0.0002311402826622455
# sample 4739:
# reference surrogate loss: 0.0007620641669647821
# sample 4740:
# reference surrogate loss: 0.001299293137750901
# sample 4741:
# reference surrogate loss: 0.0002418165351072421
# sample 4742:
# reference surrogate loss: 0.000826247300278693
# sample 4743:
# reference surrogate loss: 0.00022103593354061424
# sample 4744:
# reference surrogate loss: 0.00015238577565357403
# sample 4745:
# reference surrogate loss: 0.00021365581260579525
# sample 4746:
# reference surrogate loss: 0.00033708284800471056
# sample 4747:
# reference surrogate loss: 0.0005890094657605704
# sample 4748:
# reference surrogate loss: 0.0002761233123993456
# sample 4749:
# reference surrogate loss: 0.0006605208045480371
# sample 4750:
# reference surrogate loss: 0.0006744118223249718
# sample 4751:
# reference surrogate loss: 0.00015897952096932677
# sample 4752:
# reference surrogate loss: 0.0003601807322608508
# sample 4753:
# reference surrogate loss: 0.00026050667265753447
# sample 4754:
# reference surrogate loss: 0.0002684717480585519
# sample 4755:
# reference surrogate loss: 0.0002021124935525087
# sample 4756:
# reference surrogate loss: 0.00022697439412189269
# sample 4757:
# reference surrogate loss: 0.00021177706013686404
# sample 4758:
# reference surrogate loss: 0.0012034464820602775
# sample 4759:
# reference surrogate loss: 0.00044352991872309566
# sample 4760:
# reference surrogate loss: 0.0005486881770604413
# sample 4761:
# reference surrogate loss: 0.0003525813658007415
# sample 4762:
# reference surrogate loss: 0.00016628642528648818
# sample 4763:
# reference surrogate loss: 0.00035531622527296136
# sample 4764:
# reference surrogate loss: 0.000830187014855932
# sample 4765:
# reference surrogate loss: 0.00014243455280094075
# sample 4766:
# reference surrogate loss: 0.0004036009461338974
# sample 4767:
# reference surrogate loss: 0.00020393925463380036
# sample 4768:
# reference surrogate loss: 0.00021599009115291778
# sample 4769:
# reference surrogate loss: 0.00015031701807277642
# sample 4770:
# reference surrogate loss: 0.00021201963318495665
# sample 4771:
# reference surrogate loss: 0.0003518386868941459
# sample 4772:
# reference surrogate loss: 0.00038671741156592887
# sample 4773:
# reference surrogate loss: 0.00028868816827998245
# sample 4774:
# reference surrogate loss: 0.000806304826355797
# sample 4775:
# reference surrogate loss: 0.0001767816116173826
# sample 4776:
# reference surrogate loss: 0.00027519964802147356
# sample 4777:
# reference surrogate loss: 0.0008946974342693981
# sample 4778:
# reference surrogate loss: 0.00026383368688454034
# sample 4779:
# reference surrogate loss: 0.0004381717149368747
# sample 4780:
# reference surrogate loss: 0.00014784504735088078
# sample 4781:
# reference surrogate loss: 0.0002850517879651182
# sample 4782:
# reference surrogate loss: 0.0002376767520000378
# sample 4783:
# reference surrogate loss: 0.0007369014186928702
# sample 4784:
# reference surrogate loss: 0.0004134941056788133
# sample 4785:
# reference surrogate loss: 0.0003475149448184389
# sample 4786:
# reference surrogate loss: 0.0004873306305561709
# sample 4787:
# reference surrogate loss: 0.00016023182311997175
# sample 4788:
# reference surrogate loss: 0.00018089100254781165
# sample 4789:
# reference surrogate loss: 0.00018763350393657952
# sample 4790:
# reference surrogate loss: 0.000282690073655667
# sample 4791:
# reference surrogate loss: 0.00036116452811341127
# sample 4792:
# reference surrogate loss: 0.00016888993857988588
# sample 4793:
# reference surrogate loss: 0.0002605028612170379
# sample 4794:
# reference surrogate loss: 0.0002543586160168587
# sample 4795:
# reference surrogate loss: 0.0002199076174878023
# sample 4796:
# reference surrogate loss: 0.00020356035321356103
# sample 4797:
# reference surrogate loss: 0.00015862532674604246
# sample 4798:
# reference surrogate loss: 0.00012701447564844592
# sample 4799:
# reference surrogate loss: 0.00021330005450637124
# sample 4800:
# reference surrogate loss: 0.00039085140394812257
# sample 4801:
# reference surrogate loss: 0.0003238656259565431
# sample 4802:
# reference surrogate loss: 0.00018071220906157315
# sample 4803:
# reference surrogate loss: 0.0003315514805943831
# sample 4804:
# reference surrogate loss: 0.00021122834374542876
# sample 4805:
# reference surrogate loss: 0.0012965773819477722
# sample 4806:
# reference surrogate loss: 0.00015637776327737107
# sample 4807:
# reference surrogate loss: 0.0003379121643432015
# sample 4808:
# reference surrogate loss: 0.00025105244969814144
# sample 4809:
# reference surrogate loss: 0.00035316332592083555
# sample 4810:
# reference surrogate loss: 0.0002009005287704202
# sample 4811:
# reference surrogate loss: 0.0004921420443984026
# sample 4812:
# reference surrogate loss: 0.0003030779769315206
# sample 4813:
# reference surrogate loss: 0.0002928793798631091
# sample 4814:
# reference surrogate loss: 0.0005188388393668752
# sample 4815:
# reference surrogate loss: 0.00032882670006606496
# sample 4816:
# reference surrogate loss: 0.0002714739312643655
# sample 4817:
# reference surrogate loss: 0.00027246720712925665
# sample 4818:
# reference surrogate loss: 0.00046233028291653433
# sample 4819:
# reference surrogate loss: 0.0005476822837913176
# sample 4820:
# reference surrogate loss: 0.00026741798374874115
# sample 4821:
# reference surrogate loss: 0.0005935041252904671
# sample 4822:
# reference surrogate loss: 0.00019666662550044123
# sample 4823:
# reference surrogate loss: 0.000407568667119218
# sample 4824:
# reference surrogate loss: 0.000150960785123333
# sample 4825:
# reference surrogate loss: 0.00026496985762913816
# sample 4826:
# reference surrogate loss: 0.0005321882402058442
# sample 4827:
# reference surrogate loss: 0.0008048300390135488
# sample 4828:
# reference surrogate loss: 0.0002286186603606133
# sample 4829:
# reference surrogate loss: 0.0005724139400895556
# sample 4830:
# reference surrogate loss: 0.0006176610086696677
# sample 4831:
# reference surrogate loss: 0.0002944007031389084
# sample 4832:
# reference surrogate loss: 0.0009095904614442318
# sample 4833:
# reference surrogate loss: 0.0004214450984052487
# sample 4834:
# reference surrogate loss: 0.0004561084802194859
# sample 4835:
# reference surrogate loss: 0.00017788926986184173
# sample 4836:
# reference surrogate loss: 0.000218442235210059
# sample 4837:
# reference surrogate loss: 0.0004879963204420523
# sample 4838:
# reference surrogate loss: 0.00036369256747748047
# sample 4839:
# reference surrogate loss: 0.000106287160182017
# sample 4840:
# reference surrogate loss: 0.00026434349828141634
# sample 4841:
# reference surrogate loss: 0.0004180705974914378
# sample 4842:
# reference surrogate loss: 0.0002469475436879254
# sample 4843:
# reference surrogate loss: 0.0007976445120649878
# sample 4844:
# reference surrogate loss: 0.00030447360086527375
# sample 4845:
# reference surrogate loss: 0.00022565670015262107
# sample 4846:
# reference surrogate loss: 0.00016887433488399495
# sample 4847:
# reference surrogate loss: 0.00021364491324105117
# sample 4848:
# reference surrogate loss: 0.000566421771703407
# sample 4849:
# reference surrogate loss: 0.0005063633660231659
# sample 4850:
# reference surrogate loss: 0.00015950407671860845
# sample 4851:
# reference surrogate loss: 0.0012443716817007733
# sample 4852:
# reference surrogate loss: 0.0002788613848927479
# sample 4853:
# reference surrogate loss: 0.00022952616529425818
# sample 4854:
# reference surrogate loss: 0.0002595641558644779
# sample 4855:
# reference surrogate loss: 0.0001731819581962668
# sample 4856:
# reference surrogate loss: 0.0005459080127705462
# sample 4857:
# reference surrogate loss: 0.0002554527470755019
# sample 4858:
# reference surrogate loss: 0.00033009527217386925
# sample 4859:
# reference surrogate loss: 0.0004787717339771458
# sample 4860:
# reference surrogate loss: 0.0005335744737420267
# sample 4861:
# reference surrogate loss: 0.0004211753913634375
# sample 4862:
# reference surrogate loss: 0.0003888730433234677
# sample 4863:
# reference surrogate loss: 0.00018287568435781942
# sample 4864:
# reference surrogate loss: 0.00030681227186457605
# sample 4865:
# reference surrogate loss: 0.0004300041251812381
# sample 4866:
# reference surrogate loss: 0.0002729390258495723
# sample 4867:
# reference surrogate loss: 0.0009906915256516768
# sample 4868:
# reference surrogate loss: 0.00033995566785671727
# sample 4869:
# reference surrogate loss: 0.00021387893353175258
# sample 4870:
# reference surrogate loss: 0.00025834958871251423
# sample 4871:
# reference surrogate loss: 0.00013086758982194802
# sample 4872:
# reference surrogate loss: 0.0003416834392326873
# sample 4873:
# reference surrogate loss: 0.0003891274703016201
# sample 4874:
# reference surrogate loss: 0.00042664832799022
# sample 4875:
# reference surrogate loss: 0.0006249708777350538
# sample 4876:
# reference surrogate loss: 0.0005886396658068005
# sample 4877:
# reference surrogate loss: 0.0003538700447816012
# sample 4878:
# reference surrogate loss: 0.0006716799918913274
# sample 4879:
# reference surrogate loss: 0.00024705740965336176
# sample 4880:
# reference surrogate loss: 0.00024342546203648396
# sample 4881:
# reference surrogate loss: 0.00047000265752972226
# sample 4882:
# reference surrogate loss: 0.00018962376600062392
# sample 4883:
# reference surrogate loss: 0.0002350011215961345
# sample 4884:
# reference surrogate loss: 0.0005290848019021688
# sample 4885:
# reference surrogate loss: 0.000497336050861108
# sample 4886:
# reference surrogate loss: 0.0003905419781433661
# sample 4887:
# reference surrogate loss: 0.00036315481820370366
# sample 4888:
# reference surrogate loss: 0.00015615184895234613
# sample 4889:
# reference surrogate loss: 0.00015920074928565953
# sample 4890:
# reference surrogate loss: 0.000582869615207704
# sample 4891:
# reference surrogate loss: 0.00038030537394084796
# sample 4892:
# reference surrogate loss: 0.00018605843698127345
# sample 4893:
# reference surrogate loss: 0.00015588248891007517
# sample 4894:
# reference surrogate loss: 0.0003176352568659002
# sample 4895:
# reference surrogate loss: 0.0002220751337085325
# sample 4896:
# reference surrogate loss: 0.0002269438461242057
# sample 4897:
# reference surrogate loss: 0.00018750347367579856
# sample 4898:
# reference surrogate loss: 0.0002702882387681793
# sample 4899:
# reference surrogate loss: 0.0002318443741000653
# sample 4900:
# reference surrogate loss: 0.00021142892969949756
# sample 4901:
# reference surrogate loss: 0.00024655074893753515
# sample 4902:
# reference surrogate loss: 0.00011345681410568353
# sample 4903:
# reference surrogate loss: 0.00020579704510925723
# sample 4904:
# reference surrogate loss: 0.00043586098868297896
# sample 4905:
# reference surrogate loss: 0.0002952151051245355
# sample 4906:
# reference surrogate loss: 0.0008452359500275008
# sample 4907:
# reference surrogate loss: 0.0006574826280068002
# sample 4908:
# reference surrogate loss: 0.00028501415323312074
# sample 4909:
# reference surrogate loss: 0.0007071367513982185
# sample 4910:
# reference surrogate loss: 0.0002510669514592667
# sample 4911:
# reference surrogate loss: 0.00031658069271167655
# sample 4912:
# reference surrogate loss: 0.0003301365401608969
# sample 4913:
# reference surrogate loss: 0.001233011483657842
# sample 4914:
# reference surrogate loss: 0.00014669773520004092
# sample 4915:
# reference surrogate loss: 0.0005465731194205237
# sample 4916:
# reference surrogate loss: 0.00016741585848967233
# sample 4917:
# reference surrogate loss: 0.000433019398105694
# sample 4918:
# reference surrogate loss: 0.00012833243770948854
# sample 4919:
# reference surrogate loss: 0.00031785096769376686
# sample 4920:
# reference surrogate loss: 0.00025852449754060203
# sample 4921:
# reference surrogate loss: 0.00020186499564500693
# sample 4922:
# reference surrogate loss: 0.00031455706419492024
# sample 4923:
# reference surrogate loss: 0.000186350191436091
# sample 4924:
# reference surrogate loss: 0.0008576843180438942
# sample 4925:
# reference surrogate loss: 0.00015653272895188586
# sample 4926:
# reference surrogate loss: 0.00022456345773291808
# sample 4927:
# reference surrogate loss: 0.00019482759830213858
# sample 4928:
# reference surrogate loss: 0.00036640627577866347
# sample 4929:
# reference surrogate loss: 0.00018145265761804197
# sample 4930:
# reference surrogate loss: 0.00015291194332767155
# sample 4931:
# reference surrogate loss: 0.000265980011424638
# sample 4932:
# reference surrogate loss: 0.0003438005535150168
# sample 4933:
# reference surrogate loss: 0.0005964088182444094
# sample 4934:
# reference surrogate loss: 0.0002915291820442256
# sample 4935:
# reference surrogate loss: 0.0005794241994103722
# sample 4936:
# reference surrogate loss: 0.00032311424978459513
# sample 4937:
# reference surrogate loss: 0.0003653081699861449
# sample 4938:
# reference surrogate loss: 0.00032571143952830894
# sample 4939:
# reference surrogate loss: 0.00021739530495024084
# sample 4940:
# reference surrogate loss: 0.0003481816883581512
# sample 4941:
# reference surrogate loss: 0.00020786120470472902
# sample 4942:
# reference surrogate loss: 0.0002639893309588359
# sample 4943:
# reference surrogate loss: 0.0003624125787913268
# sample 4944:
# reference surrogate loss: 0.0002054324433458099
# sample 4945:
# reference surrogate loss: 0.00037680149352947723
# sample 4946:
# reference surrogate loss: 0.0004634413857609321
# sample 4947:
# reference surrogate loss: 0.00016541248024104505
# sample 4948:
# reference surrogate loss: 0.0007761978422504701
# sample 4949:
# reference surrogate loss: 0.00019177097207889737
# sample 4950:
# reference surrogate loss: 0.0005992874389617597
# sample 4951:
# reference surrogate loss: 0.00042543437745767854
# sample 4952:
# reference surrogate loss: 0.00017218121514983586
# sample 4953:
# reference surrogate loss: 0.0005404237091399811
# sample 4954:
# reference surrogate loss: 0.0007979128590072104
# sample 4955:
# reference surrogate loss: 0.0005393665028496919
# sample 4956:
# reference surrogate loss: 0.000487862503810943
# sample 4957:
# reference surrogate loss: 0.00022391454081516216
# sample 4958:
# reference surrogate loss: 0.00014882270412064358
# sample 4959:
# reference surrogate loss: 0.00010110582979061533
# sample 4960:
# reference surrogate loss: 0.0004710732864061651
# sample 4961:
# reference surrogate loss: 0.0008925676297089069
# sample 4962:
# reference surrogate loss: 0.0006201124225717614
# sample 4963:
# reference surrogate loss: 0.00017484561137415255
# sample 4964:
# reference surrogate loss: 0.0005675635244142274
# sample 4965:
# reference surrogate loss: 0.0004482788866320142
# sample 4966:
# reference surrogate loss: 0.0001602862758103285
# sample 4967:
# reference surrogate loss: 0.0002443760028583153
# sample 4968:
# reference surrogate loss: 0.00041859458613746625
# sample 4969:
# reference surrogate loss: 0.00018419114653389634
# sample 4970:
# reference surrogate loss: 0.0006115700460607165
# sample 4971:
# reference surrogate loss: 0.00020101602328792545
# sample 4972:
# reference surrogate loss: 0.0002144026441837088
# sample 4973:
# reference surrogate loss: 0.000697066763602816
# sample 4974:
# reference surrogate loss: 0.00041573794767657546
# sample 4975:
# reference surrogate loss: 0.0002481819286055398
# sample 4976:
# reference surrogate loss: 0.0001572881944738036
# sample 4977:
# reference surrogate loss: 0.00018750534723110945
# sample 4978:
# reference surrogate loss: 0.00032571447296980693
# sample 4979:
# reference surrogate loss: 0.0003056441579603053
# sample 4980:
# reference surrogate loss: 0.0003341442531128447
# sample 4981:
# reference surrogate loss: 0.00046393158852708893
# sample 4982:
# reference surrogate loss: 0.0007125738574731422
# sample 4983:
# reference surrogate loss: 0.00010785707402738431
# sample 4984:
# reference surrogate loss: 0.0004302176393824464
# sample 4985:
# reference surrogate loss: 0.00019341267126948836
# sample 4986:
# reference surrogate loss: 0.00022106032422408717
# sample 4987:
# reference surrogate loss: 0.0005276662627884399
# sample 4988:
# reference surrogate loss: 0.00018461648993373103
# sample 4989:
# reference surrogate loss: 0.0001515586898388488
# sample 4990:
# reference surrogate loss: 0.00033588402850148746
# sample 4991:
# reference surrogate loss: 0.00017641684124547474
# sample 4992:
# reference surrogate loss: 0.0004334607850375871
# sample 4993:
# reference surrogate loss: 0.0005566573346422743
# sample 4994:
# reference surrogate loss: 0.0008100402950690366
# sample 4995:
# reference surrogate loss: 0.000740600840653638
# sample 4996:
# reference surrogate loss: 0.00016876360503736976
# sample 4997:
# reference surrogate loss: 0.0003629102889564084
# sample 4998:
# reference surrogate loss: 0.00043344952176860296
# sample 4999:
# reference surrogate loss: 0.000560257429176092
#
# number of POD basi: 64
# mean reference surrogate loss: 3.71e-04
# std reference surrogate loss: 2.31e-04

# %%
reference_surrogate_loss_list = []
for i in range(valid_start_index, valid_start_index + num_samples_for_reference_surrogate_loss):
    print(f'sample {i}:')
    reference_surrogate_loss = surrogate_loss(reference_reduced_minimizers[i], i, sub_dim=128)
    print(f'reference surrogate loss: {reference_surrogate_loss.item()}')
    reference_surrogate_loss_list.append(reference_surrogate_loss.item())
print("")
print("number of POD basi: 128")
print(f'mean reference surrogate loss: {np.mean(reference_surrogate_loss_list):.2e}')
print(f'std reference surrogate loss: {np.std(reference_surrogate_loss_list):.2e}')
# Out:
# sample 4500:
# reference surrogate loss: 0.00010218305421294538
# sample 4501:
# reference surrogate loss: 0.0001230687282425258
# sample 4502:
# reference surrogate loss: 0.00011238575568350839
# sample 4503:
# reference surrogate loss: 0.00012242223835334798
# sample 4504:
# reference surrogate loss: 6.425059196391025e-05
# sample 4505:
# reference surrogate loss: 7.004457719506085e-05
# sample 4506:
# reference surrogate loss: 9.061663736242842e-05
# sample 4507:
# reference surrogate loss: 9.046295523718051e-05
# sample 4508:
# reference surrogate loss: 8.838564563484752e-05
# sample 4509:
# reference surrogate loss: 8.526154847898759e-05
# sample 4510:
# reference surrogate loss: 0.00014081604340288045
# sample 4511:
# reference surrogate loss: 0.00012143582778989526
# sample 4512:
# reference surrogate loss: 8.094461445273815e-05
# sample 4513:
# reference surrogate loss: 8.15948096621888e-05
# sample 4514:
# reference surrogate loss: 7.603310732196e-05
# sample 4515:
# reference surrogate loss: 0.00010740180345325534
# sample 4516:
# reference surrogate loss: 8.733160486529279e-05
# sample 4517:
# reference surrogate loss: 0.00011853639230885449
# sample 4518:
# reference surrogate loss: 0.0001469538232030665
# sample 4519:
# reference surrogate loss: 0.00011793979490870576
# sample 4520:
# reference surrogate loss: 9.889297655374385e-05
# sample 4521:
# reference surrogate loss: 9.685635054035302e-05
# sample 4522:
# reference surrogate loss: 0.00015260216716894703
# sample 4523:
# reference surrogate loss: 0.00010263416259292946
# sample 4524:
# reference surrogate loss: 0.00013947233301370154
# sample 4525:
# reference surrogate loss: 0.00011873751584268177
# sample 4526:
# reference surrogate loss: 0.00014566840976315554
# sample 4527:
# reference surrogate loss: 0.00010237977995974923
# sample 4528:
# reference surrogate loss: 0.00013372374149245303
# sample 4529:
# reference surrogate loss: 0.00010362704507360654
# sample 4530:
# reference surrogate loss: 0.00012999797925394851
# sample 4531:
# reference surrogate loss: 9.131745750901032e-05
# sample 4532:
# reference surrogate loss: 0.00013848378900949143
# sample 4533:
# reference surrogate loss: 7.836358331103632e-05
# sample 4534:
# reference surrogate loss: 0.00012607182842350184
# sample 4535:
# reference surrogate loss: 0.00012723308821116497
# sample 4536:
# reference surrogate loss: 5.878260980352046e-05
# sample 4537:
# reference surrogate loss: 9.923203076933618e-05
# sample 4538:
# reference surrogate loss: 9.322858668370237e-05
# sample 4539:
# reference surrogate loss: 6.920022879230991e-05
# sample 4540:
# reference surrogate loss: 0.0001465053854174947
# sample 4541:
# reference surrogate loss: 0.0001767435877537693
# sample 4542:
# reference surrogate loss: 0.0001052683520830211
# sample 4543:
# reference surrogate loss: 0.00011395961227744777
# sample 4544:
# reference surrogate loss: 0.00011471276789043472
# sample 4545:
# reference surrogate loss: 0.0001488221786842825
# sample 4546:
# reference surrogate loss: 0.00010148021490619108
# sample 4547:
# reference surrogate loss: 0.00011987623500786526
# sample 4548:
# reference surrogate loss: 0.00010366070979639375
# sample 4549:
# reference surrogate loss: 0.00011403271244403435
# sample 4550:
# reference surrogate loss: 9.634718519335728e-05
# sample 4551:
# reference surrogate loss: 0.00012842601254869912
# sample 4552:
# reference surrogate loss: 0.00013965089472622871
# sample 4553:
# reference surrogate loss: 0.00012721041000918198
# sample 4554:
# reference surrogate loss: 5.0072712534987573e-05
# sample 4555:
# reference surrogate loss: 7.760110294818823e-05
# sample 4556:
# reference surrogate loss: 9.62670803681398e-05
# sample 4557:
# reference surrogate loss: 0.0001313704238870006
# sample 4558:
# reference surrogate loss: 0.00011262326160421665
# sample 4559:
# reference surrogate loss: 9.872922316422894e-05
# sample 4560:
# reference surrogate loss: 0.00010918169270235367
# sample 4561:
# reference surrogate loss: 0.00010923192973777418
# sample 4562:
# reference surrogate loss: 0.0001012222915566241
# sample 4563:
# reference surrogate loss: 7.641628525489885e-05
# sample 4564:
# reference surrogate loss: 7.219603324282176e-05
# sample 4565:
# reference surrogate loss: 0.00012636328666437713
# sample 4566:
# reference surrogate loss: 6.92650460500932e-05
# sample 4567:
# reference surrogate loss: 0.00014550965956594553
# sample 4568:
# reference surrogate loss: 9.445381271788733e-05
# sample 4569:
# reference surrogate loss: 0.00013094402271507377
# sample 4570:
# reference surrogate loss: 0.00012053843903303552
# sample 4571:
# reference surrogate loss: 0.00011386892573961305
# sample 4572:
# reference surrogate loss: 0.00017987390512952395
# sample 4573:
# reference surrogate loss: 5.768410380180278e-05
# sample 4574:
# reference surrogate loss: 0.00013286427476844054
# sample 4575:
# reference surrogate loss: 0.00010017969709785746
# sample 4576:
# reference surrogate loss: 8.426618882628745e-05
# sample 4577:
# reference surrogate loss: 9.561730363416565e-05
# sample 4578:
# reference surrogate loss: 0.00014993766446402823
# sample 4579:
# reference surrogate loss: 0.00011991244480791252
# sample 4580:
# reference surrogate loss: 9.539898812271908e-05
# sample 4581:
# reference surrogate loss: 8.233703789550795e-05
# sample 4582:
# reference surrogate loss: 0.00016528145921346216
# sample 4583:
# reference surrogate loss: 8.23279615089767e-05
# sample 4584:
# reference surrogate loss: 0.0001084362783612125
# sample 4585:
# reference surrogate loss: 0.00010584164441285182
# sample 4586:
# reference surrogate loss: 8.122001783461563e-05
# sample 4587:
# reference surrogate loss: 7.205369896090552e-05
# sample 4588:
# reference surrogate loss: 0.00016303426813824018
# sample 4589:
# reference surrogate loss: 6.954914571366544e-05
# sample 4590:
# reference surrogate loss: 8.970737691837982e-05
# sample 4591:
# reference surrogate loss: 0.00015874120981185236
# sample 4592:
# reference surrogate loss: 8.136824796323161e-05
# sample 4593:
# reference surrogate loss: 0.00010823036298446276
# sample 4594:
# reference surrogate loss: 9.743515543703118e-05
# sample 4595:
# reference surrogate loss: 0.00015175411129031424
# sample 4596:
# reference surrogate loss: 0.00011486553385919862
# sample 4597:
# reference surrogate loss: 0.00011141703199135655
# sample 4598:
# reference surrogate loss: 6.716041497489833e-05
# sample 4599:
# reference surrogate loss: 8.512557877060623e-05
# sample 4600:
# reference surrogate loss: 0.0001598416916537282
# sample 4601:
# reference surrogate loss: 9.989879413407898e-05
# sample 4602:
# reference surrogate loss: 0.00014179375635658964
# sample 4603:
# reference surrogate loss: 8.524849779956156e-05
# sample 4604:
# reference surrogate loss: 0.00013921639214165005
# sample 4605:
# reference surrogate loss: 8.166731807812688e-05
# sample 4606:
# reference surrogate loss: 8.163119561044319e-05
# sample 4607:
# reference surrogate loss: 0.00016721185586265896
# sample 4608:
# reference surrogate loss: 9.519345207786856e-05
# sample 4609:
# reference surrogate loss: 0.0001420105005944805
# sample 4610:
# reference surrogate loss: 0.00010129145334514256
# sample 4611:
# reference surrogate loss: 0.00011940131991483582
# sample 4612:
# reference surrogate loss: 8.362106205872522e-05
# sample 4613:
# reference surrogate loss: 0.00013623897841164023
# sample 4614:
# reference surrogate loss: 0.00011824532832371837
# sample 4615:
# reference surrogate loss: 9.27607607212888e-05
# sample 4616:
# reference surrogate loss: 0.00011592707083529774
# sample 4617:
# reference surrogate loss: 8.979781731643932e-05
# sample 4618:
# reference surrogate loss: 0.0001325803038172424
# sample 4619:
# reference surrogate loss: 0.000112163785179753
# sample 4620:
# reference surrogate loss: 0.00015025967677861907
# sample 4621:
# reference surrogate loss: 0.00010484763005380593
# sample 4622:
# reference surrogate loss: 0.00013838910192442988
# sample 4623:
# reference surrogate loss: 0.00012726103371618613
# sample 4624:
# reference surrogate loss: 0.00015744300544096035
# sample 4625:
# reference surrogate loss: 7.205262165888016e-05
# sample 4626:
# reference surrogate loss: 0.00014078314568921613
# sample 4627:
# reference surrogate loss: 0.00010364968967202515
# sample 4628:
# reference surrogate loss: 9.215591752798069e-05
# sample 4629:
# reference surrogate loss: 0.00010713810825246917
# sample 4630:
# reference surrogate loss: 0.00013249503802881257
# sample 4631:
# reference surrogate loss: 0.00010693306022413473
# sample 4632:
# reference surrogate loss: 0.0001157355090906087
# sample 4633:
# reference surrogate loss: 9.708206195457869e-05
# sample 4634:
# reference surrogate loss: 0.0001134516054350776
# sample 4635:
# reference surrogate loss: 0.0001163605495453357
# sample 4636:
# reference surrogate loss: 7.098164754415492e-05
# sample 4637:
# reference surrogate loss: 0.00010327561203160585
# sample 4638:
# reference surrogate loss: 0.00012067642953761393
# sample 4639:
# reference surrogate loss: 0.00014327810891501258
# sample 4640:
# reference surrogate loss: 0.0001646667243315747
# sample 4641:
# reference surrogate loss: 8.840598562565027e-05
# sample 4642:
# reference surrogate loss: 8.44170910556663e-05
# sample 4643:
# reference surrogate loss: 0.0001349911059014275
# sample 4644:
# reference surrogate loss: 6.39270964415406e-05
# sample 4645:
# reference surrogate loss: 0.00010766088271330077
# sample 4646:
# reference surrogate loss: 0.00011568840797959723
# sample 4647:
# reference surrogate loss: 0.00011139109632596345
# sample 4648:
# reference surrogate loss: 0.0001281723715214067
# sample 4649:
# reference surrogate loss: 0.00012498814886985343
# sample 4650:
# reference surrogate loss: 8.488015693131068e-05
# sample 4651:
# reference surrogate loss: 9.91827300027559e-05
# sample 4652:
# reference surrogate loss: 0.00010838929639334083
# sample 4653:
# reference surrogate loss: 0.00012856226596569265
# sample 4654:
# reference surrogate loss: 9.622383874341445e-05
# sample 4655:
# reference surrogate loss: 7.201833777736866e-05
# sample 4656:
# reference surrogate loss: 0.00015207527842542312
# sample 4657:
# reference surrogate loss: 0.00014677286746955787
# sample 4658:
# reference surrogate loss: 0.0001270377755240304
# sample 4659:
# reference surrogate loss: 0.0001066627119581387
# sample 4660:
# reference surrogate loss: 0.0001103657066543473
# sample 4661:
# reference surrogate loss: 0.00012980245407279156
# sample 4662:
# reference surrogate loss: 0.00011993785840025417
# sample 4663:
# reference surrogate loss: 0.0001280182474656666
# sample 4664:
# reference surrogate loss: 0.0001107709162446735
# sample 4665:
# reference surrogate loss: 0.00010815638570105257
# sample 4666:
# reference surrogate loss: 8.315240774248167e-05
# sample 4667:
# reference surrogate loss: 0.00010240473203393385
# sample 4668:
# reference surrogate loss: 0.0001141749483497545
# sample 4669:
# reference surrogate loss: 8.738032115562788e-05
# sample 4670:
# reference surrogate loss: 8.65033768475687e-05
# sample 4671:
# reference surrogate loss: 8.309298657538378e-05
# sample 4672:
# reference surrogate loss: 0.00012909849975817345
# sample 4673:
# reference surrogate loss: 0.00012023884887812919
# sample 4674:
# reference surrogate loss: 0.00012860618411081326
# sample 4675:
# reference surrogate loss: 0.00011444801784921133
# sample 4676:
# reference surrogate loss: 0.0001231866243072144
# sample 4677:
# reference surrogate loss: 8.73307552671232e-05
# sample 4678:
# reference surrogate loss: 0.00010938330065957125
# sample 4679:
# reference surrogate loss: 0.00013342950158778955
# sample 4680:
# reference surrogate loss: 0.00011221772094227589
# sample 4681:
# reference surrogate loss: 7.745709069850726e-05
# sample 4682:
# reference surrogate loss: 6.854138192302628e-05
# sample 4683:
# reference surrogate loss: 0.00012863269980112335
# sample 4684:
# reference surrogate loss: 0.0001450890764638224
# sample 4685:
# reference surrogate loss: 9.130855384720249e-05
# sample 4686:
# reference surrogate loss: 9.882495570390226e-05
# sample 4687:
# reference surrogate loss: 0.00011879851863216828
# sample 4688:
# reference surrogate loss: 0.00011002287961203727
# sample 4689:
# reference surrogate loss: 0.00012921985818103998
# sample 4690:
# reference surrogate loss: 0.00014791642278288997
# sample 4691:
# reference surrogate loss: 4.845149950627459e-05
# sample 4692:
# reference surrogate loss: 0.00010069018460501233
# sample 4693:
# reference surrogate loss: 0.00010109421555082321
# sample 4694:
# reference surrogate loss: 0.0001365429226505288
# sample 4695:
# reference surrogate loss: 9.822156198580068e-05
# sample 4696:
# reference surrogate loss: 9.132551998503047e-05
# sample 4697:
# reference surrogate loss: 0.00011150265042036978
# sample 4698:
# reference surrogate loss: 0.00010532303952293098
# sample 4699:
# reference surrogate loss: 0.0001312066315315441
# sample 4700:
# reference surrogate loss: 0.00013461919194557304
# sample 4701:
# reference surrogate loss: 0.00010899405252495775
# sample 4702:
# reference surrogate loss: 0.00011413938441817706
# sample 4703:
# reference surrogate loss: 0.00011158778889197585
# sample 4704:
# reference surrogate loss: 6.370984833625748e-05
# sample 4705:
# reference surrogate loss: 0.00010530993980339964
# sample 4706:
# reference surrogate loss: 0.00011551456272851368
# sample 4707:
# reference surrogate loss: 0.000103840353434137
# sample 4708:
# reference surrogate loss: 0.00017145661294182268
# sample 4709:
# reference surrogate loss: 0.0001487187412179125
# sample 4710:
# reference surrogate loss: 8.790523638291248e-05
# sample 4711:
# reference surrogate loss: 7.935629421007562e-05
# sample 4712:
# reference surrogate loss: 9.307571847338991e-05
# sample 4713:
# reference surrogate loss: 9.626945586194147e-05
# sample 4714:
# reference surrogate loss: 0.00010542293963711202
# sample 4715:
# reference surrogate loss: 0.00012236933473097622
# sample 4716:
# reference surrogate loss: 9.200493543470856e-05
# sample 4717:
# reference surrogate loss: 0.00010850112938531886
# sample 4718:
# reference surrogate loss: 9.109842943355595e-05
# sample 4719:
# reference surrogate loss: 0.0001400851362183264
# sample 4720:
# reference surrogate loss: 9.038985833864643e-05
# sample 4721:
# reference surrogate loss: 0.00010816327310414486
# sample 4722:
# reference surrogate loss: 0.00010296433499523694
# sample 4723:
# reference surrogate loss: 8.698397947792813e-05
# sample 4724:
# reference surrogate loss: 0.00013740342655887972
# sample 4725:
# reference surrogate loss: 0.0001515798006423985
# sample 4726:
# reference surrogate loss: 0.00014033188931250606
# sample 4727:
# reference surrogate loss: 0.0001722227590181813
# sample 4728:
# reference surrogate loss: 0.00010432762476542123
# sample 4729:
# reference surrogate loss: 0.00011518272128130391
# sample 4730:
# reference surrogate loss: 0.00013068728469090019
# sample 4731:
# reference surrogate loss: 0.00012779149994557315
# sample 4732:
# reference surrogate loss: 9.87135305721143e-05
# sample 4733:
# reference surrogate loss: 9.759231091233111e-05
# sample 4734:
# reference surrogate loss: 9.285817679094421e-05
# sample 4735:
# reference surrogate loss: 0.00012356551519476788
# sample 4736:
# reference surrogate loss: 7.999491921295565e-05
# sample 4737:
# reference surrogate loss: 0.00011898025971346371
# sample 4738:
# reference surrogate loss: 0.00010416640606170091
# sample 4739:
# reference surrogate loss: 0.00014093196668918395
# sample 4740:
# reference surrogate loss: 0.00012990514820399035
# sample 4741:
# reference surrogate loss: 0.00010092924097993006
# sample 4742:
# reference surrogate loss: 8.976380965264319e-05
# sample 4743:
# reference surrogate loss: 0.0001135048668570171
# sample 4744:
# reference surrogate loss: 7.499896888862878e-05
# sample 4745:
# reference surrogate loss: 0.00011587832163773015
# sample 4746:
# reference surrogate loss: 0.00010414732197627785
# sample 4747:
# reference surrogate loss: 9.95295784902428e-05
# sample 4748:
# reference surrogate loss: 9.249068460692733e-05
# sample 4749:
# reference surrogate loss: 0.00015353943297347072
# sample 4750:
# reference surrogate loss: 9.793397995450093e-05
# sample 4751:
# reference surrogate loss: 0.00012431959845859986
# sample 4752:
# reference surrogate loss: 0.00015350598069518995
# sample 4753:
# reference surrogate loss: 0.00012797707112177648
# sample 4754:
# reference surrogate loss: 9.9375963300119e-05
# sample 4755:
# reference surrogate loss: 0.00010261178866377563
# sample 4756:
# reference surrogate loss: 8.386683594374666e-05
# sample 4757:
# reference surrogate loss: 7.674798346046785e-05
# sample 4758:
# reference surrogate loss: 0.00012830024535293028
# sample 4759:
# reference surrogate loss: 0.00010943940933527685
# sample 4760:
# reference surrogate loss: 0.00012329247098663565
# sample 4761:
# reference surrogate loss: 0.00014327071145880943
# sample 4762:
# reference surrogate loss: 0.00011065828023171242
# sample 4763:
# reference surrogate loss: 0.00016334519303362605
# sample 4764:
# reference surrogate loss: 7.606614765021114e-05
# sample 4765:
# reference surrogate loss: 5.942328569963351e-05
# sample 4766:
# reference surrogate loss: 6.822035939824111e-05
# sample 4767:
# reference surrogate loss: 0.00010746345335355123
# sample 4768:
# reference surrogate loss: 9.334005785444077e-05
# sample 4769:
# reference surrogate loss: 0.00010198333750133237
# sample 4770:
# reference surrogate loss: 9.920514603112274e-05
# sample 4771:
# reference surrogate loss: 0.00011841646629640046
# sample 4772:
# reference surrogate loss: 9.772073967173611e-05
# sample 4773:
# reference surrogate loss: 9.440298403928793e-05
# sample 4774:
# reference surrogate loss: 0.00018015249521297072
# sample 4775:
# reference surrogate loss: 8.582775994869785e-05
# sample 4776:
# reference surrogate loss: 6.2650804001807e-05
# sample 4777:
# reference surrogate loss: 7.783401948713298e-05
# sample 4778:
# reference surrogate loss: 8.699803135980844e-05
# sample 4779:
# reference surrogate loss: 0.00011608754650849207
# sample 4780:
# reference surrogate loss: 7.274993588279877e-05
# sample 4781:
# reference surrogate loss: 8.813260325846173e-05
# sample 4782:
# reference surrogate loss: 0.00011994433399187265
# sample 4783:
# reference surrogate loss: 0.00014409816010263476
# sample 4784:
# reference surrogate loss: 0.00011454696149360011
# sample 4785:
# reference surrogate loss: 0.00013605317156439867
# sample 4786:
# reference surrogate loss: 0.0001452791861327185
# sample 4787:
# reference surrogate loss: 0.0001179268435487213
# sample 4788:
# reference surrogate loss: 9.05753508890772e-05
# sample 4789:
# reference surrogate loss: 0.00010308213428356083
# sample 4790:
# reference surrogate loss: 9.176782240039039e-05
# sample 4791:
# reference surrogate loss: 0.0001091614608890179
# sample 4792:
# reference surrogate loss: 0.00010499936696350964
# sample 4793:
# reference surrogate loss: 8.44300708995327e-05
# sample 4794:
# reference surrogate loss: 0.000173291238336315
# sample 4795:
# reference surrogate loss: 0.00011900035378786811
# sample 4796:
# reference surrogate loss: 0.00011049707601662462
# sample 4797:
# reference surrogate loss: 7.943110407371279e-05
# sample 4798:
# reference surrogate loss: 8.074335725893889e-05
# sample 4799:
# reference surrogate loss: 8.867234234832821e-05
# sample 4800:
# reference surrogate loss: 8.270284680578222e-05
# sample 4801:
# reference surrogate loss: 0.0001184009616148618
# sample 4802:
# reference surrogate loss: 8.193296176695064e-05
# sample 4803:
# reference surrogate loss: 0.000116375145112535
# sample 4804:
# reference surrogate loss: 0.00012165263750740785
# sample 4805:
# reference surrogate loss: 9.672905184876512e-05
# sample 4806:
# reference surrogate loss: 0.00011355746180430337
# sample 4807:
# reference surrogate loss: 8.685901154414921e-05
# sample 4808:
# reference surrogate loss: 7.987069369042032e-05
# sample 4809:
# reference surrogate loss: 0.00011618287848480513
# sample 4810:
# reference surrogate loss: 9.43995955386967e-05
# sample 4811:
# reference surrogate loss: 0.00016512057044448802
# sample 4812:
# reference surrogate loss: 0.0001351323041667296
# sample 4813:
# reference surrogate loss: 0.00010257586540585173
# sample 4814:
# reference surrogate loss: 0.00015037448106158813
# sample 4815:
# reference surrogate loss: 0.00010456705692485357
# sample 4816:
# reference surrogate loss: 0.00013629246731894362
# sample 4817:
# reference surrogate loss: 7.313126072805431e-05
# sample 4818:
# reference surrogate loss: 7.065771244185726e-05
# sample 4819:
# reference surrogate loss: 8.123466334097884e-05
# sample 4820:
# reference surrogate loss: 8.741081294116881e-05
# sample 4821:
# reference surrogate loss: 0.00012419177237976697
# sample 4822:
# reference surrogate loss: 0.00010997087345709922
# sample 4823:
# reference surrogate loss: 6.630177596234077e-05
# sample 4824:
# reference surrogate loss: 0.00011246331759218187
# sample 4825:
# reference surrogate loss: 9.908103457534345e-05
# sample 4826:
# reference surrogate loss: 8.055090822756128e-05
# sample 4827:
# reference surrogate loss: 0.00011663516515825201
# sample 4828:
# reference surrogate loss: 9.59106941564869e-05
# sample 4829:
# reference surrogate loss: 9.673236446872124e-05
# sample 4830:
# reference surrogate loss: 0.00011436878052273336
# sample 4831:
# reference surrogate loss: 0.0001098916285722229
# sample 4832:
# reference surrogate loss: 0.00010288530084978653
# sample 4833:
# reference surrogate loss: 0.00012579034292836688
# sample 4834:
# reference surrogate loss: 7.022229289188608e-05
# sample 4835:
# reference surrogate loss: 0.00011771117331682568
# sample 4836:
# reference surrogate loss: 6.536478400498424e-05
# sample 4837:
# reference surrogate loss: 0.00011797139571734228
# sample 4838:
# reference surrogate loss: 0.0001252031687151156
# sample 4839:
# reference surrogate loss: 8.328526890100107e-05
# sample 4840:
# reference surrogate loss: 9.629672291033842e-05
# sample 4841:
# reference surrogate loss: 0.00014678563250947185
# sample 4842:
# reference surrogate loss: 9.448810377676864e-05
# sample 4843:
# reference surrogate loss: 0.00011313227315135066
# sample 4844:
# reference surrogate loss: 0.00011317144376854493
# sample 4845:
# reference surrogate loss: 0.00012497811759804023
# sample 4846:
# reference surrogate loss: 0.00013056737620353864
# sample 4847:
# reference surrogate loss: 0.00012513982467732276
# sample 4848:
# reference surrogate loss: 6.341834840029037e-05
# sample 4849:
# reference surrogate loss: 6.123813270297873e-05
# sample 4850:
# reference surrogate loss: 8.08618043726117e-05
# sample 4851:
# reference surrogate loss: 0.00015658450466249363
# sample 4852:
# reference surrogate loss: 0.00010144247750099034
# sample 4853:
# reference surrogate loss: 9.633175053824772e-05
# sample 4854:
# reference surrogate loss: 8.186111510788407e-05
# sample 4855:
# reference surrogate loss: 8.188393627928114e-05
# sample 4856:
# reference surrogate loss: 9.987663689936532e-05
# sample 4857:
# reference surrogate loss: 0.0001360433558355023
# sample 4858:
# reference surrogate loss: 0.00010850531260664376
# sample 4859:
# reference surrogate loss: 0.00015072674882410375
# sample 4860:
# reference surrogate loss: 0.0001578805068875866
# sample 4861:
# reference surrogate loss: 8.360858167155705e-05
# sample 4862:
# reference surrogate loss: 9.950291795446375e-05
# sample 4863:
# reference surrogate loss: 6.518113215858712e-05
# sample 4864:
# reference surrogate loss: 0.0001223974752653234
# sample 4865:
# reference surrogate loss: 0.00013628614148086804
# sample 4866:
# reference surrogate loss: 7.281477487830479e-05
# sample 4867:
# reference surrogate loss: 0.00012242640054105358
# sample 4868:
# reference surrogate loss: 9.062656567548899e-05
# sample 4869:
# reference surrogate loss: 8.791241101335778e-05
# sample 4870:
# reference surrogate loss: 0.00016365005107887853
# sample 4871:
# reference surrogate loss: 6.830089789611193e-05
# sample 4872:
# reference surrogate loss: 0.00010542843257543844
# sample 4873:
# reference surrogate loss: 0.00014930647776112416
# sample 4874:
# reference surrogate loss: 6.396830065069636e-05
# sample 4875:
# reference surrogate loss: 7.109848098441063e-05
# sample 4876:
# reference surrogate loss: 0.00012111099410594406
# sample 4877:
# reference surrogate loss: 0.0001442953326060703
# sample 4878:
# reference surrogate loss: 0.00010283931499732724
# sample 4879:
# reference surrogate loss: 8.460454946890295e-05
# sample 4880:
# reference surrogate loss: 9.095905099187895e-05
# sample 4881:
# reference surrogate loss: 9.61721946102223e-05
# sample 4882:
# reference surrogate loss: 0.00011040619388813511
# sample 4883:
# reference surrogate loss: 7.995352465983707e-05
# sample 4884:
# reference surrogate loss: 0.00011012060690895886
# sample 4885:
# reference surrogate loss: 0.00014098965895636972
# sample 4886:
# reference surrogate loss: 8.302616373434546e-05
# sample 4887:
# reference surrogate loss: 0.00010409074853279243
# sample 4888:
# reference surrogate loss: 0.00012297736836641704
# sample 4889:
# reference surrogate loss: 0.00011155511517824124
# sample 4890:
# reference surrogate loss: 0.00010783561818139553
# sample 4891:
# reference surrogate loss: 9.152739399920229e-05
# sample 4892:
# reference surrogate loss: 7.794947051631418e-05
# sample 4893:
# reference surrogate loss: 0.0001222419004507369
# sample 4894:
# reference surrogate loss: 9.881736162409283e-05
# sample 4895:
# reference surrogate loss: 6.391706627284499e-05
# sample 4896:
# reference surrogate loss: 7.504640173849886e-05
# sample 4897:
# reference surrogate loss: 0.00011374351536375116
# sample 4898:
# reference surrogate loss: 0.00010871971815595849
# sample 4899:
# reference surrogate loss: 0.00011134503872800572
# sample 4900:
# reference surrogate loss: 8.451242076534804e-05
# sample 4901:
# reference surrogate loss: 0.00011675107475017654
# sample 4902:
# reference surrogate loss: 9.431582691554752e-05
# sample 4903:
# reference surrogate loss: 0.00011401910234964951
# sample 4904:
# reference surrogate loss: 0.00011459239758715434
# sample 4905:
# reference surrogate loss: 0.00010070429734421182
# sample 4906:
# reference surrogate loss: 0.00016532454961448728
# sample 4907:
# reference surrogate loss: 0.00010438482776820024
# sample 4908:
# reference surrogate loss: 8.068677646111411e-05
# sample 4909:
# reference surrogate loss: 0.00013274677854613337
# sample 4910:
# reference surrogate loss: 0.00015765266676925904
# sample 4911:
# reference surrogate loss: 0.00010872595239508343
# sample 4912:
# reference surrogate loss: 0.00011211007703026965
# sample 4913:
# reference surrogate loss: 0.00010815004780950765
# sample 4914:
# reference surrogate loss: 5.655355704337062e-05
# sample 4915:
# reference surrogate loss: 0.00017009976863446852
# sample 4916:
# reference surrogate loss: 0.00010742367954708065
# sample 4917:
# reference surrogate loss: 0.00012534595469082532
# sample 4918:
# reference surrogate loss: 8.939821761666522e-05
# sample 4919:
# reference surrogate loss: 9.498871899027428e-05
# sample 4920:
# reference surrogate loss: 0.00011264708750879926
# sample 4921:
# reference surrogate loss: 0.00014928417847270836
# sample 4922:
# reference surrogate loss: 0.00012920322603093837
# sample 4923:
# reference surrogate loss: 0.0001572284960513759
# sample 4924:
# reference surrogate loss: 0.000138544021588638
# sample 4925:
# reference surrogate loss: 0.00010592584732971311
# sample 4926:
# reference surrogate loss: 0.0001072036818592359
# sample 4927:
# reference surrogate loss: 0.0001163439818319123
# sample 4928:
# reference surrogate loss: 0.000109697193878322
# sample 4929:
# reference surrogate loss: 9.664696548394858e-05
# sample 4930:
# reference surrogate loss: 7.5808039580183e-05
# sample 4931:
# reference surrogate loss: 6.615044947966275e-05
# sample 4932:
# reference surrogate loss: 0.00012141318075253871
# sample 4933:
# reference surrogate loss: 0.000126670998620515
# sample 4934:
# reference surrogate loss: 9.51638290229706e-05
# sample 4935:
# reference surrogate loss: 0.00011510342521670047
# sample 4936:
# reference surrogate loss: 8.665842725785744e-05
# sample 4937:
# reference surrogate loss: 0.00012994952287859185
# sample 4938:
# reference surrogate loss: 7.787307598339233e-05
# sample 4939:
# reference surrogate loss: 0.0001314851861800026
# sample 4940:
# reference surrogate loss: 0.0001652791670618825
# sample 4941:
# reference surrogate loss: 0.00015174377587445775
# sample 4942:
# reference surrogate loss: 0.00012274841387038826
# sample 4943:
# reference surrogate loss: 7.97690363381065e-05
# sample 4944:
# reference surrogate loss: 0.00013646864322613972
# sample 4945:
# reference surrogate loss: 0.00010334988791771416
# sample 4946:
# reference surrogate loss: 7.210006675184566e-05
# sample 4947:
# reference surrogate loss: 7.344963319444453e-05
# sample 4948:
# reference surrogate loss: 7.845144403351156e-05
# sample 4949:
# reference surrogate loss: 9.851716309361436e-05
# sample 4950:
# reference surrogate loss: 9.796397027295178e-05
# sample 4951:
# reference surrogate loss: 0.00011906090509072875
# sample 4952:
# reference surrogate loss: 0.00010317464325648729
# sample 4953:
# reference surrogate loss: 0.00010732088004927753
# sample 4954:
# reference surrogate loss: 0.00013437614715172685
# sample 4955:
# reference surrogate loss: 9.079733206363017e-05
# sample 4956:
# reference surrogate loss: 0.00010992259340159016
# sample 4957:
# reference surrogate loss: 0.00015138199424180598
# sample 4958:
# reference surrogate loss: 7.231480492353448e-05
# sample 4959:
# reference surrogate loss: 7.575362295009214e-05
# sample 4960:
# reference surrogate loss: 8.608589064196259e-05
# sample 4961:
# reference surrogate loss: 0.00014025087926028412
# sample 4962:
# reference surrogate loss: 6.09424352984167e-05
# sample 4963:
# reference surrogate loss: 6.786864950591998e-05
# sample 4964:
# reference surrogate loss: 0.00010937572895031167
# sample 4965:
# reference surrogate loss: 9.188766024470496e-05
# sample 4966:
# reference surrogate loss: 8.308457195771446e-05
# sample 4967:
# reference surrogate loss: 9.92974052345108e-05
# sample 4968:
# reference surrogate loss: 9.534483527962045e-05
# sample 4969:
# reference surrogate loss: 0.00011032173548408686
# sample 4970:
# reference surrogate loss: 9.451176996466693e-05
# sample 4971:
# reference surrogate loss: 0.00014482704152984915
# sample 4972:
# reference surrogate loss: 7.690110401115113e-05
# sample 4973:
# reference surrogate loss: 0.00010672855925042413
# sample 4974:
# reference surrogate loss: 9.050740448546257e-05
# sample 4975:
# reference surrogate loss: 0.0001315088407178866
# sample 4976:
# reference surrogate loss: 0.0001190647341156037
# sample 4977:
# reference surrogate loss: 9.902525919325278e-05
# sample 4978:
# reference surrogate loss: 0.0001097133205603118
# sample 4979:
# reference surrogate loss: 0.00010870117683658975
# sample 4980:
# reference surrogate loss: 0.00013012208309848283
# sample 4981:
# reference surrogate loss: 0.00014247193616356846
# sample 4982:
# reference surrogate loss: 0.00010607560848407971
# sample 4983:
# reference surrogate loss: 8.49024773386109e-05
# sample 4984:
# reference surrogate loss: 0.00010418593458139114
# sample 4985:
# reference surrogate loss: 0.00012360147858547776
# sample 4986:
# reference surrogate loss: 0.00012231807129703398
# sample 4987:
# reference surrogate loss: 0.00012076811743977345
# sample 4988:
# reference surrogate loss: 0.0001340645856720002
# sample 4989:
# reference surrogate loss: 0.00012094462920653193
# sample 4990:
# reference surrogate loss: 9.256581918570816e-05
# sample 4991:
# reference surrogate loss: 9.614898168242014e-05
# sample 4992:
# reference surrogate loss: 0.00013024813238304844
# sample 4993:
# reference surrogate loss: 0.0001610956987381229
# sample 4994:
# reference surrogate loss: 0.0001391146629010631
# sample 4995:
# reference surrogate loss: 0.0001564062828365298
# sample 4996:
# reference surrogate loss: 9.221147484450576e-05
# sample 4997:
# reference surrogate loss: 0.00017619430075588305
# sample 4998:
# reference surrogate loss: 9.009144260785362e-05
# sample 4999:
# reference surrogate loss: 0.0001192334041404397
#
# number of POD basi: 128
# mean reference surrogate loss: 1.09e-04
# std reference surrogate loss: 2.58e-05

# %%
# reference_surrogate_loss_list = []
# for i in range(valid_start_index, valid_start_index + num_samples_for_reference_surrogate_loss):
#     print(f'sample {i}:')
#     reference_surrogate_loss = surrogate_loss(reference_reduced_minimizers[i], i, sub_dim=256)
#     print(f'reference surrogate loss: {reference_surrogate_loss.item()}')
#     reference_surrogate_loss_list.append(reference_surrogate_loss.item())
# print("")
# print("number of POD basi: 256")
# print(f'mean reference surrogate loss: {np.mean(reference_surrogate_loss_list):.2e}')
# print(f'std reference surrogate loss: {np.std(reference_surrogate_loss_list):.2e}')

# %%
# reference_surrogate_loss_list = []
# for i in range(valid_start_index, valid_start_index + num_samples_for_reference_surrogate_loss):
#     print(f'sample {i}:')
#     reference_surrogate_loss = surrogate_loss(reference_reduced_minimizers[i], i, sub_dim=512)
#     print(f'reference surrogate loss: {reference_surrogate_loss.item()}')
#     reference_surrogate_loss_list.append(reference_surrogate_loss.item())
# print("")
# print("number of POD basi: 512")
# print(f'mean reference surrogate loss: {np.mean(reference_surrogate_loss_list):.2e}')
# print(f'std reference surrogate loss: {np.std(reference_surrogate_loss_list):.2e}')

# %%
# fig, ax = plt.subplots(figsize=(8, 6))  # Fixed figure size
# cax = ax.imshow(surrogate_loss.reduced_weight_list[0]['quadratic'].numpy(),  cmap='turbo')
# ax.set_xlabel('column index', fontsize=15)   
# ax.set_ylabel('row index', fontsize=15)
# ax.set_title('Reduced quadratic weight matrix', fontsize=15)
# ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_aspect('equal')
# cbar = fig.colorbar(cax, ax=ax)
# cbar.ax.tick_params(labelsize=13)  # Increase colorbar tick label font size

# fig.savefig(os.path.join(train_dataset_path, 'reduced_quadratic_weight_matrix_full.png'), dpi=300, bbox_inches='tight')

# %%
# fig, ax = plt.subplots(figsize=(8, 6))  # Fixed figure size
# cax = ax.imshow(surrogate_loss.reduced_weight_list[0]['quadratic'][:64,:64].numpy(),  cmap='turbo')
# ax.set_xlabel('column index', fontsize=15)   
# ax.set_ylabel('row index', fontsize=15)
# ax.set_title('Reduced quadratic weight matrix [0:64, 0:64]', fontsize=15)
# ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_aspect('equal')
# cbar = fig.colorbar(cax, ax=ax)
# cbar.ax.tick_params(labelsize=13)  # Increase colorbar tick label font size
# fig.savefig(os.path.join(train_dataset_path, 'reduced_quadratic_weight_matrix_0-64.png'), dpi=300, bbox_inches='tight')

# %%
# fig, ax = plt.subplots(figsize=(8, 6))  # Fixed figure size
# cax = ax.imshow(surrogate_loss.reduced_weight_list[0]['quadratic'][:16,:16].numpy(),  cmap='turbo')
# ax.set_xlabel('column index', fontsize=15) 
# ax.set_ylabel('row index', fontsize=15)
# ax.set_title('Reduced quadratic weight matrix [0:16, 0:16]', fontsize=15)
# ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_aspect('equal')
# cbar = fig.colorbar(cax, ax=ax)
# cbar.ax.tick_params(labelsize=13)  # Increase colorbar tick label font size
# fig.savefig(os.path.join(train_dataset_path, 'reduced_quadratic_weight_matrix_0-16.png'), dpi=300, bbox_inches='tight')

# %%
num_p_fc = len(p_dof)
dolfinx_mesh_coords = mesh.geometry.x[:,:2]

num_x, num_y = mesh_args['num_x'], mesh_args['num_y']
x = np.linspace(0, mesh_args['upper_right_x'], num_x+1)
y = np.linspace(0, mesh_args['upper_right_y'], num_y+1)
image_mesh_coords = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
perm = [np.where((image_mesh_coords == row).all(axis=1))[0][0] for row in dolfinx_mesh_coords]

CG_element = basix.ufl.element('CG', 'triangle', 1)
Vh['CG1'] = dolfinx.fem.functionspace(mesh, CG_element)

# %%
# for i in range(3):
#     k = dolfinx.fem.Function(Vh['CG1'])
#     k.x.array[:] = k_dof[i]
#     k_vertex_values[i][perm] = k.x.array[:][scifem.vertex_to_dofmap(Vh['CG1'])]
#     plt.imshow(k_vertex_values[i].reshape(num_x+1, num_y+1).T, extent=[0, 1, 0, 1], origin='lower', cmap='turbo')
#     plt.colorbar()
#     plt.title('Random parameter function k')
#     plt.show()

# %%
# if not os.path.exists(os.path.join(train_dataset_path, 'k_vertex_values.npy')):
#     print('Computing k_vertex_values...')
#     k_vertex_values = np.zeros((num_k_fc, (mesh_args['num_x'] + 1) * (mesh_args['num_y'] + 1)))
#     for i in tqdm(range(num_k_fc)):
#         k_fc = dolfinx.fem.Function(Vh['k'])
#         k_fc.x.array[:] = k_dof[i]
#         k_vertex_values[i][perm] = evaluate_expression(mesh, k_fc, mesh.geometry.x)[1][:, 0]
#     np.save(os.path.join(train_dataset_path, 'k_vertex_values.npy'), k_vertex_values)
# else:
#     k_vertex_values = np.load(os.path.join(train_dataset_path, 'k_vertex_values.npy'))

# %%
# k_vertex_values = np.zeros((num_k_fc, (mesh_args['num_x'] + 1) * (mesh_args['num_y'] + 1)))

# for i in tqdm(range(num_k_fc)):
#     k = dolfinx.fem.Function(Vh['k'])
#     k.x.array[:] = k_dof[i]
#     k_vertex_values[i][perm] = evaluate_expression(mesh, k, mesh.geometry.x)[1][:, 0]

# %%
image_p_vertex_values = np.zeros((num_p_fc, 1, mesh_args['num_y']+1, mesh_args['num_x']+1))
for i in tqdm(range(num_p_fc)):
    image_p_vertex_values[i,0,:,:] = p_vertex_values[i].reshape(num_x+1, num_y+1).T
# Out:
# 100%|██████████| 5000/5000 [00:01<00:00, 4163.35it/s]

# %%
# for i in range(num_k_fc):
#     k = dolfinx.fem.Function(Vh['CG1'])
#     k.x.array[:] = k_dof[i]
#     k_vertex_values[i][perm] = k.x.array[:][scifem.vertex_to_dofmap(Vh['CG1'])]

# device = torch.device('cuda:3')

# image_k_vertex_values = np.zeros((num_k_fc, 1, num_x+1, num_y+1))
# for i in range(num_k_fc):
#     image_k_vertex_values[i,0,:,:] = k_vertex_values[i].reshape(num_x+1, num_y+1)

# k_vertex_values_tensor = torch.tensor(image_k_vertex_values, dtype=torch_dtype['float32']).to(device)

# %%
device = torch.device('cuda:1')
p_vertex_values_tensor = torch.tensor(image_p_vertex_values, dtype=torch_dtype['float32']).to(device)

# %%
x = mesh.geometry.x[:, 0]
y = mesh.geometry.x[:, 1]
p = dolfinx.fem.Function(Vh['p'])
p.x.array[:] = p_dof[0]
plt.tricontourf(x, y, evaluate_expression(mesh, p, mesh.geometry.x)[1][:, 0], cmap='turbo', levels=100)
plt.colorbar()
plt.title('Random parameter function p')
plt.show()

# %%
plt.imshow(p_vertex_values_tensor[0,0,:,:].cpu().numpy(), extent=[0, 1, 0, 1], origin='lower', cmap='turbo')
plt.colorbar()
plt.title('Random parameter function p')
plt.show()

# %%
surrogate_loss = SurrogateLoss(reduced_weight_list).astype(torch_dtype['float32']).to(device)
num_basis = output_reduced_basis_args['num_basis']
model = ConvolutionalNN_129x129(output_dim=num_basis, activation='leakyrelu', init_func='xavier_uniform')
model = model.to(device)

# %%
_, _ = print_model_size(model)
# Out:
# Total number of model parameters: 15117440 (~57.67 MiB)

# %%
iterations = 3000
num_train = 3000
num_valid = 500

batch_size = {
    'train': 1000,
    'valid': num_valid
}

# %%
data_loss = torch.nn.MSELoss(reduction='mean')
reference_reduced_minimizers = reference_reduced_minimizers.to(torch_dtype['float32']).to(device)
num_samples_for_data_loss = output_reduced_basis_args['num_evals']

# %%
loss_history = {
    'train_physical': [],
    'train_data': [],
    'train_total': [],
    'valid_physical': [],
    'valid_data': [],
    'valid_total': []
}
valid_start_index = 4500

train_batch_indices_iterator = BatchIndicesIterator(start=0, end=num_train, batch_size=batch_size['train'], shuffle=True)
valid_batch_indices_iterator = BatchIndicesIterator(start=valid_start_index, end=valid_start_index + num_valid, batch_size=batch_size['valid'], shuffle=False)
data_loss_indices = torch.arange(num_samples_for_data_loss, dtype=torch.int64).to(device)

print(f'num_training_samples: {num_train}')
optimizer = SOAP(params=model.parameters(), lr=5e-3, betas=(.95, .95), weight_decay=.01, precondition_frequency=5)
# optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.01)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.9)

best_valid_loss = float('inf')
best_model_path = os.path.join(model_train_outputs_path, f"best_model_params_{num_train}.pth")
best_model_iterations = []  

counter = 0
while counter < iterations:
    for batch_indices in train_batch_indices_iterator:
        model.train()
        loss = {'physical': torch.tensor(0.0).to(device),
                'data': torch.tensor(0.0).to(device),
                'total': torch.tensor(0.0).to(device)}

        input_ = p_vertex_values_tensor[batch_indices]
        output = model(input_)

        data_loss_batch_indices = []
        for j, index in enumerate(batch_indices):
            loss['physical'] += (surrogate_loss(output[j], index))[0]
            if index in data_loss_indices:
                loss['data'] += data_loss(output[j], reference_reduced_minimizers[index])
                data_loss_batch_indices.append(index)

        loss['physical'] /= len(batch_indices)
        loss['data'] /= len(data_loss_batch_indices) if len(data_loss_batch_indices) > 0 else 1
        loss['total'] = loss['physical'] + loss['data']

        optimizer.zero_grad()
        loss['total'].backward()
        optimizer.step()
        counter += 1

        print('')
        print(f'Iteration: {counter}')
        print(f'Train loss: physical {loss["physical"].item()} | data {loss["data"].item()} | total {loss["total"].item()}')

        loss_history['train_physical'].append(loss['physical'].item())
        loss_history['train_data'].append(loss['data'].item())
        loss_history['train_total'].append(loss['total'].item())

        with torch.no_grad():
            model.eval()
            valid_loss = {'physical': torch.tensor(0.0).to(device),
                          'data': torch.tensor(0.0).to(device),
                          'total': torch.tensor(0.0).to(device)}
            for valid_batch_indices in valid_batch_indices_iterator:
                valid_input = p_vertex_values_tensor[valid_batch_indices]
                valid_output = model(valid_input)
                for j, index in enumerate(valid_batch_indices):
                    valid_loss['physical'] += (surrogate_loss(valid_output[j], index))[0]
                    valid_loss['data'] += data_loss(valid_output[j], reference_reduced_minimizers[index])
                valid_loss['physical'] /= len(valid_batch_indices)
                valid_loss['data'] /= len(valid_batch_indices)
                valid_loss['total'] = valid_loss['physical'] + valid_loss['data']

            valid_physical_loss_value = valid_loss['physical'].item()
            valid_data_loss_value = valid_loss['data'].item()
            valid_total_loss_value = valid_loss['total'].item()
            print(f'Valid loss: physical {valid_loss["physical"].item()} | data {valid_loss["data"].item()} | total {valid_loss["total"].item()}')

            loss_history['valid_physical'].append(valid_loss['physical'].item())
            loss_history['valid_data'].append(valid_loss['data'].item())
            loss_history['valid_total'].append(valid_loss['total'].item())

            # Save best model
            if valid_physical_loss_value < best_valid_loss:
                best_valid_loss = valid_physical_loss_value
                torch.save(model.state_dict(), best_model_path)
                best_model_iterations.append(counter) 
                print(f"New best model saved at iteration {counter} with validation physical loss {best_valid_loss:.6f}")

    lr_scheduler.step()

# Save training history and final model
loss_history = {key: np.array(value) for key, value in loss_history.items()}
np.save(os.path.join(model_train_outputs_path, f'loss_history_{num_train}.npy'), loss_history)
torch.save(model.state_dict(), os.path.join(model_train_outputs_path, f"latest_model_params_{num_train}.pth"))
# Out:
# num_training_samples: 3000
#
# Iteration: 1
# Train loss: physical 5.942257404327393 | data 0.017545700073242188 | total 5.959803104400635
# Valid loss: physical 5.735286712646484 | data 0.017436577007174492 | total 5.752723217010498
# New best model saved at iteration 1 with validation physical loss 5.735287
#
# Iteration: 2
# Train loss: physical 5.737150192260742 | data 0.017626848071813583 | total 5.754776954650879
# Valid loss: physical 4479.44384765625 | data 4.9147047996521 | total 4484.3583984375
#
# Iteration: 3
# Train loss: physical 4481.59912109375 | data 5.132874965667725 | total 4486.73193359375
# Valid loss: physical 554.0331420898438 | data 0.49348729848861694 | total 554.526611328125
#
# Iteration: 4
# Train loss: physical 562.8552856445312 | data 0.5199323296546936 | total 563.375244140625
# Valid loss: physical 150.11871337890625 | data 0.1788540780544281 | total 150.2975616455078
#
# Iteration: 5
# Train loss: physical 140.7806854248047 | data 0.18092402815818787 | total 140.96160888671875
# Valid loss: physical 214.44915771484375 | data 0.25187423825263977 | total 214.70103454589844
#
# Iteration: 6
# Train loss: physical 219.4777374267578 | data 0.2627200484275818 | total 219.74046325683594
# Valid loss: physical 41.437339782714844 | data 0.06425274908542633 | total 41.501590728759766
#
# Iteration: 7
# Train loss: physical 41.40315246582031 | data 0.06516211479902267 | total 41.46831512451172
# Valid loss: physical 88.20720672607422 | data 0.09946015477180481 | total 88.3066635131836
#
# Iteration: 8
# Train loss: physical 84.879638671875 | data 0.1016254723072052 | total 84.98126220703125
# Valid loss: physical 62.86661148071289 | data 0.09371950477361679 | total 62.960330963134766
#
# Iteration: 9
# Train loss: physical 65.85569763183594 | data 0.09956330060958862 | total 65.95526123046875
# Valid loss: physical 22.776792526245117 | data 0.03322320431470871 | total 22.810016632080078
#
# Iteration: 10
# Train loss: physical 24.168615341186523 | data 0.035141147673130035 | total 24.20375633239746
# Valid loss: physical 4.554798603057861 | data 0.016740670427680016 | total 4.571539402008057
# New best model saved at iteration 10 with validation physical loss 4.554799
#
# Iteration: 11
# Train loss: physical 4.612497806549072 | data 0.01793031021952629 | total 4.630428314208984
# Valid loss: physical 51.591331481933594 | data 0.0646018534898758 | total 51.65593338012695
#
# Iteration: 12
# Train loss: physical 60.0258903503418 | data 0.07128988206386566 | total 60.0971794128418
# Valid loss: physical 30.593381881713867 | data 0.06744009256362915 | total 30.66082191467285
#
# Iteration: 13
# Train loss: physical 30.787918090820312 | data 0.06299562007188797 | total 30.850914001464844
# Valid loss: physical 365.6697082519531 | data 0.3047942519187927 | total 365.9744873046875
#
# Iteration: 14
# Train loss: physical 395.2128601074219 | data 0.34478387236595154 | total 395.5576477050781
# Valid loss: physical 16.037059783935547 | data 0.03411279618740082 | total 16.0711727142334
#
# Iteration: 15
# Train loss: physical 15.389902114868164 | data 0.03302058205008507 | total 15.42292308807373
# Valid loss: physical 13.50009536743164 | data 0.032402265816926956 | total 13.53249740600586
#
# Iteration: 16
# Train loss: physical 13.234845161437988 | data 0.030550921335816383 | total 13.265396118164062
# Valid loss: physical 11.762059211730957 | data 0.022941621020436287 | total 11.785000801086426
#
# Iteration: 17
# Train loss: physical 12.057191848754883 | data 0.023770319297909737 | total 12.080962181091309
# Valid loss: physical 23.076313018798828 | data 0.03655322641134262 | total 23.112865447998047
#
# Iteration: 18
# Train loss: physical 22.32182502746582 | data 0.03800181671977043 | total 22.359827041625977
# Valid loss: physical 49.88251876831055 | data 0.06684911996126175 | total 49.94936752319336
#
# Iteration: 19
# Train loss: physical 50.926727294921875 | data 0.07147015631198883 | total 50.99819564819336
# Valid loss: physical 70.4191665649414 | data 0.08636527508497238 | total 70.50553131103516
#
# Iteration: 20
# Train loss: physical 65.59173583984375 | data 0.08404451608657837 | total 65.67578125
# Valid loss: physical 82.31183624267578 | data 0.10013791918754578 | total 82.41197204589844
#
# Iteration: 21
# Train loss: physical 88.36971282958984 | data 0.11562392860651016 | total 88.48533630371094
# Valid loss: physical 72.75330352783203 | data 0.09153926372528076 | total 72.84484100341797
#
# Iteration: 22
# Train loss: physical 74.44998168945312 | data 0.09489895403385162 | total 74.54488372802734
# Valid loss: physical 60.979103088378906 | data 0.08220064640045166 | total 61.061302185058594
#
# Iteration: 23
# Train loss: physical 62.6024055480957 | data 0.09399290382862091 | total 62.6963996887207
# Valid loss: physical 44.26410675048828 | data 0.06475307792425156 | total 44.328861236572266
#
# Iteration: 24
# Train loss: physical 42.407806396484375 | data 0.06477797776460648 | total 42.47258377075195
# Valid loss: physical 32.480350494384766 | data 0.05290563404560089 | total 32.53325653076172
#
# Iteration: 25
# Train loss: physical 33.77421951293945 | data 0.05803413689136505 | total 33.832252502441406
# Valid loss: physical 22.77578353881836 | data 0.04110057279467583 | total 22.816884994506836
#
# Iteration: 26
# Train loss: physical 21.61897087097168 | data 0.040900327265262604 | total 21.65987205505371
# Valid loss: physical 19.57632827758789 | data 0.03693695366382599 | total 19.613265991210938
#
# Iteration: 27
# Train loss: physical 19.54669761657715 | data 0.036439381539821625 | total 19.58313751220703
# Valid loss: physical 15.12331485748291 | data 0.030621986836194992 | total 15.153936386108398
#
# Iteration: 28
# Train loss: physical 14.917976379394531 | data 0.030702462419867516 | total 14.948678970336914
# Valid loss: physical 13.327801704406738 | data 0.02793688140809536 | total 13.355738639831543
#
# Iteration: 29
# Train loss: physical 13.371700286865234 | data 0.028780803084373474 | total 13.400481224060059
# Valid loss: physical 12.074098587036133 | data 0.02611204981803894 | total 12.100210189819336
#
# Iteration: 30
# Train loss: physical 12.312978744506836 | data 0.02745174802839756 | total 12.34043025970459
# Valid loss: physical 11.015214920043945 | data 0.024451861158013344 | total 11.039667129516602
#
# Iteration: 31
# Train loss: physical 11.310196876525879 | data 0.02496657334268093 | total 11.335163116455078
# Valid loss: physical 10.175535202026367 | data 0.023093342781066895 | total 10.198628425598145
#
# Iteration: 32
# Train loss: physical 10.567450523376465 | data 0.02495698444545269 | total 10.5924072265625
# Valid loss: physical 9.753660202026367 | data 0.022421227768063545 | total 9.776081085205078
#
# Iteration: 33
# Train loss: physical 9.506107330322266 | data 0.023151611909270287 | total 9.529258728027344
# Valid loss: physical 9.491423606872559 | data 0.021856550127267838 | total 9.513279914855957
#
# Iteration: 34
# Train loss: physical 9.236650466918945 | data 0.02216154709458351 | total 9.258811950683594
# Valid loss: physical 9.343059539794922 | data 0.02139436826109886 | total 9.36445426940918
#
# Iteration: 35
# Train loss: physical 9.658010482788086 | data 0.022212106734514236 | total 9.680222511291504
# Valid loss: physical 8.914724349975586 | data 0.020667023956775665 | total 8.935391426086426
#
# Iteration: 36
# Train loss: physical 9.33662223815918 | data 0.022995255887508392 | total 9.359617233276367
# Valid loss: physical 8.406296730041504 | data 0.01981743611395359 | total 8.426114082336426
#
# Iteration: 37
# Train loss: physical 8.85537338256836 | data 0.02121858485043049 | total 8.876591682434082
# Valid loss: physical 9.207564353942871 | data 0.020649800077080727 | total 9.228214263916016
#
# Iteration: 38
# Train loss: physical 9.008649826049805 | data 0.02177535556256771 | total 9.030425071716309
# Valid loss: physical 7.273287296295166 | data 0.01796616055071354 | total 7.291253566741943
#
# Iteration: 39
# Train loss: physical 7.472541809082031 | data 0.018605710938572884 | total 7.491147518157959
# Valid loss: physical 6.510871887207031 | data 0.01688575930893421 | total 6.52775764465332
#
# Iteration: 40
# Train loss: physical 6.282334804534912 | data 0.016918031498789787 | total 6.299252986907959
# Valid loss: physical 5.660840034484863 | data 0.015704547986388206 | total 5.676544666290283
#
# Iteration: 41
# Train loss: physical 5.9440436363220215 | data 0.01748257875442505 | total 5.961526393890381
# Valid loss: physical 4.823189735412598 | data 0.014471113681793213 | total 4.837660789489746
#
# Iteration: 42
# Train loss: physical 5.047142505645752 | data 0.014983662404119968 | total 5.062126159667969
# Valid loss: physical 4.122256755828857 | data 0.013469352386891842 | total 4.135725975036621
# New best model saved at iteration 42 with validation physical loss 4.122257
#
# Iteration: 43
# Train loss: physical 4.286373615264893 | data 0.014212765730917454 | total 4.300586223602295
# Valid loss: physical 3.569234848022461 | data 0.012439568527042866 | total 3.581674337387085
# New best model saved at iteration 43 with validation physical loss 3.569235
#
# Iteration: 44
# Train loss: physical 3.546623468399048 | data 0.011914091184735298 | total 3.558537483215332
# Valid loss: physical 3.274056911468506 | data 0.011572347022593021 | total 3.2856292724609375
# New best model saved at iteration 44 with validation physical loss 3.274057
#
# Iteration: 45
# Train loss: physical 3.320815086364746 | data 0.012034895829856396 | total 3.3328499794006348
# Valid loss: physical 3.0808651447296143 | data 0.010798489674925804 | total 3.0916635990142822
# New best model saved at iteration 45 with validation physical loss 3.080865
#
# Iteration: 46
# Train loss: physical 3.084925889968872 | data 0.010767207480967045 | total 3.0956931114196777
# Valid loss: physical 2.9305830001831055 | data 0.010108300484716892 | total 2.9406912326812744
# New best model saved at iteration 46 with validation physical loss 2.930583
#
# Iteration: 47
# Train loss: physical 3.0088894367218018 | data 0.01028175838291645 | total 3.0191712379455566
# Valid loss: physical 2.775348663330078 | data 0.009508754126727581 | total 2.7848575115203857
# New best model saved at iteration 47 with validation physical loss 2.775349
#
# Iteration: 48
# Train loss: physical 2.7975010871887207 | data 0.009633458219468594 | total 2.8071346282958984
# Valid loss: physical 2.6262733936309814 | data 0.00896742194890976 | total 2.6352407932281494
# New best model saved at iteration 48 with validation physical loss 2.626273
#
# Iteration: 49
# Train loss: physical 2.676649332046509 | data 0.009006744250655174 | total 2.6856560707092285
# Valid loss: physical 2.484994888305664 | data 0.008430268615484238 | total 2.493425130844116
# New best model saved at iteration 49 with validation physical loss 2.484995
#
# Iteration: 50
# Train loss: physical 2.541513204574585 | data 0.008447346277534962 | total 2.5499606132507324
# Valid loss: physical 2.3764305114746094 | data 0.007928620092570782 | total 2.384359121322632
# New best model saved at iteration 50 with validation physical loss 2.376431
#
# Iteration: 51
# Train loss: physical 2.5438380241394043 | data 0.008171203546226025 | total 2.552009344100952
# Valid loss: physical 2.2713868618011475 | data 0.007436621934175491 | total 2.2788233757019043
# New best model saved at iteration 51 with validation physical loss 2.271387
#
# Iteration: 52
# Train loss: physical 2.366760015487671 | data 0.007580687757581472 | total 2.374340772628784
# Valid loss: physical 2.1756646633148193 | data 0.007025637663900852 | total 2.182690382003784
# New best model saved at iteration 52 with validation physical loss 2.175665
#
# Iteration: 53
# Train loss: physical 2.4053189754486084 | data 0.007204617373645306 | total 2.4125235080718994
# Valid loss: physical 2.0272090435028076 | data 0.006610718555748463 | total 2.0338196754455566
# New best model saved at iteration 53 with validation physical loss 2.027209
#
# Iteration: 54
# Train loss: physical 2.049772024154663 | data 0.006710977293550968 | total 2.056483030319214
# Valid loss: physical 1.8946738243103027 | data 0.006234088912606239 | total 1.9009078741073608
# New best model saved at iteration 54 with validation physical loss 1.894674
#
# Iteration: 55
# Train loss: physical 2.0408852100372314 | data 0.006330861244350672 | total 2.0472161769866943
# Valid loss: physical 1.7984338998794556 | data 0.005903128068894148 | total 1.8043370246887207
# New best model saved at iteration 55 with validation physical loss 1.798434
#
# Iteration: 56
# Train loss: physical 1.8120466470718384 | data 0.006079566664993763 | total 1.8181262016296387
# Valid loss: physical 1.7463403940200806 | data 0.0055841258727014065 | total 1.7519245147705078
# New best model saved at iteration 56 with validation physical loss 1.746340
#
# Iteration: 57
# Train loss: physical 1.77204430103302 | data 0.005296945571899414 | total 1.7773412466049194
# Valid loss: physical 1.713496446609497 | data 0.00531785050407052 | total 1.7188142538070679
# New best model saved at iteration 57 with validation physical loss 1.713496
#
# Iteration: 58
# Train loss: physical 1.7460445165634155 | data 0.005413576494902372 | total 1.7514580488204956
# Valid loss: physical 1.6459228992462158 | data 0.005034273024648428 | total 1.6509572267532349
# New best model saved at iteration 58 with validation physical loss 1.645923
#
# Iteration: 59
# Train loss: physical 1.6678681373596191 | data 0.0051202550530433655 | total 1.6729884147644043
# Valid loss: physical 1.5559375286102295 | data 0.004728373605757952 | total 1.5606658458709717
# New best model saved at iteration 59 with validation physical loss 1.555938
#
# Iteration: 60
# Train loss: physical 1.5509191751480103 | data 0.004430529661476612 | total 1.5553497076034546
# Valid loss: physical 1.4699350595474243 | data 0.004415742587298155 | total 1.4743508100509644
# New best model saved at iteration 60 with validation physical loss 1.469935
#
# Iteration: 61
# Train loss: physical 1.4963281154632568 | data 0.004465362057089806 | total 1.50079345703125
# Valid loss: physical 1.4237321615219116 | data 0.004166049417108297 | total 1.4278981685638428
# New best model saved at iteration 61 with validation physical loss 1.423732
#
# Iteration: 62
# Train loss: physical 1.42729914188385 | data 0.004057695623487234 | total 1.4313567876815796
# Valid loss: physical 1.408005714416504 | data 0.004017825238406658 | total 1.4120235443115234
# New best model saved at iteration 62 with validation physical loss 1.408006
#
# Iteration: 63
# Train loss: physical 1.46598219871521 | data 0.004055558238178492 | total 1.4700376987457275
# Valid loss: physical 1.3503059148788452 | data 0.003927200101315975 | total 1.3542331457138062
# New best model saved at iteration 63 with validation physical loss 1.350306
#
# Iteration: 64
# Train loss: physical 1.3643581867218018 | data 0.003933978732675314 | total 1.368292212486267
# Valid loss: physical 1.2807860374450684 | data 0.003852025605738163 | total 1.2846380472183228
# New best model saved at iteration 64 with validation physical loss 1.280786
#
# Iteration: 65
# Train loss: physical 1.3337308168411255 | data 0.0037404464092105627 | total 1.3374712467193604
# Valid loss: physical 1.2389554977416992 | data 0.0038077153731137514 | total 1.2427631616592407
# New best model saved at iteration 65 with validation physical loss 1.238955
#
# Iteration: 66
# Train loss: physical 1.2602945566177368 | data 0.003979451023042202 | total 1.264274001121521
# Valid loss: physical 1.2196649312973022 | data 0.0037537398748099804 | total 1.2234187126159668
# New best model saved at iteration 66 with validation physical loss 1.219665
#
# Iteration: 67
# Train loss: physical 1.2436867952346802 | data 0.0037563052028417587 | total 1.2474430799484253
# Valid loss: physical 1.1785475015640259 | data 0.0036735287867486477 | total 1.1822210550308228
# New best model saved at iteration 67 with validation physical loss 1.178548
#
# Iteration: 68
# Train loss: physical 1.1999797821044922 | data 0.0036314092576503754 | total 1.203611135482788
# Valid loss: physical 1.0976791381835938 | data 0.003553563728928566 | total 1.101232647895813
# New best model saved at iteration 68 with validation physical loss 1.097679
#
# Iteration: 69
# Train loss: physical 1.1197906732559204 | data 0.003788773436099291 | total 1.123579502105713
# Valid loss: physical 1.0381356477737427 | data 0.0034457037691026926 | total 1.041581392288208
# New best model saved at iteration 69 with validation physical loss 1.038136
#
# Iteration: 70
# Train loss: physical 1.0582513809204102 | data 0.0035645421594381332 | total 1.0618159770965576
# Valid loss: physical 1.0178052186965942 | data 0.003376343520358205 | total 1.021181583404541
# New best model saved at iteration 70 with validation physical loss 1.017805
#
# Iteration: 71
# Train loss: physical 1.019877314567566 | data 0.0034854456316679716 | total 1.0233627557754517
# Valid loss: physical 0.9754470586776733 | data 0.0033297843765467405 | total 0.9787768721580505
# New best model saved at iteration 71 with validation physical loss 0.975447
#
# Iteration: 72
# Train loss: physical 0.995448112487793 | data 0.003513125004246831 | total 0.9989612102508545
# Valid loss: physical 0.8934512734413147 | data 0.0033083143644034863 | total 0.896759569644928
# New best model saved at iteration 72 with validation physical loss 0.893451
#
# Iteration: 73
# Train loss: physical 0.8775254487991333 | data 0.003217555582523346 | total 0.8807430267333984
# Valid loss: physical 0.8464767336845398 | data 0.0033239414915442467 | total 0.8498006463050842
# New best model saved at iteration 73 with validation physical loss 0.846477
#
# Iteration: 74
# Train loss: physical 0.8138975501060486 | data 0.0036096603143960238 | total 0.8175072073936462
# Valid loss: physical 0.8331576585769653 | data 0.003335266839712858 | total 0.8364928960800171
# New best model saved at iteration 74 with validation physical loss 0.833158
#
# Iteration: 75
# Train loss: physical 0.8644788265228271 | data 0.003500682068988681 | total 0.8679795265197754
# Valid loss: physical 0.7998879551887512 | data 0.0033057336695492268 | total 0.8031936883926392
# New best model saved at iteration 75 with validation physical loss 0.799888
#
# Iteration: 76
# Train loss: physical 0.7783547639846802 | data 0.0034788232296705246 | total 0.7818335890769958
# Valid loss: physical 0.7447488903999329 | data 0.0032254548277705908 | total 0.7479743361473083
# New best model saved at iteration 76 with validation physical loss 0.744749
#
# Iteration: 77
# Train loss: physical 0.735267698764801 | data 0.003352665575221181 | total 0.7386203408241272
# Valid loss: physical 0.7131052613258362 | data 0.003136984771117568 | total 0.716242253780365
# New best model saved at iteration 77 with validation physical loss 0.713105
#
# Iteration: 78
# Train loss: physical 0.7278239727020264 | data 0.0032266622874885798 | total 0.7310506105422974
# Valid loss: physical 0.6927331686019897 | data 0.003051841864362359 | total 0.6957849860191345
# New best model saved at iteration 78 with validation physical loss 0.692733
#
# Iteration: 79
# Train loss: physical 0.6815332770347595 | data 0.0031324869487434626 | total 0.6846657395362854
# Valid loss: physical 0.650897741317749 | data 0.002958805998787284 | total 0.6538565754890442
# New best model saved at iteration 79 with validation physical loss 0.650898
#
# Iteration: 80
# Train loss: physical 0.6569473147392273 | data 0.0032481870148330927 | total 0.660195529460907
# Valid loss: physical 0.6011475324630737 | data 0.0028613796457648277 | total 0.6040089130401611
# New best model saved at iteration 80 with validation physical loss 0.601148
#
# Iteration: 81
# Train loss: physical 0.5929253101348877 | data 0.002911781892180443 | total 0.5958371162414551
# Valid loss: physical 0.5703171491622925 | data 0.0027574426494538784 | total 0.5730745792388916
# New best model saved at iteration 81 with validation physical loss 0.570317
#
# Iteration: 82
# Train loss: physical 0.5736541748046875 | data 0.0030232034623622894 | total 0.5766773819923401
# Valid loss: physical 0.5415118932723999 | data 0.0026490993332117796 | total 0.5441610217094421
# New best model saved at iteration 82 with validation physical loss 0.541512
#
# Iteration: 83
# Train loss: physical 0.5212411284446716 | data 0.0026558416429907084 | total 0.5238969922065735
# Valid loss: physical 0.4905645251274109 | data 0.002513541141524911 | total 0.4930780529975891
# New best model saved at iteration 83 with validation physical loss 0.490565
#
# Iteration: 84
# Train loss: physical 0.49264582991600037 | data 0.002598032122477889 | total 0.4952438473701477
# Valid loss: physical 0.4485211670398712 | data 0.002372336108237505 | total 0.45089349150657654
# New best model saved at iteration 84 with validation physical loss 0.448521
#
# Iteration: 85
# Train loss: physical 0.43793147802352905 | data 0.0025622579269111156 | total 0.44049373269081116
# Valid loss: physical 0.4281010031700134 | data 0.0022447211667895317 | total 0.43034571409225464
# New best model saved at iteration 85 with validation physical loss 0.428101
#
# Iteration: 86
# Train loss: physical 0.4328373968601227 | data 0.002285750349983573 | total 0.43512314558029175
# Valid loss: physical 0.3998691737651825 | data 0.002132684225216508 | total 0.40200185775756836
# New best model saved at iteration 86 with validation physical loss 0.399869
#
# Iteration: 87
# Train loss: physical 0.3928973376750946 | data 0.0021658893674612045 | total 0.39506322145462036
# Valid loss: physical 0.36682814359664917 | data 0.002036031801253557 | total 0.36886417865753174
# New best model saved at iteration 87 with validation physical loss 0.366828
#
# Iteration: 88
# Train loss: physical 0.3662460446357727 | data 0.0022164846304804087 | total 0.36846253275871277
# Valid loss: physical 0.3484399914741516 | data 0.0019521869253367186 | total 0.3503921926021576
# New best model saved at iteration 88 with validation physical loss 0.348440
#
# Iteration: 89
# Train loss: physical 0.3441086411476135 | data 0.001984677277505398 | total 0.3460933268070221
# Valid loss: physical 0.33388131856918335 | data 0.001861023367382586 | total 0.33574235439300537
# New best model saved at iteration 89 with validation physical loss 0.333881
#
# Iteration: 90
# Train loss: physical 0.3341180682182312 | data 0.0018604968208819628 | total 0.33597856760025024
# Valid loss: physical 0.30583199858665466 | data 0.0017591763753443956 | total 0.30759117007255554
# New best model saved at iteration 90 with validation physical loss 0.305832
#
# Iteration: 91
# Train loss: physical 0.2971572279930115 | data 0.0016746690962463617 | total 0.29883190989494324
# Valid loss: physical 0.28177642822265625 | data 0.0016647826414555311 | total 0.2834412157535553
# New best model saved at iteration 91 with validation physical loss 0.281776
#
# Iteration: 92
# Train loss: physical 0.2884597182273865 | data 0.0017403194215148687 | total 0.29020002484321594
# Valid loss: physical 0.2745085060596466 | data 0.0015963019104674459 | total 0.27610480785369873
# New best model saved at iteration 92 with validation physical loss 0.274509
#
# Iteration: 93
# Train loss: physical 0.26534610986709595 | data 0.001734942547045648 | total 0.26708105206489563
# Valid loss: physical 0.2685861587524414 | data 0.0015470534563064575 | total 0.27013319730758667
# New best model saved at iteration 93 with validation physical loss 0.268586
#
# Iteration: 94
# Train loss: physical 0.26212504506111145 | data 0.001514081028290093 | total 0.2636391222476959
# Valid loss: physical 0.2506428062915802 | data 0.0015117565635591745 | total 0.25215455889701843
# New best model saved at iteration 94 with validation physical loss 0.250643
#
# Iteration: 95
# Train loss: physical 0.24957728385925293 | data 0.0016210207249969244 | total 0.25119829177856445
# Valid loss: physical 0.23549537360668182 | data 0.0014909508172422647 | total 0.23698632419109344
# New best model saved at iteration 95 with validation physical loss 0.235495
#
# Iteration: 96
# Train loss: physical 0.2293248325586319 | data 0.0014988970942795277 | total 0.23082372546195984
# Valid loss: physical 0.23154094815254211 | data 0.00147857959382236 | total 0.23301953077316284
# New best model saved at iteration 96 with validation physical loss 0.231541
#
# Iteration: 97
# Train loss: physical 0.2228223979473114 | data 0.0014643841423094273 | total 0.2242867797613144
# Valid loss: physical 0.2258962094783783 | data 0.0014628821518272161 | total 0.2273590862751007
# New best model saved at iteration 97 with validation physical loss 0.225896
#
# Iteration: 98
# Train loss: physical 0.22412927448749542 | data 0.0015308903530240059 | total 0.22566016018390656
# Valid loss: physical 0.21192170679569244 | data 0.001433690544217825 | total 0.2133553922176361
# New best model saved at iteration 98 with validation physical loss 0.211922
#
# Iteration: 99
# Train loss: physical 0.21247412264347076 | data 0.0014099363470450044 | total 0.21388405561447144
# Valid loss: physical 0.20538271963596344 | data 0.0014040489913895726 | total 0.20678676664829254
# New best model saved at iteration 99 with validation physical loss 0.205383
#
# Iteration: 100
# Train loss: physical 0.19999171793460846 | data 0.0014026409480720758 | total 0.20139436423778534
# Valid loss: physical 0.2076251357793808 | data 0.0013840795727446675 | total 0.20900921523571014
#
# Iteration: 101
# Train loss: physical 0.20255322754383087 | data 0.001338411238975823 | total 0.20389163494110107
# Valid loss: physical 0.2015269249677658 | data 0.001370375044643879 | total 0.20289729535579681
# New best model saved at iteration 101 with validation physical loss 0.201527
#
# Iteration: 102
# Train loss: physical 0.1980656236410141 | data 0.0014255638234317303 | total 0.19949118793010712
# Valid loss: physical 0.19012609124183655 | data 0.001361263100989163 | total 0.1914873570203781
# New best model saved at iteration 102 with validation physical loss 0.190126
#
# Iteration: 103
# Train loss: physical 0.18868093192577362 | data 0.0013591302558779716 | total 0.19004006683826447
# Valid loss: physical 0.18615444004535675 | data 0.0013558223145082593 | total 0.18751026690006256
# New best model saved at iteration 103 with validation physical loss 0.186154
#
# Iteration: 104
# Train loss: physical 0.18434369564056396 | data 0.0013287907931953669 | total 0.18567249178886414
# Valid loss: physical 0.18510571122169495 | data 0.0013431422412395477 | total 0.1864488571882248
# New best model saved at iteration 104 with validation physical loss 0.185106
#
# Iteration: 105
# Train loss: physical 0.17893174290657043 | data 0.0013535108882933855 | total 0.1802852600812912
# Valid loss: physical 0.17647452652454376 | data 0.0013153015170246363 | total 0.1777898222208023
# New best model saved at iteration 105 with validation physical loss 0.176475
#
# Iteration: 106
# Train loss: physical 0.17302671074867249 | data 0.0012975218705832958 | total 0.17432422935962677
# Valid loss: physical 0.17107640206813812 | data 0.0012839066330343485 | total 0.17236031591892242
# New best model saved at iteration 106 with validation physical loss 0.171076
#
# Iteration: 107
# Train loss: physical 0.16414064168930054 | data 0.0012629411648958921 | total 0.1654035896062851
# Valid loss: physical 0.17307880520820618 | data 0.0012601498747244477 | total 0.1743389517068863
#
# Iteration: 108
# Train loss: physical 0.17058853805065155 | data 0.0012694805627688766 | total 0.171858012676239
# Valid loss: physical 0.16781146824359894 | data 0.0012417200487107038 | total 0.16905318200588226
# New best model saved at iteration 108 with validation physical loss 0.167811
#
# Iteration: 109
# Train loss: physical 0.16424624621868134 | data 0.0012198410695418715 | total 0.1654660850763321
# Valid loss: physical 0.15670305490493774 | data 0.0012256006011739373 | total 0.15792866051197052
# New best model saved at iteration 109 with validation physical loss 0.156703
#
# Iteration: 110
# Train loss: physical 0.1544802337884903 | data 0.001229750458151102 | total 0.15570998191833496
# Valid loss: physical 0.15251021087169647 | data 0.0012137731537222862 | total 0.15372398495674133
# New best model saved at iteration 110 with validation physical loss 0.152510
#
# Iteration: 111
# Train loss: physical 0.14741146564483643 | data 0.0012031873920932412 | total 0.14861465990543365
# Valid loss: physical 0.15070107579231262 | data 0.0011990672210231423 | total 0.15190014243125916
# New best model saved at iteration 111 with validation physical loss 0.150701
#
# Iteration: 112
# Train loss: physical 0.15194900333881378 | data 0.0011711876140907407 | total 0.15312018990516663
# Valid loss: physical 0.14301466941833496 | data 0.001174612552858889 | total 0.1441892832517624
# New best model saved at iteration 112 with validation physical loss 0.143015
#
# Iteration: 113
# Train loss: physical 0.13804326951503754 | data 0.0011748126707971096 | total 0.13921807706356049
# Valid loss: physical 0.13864506781101227 | data 0.00114874925930053 | total 0.13979381322860718
# New best model saved at iteration 113 with validation physical loss 0.138645
#
# Iteration: 114
# Train loss: physical 0.1346398890018463 | data 0.0011559120612218976 | total 0.13579580187797546
# Valid loss: physical 0.13651874661445618 | data 0.001124437665566802 | total 0.13764318823814392
# New best model saved at iteration 114 with validation physical loss 0.136519
#
# Iteration: 115
# Train loss: physical 0.13292986154556274 | data 0.0011248196242377162 | total 0.13405467569828033
# Valid loss: physical 0.12958437204360962 | data 0.0010999906808137894 | total 0.13068436086177826
# New best model saved at iteration 115 with validation physical loss 0.129584
#
# Iteration: 116
# Train loss: physical 0.12720374763011932 | data 0.0011105532757937908 | total 0.1283143013715744
# Valid loss: physical 0.12319666892290115 | data 0.0010790197411552072 | total 0.12427569180727005
# New best model saved at iteration 116 with validation physical loss 0.123197
#
# Iteration: 117
# Train loss: physical 0.12121584266424179 | data 0.0010599814122542739 | total 0.12227582186460495
# Valid loss: physical 0.12197472155094147 | data 0.0010629033204168081 | total 0.12303762137889862
# New best model saved at iteration 117 with validation physical loss 0.121975
#
# Iteration: 118
# Train loss: physical 0.11969168484210968 | data 0.0010955675970762968 | total 0.12078725546598434
# Valid loss: physical 0.11747152358293533 | data 0.0010422058403491974 | total 0.11851373314857483
# New best model saved at iteration 118 with validation physical loss 0.117472
#
# Iteration: 119
# Train loss: physical 0.11820847541093826 | data 0.0010224065044894814 | total 0.11923088133335114
# Valid loss: physical 0.10944119840860367 | data 0.001018859213218093 | total 0.1104600578546524
# New best model saved at iteration 119 with validation physical loss 0.109441
#
# Iteration: 120
# Train loss: physical 0.10721840709447861 | data 0.001017439761199057 | total 0.10823584347963333
# Valid loss: physical 0.10759790241718292 | data 0.0009990195976570249 | total 0.10859692096710205
# New best model saved at iteration 120 with validation physical loss 0.107598
#
# Iteration: 121
# Train loss: physical 0.10535579174757004 | data 0.0009969730162993073 | total 0.10635276138782501
# Valid loss: physical 0.10548199713230133 | data 0.0009801347041502595 | total 0.10646212846040726
# New best model saved at iteration 121 with validation physical loss 0.105482
#
# Iteration: 122
# Train loss: physical 0.10505125671625137 | data 0.0009843716397881508 | total 0.10603562742471695
# Valid loss: physical 0.09931677579879761 | data 0.0009627174586057663 | total 0.10027949512004852
# New best model saved at iteration 122 with validation physical loss 0.099317
#
# Iteration: 123
# Train loss: physical 0.09791775047779083 | data 0.0009786492446437478 | total 0.09889639914035797
# Valid loss: physical 0.0968920961022377 | data 0.0009502079337835312 | total 0.09784230589866638
# New best model saved at iteration 123 with validation physical loss 0.096892
#
# Iteration: 124
# Train loss: physical 0.09531373530626297 | data 0.0009291066089645028 | total 0.09624284505844116
# Valid loss: physical 0.09659852832555771 | data 0.0009394785738550127 | total 0.09753800928592682
# New best model saved at iteration 124 with validation physical loss 0.096599
#
# Iteration: 125
# Train loss: physical 0.09811088442802429 | data 0.0009692060993984342 | total 0.09908009320497513
# Valid loss: physical 0.0927390605211258 | data 0.0009249249706044793 | total 0.09366398304700851
# New best model saved at iteration 125 with validation physical loss 0.092739
#
# Iteration: 126
# Train loss: physical 0.09061720222234726 | data 0.0009457594132982194 | total 0.09156296402215958
# Valid loss: physical 0.09132280945777893 | data 0.0009108873782679439 | total 0.09223369508981705
# New best model saved at iteration 126 with validation physical loss 0.091323
#
# Iteration: 127
# Train loss: physical 0.09006090462207794 | data 0.0009446960175409913 | total 0.0910056009888649
# Valid loss: physical 0.09170468151569366 | data 0.0008996743126772344 | total 0.09260435402393341
#
# Iteration: 128
# Train loss: physical 0.09136904776096344 | data 0.0008961614221334457 | total 0.09226521104574203
# Valid loss: physical 0.08864236623048782 | data 0.0008894557249732316 | total 0.08953182399272919
# New best model saved at iteration 128 with validation physical loss 0.088642
#
# Iteration: 129
# Train loss: physical 0.08790197223424911 | data 0.0008966987952589989 | total 0.08879867196083069
# Valid loss: physical 0.08612161129713058 | data 0.0008814694592729211 | total 0.08700308203697205
# New best model saved at iteration 129 with validation physical loss 0.086122
#
# Iteration: 130
# Train loss: physical 0.08533080667257309 | data 0.0008913700003176928 | total 0.08622217923402786
# Valid loss: physical 0.0858549177646637 | data 0.0008727004751563072 | total 0.08672761917114258
# New best model saved at iteration 130 with validation physical loss 0.085855
#
# Iteration: 131
# Train loss: physical 0.08339474350214005 | data 0.0008527491590939462 | total 0.08424749225378036
# Valid loss: physical 0.08287131041288376 | data 0.0008595359977334738 | total 0.08373084664344788
# New best model saved at iteration 131 with validation physical loss 0.082871
#
# Iteration: 132
# Train loss: physical 0.08248019963502884 | data 0.0008969918708316982 | total 0.08337718993425369
# Valid loss: physical 0.08007269352674484 | data 0.0008447559084743261 | total 0.08091744780540466
# New best model saved at iteration 132 with validation physical loss 0.080073
#
# Iteration: 133
# Train loss: physical 0.07933766394853592 | data 0.0008854801999405026 | total 0.08022314310073853
# Valid loss: physical 0.07932079583406448 | data 0.0008344054804183543 | total 0.08015520125627518
# New best model saved at iteration 133 with validation physical loss 0.079321
#
# Iteration: 134
# Train loss: physical 0.07863594591617584 | data 0.0008197561837732792 | total 0.07945570349693298
# Valid loss: physical 0.07590075582265854 | data 0.0008284415234811604 | total 0.0767292007803917
# New best model saved at iteration 134 with validation physical loss 0.075901
#
# Iteration: 135
# Train loss: physical 0.07178627699613571 | data 0.0008200243464671075 | total 0.07260630279779434
# Valid loss: physical 0.07319363206624985 | data 0.0008247262449003756 | total 0.07401835918426514
# New best model saved at iteration 135 with validation physical loss 0.073194
#
# Iteration: 136
# Train loss: physical 0.07133947312831879 | data 0.000824721297249198 | total 0.07216419279575348
# Valid loss: physical 0.07196317613124847 | data 0.0008200432057492435 | total 0.0727832168340683
# New best model saved at iteration 136 with validation physical loss 0.071963
#
# Iteration: 137
# Train loss: physical 0.07123899459838867 | data 0.0008278433233499527 | total 0.07206683605909348
# Valid loss: physical 0.06918990612030029 | data 0.0008101211860775948 | total 0.07000003010034561
# New best model saved at iteration 137 with validation physical loss 0.069190
#
# Iteration: 138
# Train loss: physical 0.0666382685303688 | data 0.0008079298422671854 | total 0.06744620203971863
# Valid loss: physical 0.06786374747753143 | data 0.00079918815754354 | total 0.06866293400526047
# New best model saved at iteration 138 with validation physical loss 0.067864
#
# Iteration: 139
# Train loss: physical 0.06611436605453491 | data 0.0007497086771763861 | total 0.06686407327651978
# Valid loss: physical 0.06774833798408508 | data 0.0007945796241983771 | total 0.06854292005300522
# New best model saved at iteration 139 with validation physical loss 0.067748
#
# Iteration: 140
# Train loss: physical 0.06617406010627747 | data 0.0008329818374477327 | total 0.06700704246759415
# Valid loss: physical 0.06534086912870407 | data 0.0007945586112327874 | total 0.06613542884588242
# New best model saved at iteration 140 with validation physical loss 0.065341
#
# Iteration: 141
# Train loss: physical 0.06374996155500412 | data 0.0008008591248653829 | total 0.06455081701278687
# Valid loss: physical 0.0641208067536354 | data 0.0007980347727425396 | total 0.06491883844137192
# New best model saved at iteration 141 with validation physical loss 0.064121
#
# Iteration: 142
# Train loss: physical 0.06152305379509926 | data 0.0007970533333718777 | total 0.062320105731487274
# Valid loss: physical 0.06441831588745117 | data 0.0007983084651641548 | total 0.06521662324666977
#
# Iteration: 143
# Train loss: physical 0.06352425366640091 | data 0.0007787466747686267 | total 0.06430300325155258
# Valid loss: physical 0.062089353799819946 | data 0.0007898312178440392 | total 0.06287918239831924
# New best model saved at iteration 143 with validation physical loss 0.062089
#
# Iteration: 144
# Train loss: physical 0.06174600124359131 | data 0.0007987287826836109 | total 0.06254473328590393
# Valid loss: physical 0.06081472337245941 | data 0.0007788169896230102 | total 0.061593540012836456
# New best model saved at iteration 144 with validation physical loss 0.060815
#
# Iteration: 145
# Train loss: physical 0.06026015058159828 | data 0.0007613610941916704 | total 0.061021510511636734
# Valid loss: physical 0.05970268324017525 | data 0.0007707879412919283 | total 0.060473471879959106
# New best model saved at iteration 145 with validation physical loss 0.059703
#
# Iteration: 146
# Train loss: physical 0.05941703915596008 | data 0.0007603756967000663 | total 0.06017741560935974
# Valid loss: physical 0.05761002376675606 | data 0.000765161239542067 | total 0.05837518349289894
# New best model saved at iteration 146 with validation physical loss 0.057610
#
# Iteration: 147
# Train loss: physical 0.0562116838991642 | data 0.0007829007809050381 | total 0.05699458345770836
# Valid loss: physical 0.056732259690761566 | data 0.0007597275543957949 | total 0.05749198794364929
# New best model saved at iteration 147 with validation physical loss 0.056732
#
# Iteration: 148
# Train loss: physical 0.05591645464301109 | data 0.000759736227337271 | total 0.056676190346479416
# Valid loss: physical 0.0553484745323658 | data 0.0007493180455639958 | total 0.05609779432415962
# New best model saved at iteration 148 with validation physical loss 0.055348
#
# Iteration: 149
# Train loss: physical 0.05433189123868942 | data 0.0007552307797595859 | total 0.055087123066186905
# Valid loss: physical 0.05347249656915665 | data 0.0007341579184867442 | total 0.05420665442943573
# New best model saved at iteration 149 with validation physical loss 0.053472
#
# Iteration: 150
# Train loss: physical 0.05307236686348915 | data 0.000719039177056402 | total 0.053791407495737076
# Valid loss: physical 0.05298231169581413 | data 0.0007197808590717614 | total 0.05370209366083145
# New best model saved at iteration 150 with validation physical loss 0.052982
#
# Iteration: 151
# Train loss: physical 0.05216442421078682 | data 0.0007473529549315572 | total 0.052911777049303055
# Valid loss: physical 0.05192682147026062 | data 0.0007100821821950376 | total 0.052636902779340744
# New best model saved at iteration 151 with validation physical loss 0.051927
#
# Iteration: 152
# Train loss: physical 0.05199764296412468 | data 0.000706532213371247 | total 0.05270417407155037
# Valid loss: physical 0.050756264477968216 | data 0.0007039132760837674 | total 0.05146017670631409
# New best model saved at iteration 152 with validation physical loss 0.050756
#
# Iteration: 153
# Train loss: physical 0.04947736859321594 | data 0.0006762536359019578 | total 0.050153620541095734
# Valid loss: physical 0.05069003626704216 | data 0.000696949427947402 | total 0.051386985927820206
# New best model saved at iteration 153 with validation physical loss 0.050690
#
# Iteration: 154
# Train loss: physical 0.05026109144091606 | data 0.0006798607064411044 | total 0.05094095319509506
# Valid loss: physical 0.04947630688548088 | data 0.0006848355988040566 | total 0.05016114190220833
# New best model saved at iteration 154 with validation physical loss 0.049476
#
# Iteration: 155
# Train loss: physical 0.048984795808792114 | data 0.0007079183124005795 | total 0.04969271272420883
# Valid loss: physical 0.04906715452671051 | data 0.0006709228619001806 | total 0.0497380755841732
# New best model saved at iteration 155 with validation physical loss 0.049067
#
# Iteration: 156
# Train loss: physical 0.04826554283499718 | data 0.0006618562620133162 | total 0.04892740026116371
# Valid loss: physical 0.048546202480793 | data 0.0006598664913326502 | total 0.049206070601940155
# New best model saved at iteration 156 with validation physical loss 0.048546
#
# Iteration: 157
# Train loss: physical 0.048339977860450745 | data 0.0006969246314838529 | total 0.0490369014441967
# Valid loss: physical 0.047307826578617096 | data 0.0006527062505483627 | total 0.04796053469181061
# New best model saved at iteration 157 with validation physical loss 0.047308
#
# Iteration: 158
# Train loss: physical 0.047094348818063736 | data 0.0006308768643066287 | total 0.04772522673010826
# Valid loss: physical 0.046994399279356 | data 0.0006463137688115239 | total 0.047640714794397354
# New best model saved at iteration 158 with validation physical loss 0.046994
#
# Iteration: 159
# Train loss: physical 0.04563452675938606 | data 0.0006290338933467865 | total 0.04626356065273285
# Valid loss: physical 0.045565374195575714 | data 0.0006358983810059726 | total 0.046201273798942566
# New best model saved at iteration 159 with validation physical loss 0.045565
#
# Iteration: 160
# Train loss: physical 0.0447627492249012 | data 0.0006328566814772785 | total 0.04539560526609421
# Valid loss: physical 0.044735345989465714 | data 0.0006247473647817969 | total 0.04536009207367897
# New best model saved at iteration 160 with validation physical loss 0.044735
#
# Iteration: 161
# Train loss: physical 0.043732624500989914 | data 0.0006301442044787109 | total 0.04436276853084564
# Valid loss: physical 0.043958451598882675 | data 0.000616425066255033 | total 0.04457487538456917
# New best model saved at iteration 161 with validation physical loss 0.043958
#
# Iteration: 162
# Train loss: physical 0.04337259754538536 | data 0.0006127274828031659 | total 0.04398532584309578
# Valid loss: physical 0.04268159717321396 | data 0.0006115558207966387 | total 0.04329315200448036
# New best model saved at iteration 162 with validation physical loss 0.042682
#
# Iteration: 163
# Train loss: physical 0.041847217828035355 | data 0.0006161585915833712 | total 0.04246337711811066
# Valid loss: physical 0.04225543141365051 | data 0.0006083612679503858 | total 0.042863793671131134
# New best model saved at iteration 163 with validation physical loss 0.042255
#
# Iteration: 164
# Train loss: physical 0.04154687374830246 | data 0.0005968848709017038 | total 0.04214375838637352
# Valid loss: physical 0.041549474000930786 | data 0.0006026864284649491 | total 0.04215215891599655
# New best model saved at iteration 164 with validation physical loss 0.041549
#
# Iteration: 165
# Train loss: physical 0.04095473513007164 | data 0.0006065974594093859 | total 0.04156133159995079
# Valid loss: physical 0.04083860293030739 | data 0.0005961021524854004 | total 0.04143470525741577
# New best model saved at iteration 165 with validation physical loss 0.040839
#
# Iteration: 166
# Train loss: physical 0.0402228981256485 | data 0.0005915006040595472 | total 0.04081439971923828
# Valid loss: physical 0.04063832387328148 | data 0.0005902232951484621 | total 0.04122854769229889
# New best model saved at iteration 166 with validation physical loss 0.040638
#
# Iteration: 167
# Train loss: physical 0.0396011583507061 | data 0.0005965772434137762 | total 0.04019773378968239
# Valid loss: physical 0.0398254357278347 | data 0.0005861734389327466 | total 0.040411610156297684
# New best model saved at iteration 167 with validation physical loss 0.039825
#
# Iteration: 168
# Train loss: physical 0.039182938635349274 | data 0.0005794750177301466 | total 0.03976241499185562
# Valid loss: physical 0.03979706019163132 | data 0.0005821805680170655 | total 0.04037924110889435
# New best model saved at iteration 168 with validation physical loss 0.039797
#
# Iteration: 169
# Train loss: physical 0.03870636597275734 | data 0.0006072725518606603 | total 0.03931363672018051
# Valid loss: physical 0.03877042606472969 | data 0.0005749941919930279 | total 0.03934542089700699
# New best model saved at iteration 169 with validation physical loss 0.038770
#
# Iteration: 170
# Train loss: physical 0.03814531862735748 | data 0.0005693049170076847 | total 0.03871462494134903
# Valid loss: physical 0.038121215999126434 | data 0.0005663373158313334 | total 0.03868755325675011
# New best model saved at iteration 170 with validation physical loss 0.038121
#
# Iteration: 171
# Train loss: physical 0.03711376711726189 | data 0.0005403993418440223 | total 0.03765416517853737
# Valid loss: physical 0.037852056324481964 | data 0.0005597167764790356 | total 0.03841177374124527
# New best model saved at iteration 171 with validation physical loss 0.037852
#
# Iteration: 172
# Train loss: physical 0.037428826093673706 | data 0.0005611329106613994 | total 0.03798995912075043
# Valid loss: physical 0.03675340861082077 | data 0.0005568976048380136 | total 0.03731030598282814
# New best model saved at iteration 172 with validation physical loss 0.036753
#
# Iteration: 173
# Train loss: physical 0.036019306629896164 | data 0.0005867395084351301 | total 0.03660604730248451
# Valid loss: physical 0.03672486171126366 | data 0.0005526543827727437 | total 0.03727751597762108
# New best model saved at iteration 173 with validation physical loss 0.036725
#
# Iteration: 174
# Train loss: physical 0.03568411245942116 | data 0.0005145689356140792 | total 0.036198683083057404
# Valid loss: physical 0.035700518637895584 | data 0.0005429529119282961 | total 0.03624347224831581
# New best model saved at iteration 174 with validation physical loss 0.035701
#
# Iteration: 175
# Train loss: physical 0.034901928156614304 | data 0.0005590432556346059 | total 0.03546097129583359
# Valid loss: physical 0.035599496215581894 | data 0.0005335127934813499 | total 0.03613300994038582
# New best model saved at iteration 175 with validation physical loss 0.035599
#
# Iteration: 176
# Train loss: physical 0.03505498543381691 | data 0.0005226084031164646 | total 0.035577595233917236
# Valid loss: physical 0.034828029572963715 | data 0.000527423107996583 | total 0.035355452448129654
# New best model saved at iteration 176 with validation physical loss 0.034828
#
# Iteration: 177
# Train loss: physical 0.034015364944934845 | data 0.0005144313909113407 | total 0.03452979773283005
# Valid loss: physical 0.0346788614988327 | data 0.0005222113104537129 | total 0.035201072692871094
# New best model saved at iteration 177 with validation physical loss 0.034679
#
# Iteration: 178
# Train loss: physical 0.03388294205069542 | data 0.0005230702226981521 | total 0.034406013786792755
# Valid loss: physical 0.03374365717172623 | data 0.0005109062185510993 | total 0.034254562109708786
# New best model saved at iteration 178 with validation physical loss 0.033744
#
# Iteration: 179
# Train loss: physical 0.03335082158446312 | data 0.0005169717478565872 | total 0.03386779502034187
# Valid loss: physical 0.03329833596944809 | data 0.0005013605114072561 | total 0.03379969671368599
# New best model saved at iteration 179 with validation physical loss 0.033298
#
# Iteration: 180
# Train loss: physical 0.0321599505841732 | data 0.0004851990088354796 | total 0.032645151019096375
# Valid loss: physical 0.03271571174263954 | data 0.0004976547206752002 | total 0.03321336582303047
# New best model saved at iteration 180 with validation physical loss 0.032716
#
# Iteration: 181
# Train loss: physical 0.03173980116844177 | data 0.0004925504326820374 | total 0.03223235160112381
# ...
# Valid loss: physical 0.0011912551708519459 | data 2.2124127099232282e-06 | total 0.001193467527627945
#
# Iteration: 2930
# Train loss: physical 0.00012332714686635882 | data 2.418705093987228e-07 | total 0.0001235690142493695
# Valid loss: physical 0.001191152143292129 | data 2.171459982491797e-06 | total 0.0011933236382901669
#
# Iteration: 2931
# Train loss: physical 0.00012252152373548597 | data 2.645394374667376e-07 | total 0.00012278606300242245
# Valid loss: physical 0.0011894450290128589 | data 2.1763485165138263e-06 | total 0.0011916214134544134
#
# Iteration: 2932
# Train loss: physical 0.00012378192332107574 | data 2.5429304173485434e-07 | total 0.00012403621803969145
# Valid loss: physical 0.0011880238307639956 | data 2.1677631139027653e-06 | total 0.001190191600471735
#
# Iteration: 2933
# Train loss: physical 0.00012607777898665518 | data 2.3681963057242683e-07 | total 0.00012631459685508162
# Valid loss: physical 0.0011975131928920746 | data 2.2017950414010556e-06 | total 0.0011997149558737874
#
# Iteration: 2934
# Train loss: physical 0.00012718905054498464 | data 2.4684229060767393e-07 | total 0.00012743589468300343
# Valid loss: physical 0.0011934962822124362 | data 2.180927367589902e-06 | total 0.001195677206851542
#
# Iteration: 2935
# Train loss: physical 0.00012844718003179878 | data 2.515937467251206e-07 | total 0.00012869876809418201
# Valid loss: physical 0.0011891942704096437 | data 2.188910912082065e-06 | total 0.0011913832277059555
#
# Iteration: 2936
# Train loss: physical 0.0001263680460397154 | data 2.4717957103348454e-07 | total 0.00012661522487178445
# Valid loss: physical 0.0011923712445423007 | data 2.2088713649282e-06 | total 0.001194580108858645
#
# Iteration: 2937
# Train loss: physical 0.00012720120139420033 | data 2.448917086894653e-07 | total 0.0001274460955755785
# Valid loss: physical 0.0011999895796179771 | data 2.2019548850948922e-06 | total 0.0012021915754303336
#
# Iteration: 2938
# Train loss: physical 0.0001256173854926601 | data 2.403630503522436e-07 | total 0.00012585775402840227
# Valid loss: physical 0.0012111063115298748 | data 2.236609361716546e-06 | total 0.0012133428826928139
#
# Iteration: 2939
# Train loss: physical 0.00012403404980432242 | data 2.4921413910306e-07 | total 0.00012428326590452343
# Valid loss: physical 0.001221613259986043 | data 2.2623344193561934e-06 | total 0.0012238755589351058
#
# Iteration: 2940
# Train loss: physical 0.00012689769209828228 | data 2.3743533006381767e-07 | total 0.0001271351211471483
# Valid loss: physical 0.0012112784897908568 | data 2.23367965190846e-06 | total 0.0012135121505707502
#
# Iteration: 2941
# Train loss: physical 0.00012741399405058473 | data 2.4524436526007776e-07 | total 0.0001276592374779284
# Valid loss: physical 0.0012068140786141157 | data 2.231911821581889e-06 | total 0.0012090459931641817
#
# Iteration: 2942
# Train loss: physical 0.00012554538261611015 | data 2.4292475586662476e-07 | total 0.0001257883122889325
# Valid loss: physical 0.001197327859699726 | data 2.2218555386643857e-06 | total 0.001199549762532115
#
# Iteration: 2943
# Train loss: physical 0.00012223805242683738 | data 2.455215906138619e-07 | total 0.0001224835723405704
# Valid loss: physical 0.0011924415593966842 | data 2.1930193270236487e-06 | total 0.00119463459122926
#
# Iteration: 2944
# Train loss: physical 0.0001251394860446453 | data 2.425454397325666e-07 | total 0.00012538203736767173
# Valid loss: physical 0.0011856501223519444 | data 2.1685491446987726e-06 | total 0.0011878187069669366
#
# Iteration: 2945
# Train loss: physical 0.00012470198271330446 | data 2.280379760577489e-07 | total 0.0001249300257768482
# Valid loss: physical 0.001188661903142929 | data 2.152944716726779e-06 | total 0.0011908148881047964
#
# Iteration: 2946
# Train loss: physical 0.00012433445954229683 | data 2.519757060781558e-07 | total 0.00012458644050639123
# Valid loss: physical 0.0011849034344777465 | data 2.147815848729806e-06 | total 0.0011870512971654534
#
# Iteration: 2947
# Train loss: physical 0.00012431216600816697 | data 2.6160816446463286e-07 | total 0.00012457378034014255
# Valid loss: physical 0.001194547745399177 | data 2.16702937905211e-06 | total 0.0011967148166149855
#
# Iteration: 2948
# Train loss: physical 0.00012219429481774569 | data 2.2843028091301676e-07 | total 0.0001224227307830006
# Valid loss: physical 0.0011952737113460898 | data 2.1829594061273383e-06 | total 0.0011974566150456667
#
# Iteration: 2949
# Train loss: physical 0.0001242125144926831 | data 2.290576759378382e-07 | total 0.00012444157619029284
# Valid loss: physical 0.0012048548087477684 | data 2.215625499957241e-06 | total 0.0012070704251527786
#
# Iteration: 2950
# Train loss: physical 0.00012255299952812493 | data 2.3171429575086222e-07 | total 0.00012278470967430621
# Valid loss: physical 0.0012053318787366152 | data 2.220614760517492e-06 | total 0.001207552501000464
#
# Iteration: 2951
# Train loss: physical 0.0001234607771039009 | data 2.4415007260358834e-07 | total 0.00012370492913760245
# Valid loss: physical 0.0011963649885728955 | data 2.2035026177036343e-06 | total 0.0011985684977844357
#
# Iteration: 2952
# Train loss: physical 0.00012275422341190279 | data 2.3597732479174738e-07 | total 0.00012299019726924598
# Valid loss: physical 0.0011937576346099377 | data 2.201970573878498e-06 | total 0.0011959596304222941
#
# Iteration: 2953
# Train loss: physical 0.00012071002129232511 | data 2.3373151236683043e-07 | total 0.00012094375415472314
# Valid loss: physical 0.001198446610942483 | data 2.1903531433054013e-06 | total 0.0012006369652226567
#
# Iteration: 2954
# Train loss: physical 0.0001214208677993156 | data 2.4817217081363196e-07 | total 0.00012166904343757778
# Valid loss: physical 0.0011876533972099423 | data 2.1747525806858903e-06 | total 0.0011898281518369913
#
# Iteration: 2955
# Train loss: physical 0.00012421311112120748 | data 2.3335002197200083e-07 | total 0.00012444646563380957
# Valid loss: physical 0.0011988383485004306 | data 2.1834082417626632e-06 | total 0.0012010217178612947
#
# Iteration: 2956
# Train loss: physical 0.00012418866390362382 | data 2.3337976529091975e-07 | total 0.00012442204752005637
# Valid loss: physical 0.001200080499984324 | data 2.186245410484844e-06 | total 0.0012022667797282338
#
# Iteration: 2957
# Train loss: physical 0.0001227973698405549 | data 2.456362722114136e-07 | total 0.00012304300616960973
# Valid loss: physical 0.0011819396167993546 | data 2.154476078430889e-06 | total 0.0011840941151604056
#
# Iteration: 2958
# Train loss: physical 0.00012097669241484255 | data 2.2648261222002475e-07 | total 0.00012120317842345685
# Valid loss: physical 0.0011780839413404465 | data 2.1556279534706846e-06 | total 0.0011802396038547158
#
# Iteration: 2959
# Train loss: physical 0.0001222822756972164 | data 2.5936557790373627e-07 | total 0.00012254163448233157
# Valid loss: physical 0.001196439377963543 | data 2.1837279291503364e-06 | total 0.0011986230965703726
#
# Iteration: 2960
# Train loss: physical 0.00012425136810634285 | data 2.3396660253638402e-07 | total 0.00012448533379938453
# Valid loss: physical 0.001190112205222249 | data 2.184336153732147e-06 | total 0.0011922965059056878
#
# Iteration: 2961
# Train loss: physical 0.00012229908315930516 | data 2.1494298607649398e-07 | total 0.00012251402949914336
# Valid loss: physical 0.001196258352138102 | data 2.1940820715826703e-06 | total 0.0011984524317085743
#
# Iteration: 2962
# Train loss: physical 0.00012364650319796056 | data 2.488695827196352e-07 | total 0.00012389537005219609
# Valid loss: physical 0.0011924190912395716 | data 2.2036124391888734e-06 | total 0.0011946227168664336
#
# Iteration: 2963
# Train loss: physical 0.00012312018952798098 | data 2.2332496030230686e-07 | total 0.00012334351777099073
# Valid loss: physical 0.0011963456636294723 | data 2.19688035940635e-06 | total 0.0011985425371676683
#
# Iteration: 2964
# Train loss: physical 0.00012157094897702336 | data 2.3175631724825507e-07 | total 0.00012180270277895033
# Valid loss: physical 0.0011961522977799177 | data 2.1972482500132173e-06 | total 0.0011983495205640793
#
# Iteration: 2965
# Train loss: physical 0.00012553251872304827 | data 2.3345128852270136e-07 | total 0.00012576597509905696
# Valid loss: physical 0.0011987196048721671 | data 2.1856219518667785e-06 | total 0.001200905186124146
#
# Iteration: 2966
# Train loss: physical 0.00012840975250583142 | data 2.459008214827918e-07 | total 0.00012865565076936036
# Valid loss: physical 0.0011953574139624834 | data 2.179716602768167e-06 | total 0.001197537174448371
#
# Iteration: 2967
# Train loss: physical 0.00012707388668786734 | data 2.425439333819668e-07 | total 0.00012731642345897853
# Valid loss: physical 0.0012010196223855019 | data 2.190302211602102e-06 | total 0.0012032099766656756
#
# Iteration: 2968
# Train loss: physical 0.00012346231960691512 | data 2.2495662221899693e-07 | total 0.00012368727766443044
# Valid loss: physical 0.0012009743368253112 | data 2.2097290184319718e-06 | total 0.0012031840160489082
#
# Iteration: 2969
# Train loss: physical 0.0001260297285625711 | data 2.5023649641298107e-07 | total 0.0001262799632968381
# Valid loss: physical 0.0012051282683387399 | data 2.226800916105276e-06 | total 0.0012073550606146455
#
# Iteration: 2970
# Train loss: physical 0.00012797630915883929 | data 2.4859039626790036e-07 | total 0.00012822489952668548
# Valid loss: physical 0.0012084365589544177 | data 2.220691158072441e-06 | total 0.0012106572976335883
#
# Iteration: 2971
# Train loss: physical 0.0001248191692866385 | data 2.1484804335614172e-07 | total 0.0001250340137630701
# Valid loss: physical 0.0012075054692104459 | data 2.231950929854065e-06 | total 0.0012097373837605119
#
# Iteration: 2972
# Train loss: physical 0.0001252896909136325 | data 2.4005862542253453e-07 | total 0.00012552975385915488
# Valid loss: physical 0.0012176769087091088 | data 2.280179160152329e-06 | total 0.001219957135617733
#
# Iteration: 2973
# Train loss: physical 0.00012467277701944113 | data 2.486569030679675e-07 | total 0.00012492144014686346
# Valid loss: physical 0.0012178755132481456 | data 2.2641602299700025e-06 | total 0.0012201396748423576
#
# Iteration: 2974
# Train loss: physical 0.00012458814308047295 | data 2.532756582240836e-07 | total 0.00012484141916502267
# Valid loss: physical 0.001207674271427095 | data 2.212891786257387e-06 | total 0.0012098872102797031
#
# Iteration: 2975
# Train loss: physical 0.00012352550402283669 | data 2.3496451717619493e-07 | total 0.00012376047379802912
# Valid loss: physical 0.0011983421863988042 | data 2.1882888177060522e-06 | total 0.001200530445203185
#
# Iteration: 2976
# Train loss: physical 0.00012255263573024422 | data 2.1011948092564126e-07 | total 0.0001227627508342266
# Valid loss: physical 0.0012005571043118834 | data 2.186164465456386e-06 | total 0.0012027432676404715
#
# Iteration: 2977
# Train loss: physical 0.00012319267261773348 | data 2.2119522213870368e-07 | total 0.00012341386172920465
# Valid loss: physical 0.0011924527352675796 | data 2.154957201128127e-06 | total 0.001194607699289918
#
# Iteration: 2978
# Train loss: physical 0.00012365019938442856 | data 2.2223788676001277e-07 | total 0.00012387243623379618
# Valid loss: physical 0.0011891537578776479 | data 2.1589705738733755e-06 | total 0.0011913126800209284
#
# Iteration: 2979
# Train loss: physical 0.00012351680197753012 | data 2.572355697338935e-07 | total 0.00012377403618302196
# Valid loss: physical 0.0011873493203893304 | data 2.1710925466322806e-06 | total 0.0011895204661414027
#
# Iteration: 2980
# Train loss: physical 0.00012423134467098862 | data 2.3335987009431847e-07 | total 0.0001244646991835907
# Valid loss: physical 0.001203902531415224 | data 2.199639084210503e-06 | total 0.001206102198921144
#
# Iteration: 2981
# Train loss: physical 0.00012357128434814513 | data 2.2776683294978284e-07 | total 0.00012379905092529953
# Valid loss: physical 0.001208487548865378 | data 2.218067720605177e-06 | total 0.0012107056099921465
#
# Iteration: 2982
# Train loss: physical 0.00012350798351690173 | data 2.3471454824175453e-07 | total 0.00012374269135762006
# Valid loss: physical 0.0012010977370664477 | data 2.2169188014231622e-06 | total 0.001203314634039998
#
# Iteration: 2983
# Train loss: physical 0.00012322056863922626 | data 2.3337675258972013e-07 | total 0.0001234539522556588
# Valid loss: physical 0.0012097351718693972 | data 2.2296360384643776e-06 | total 0.0012119647581130266
#
# Iteration: 2984
# Train loss: physical 0.00012399090337567031 | data 2.1719442599987815e-07 | total 0.0001242080907104537
# Valid loss: physical 0.0012013831874355674 | data 2.21279583456635e-06 | total 0.0012035960098728538
#
# Iteration: 2985
# Train loss: physical 0.0001238234108313918 | data 2.5341142873003264e-07 | total 0.0001240768178831786
# Valid loss: physical 0.0012064602924510837 | data 2.2113417799118906e-06 | total 0.0012086716014891863
#
# Iteration: 2986
# Train loss: physical 0.00012273312313482165 | data 2.2405117761081783e-07 | total 0.00012295717897359282
# Valid loss: physical 0.001218509511090815 | data 2.2267738586378982e-06 | total 0.0012207363033667207
#
# Iteration: 2987
# Train loss: physical 0.00012673343007918447 | data 2.256274029832639e-07 | total 0.0001269590575248003
# Valid loss: physical 0.0012092767283320427 | data 2.2207500478543807e-06 | total 0.0012114974670112133
#
# Iteration: 2988
# Train loss: physical 0.00012424624583218247 | data 2.3725313269551407e-07 | total 0.00012448350025806576
# Valid loss: physical 0.0012054634280502796 | data 2.2365634322341066e-06 | total 0.0012076999992132187
#
# Iteration: 2989
# Train loss: physical 0.0001227208413183689 | data 2.3066164089868835e-07 | total 0.00012295150372665375
# Valid loss: physical 0.001203967141918838 | data 2.2355081910063745e-06 | total 0.0012062026653438807
#
# Iteration: 2990
# Train loss: physical 0.00012443149171303958 | data 2.446022904223355e-07 | total 0.0001246760948561132
# Valid loss: physical 0.00119727139826864 | data 2.208381602031295e-06 | total 0.001199479796923697
#
# Iteration: 2991
# Train loss: physical 0.00012479127326514572 | data 2.1979037967412296e-07 | total 0.00012501106539275497
# Valid loss: physical 0.001205194042995572 | data 2.2249964786169585e-06 | total 0.0012074190890416503
#
# Iteration: 2992
# Train loss: physical 0.00012696027988567948 | data 2.338187101713629e-07 | total 0.00012719410005956888
# Valid loss: physical 0.0012073124526068568 | data 2.2056678972148802e-06 | total 0.0012095181737095118
#
# Iteration: 2993
# Train loss: physical 0.00012933957623317838 | data 2.4368745243918966e-07 | total 0.0001295832626055926
# Valid loss: physical 0.0012095451820641756 | data 2.196676632593153e-06 | total 0.001211741822771728
#
# Iteration: 2994
# Train loss: physical 0.0001266499748453498 | data 2.3863231035647914e-07 | total 0.00012688861170317978
# Valid loss: physical 0.0011942031560465693 | data 2.1698119780921843e-06 | total 0.0011963730212301016
#
# Iteration: 2995
# Train loss: physical 0.0001255021197721362 | data 2.2337077609790867e-07 | total 0.00012572549167089164
# Valid loss: physical 0.0011921704281121492 | data 2.1609223495033802e-06 | total 0.0011943313293159008
#
# Iteration: 2996
# Train loss: physical 0.00020078958186786622 | data 2.334396498326896e-07 | total 0.00020102302369195968
# Valid loss: physical 0.0011894390918314457 | data 2.2523465759149985e-06 | total 0.0011916914954781532
#
# Iteration: 2997
# Train loss: physical 0.00013939011842012405 | data 3.564531425581663e-07 | total 0.0001397465675836429
# Valid loss: physical 0.0011991880601271987 | data 2.2801239083491964e-06 | total 0.001201468170620501
#
# Iteration: 2998
# Train loss: physical 0.00015555525897070765 | data 4.1638040215730143e-07 | total 0.00015597163292113692
# Valid loss: physical 0.0012255697511136532 | data 2.31706621889316e-06 | total 0.0012278867652639747
#
# Iteration: 2999
# Train loss: physical 0.00015905691543594003 | data 3.7109535355739354e-07 | total 0.0001594280038261786
# Valid loss: physical 0.0012338090455159545 | data 2.329006065338035e-06 | total 0.0012361380504444242
#
# Iteration: 3000
# Train loss: physical 0.00015884210006333888 | data 3.5664803021973057e-07 | total 0.00015919875295367092
# Valid loss: physical 0.001234804978594184 | data 2.326352841919288e-06 | total 0.0012371313059702516

# %%
counter_indices = np.arange(1, len(loss_history['train_physical'])+1)
plt.loglog(counter_indices, loss_history['train_physical'], label='Training Loss (Residual)', color='blue')
plt.loglog(counter_indices, loss_history['train_data'], label='Training Loss (Data)', color='red')
plt.loglog(counter_indices, loss_history['valid_physical'], label='Validation Loss (Residual)', color='orange')
plt.loglog(counter_indices, loss_history['valid_data'], label='Validation Loss (Data)', color='green')
plt.plot(counter_indices[-1], loss_history['train_physical'][-1], 'bo', markersize=5, label='Final training loss (Residual)')  # blue dot on last point
plt.plot(best_model_iterations[-1], loss_history['valid_physical'][best_model_iterations[-1]-1], 'go', markersize=5, label='Lowest validation loss (Residual)')  # red dot for best model iteration
plt.plot(best_model_iterations, [loss_history['valid_physical'][i-1] for i in best_model_iterations], 'gx', markersize=2, label='Best model saved (Residual)')  # green dots for best model iterations
# Annotate the last value
plt.annotate(f'{loss_history['train_physical'][-1]:.2e}',
             xy=(counter_indices[-1], loss_history['train_physical'][-1]),
             xytext=(-20, 30),
             textcoords='offset points',
             color='red',
             fontsize=8,
             arrowprops=dict(arrowstyle='->', color='red', lw=0.5))

plt.annotate(f'{loss_history['valid_physical'][best_model_iterations[-1]-1]:.2e}',
                xy=(best_model_iterations[-1], loss_history['valid_physical'][best_model_iterations[-1]-1]),
                xytext=(-20, 40),
                textcoords='offset points',
                color='red',
                fontsize=8,
                arrowprops=dict(arrowstyle='->', color='red', lw=0.5))

plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title(f'Loss history (num_train: {num_train} | num_valid: {num_valid})')
plt.legend()
plt.savefig(os.path.join(model_train_outputs_path, f'loss_history_{num_train}.png'), dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
model = ConvolutionalNN_129x129(output_dim=num_basis, activation='leakyrelu', init_func='xavier_uniform')
model.load_state_dict(torch.load(os.path.join(model_train_outputs_path, f"best_model_params_{num_train}.pth")))
model = model.to(device)

# %%
num_test = 500

test_p_dof = load_npy(test_dataset_path+'/p_dof.npy')[:num_test]
test_sigma_u_dof = load_npy(test_dataset_path+'/sigma_u_dof.npy')[:num_test]
test_p_vertex_values = load_npy(test_dataset_path+'/p_vertex_values.npy')[:num_test]

# %%
test_image_p_vertex_values = np.zeros((num_test, 1, mesh_args['num_y']+1, mesh_args['num_x']+1))
for i in tqdm(range(num_test)):
    test_image_p_vertex_values[i,0,:,:] = test_p_vertex_values[i].reshape(num_x+1, num_y+1).T
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 6500.52it/s]

# %%
test_p_vertex_values_tensor = torch.tensor(test_image_p_vertex_values, dtype=torch_dtype['float32']).to(device)

# %%
test_pod_coeff_pred  = model(test_p_vertex_values_tensor)
test_pod_coeff_pred = test_pod_coeff_pred.cpu().detach()
test_pred = test_pod_coeff_pred.to(torch.float64) @ pod_basis_dof.T
test_pred = test_pred.numpy()

# %%
np.save(os.path.join(model_test_outputs_path, "test_pred_sigma_u_dof.npy"), test_pred)

# %%
compute_squared_L2_norm = poisson_least_squares.compute_squared_L2_norm
compute_squared_hdiv_h1_norm = poisson_least_squares.compute_squared_hdiv_h1_norm

# %%
sigma_u_norm_dict = {
    'squared_L2': np.zeros(num_test),
    'avg_squared_L2': 0.0,
    'squared_hdiv_h1': np.zeros(num_test),
    'avg_squared_hdiv_h1': 0.0
}

# %%
for i in tqdm(range(num_test)):
    sigma_u_label_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_label_fc.x.array[:] = test_sigma_u_dof[i] 
    sigma_u_norm_dict['squared_L2'][i] = compute_squared_L2_norm(sigma_u_label_fc)
sigma_u_norm_dict['avg_squared_L2'] = np.mean(sigma_u_norm_dict['squared_L2'])
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 175.62it/s]

# %%
for i in tqdm(range(num_test)):
    sigma_u_label_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_label_fc.x.array[:] = test_sigma_u_dof[i]
    sigma_label_fc = sigma_u_label_fc.sub(0).collapse()
    u_label_fc = sigma_u_label_fc.sub(1).collapse()
    sigma_u_norm_dict['squared_hdiv_h1'][i] = compute_squared_hdiv_h1_norm(sigma_label_fc, u_label_fc)
sigma_u_norm_dict['avg_squared_hdiv_h1'] = np.mean(sigma_u_norm_dict['squared_hdiv_h1'])
# Out:
# 100%|██████████| 500/500 [00:07<00:00, 68.88it/s]

# %%
print(f"Average squared L2 norm of sigma_u: {sigma_u_norm_dict['avg_squared_L2']:.2e}")
print(f"Average squared H(div)xH1 norm of sigma_u: {sigma_u_norm_dict['avg_squared_hdiv_h1']:.2e}")
# Out:
# Average squared L2 norm of sigma_u: 2.54e-01
# Average squared H(div)xH1 norm of sigma_u: 1.43e+00

# %%
sigma_u_error_dict = {
    'squared_L2': np.zeros(num_test),
    'relative_squared_L2': np.zeros(num_test),
    'squared_hdiv_h1': np.zeros(num_test),
    'relative_squared_hdiv_h1': np.zeros(num_test)
}

# %%
for i in tqdm(range(num_test)):
    sigma_u_label_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_label_fc.x.array[:] = test_sigma_u_dof[i]
    sigma_label_fc = sigma_u_label_fc.sub(0).collapse()
    u_label_fc = sigma_u_label_fc.sub(1).collapse()

    sigma_u_pred_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_pred_fc.x.array[:] = test_pred[i]
    sigma_pred_fc = sigma_u_pred_fc.sub(0).collapse()
    u_pred_fc = sigma_u_pred_fc.sub(1).collapse()

    sigma_u_error_dict['squared_L2'][i] = compute_squared_L2_norm(sigma_u_label_fc - sigma_u_pred_fc)
    sigma_u_error_dict['relative_squared_L2'][i] = sigma_u_error_dict['squared_L2'][i] / sigma_u_norm_dict['avg_squared_L2']

    sigma_u_error_dict['squared_hdiv_h1'][i] = compute_squared_hdiv_h1_norm(sigma_label_fc - sigma_pred_fc, u_label_fc - u_pred_fc)
    sigma_u_error_dict['relative_squared_hdiv_h1'][i] = sigma_u_error_dict['squared_hdiv_h1'][i] / sigma_u_norm_dict['avg_squared_hdiv_h1']
# Out:
# 100%|██████████| 500/500 [00:18<00:00, 27.53it/s]

# %%
sigma_u_error_dict['bochner_L2'] = np.sqrt(np.mean(sigma_u_error_dict['squared_L2']))
sigma_u_error_dict['relative_bochner_L2'] = np.sqrt(np.mean(sigma_u_error_dict['relative_squared_L2']))
sigma_u_error_dict['bochner_hdiv_h1'] = np.sqrt(np.mean(sigma_u_error_dict['squared_hdiv_h1']))
sigma_u_error_dict['relative_bochner_hdiv_h1'] = np.sqrt(np.mean(sigma_u_error_dict['relative_squared_hdiv_h1']))

sigma_u_error_dict['std_L2'] = np.std(np.sqrt(sigma_u_error_dict['squared_L2']))
sigma_u_error_dict['std_relative_L2'] = np.std(np.sqrt(sigma_u_error_dict['relative_squared_L2']))
sigma_u_error_dict['std_hdiv_h1'] = np.std(np.sqrt(sigma_u_error_dict['squared_hdiv_h1']))
sigma_u_error_dict['std_relative_hdiv_h1'] = np.std(np.sqrt(sigma_u_error_dict['relative_squared_hdiv_h1']))

# %%
print(f'sigma_u relative Bochner L2 error (std): {sigma_u_error_dict["relative_bochner_L2"]:.2e} ({sigma_u_error_dict["std_relative_L2"]:.2e})')
print(f'sigma_u relative Bochner H(div) x H1 error (std): {sigma_u_error_dict["relative_bochner_hdiv_h1"]:.2e} ({sigma_u_error_dict["std_relative_hdiv_h1"]:.2e})')
# Out:
# sigma_u relative Bochner L2 error (std): 2.25e-02 (7.69e-03)
# sigma_u relative Bochner H(div) x H1 error (std): 1.71e-02 (5.38e-03)

# %%
np.save(os.path.join(model_test_outputs_path, "sigma_u_error_dict.npy"), sigma_u_error_dict)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
def plot_ref_pred_diff(x, y, ref_f_grid_evals, pred_f_grid_evals, diff_f_grid_evals, variable_name, 
                        levels=100, 
                        ref_pred_format='%.3f',
                        ref_pred_colorbar_pad=0.02, 
                        diff_colorbar_pad=0.01,
                        tick_labelsize=15,  # NEW: control tick font size
                        colorbar_labelsize=15):  # NEW: control colorbar tick font size

    vmin = min(ref_f_grid_evals.min(), pred_f_grid_evals.min())
    vmax = max(ref_f_grid_evals.max(), pred_f_grid_evals.max())

    fig, axs = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

    # Reference
    cf0 = axs[0].tricontourf(x, y, ref_f_grid_evals, levels=levels, cmap='turbo', vmin=vmin, vmax=vmax)
    axs[0].set_title(fr'Reference {variable_name}', fontsize=18)
    axs[0].tick_params(axis='both', which='major', labelsize=tick_labelsize)
    axs[0].set_xticklabels([])
    axs[0].set_yticklabels([])


    # Prediction
    cf1 = axs[1].tricontourf(x, y, pred_f_grid_evals, levels=levels, cmap='turbo', vmin=vmin, vmax=vmax)
    axs[1].set_title(fr'Prediction {variable_name}', fontsize=18)
    axs[1].tick_params(axis='both', which='major', labelsize=tick_labelsize)
    axs[1].set_xticklabels([])
    axs[1].set_yticklabels([])

    # Shared colorbar for first two subplots
    cbar_shared = fig.colorbar(cf1, ax=[axs[0], axs[1]], format=ref_pred_format, pad=ref_pred_colorbar_pad)
    cbar_shared.ax.tick_params(labelsize=colorbar_labelsize)  # Increase colorbar ticks
    cbar_shared.locator = ticker.MaxNLocator(nbins=5)
    cbar_shared.update_ticks()

    # Difference plot (independent colorbar)
    cf2 = axs[2].tricontourf(x, y, diff_f_grid_evals, levels=levels, cmap='turbo')
    axs[2].set_title(fr'Difference {variable_name}', fontsize=18)
    axs[2].tick_params(axis='both', which='major', labelsize=tick_labelsize)
    axs[2].set_xticklabels([])
    axs[2].set_yticklabels([])

    cbar_diff = fig.colorbar(cf2, ax=axs[2], pad=diff_colorbar_pad)
    cbar_diff.ax.tick_params(labelsize=colorbar_labelsize)  # Increase colorbar ticks
    cbar_diff.formatter = ticker.ScalarFormatter(useMathText=True)
    cbar_diff.formatter.set_scientific(True)
    cbar_diff.formatter.set_powerlimits((-2, 2))
    cbar_diff.locator = ticker.MaxNLocator(nbins=5)
    cbar_diff.update_ticks()

    cbar_diff.ax.yaxis.get_offset_text().set_fontsize(colorbar_labelsize)

    # Remove ticks on x and y axes if needed
    for ax in axs:
        ax.tick_params(left=False, bottom=False)

    return fig

# %%
for i in range(3):
    # plt.figure(figsize=(6, 5))  # Optional: larger figure size
    img = plt.imshow(test_p_vertex_values_tensor[i,0,:,:].cpu().numpy(),
                     extent=[0, 1, 0, 1], origin='lower', cmap='turbo')

    cbar = plt.colorbar()
    cbar.ax.tick_params(labelsize=16)  # Increase colorbar tick labels

    plt.title('parameter (setup 1)', fontsize=20)
    # plt.xticks(fontsize=16)
    # plt.yticks(fontsize=16)

    plt.savefig(os.path.join(model_test_outputs_path, f'test_p_{i}.png'),
                dpi=300, bbox_inches='tight')
    plt.close()

# %%
for test_sample_index in range(3):
    pred_sigma_u_fc = dolfinx.fem.Function(Vh['sigma_u'])
    pred_sigma_u_fc.x.array[:] = test_pred[test_sample_index]
    pred_sigma_fc = pred_sigma_u_fc.sub(0).collapse()
    pred_u_fc = pred_sigma_u_fc.sub(1).collapse()

    ref_sigma_u_fc = dolfinx.fem.Function(Vh['sigma_u'])
    ref_sigma_u_fc.x.array[:] = test_sigma_u_dof[test_sample_index]
    ref_sigma_fc = ref_sigma_u_fc.sub(0).collapse()
    ref_u_fc = ref_sigma_u_fc.sub(1).collapse()


    pred_sigma_grid_evals = evaluate_expression(mesh, pred_sigma_fc, mesh.geometry.x)[1]
    pred_u_grid_evals = evaluate_expression(mesh, pred_u_fc, mesh.geometry.x)[1]


    ref_sigma_grid_evals = evaluate_expression(mesh, ref_sigma_fc, mesh.geometry.x)[1]
    ref_u_grid_evals = evaluate_expression(mesh, ref_u_fc, mesh.geometry.x)[1]


    diff_sigma_grid_evals = pred_sigma_grid_evals - ref_sigma_grid_evals
    diff_u_grid_evals = pred_u_grid_evals - ref_u_grid_evals

    x = mesh.geometry.x[:, 0]
    y = mesh.geometry.x[:, 1]


    fig = plot_ref_pred_diff(x, y, ref_u_grid_evals[:,0], pred_u_grid_evals[:,0], diff_u_grid_evals[:,0], r'$u^{\circ}$',
                            levels=100,
                            ref_pred_format='%.3f',
                            ref_pred_colorbar_pad=0.01,
                            diff_colorbar_pad=-0.01)
    fig.savefig(os.path.join(model_test_outputs_path, f'u_ref_pred_diff_{test_sample_index}.png'), dpi=300, bbox_inches='tight')


    fig = plot_ref_pred_diff(x, y, ref_sigma_grid_evals[:,0], pred_sigma_grid_evals[:, 0], diff_sigma_grid_evals[:, 0], r'$\sigma_1^{\circ}$', 
                            levels=100,
                            ref_pred_format='%.1f',
                            ref_pred_colorbar_pad=0.01, 
                            diff_colorbar_pad=-0.01)
    fig.savefig(os.path.join(model_test_outputs_path, f'sigma_1_ref_pred_diff_{test_sample_index}.png'), dpi=300, bbox_inches='tight')


    fig = plot_ref_pred_diff(x, y, ref_sigma_grid_evals[:,1], pred_sigma_grid_evals[:, 1], diff_sigma_grid_evals[:, 1], r'$\sigma_2^{\circ}$', 
                            levels=100,
                            ref_pred_format='%.1f',
                            ref_pred_colorbar_pad=0.01, 
                            diff_colorbar_pad=-0.01)
    fig.savefig(os.path.join(model_test_outputs_path, f'sigma_2_ref_pred_diff_{test_sample_index}.png'), dpi=300, bbox_inches='tight')

# %%
compute_physical_loss_1 = poisson_least_squares.compute_physical_loss_1
compute_physical_loss_2 = poisson_least_squares.compute_physical_loss_2

# %%
residual_loss_dict = {
    'loss_1': np.zeros(num_test),
    'loss_2': np.zeros(num_test),
    'total_loss': np.zeros(num_test),
    'sqrt_total_loss': np.zeros(num_test)
}
for test_index in range(num_test): 
    pred_fc = dolfinx.fem.Function(Vh['sigma_u'])
    pred_fc.x.array[:] = test_pred[test_index]
    pred_sigma_fc = pred_fc.sub(0).collapse()
    pred_u_fc = pred_fc.sub(1).collapse()

    p_fc = dolfinx.fem.Function(Vh['p'])
    p_fc.x.array[:] = test_p_dof[test_index]

    residual_loss_1 = compute_physical_loss_1(pred_sigma_fc, pred_u_fc, p_fc)
    residual_loss_2 = compute_physical_loss_2(pred_sigma_fc, pred_u_fc, p_fc)

    residual_loss = residual_loss_1 + residual_loss_2

    sqrt_residual_loss = np.sqrt(residual_loss)

    residual_loss_dict['loss_1'][test_index] = residual_loss_1
    residual_loss_dict['loss_2'][test_index] = residual_loss_2
    residual_loss_dict['total_loss'][test_index] = residual_loss
    residual_loss_dict['sqrt_total_loss'][test_index] = sqrt_residual_loss
    print(f'Test sample {test_index}:')
    print(f'Residual loss 1: {residual_loss_1} | Residual loss 2: {residual_loss_2}')
    print(f'Total residual loss: {residual_loss} | Sqrt residual loss: {sqrt_residual_loss}')

    print("")
# Out:
# Test sample 0:
# Residual loss 1: 0.00027672636048664686 | Residual loss 2: 6.350535561315729e-07
# Total residual loss: 0.0002773614140427784 | Sqrt residual loss: 0.01665417107041892
#
# Test sample 1:
# Residual loss 1: 0.00041171330502899156 | Residual loss 2: 1.350954633087997e-07
# Total residual loss: 0.0004118484004923004 | Sqrt residual loss: 0.020294048400757804
#
# Test sample 2:
# Residual loss 1: 0.000335289188835003 | Residual loss 2: 7.781648428589428e-07
# Total residual loss: 0.0003360673536778619 | Sqrt residual loss: 0.018332139909946737
#
# Test sample 3:
# Residual loss 1: 0.0007000920334135296 | Residual loss 2: 5.412202339526076e-06
# Total residual loss: 0.0007055042357530557 | Sqrt residual loss: 0.026561329706041744
#
# Test sample 4:
# Residual loss 1: 0.0002605827250994377 | Residual loss 2: 1.7831979307756681e-06
# Total residual loss: 0.0002623659230302134 | Sqrt residual loss: 0.016197713512413208
#
# Test sample 5:
# Residual loss 1: 0.0006437992799813438 | Residual loss 2: 1.594613407288635e-08
# Total residual loss: 0.0006438152261154167 | Sqrt residual loss: 0.02537351426419716
#
# Test sample 6:
# Residual loss 1: 0.0002768437678555932 | Residual loss 2: 1.9491234464165444e-06
# Total residual loss: 0.0002787928913020098 | Sqrt residual loss: 0.016697092300817222
#
# Test sample 7:
# Residual loss 1: 0.00023271232512522906 | Residual loss 2: 6.673828712393921e-07
# Total residual loss: 0.00023337970799646845 | Sqrt residual loss: 0.015276770208275977
#
# Test sample 8:
# Residual loss 1: 0.0004726542118026015 | Residual loss 2: 5.247621632268235e-08
# Total residual loss: 0.00047270668801892415 | Sqrt residual loss: 0.02174181887558914
#
# Test sample 9:
# Residual loss 1: 0.0004659018901333564 | Residual loss 2: 1.6813565989710456e-06
# Total residual loss: 0.0004675832467323275 | Sqrt residual loss: 0.02162367329415443
#
# Test sample 10:
# Residual loss 1: 0.00033528836242399944 | Residual loss 2: 2.246217624905839e-06
# Total residual loss: 0.0003375345800489053 | Sqrt residual loss: 0.018372114196490978
#
# Test sample 11:
# Residual loss 1: 0.0005078859520185488 | Residual loss 2: 3.1648048654131404e-07
# Total residual loss: 0.00050820243250509 | Sqrt residual loss: 0.022543345636907804
#
# Test sample 12:
# Residual loss 1: 0.00019429688658214773 | Residual loss 2: 1.647044400364292e-07
# Total residual loss: 0.00019446159102218415 | Sqrt residual loss: 0.013944948584422395
#
# Test sample 13:
# Residual loss 1: 0.0002660040628685377 | Residual loss 2: 1.6213604564847177e-06
# Total residual loss: 0.0002676254233250224 | Sqrt residual loss: 0.016359261087378684
#
# Test sample 14:
# Residual loss 1: 0.000640601995803516 | Residual loss 2: 1.4461436748603373e-06
# Total residual loss: 0.0006420481394783763 | Sqrt residual loss: 0.02533866885766449
#
# Test sample 15:
# Residual loss 1: 0.00033605373875451297 | Residual loss 2: 2.7809014914323387e-06
# Total residual loss: 0.00033883464024594533 | Sqrt residual loss: 0.01840746153726649
#
# Test sample 16:
# Residual loss 1: 0.00049101765092118 | Residual loss 2: 5.861423851123872e-07
# Total residual loss: 0.0004916037933062924 | Sqrt residual loss: 0.02217214002540784
#
# Test sample 17:
# Residual loss 1: 0.0002752512728221913 | Residual loss 2: 4.721352193366031e-08
# Total residual loss: 0.00027529848634412496 | Sqrt residual loss: 0.01659212121291684
#
# Test sample 18:
# Residual loss 1: 0.0003730065692483747 | Residual loss 2: 1.5572243976367204e-06
# Total residual loss: 0.0003745637936460114 | Sqrt residual loss: 0.01935365065423088
#
# Test sample 19:
# Residual loss 1: 0.0002948168975670345 | Residual loss 2: 1.8212099239535938e-06
# Total residual loss: 0.0002966381074909881 | Sqrt residual loss: 0.01722318517263831
# Test sample 20:
# Residual loss 1: 0.0004006650950020202 | Residual loss 2: 4.0620376016991614e-07
# Total residual loss: 0.00040107129876219014 | Sqrt residual loss: 0.020026764560512268
#
# Test sample 21:
# Residual loss 1: 0.0005372612633089038 | Residual loss 2: 5.352380718411615e-07
# Total residual loss: 0.000537796501380745 | Sqrt residual loss: 0.023190439870359184
#
# Test sample 22:
# Residual loss 1: 0.0006195570148263194 | Residual loss 2: 1.347097189468605e-07
# Total residual loss: 0.0006196917245452662 | Sqrt residual loss: 0.024893608106204015
#
# Test sample 23:
# Residual loss 1: 0.00033412499186329233 | Residual loss 2: 7.54872925477842e-09
# Total residual loss: 0.00033413254059254713 | Sqrt residual loss: 0.018279292672107067
#
# Test sample 24:
# Residual loss 1: 0.0004478973600903649 | Residual loss 2: 1.1639282178768055e-06
# Total residual loss: 0.0004490612883082417 | Sqrt residual loss: 0.021191066238116518
#
# Test sample 25:
# Residual loss 1: 0.0003397220269393885 | Residual loss 2: 2.7838680569538013e-06
# Total residual loss: 0.0003425058949963423 | Sqrt residual loss: 0.01850691478870377
#
# Test sample 26:
# Residual loss 1: 0.0002706218252539642 | Residual loss 2: 1.0414040485165543e-06
# Total residual loss: 0.00027166322930248076 | Sqrt residual loss: 0.016482209478782896
#
# Test sample 27:
# Residual loss 1: 0.0005195672470487567 | Residual loss 2: 7.966452470285858e-07
# Total residual loss: 0.0005203638922957854 | Sqrt residual loss: 0.02281148597298706
#
# Test sample 28:
# Residual loss 1: 0.00036976170052410164 | Residual loss 2: 4.6411770258806105e-09
# Total residual loss: 0.0003697663417011275 | Sqrt residual loss: 0.019229309444208535
#
# Test sample 29:
# Residual loss 1: 0.0006517568162733412 | Residual loss 2: 8.978843441329504e-06
# Total residual loss: 0.0006607356597146707 | Sqrt residual loss: 0.025704778927558795
#
# Test sample 30:
# Residual loss 1: 0.0003922688016827531 | Residual loss 2: 1.6874141938300907e-06
# Total residual loss: 0.0003939562158765832 | Sqrt residual loss: 0.019848330304501262
#
# Test sample 31:
# Residual loss 1: 0.0003575279677896744 | Residual loss 2: 1.8980865736114843e-07
# Total residual loss: 0.0003577177764470356 | Sqrt residual loss: 0.018913428468869297
#
# Test sample 32:
# Residual loss 1: 0.0008489605744691784 | Residual loss 2: 7.552926949915615e-07
# Total residual loss: 0.00084971586716417 | Sqrt residual loss: 0.029149886229009027
#
# Test sample 33:
# Residual loss 1: 0.00044038206772930904 | Residual loss 2: 8.201349671078888e-08
# Total residual loss: 0.00044046408122601984 | Sqrt residual loss: 0.020987236150241884
#
# Test sample 34:
# Residual loss 1: 0.00048274405257356026 | Residual loss 2: 1.5429961611015103e-07
# Total residual loss: 0.00048289835218967044 | Sqrt residual loss: 0.021974948286393542
#
# Test sample 35:
# Residual loss 1: 0.00020381346155427888 | Residual loss 2: 7.473856491796759e-07
# Total residual loss: 0.00020456084720345857 | Sqrt residual loss: 0.014302476960423973
#
# Test sample 36:
# Residual loss 1: 0.0009113686651585587 | Residual loss 2: 4.490116515135677e-06
# Total residual loss: 0.0009158587816736944 | Sqrt residual loss: 0.03026315881849901
#
# Test sample 37:
# Residual loss 1: 0.00042859280259639537 | Residual loss 2: 8.00062143152613e-06
# Total residual loss: 0.0004365934240279215 | Sqrt residual loss: 0.020894818114257935
#
# Test sample 38:
# Residual loss 1: 0.0008009865813558871 | Residual loss 2: 1.7912177319590166e-06
# Total residual loss: 0.0008027777990878461 | Sqrt residual loss: 0.02833333370939336
#
# Test sample 39:
# Residual loss 1: 0.00017678415148222112 | Residual loss 2: 1.0945298857587577e-07
# Total residual loss: 0.000176893604470797 | Sqrt residual loss: 0.013300135505730646
#
# Test sample 40:
# Residual loss 1: 0.00036563020008309905 | Residual loss 2: 6.366884048913737e-08
# Total residual loss: 0.0003656938689235882 | Sqrt residual loss: 0.01912312393212961
#
# Test sample 41:
# Residual loss 1: 0.0002728079012520428 | Residual loss 2: 2.7564079834091074e-06
# Total residual loss: 0.0002755643092354519 | Sqrt residual loss: 0.016600129795741114
#
# Test sample 42:
# Residual loss 1: 0.0007385776706291549 | Residual loss 2: 1.551151650401512e-06
# Total residual loss: 0.0007401288222795563 | Sqrt residual loss: 0.027205308715020242
#
# Test sample 43:
# Residual loss 1: 0.0004507652496539802 | Residual loss 2: 1.0784303773187695e-06
# Total residual loss: 0.00045184368003129896 | Sqrt residual loss: 0.021256614971140137
#
# Test sample 44:
# Residual loss 1: 0.00047463076731176624 | Residual loss 2: 1.3813777280343026e-08
# Total residual loss: 0.0004746445810890466 | Sqrt residual loss: 0.021786339322819852
#
# Test sample 45:
# Residual loss 1: 0.0004892186739595768 | Residual loss 2: 5.081788938155901e-08
# Total residual loss: 0.0004892694918489583 | Sqrt residual loss: 0.02211943696952882
#
# Test sample 46:
# Residual loss 1: 0.000401908568041199 | Residual loss 2: 7.443256768630803e-07
# Total residual loss: 0.0004026528937180621 | Sqrt residual loss: 0.02006621273977883
#
# Test sample 47:
# Residual loss 1: 0.0008736885308724082 | Residual loss 2: 1.4426143339892285e-07
# Total residual loss: 0.0008738327923058071 | Sqrt residual loss: 0.029560662920607973
#
# Test sample 48:
# Residual loss 1: 0.00018032351180888258 | Residual loss 2: 6.896356187848655e-07
# Total residual loss: 0.00018101314742766743 | Sqrt residual loss: 0.013454112658502137
#
# Test sample 49:
# Residual loss 1: 0.0003912379182361154 | Residual loss 2: 2.8986021994849968e-06
# Total residual loss: 0.0003941365204356004 | Sqrt residual loss: 0.019852871843529348
#
# Test sample 50:
# Residual loss 1: 0.00026763661176821207 | Residual loss 2: 1.4520102290514915e-06
# Total residual loss: 0.00026908862199726355 | Sqrt residual loss: 0.0164039209336446
#
# Test sample 51:
# Residual loss 1: 0.00021304530194151842 | Residual loss 2: 5.142603195558878e-07
# Total residual loss: 0.0002135595622610743 | Sqrt residual loss: 0.014613677232684261
#
# Test sample 52:
# Residual loss 1: 0.0007108825081931557 | Residual loss 2: 8.438714125522827e-10
# Total residual loss: 0.0007108833520645682 | Sqrt residual loss: 0.026662395842545136
#
# Test sample 53:
# Residual loss 1: 0.0002076839627758472 | Residual loss 2: 1.2915055453838623e-06
# Total residual loss: 0.00020897546832123108 | Sqrt residual loss: 0.014455983824051239
#
# Test sample 54:
# Residual loss 1: 0.0003170119883420052 | Residual loss 2: 5.810903043260783e-07
# Total residual loss: 0.0003175930786463313 | Sqrt residual loss: 0.01782114133960929
#
# Test sample 55:
# Residual loss 1: 0.00019127827335178204 | Residual loss 2: 1.0106462149268606e-06
# Total residual loss: 0.0001922889195667089 | Sqrt residual loss: 0.013866828028309462
#
# Test sample 56:
# Residual loss 1: 0.0005055990583374587 | Residual loss 2: 5.032749704497393e-06
# Total residual loss: 0.000510631808041956 | Sqrt residual loss: 0.02259716371675782
#
# Test sample 57:
# Residual loss 1: 0.00041163184562819234 | Residual loss 2: 2.7376732687158124e-08
# Total residual loss: 0.0004116592223608795 | Sqrt residual loss: 0.020289386939010244
#
# Test sample 58:
# Residual loss 1: 0.00038399127379733135 | Residual loss 2: 1.8369115783297203e-07
# Total residual loss: 0.0003841749649551643 | Sqrt residual loss: 0.01960038175534253
#
# Test sample 59:
# Residual loss 1: 0.0003845869473071406 | Residual loss 2: 1.4111339959087656e-08
# Total residual loss: 0.00038460105864709964 | Sqrt residual loss: 0.01961124826845807
#
# Test sample 60:
# Residual loss 1: 0.0002840145446913489 | Residual loss 2: 4.692340460021345e-07
# Total residual loss: 0.00028448377873735106 | Sqrt residual loss: 0.01686664693225512
#
# Test sample 61:
# Residual loss 1: 0.00048398129167414347 | Residual loss 2: 2.313486201825233e-06
# Total residual loss: 0.0004862947778759687 | Sqrt residual loss: 0.022052092369568215
#
# Test sample 62:
# Residual loss 1: 0.0015522583948296685 | Residual loss 2: 4.494373903383424e-06
# Total residual loss: 0.0015567527687330518 | Sqrt residual loss: 0.039455706415334295
#
# Test sample 63:
# Residual loss 1: 0.0002389333729776405 | Residual loss 2: 1.0957759399847633e-06
# Total residual loss: 0.00024002914891762528 | Sqrt residual loss: 0.015492874133537175
#
# Test sample 64:
# Residual loss 1: 0.0002261436648558206 | Residual loss 2: 5.396273038501302e-07
# Total residual loss: 0.00022668329215967074 | Sqrt residual loss: 0.015056005185960541
#
# Test sample 65:
# Residual loss 1: 0.0002022459386986729 | Residual loss 2: 5.103431849111524e-09
# Total residual loss: 0.000202251042130522 | Sqrt residual loss: 0.014221499292638664
#
# Test sample 66:
# Residual loss 1: 0.0002158559031676875 | Residual loss 2: 3.5347529041952545e-06
# Total residual loss: 0.00021939065607188275 | Sqrt residual loss: 0.014811841751513644
#
# Test sample 67:
# Residual loss 1: 0.0005419672280821306 | Residual loss 2: 3.3817052270658705e-06
# Total residual loss: 0.0005453489333091965 | Sqrt residual loss: 0.02335270719443886
#
# Test sample 68:
# Residual loss 1: 0.0005535420172580677 | Residual loss 2: 3.087770211460594e-06
# Total residual loss: 0.0005566297874695283 | Sqrt residual loss: 0.02359300293454668
#
# Test sample 69:
# Residual loss 1: 0.0004015032814474233 | Residual loss 2: 1.832017339398023e-06
# Total residual loss: 0.00040333529878682135 | Sqrt residual loss: 0.02008320937466971
#
# Test sample 70:
# Residual loss 1: 0.00030373410286892795 | Residual loss 2: 1.6762532786352962e-07
# Total residual loss: 0.00030390172819679147 | Sqrt residual loss: 0.017432777409144864
#
# Test sample 71:
# Residual loss 1: 0.0002991989434207303 | Residual loss 2: 3.532021292590371e-06
# Total residual loss: 0.00030273096471332065 | Sqrt residual loss: 0.017399165632676777
#
# Test sample 72:
# Residual loss 1: 0.00019469293068442915 | Residual loss 2: 3.913688422282778e-07
# Total residual loss: 0.00019508429952665743 | Sqrt residual loss: 0.013967258124866792
#
# Test sample 73:
# Residual loss 1: 0.00017305645302622086 | Residual loss 2: 9.731933754124235e-09
# Total residual loss: 0.00017306618495997497 | Sqrt residual loss: 0.013155462172039984
#
# Test sample 74:
# Residual loss 1: 0.0003061480269588351 | Residual loss 2: 8.196729097175193e-07
# Total residual loss: 0.0003069676998685526 | Sqrt residual loss: 0.01752049371075349
#
# Test sample 75:
# Residual loss 1: 0.0004320517785346153 | Residual loss 2: 1.101088075322448e-07
# Total residual loss: 0.00043216188734214754 | Sqrt residual loss: 0.020788503730238682
#
# Test sample 76:
# Residual loss 1: 0.0002299762467351064 | Residual loss 2: 4.75294351238025e-08
# Total residual loss: 0.0002300237761702302 | Sqrt residual loss: 0.015166534744964988
#
# Test sample 77:
# Residual loss 1: 0.00032134723733386283 | Residual loss 2: 5.338782009897022e-06
# Total residual loss: 0.00032668601934375985 | Sqrt residual loss: 0.018074457650058544
#
# Test sample 78:
# Residual loss 1: 0.0008684078269281533 | Residual loss 2: 5.901427451437633e-06
# Total residual loss: 0.0008743092543795909 | Sqrt residual loss: 0.029568720878313134
#
# Test sample 79:
# Residual loss 1: 0.00027917875862683034 | Residual loss 2: 4.972760397608036e-07
# Total residual loss: 0.00027967603466659113 | Sqrt residual loss: 0.016723517413109932
#
# Test sample 80:
# Residual loss 1: 0.0002396109705793764 | Residual loss 2: 6.988622843236458e-07
# Total residual loss: 0.00024030983286370006 | Sqrt residual loss: 0.015501929972222816
#
# Test sample 81:
# Residual loss 1: 0.00028272425926562935 | Residual loss 2: 4.7355154293689513e-07
# Total residual loss: 0.00028319781080856624 | Sqrt residual loss: 0.016828482130262556
#
# Test sample 82:
# Residual loss 1: 0.0005173010809196329 | Residual loss 2: 1.6470229837009124e-08
# Total residual loss: 0.0005173175511494699 | Sqrt residual loss: 0.02274461587166224
#
# Test sample 83:
# Residual loss 1: 0.0003025840451916452 | Residual loss 2: 9.947103029157926e-07
# Total residual loss: 0.000303578755494561 | Sqrt residual loss: 0.017423511571854882
#
# Test sample 84:
# Residual loss 1: 0.00023685116456766164 | Residual loss 2: 6.709886769193164e-07
# Total residual loss: 0.00023752215324458095 | Sqrt residual loss: 0.01541175373682635
#
# Test sample 85:
# Residual loss 1: 0.0005938456365043498 | Residual loss 2: 1.9294714635390054e-07
# Total residual loss: 0.0005940385836507037 | Sqrt residual loss: 0.024372906754236427
#
# Test sample 86:
# Residual loss 1: 0.0002517507106025192 | Residual loss 2: 7.376955056082845e-07
# Total residual loss: 0.00025248840610812747 | Sqrt residual loss: 0.01588988376635045
#
# Test sample 87:
# Residual loss 1: 0.000602062399135282 | Residual loss 2: 1.9391068764856077e-08
# Total residual loss: 0.0006020817902040469 | Sqrt residual loss: 0.024537354996088043
#
# Test sample 88:
# Residual loss 1: 0.0002644597511013317 | Residual loss 2: 1.5447412983728672e-07
# Total residual loss: 0.000264614225231169 | Sqrt residual loss: 0.016266967302824734
#
# Test sample 89:
# Residual loss 1: 0.00027879620511806873 | Residual loss 2: 5.898677418111381e-07
# Total residual loss: 0.00027938607285987987 | Sqrt residual loss: 0.01671484588202595
#
# Test sample 90:
# Residual loss 1: 0.00021709569305669956 | Residual loss 2: 5.133446855243657e-07
# Total residual loss: 0.00021760903774222393 | Sqrt residual loss: 0.01475157746623133
#
# Test sample 91:
# Residual loss 1: 0.000269060419748825 | Residual loss 2: 2.280829041431575e-07
# Total residual loss: 0.00026928850265296815 | Sqrt residual loss: 0.016410012268519732
#
# Test sample 92:
# Residual loss 1: 0.0003555523141141637 | Residual loss 2: 2.3601406427974007e-07
# Total residual loss: 0.0003557883281784434 | Sqrt residual loss: 0.018862352138014054
#
# Test sample 93:
# Residual loss 1: 0.00019215154411966013 | Residual loss 2: 1.439309537614865e-08
# Total residual loss: 0.0001921659372150363 | Sqrt residual loss: 0.013862392910859087
#
# Test sample 94:
# Residual loss 1: 0.0006697639891504694 | Residual loss 2: 2.5767994973246447e-06
# Total residual loss: 0.0006723407886477941 | Sqrt residual loss: 0.025929535064242747
#
# Test sample 95:
# Residual loss 1: 0.000541618917873851 | Residual loss 2: 6.610731685559663e-07
# Total residual loss: 0.000542279991042407 | Sqrt residual loss: 0.023286905999776075
#
# Test sample 96:
# Residual loss 1: 0.0002347515385290562 | Residual loss 2: 5.674207185450813e-07
# Total residual loss: 0.00023531895924760129 | Sqrt residual loss: 0.0153401094926862
#
# Test sample 97:
# Residual loss 1: 0.0004434131324875423 | Residual loss 2: 3.35593571825005e-06
# Total residual loss: 0.0004467690682057923 | Sqrt residual loss: 0.021136912456784986
#
# Test sample 98:
# Residual loss 1: 0.00019059598036485936 | Residual loss 2: 1.689603234550347e-06
# Total residual loss: 0.0001922855835994097 | Sqrt residual loss: 0.013866707741905059
#
# Test sample 99:
# Residual loss 1: 0.001244778531577178 | Residual loss 2: 4.210955972560945e-06
# Total residual loss: 0.0012489894875497391 | Sqrt residual loss: 0.0353410453658312
#
# Test sample 100:
# Residual loss 1: 0.00023274644590044903 | Residual loss 2: 1.4403362610959844e-06
# Total residual loss: 0.00023418678216154503 | Sqrt residual loss: 0.01530316248889572
#
# Test sample 101:
# Residual loss 1: 0.0003208675202128238 | Residual loss 2: 6.743158454403694e-10
# Total residual loss: 0.00032086819452866925 | Sqrt residual loss: 0.017912794157491713
#
# Test sample 102:
# Residual loss 1: 0.0007513184963186925 | Residual loss 2: 1.1031124897430586e-06
# Total residual loss: 0.0007524216088084355 | Sqrt residual loss: 0.027430304570099755
#
# Test sample 103:
# Residual loss 1: 0.0003875422325831742 | Residual loss 2: 5.030679742424857e-07
# Total residual loss: 0.0003880453005574167 | Sqrt residual loss: 0.01969886546371178
#
# Test sample 104:
# Residual loss 1: 0.00047656527669733787 | Residual loss 2: 3.5820754751017435e-06
# Total residual loss: 0.0004801473521724396 | Sqrt residual loss: 0.021912264880026427
#
# Test sample 105:
# Residual loss 1: 0.00102654879869891 | Residual loss 2: 9.27589346922678e-06
# Total residual loss: 0.0010358246921681367 | Sqrt residual loss: 0.03218423048898539
#
# Test sample 106:
# Residual loss 1: 0.00044632902903852845 | Residual loss 2: 1.6315823742699488e-06
# Total residual loss: 0.0004479606114127984 | Sqrt residual loss: 0.021165080000151153
#
# Test sample 107:
# Residual loss 1: 0.0001710339180717906 | Residual loss 2: 1.2671314995508626e-07
# Total residual loss: 0.00017116063122174567 | Sqrt residual loss: 0.013082837277201978
#
# Test sample 108:
# Residual loss 1: 0.0008982971520797275 | Residual loss 2: 9.262135020434735e-08
# Total residual loss: 0.000898389773429932 | Sqrt residual loss: 0.02997315087590779
#
# Test sample 109:
# Residual loss 1: 0.00021580398790854813 | Residual loss 2: 1.791844111291927e-07
# Total residual loss: 0.00021598317231967732 | Sqrt residual loss: 0.014696365956238206
#
# Test sample 110:
# Residual loss 1: 0.0004327858013717207 | Residual loss 2: 1.1148018745039062e-06
# Total residual loss: 0.0004339006032462246 | Sqrt residual loss: 0.020830280920962747
#
# Test sample 111:
# Residual loss 1: 0.0002066477875387399 | Residual loss 2: 3.2497629963121886e-07
# Total residual loss: 0.00020697276383837112 | Sqrt residual loss: 0.014386548016754092
#
# Test sample 112:
# Residual loss 1: 0.00047530171242960513 | Residual loss 2: 4.782225775332922e-06
# Total residual loss: 0.0004800839382049381 | Sqrt residual loss: 0.02191081783514568
#
# Test sample 113:
# Residual loss 1: 0.0006617804105901595 | Residual loss 2: 4.052015993027715e-06
# Total residual loss: 0.0006658324265831872 | Sqrt residual loss: 0.025803728927873724
#
# Test sample 114:
# Residual loss 1: 0.0004204339895367687 | Residual loss 2: 1.1166531636650428e-07
# Total residual loss: 0.00042054565485313524 | Sqrt residual loss: 0.02050720982613518
#
# Test sample 115:
# Residual loss 1: 0.0013772012423546498 | Residual loss 2: 1.2765700485187818e-06
# Total residual loss: 0.0013784778124031685 | Sqrt residual loss: 0.03712785763282294
#
# Test sample 116:
# Residual loss 1: 0.00045544679487428643 | Residual loss 2: 3.300385190653249e-08
# Total residual loss: 0.00045547979872619294 | Sqrt residual loss: 0.021341972699968317
#
# Test sample 117:
# Residual loss 1: 0.0004084141300092933 | Residual loss 2: 4.878938355162456e-07
# Total residual loss: 0.0004089020238448096 | Sqrt residual loss: 0.020221325966533688
#
# Test sample 118:
# Residual loss 1: 0.0013996470717118955 | Residual loss 2: 9.460070547127706e-07
# Total residual loss: 0.0014005930787666084 | Sqrt residual loss: 0.03742449837695368
#
# Test sample 119:
# Residual loss 1: 0.00029741609115888713 | Residual loss 2: 3.163357095993542e-06
# Total residual loss: 0.0003005794482548807 | Sqrt residual loss: 0.017337227236639677
#
# Test sample 120:
# Residual loss 1: 0.00034102584059903884 | Residual loss 2: 1.7066649122832513e-06
# Total residual loss: 0.0003427325055113221 | Sqrt residual loss: 0.018513036096527283
#
# Test sample 121:
# Residual loss 1: 0.0009016225607052211 | Residual loss 2: 2.7481350176364346e-06
# Total residual loss: 0.0009043706957228575 | Sqrt residual loss: 0.030072756703083566
#
# Test sample 122:
# Residual loss 1: 0.00015592831279138535 | Residual loss 2: 2.6081465433331482e-06
# Total residual loss: 0.0001585364593347185 | Sqrt residual loss: 0.012591126213914247
#
# Test sample 123:
# Residual loss 1: 0.00033392706911137854 | Residual loss 2: 3.3591413838640075e-06
# Total residual loss: 0.00033728621049524256 | Sqrt residual loss: 0.01836535353580874
#
# Test sample 124:
# Residual loss 1: 0.0015329309350378742 | Residual loss 2: 2.402582654935396e-08
# Total residual loss: 0.0015329549608644236 | Sqrt residual loss: 0.03915296873628389
#
# Test sample 125:
# Residual loss 1: 0.00023043018488022127 | Residual loss 2: 7.829716638147469e-07
# Total residual loss: 0.000231213156544036 | Sqrt residual loss: 0.015205694872120642
#
# Test sample 126:
# Residual loss 1: 0.00019526439649329214 | Residual loss 2: 1.932103580182639e-09
# Total residual loss: 0.00019526632859687232 | Sqrt residual loss: 0.013973772883400973
#
# Test sample 127:
# Residual loss 1: 0.0003252696355347781 | Residual loss 2: 1.7508695385497965e-06
# Total residual loss: 0.0003270205050733279 | Sqrt residual loss: 0.018083708277710296
#
# Test sample 128:
# Residual loss 1: 0.00042502576048146143 | Residual loss 2: 1.023700192059112e-06
# Total residual loss: 0.00042604946067352056 | Sqrt residual loss: 0.02064096559450455
#
# Test sample 129:
# Residual loss 1: 0.0007724628751277718 | Residual loss 2: 5.960471099954202e-07
# Total residual loss: 0.0007730589222377672 | Sqrt residual loss: 0.02780393717151884
#
# Test sample 130:
# Residual loss 1: 0.00038564855044746576 | Residual loss 2: 1.4510798228405462e-06
# Total residual loss: 0.0003870996302703063 | Sqrt residual loss: 0.019674847655580623
#
# Test sample 131:
# Residual loss 1: 0.00040253862793512493 | Residual loss 2: 3.687922651740544e-06
# Total residual loss: 0.00040622655058686547 | Sqrt residual loss: 0.02015506265400496
#
# Test sample 132:
# Residual loss 1: 0.00026155476709768723 | Residual loss 2: 3.999987281337798e-08
# Total residual loss: 0.0002615947669705006 | Sqrt residual loss: 0.016173891522156956
#
# Test sample 133:
# Residual loss 1: 0.00043438123874709427 | Residual loss 2: 1.6857261824098302e-06
# Total residual loss: 0.0004360669649295041 | Sqrt residual loss: 0.020882216475496658
#
# Test sample 134:
# Residual loss 1: 0.0002453145391336807 | Residual loss 2: 2.693968836871703e-06
# Total residual loss: 0.00024800850797055237 | Sqrt residual loss: 0.01574828587404205
#
# Test sample 135:
# Residual loss 1: 0.0005363217461121105 | Residual loss 2: 1.094439538650832e-06
# Total residual loss: 0.0005374161856507613 | Sqrt residual loss: 0.023182238581525325
#
# Test sample 136:
# Residual loss 1: 0.00035726486771276415 | Residual loss 2: 3.5166517692091756e-07
# Total residual loss: 0.00035761653288968507 | Sqrt residual loss: 0.01891075178012987
#
# Test sample 137:
# Residual loss 1: 0.00024606656077669204 | Residual loss 2: 1.3063580240545297e-06
# Total residual loss: 0.0002473729188007466 | Sqrt residual loss: 0.0157280932983228
#
# Test sample 138:
# Residual loss 1: 0.0003049211894223937 | Residual loss 2: 1.2304669033218847e-07
# Total residual loss: 0.0003050442361127259 | Sqrt residual loss: 0.01746551562687818
#
# Test sample 139:
# Residual loss 1: 0.0005001684101755549 | Residual loss 2: 1.170096672216988e-07
# Total residual loss: 0.0005002854198427766 | Sqrt residual loss: 0.022367061046162873
#
# Test sample 140:
# Residual loss 1: 0.00039272624966390113 | Residual loss 2: 7.813205670381541e-06
# Total residual loss: 0.0004005394553342827 | Sqrt residual loss: 0.020013481839357257
#
# Test sample 141:
# Residual loss 1: 0.0004089750690576485 | Residual loss 2: 5.385210338313796e-06
# Total residual loss: 0.00041436027939596227 | Sqrt residual loss: 0.020355841407221718
#
# Test sample 142:
# Residual loss 1: 0.00022367917462484153 | Residual loss 2: 2.1333061275400884e-06
# Total residual loss: 0.00022581248075238163 | Sqrt residual loss: 0.01502705828671672
#
# Test sample 143:
# Residual loss 1: 0.00026566888353423665 | Residual loss 2: 5.366638545714083e-07
# Total residual loss: 0.00026620554738880804 | Sqrt residual loss: 0.016315806672941673
#
# Test sample 144:
# Residual loss 1: 0.0005052722706625583 | Residual loss 2: 4.546461211976936e-09
# Total residual loss: 0.0005052768171237703 | Sqrt residual loss: 0.022478363310609834
#
# Test sample 145:
# Residual loss 1: 0.00023585057132463958 | Residual loss 2: 1.1534136456925527e-06
# Total residual loss: 0.00023700398497033214 | Sqrt residual loss: 0.015394933743616182
#
# Test sample 146:
# Residual loss 1: 0.0002661493458574496 | Residual loss 2: 5.003000805649767e-07
# Total residual loss: 0.00026664964593801454 | Sqrt residual loss: 0.01632941045898518
#
# Test sample 147:
# Residual loss 1: 0.0005483175912324011 | Residual loss 2: 2.2172485851039586e-06
# Total residual loss: 0.0005505348398175051 | Sqrt residual loss: 0.023463478851557907
#
# Test sample 148:
# Residual loss 1: 0.00028291728864525097 | Residual loss 2: 5.508301458664246e-08
# Total residual loss: 0.0002829723716598376 | Sqrt residual loss: 0.016821782654042276
#
# Test sample 149:
# Residual loss 1: 0.00018773452101423713 | Residual loss 2: 1.3308463634479584e-08
# Total residual loss: 0.0001877478294778716 | Sqrt residual loss: 0.013702110402338452
#
# Test sample 150:
# Residual loss 1: 0.00041909243548925797 | Residual loss 2: 7.430770979611921e-08
# Total residual loss: 0.00041916674319905406 | Sqrt residual loss: 0.02047356205449003
#
# Test sample 151:
# Residual loss 1: 0.0003386221364887582 | Residual loss 2: 1.6187191644943758e-07
# Total residual loss: 0.00033878400840520764 | Sqrt residual loss: 0.018406086178359798
#
# Test sample 152:
# Residual loss 1: 0.0004006125769596112 | Residual loss 2: 1.667364646669772e-07
# Total residual loss: 0.0004007793134242782 | Sqrt residual loss: 0.02001947335531777
#
# Test sample 153:
# Residual loss 1: 0.000662788505848288 | Residual loss 2: 6.420142668682194e-06
# Total residual loss: 0.0006692086485169703 | Sqrt residual loss: 0.025869067407175123
#
# Test sample 154:
# Residual loss 1: 0.0008482549757485358 | Residual loss 2: 5.961807494957391e-08
# Total residual loss: 0.0008483145938234854 | Sqrt residual loss: 0.02912584065436542
#
# Test sample 155:
# Residual loss 1: 0.00034839940648486334 | Residual loss 2: 1.1727606213359362e-06
# Total residual loss: 0.0003495721671061993 | Sqrt residual loss: 0.018696849122410954
#
# Test sample 156:
# Residual loss 1: 0.0006978805411314487 | Residual loss 2: 5.013475657042396e-07
# Total residual loss: 0.000698381888697153 | Sqrt residual loss: 0.026426915989141694
#
# Test sample 157:
# Residual loss 1: 0.0008909983396916687 | Residual loss 2: 5.480826168355874e-07
# Total residual loss: 0.0008915464223085044 | Sqrt residual loss: 0.029858774628381927
#
# Test sample 158:
# Residual loss 1: 0.00024353683021965686 | Residual loss 2: 3.075075359553239e-06
# Total residual loss: 0.0002466119055792101 | Sqrt residual loss: 0.015703881863386837
#
# Test sample 159:
# Residual loss 1: 0.00017422826152910175 | Residual loss 2: 3.5929757310399537e-09
# Total residual loss: 0.00017423185450483278 | Sqrt residual loss: 0.01319969145491033
#
# Test sample 160:
# Residual loss 1: 0.0001676353483631091 | Residual loss 2: 5.265112028128107e-07
# Total residual loss: 0.00016816185956592192 | Sqrt residual loss: 0.012967723761937633
#
# Test sample 161:
# Residual loss 1: 0.0002460700438193423 | Residual loss 2: 5.107877345730238e-07
# Total residual loss: 0.0002465808315539153 | Sqrt residual loss: 0.01570289245820385
#
# Test sample 162:
# Residual loss 1: 0.0010577348739404773 | Residual loss 2: 4.8804894904927e-07
# Total residual loss: 0.0010582229228895267 | Sqrt residual loss: 0.03253033849946119
#
# Test sample 163:
# Residual loss 1: 0.0006720308127844516 | Residual loss 2: 1.4990999120131088e-06
# Total residual loss: 0.0006735299126964647 | Sqrt residual loss: 0.025952454849136424
#
# Test sample 164:
# Residual loss 1: 0.0004225394028106503 | Residual loss 2: 5.026947074889724e-08
# Total residual loss: 0.0004225896722813992 | Sqrt residual loss: 0.020556985972690626
#
# Test sample 165:
# Residual loss 1: 0.00037730879851687255 | Residual loss 2: 1.5771143246811369e-06
# Total residual loss: 0.0003788859128415537 | Sqrt residual loss: 0.019464991981543524
#
# Test sample 166:
# Residual loss 1: 0.0014842685214777388 | Residual loss 2: 1.3750409866471651e-07
# Total residual loss: 0.0014844060255764036 | Sqrt residual loss: 0.03852799015749983
#
# Test sample 167:
# Residual loss 1: 0.00046041655648863095 | Residual loss 2: 8.892041377452903e-07
# Total residual loss: 0.00046130576062637624 | Sqrt residual loss: 0.02147802971937548
#
# Test sample 168:
# Residual loss 1: 0.00021676860094966752 | Residual loss 2: 1.0713372268617822e-07
# Total residual loss: 0.0002168757346723537 | Sqrt residual loss: 0.014726701418591798
#
# Test sample 169:
# Residual loss 1: 0.0005753167901813623 | Residual loss 2: 1.907783781704064e-06
# Total residual loss: 0.0005772245739630663 | Sqrt residual loss: 0.024025498412375678
#
# Test sample 170:
# Residual loss 1: 0.0005981336021193945 | Residual loss 2: 9.774852022546815e-07
# Total residual loss: 0.0005991110873216492 | Sqrt residual loss: 0.024476745848287292
#
# Test sample 171:
# Residual loss 1: 0.0004287602052644382 | Residual loss 2: 1.3910129116848992e-06
# Total residual loss: 0.0004301512181761231 | Sqrt residual loss: 0.020740087226820504
#
# Test sample 172:
# Residual loss 1: 0.00043436354643400184 | Residual loss 2: 5.99185332602789e-08
# Total residual loss: 0.0004344234649672621 | Sqrt residual loss: 0.0208428276624661
#
# Test sample 173:
# Residual loss 1: 0.00027663526830315287 | Residual loss 2: 3.834337587344084e-06
# Total residual loss: 0.00028046960589049694 | Sqrt residual loss: 0.016747226811938055
#
# Test sample 174:
# Residual loss 1: 0.0002745964975512313 | Residual loss 2: 7.508004475701959e-07
# Total residual loss: 0.0002753472979988015 | Sqrt residual loss: 0.016593592076425207
#
# Test sample 175:
# Residual loss 1: 0.0003041336416190467 | Residual loss 2: 4.304361441539288e-10
# Total residual loss: 0.0003041340720551908 | Sqrt residual loss: 0.01743944013021034
#
# Test sample 176:
# Residual loss 1: 0.00046755609876446795 | Residual loss 2: 3.937142754382471e-08
# Total residual loss: 0.0004675954701920118 | Sqrt residual loss: 0.02162395593299274
#
# Test sample 177:
# Residual loss 1: 0.0008283244204443398 | Residual loss 2: 6.364246444455589e-06
# Total residual loss: 0.0008346886668887954 | Sqrt residual loss: 0.02889097898806469
#
# Test sample 178:
# Residual loss 1: 0.0006596628532999404 | Residual loss 2: 3.344068936635356e-06
# Total residual loss: 0.0006630069222365757 | Sqrt residual loss: 0.025748920797512575
#
# Test sample 179:
# Residual loss 1: 0.00022409498176496353 | Residual loss 2: 8.972215196377187e-08
# Total residual loss: 0.0002241847039169273 | Sqrt residual loss: 0.0149727988003889
#
# Test sample 180:
# Residual loss 1: 0.0006637713623556251 | Residual loss 2: 1.6271793779564248e-06
# Total residual loss: 0.0006653985417335815 | Sqrt residual loss: 0.02579532015179462
#
# Test sample 181:
# Residual loss 1: 0.0003929060662096034 | Residual loss 2: 1.2740449132749494e-06
# Total residual loss: 0.0003941801111228783 | Sqrt residual loss: 0.019853969656541695
#
# Test sample 182:
# Residual loss 1: 0.0004910756862477047 | Residual loss 2: 1.4577846488324936e-07
# Total residual loss: 0.000491221464712588 | Sqrt residual loss: 0.022163516524066933
#
# Test sample 183:
# Residual loss 1: 0.00032101273324349627 | Residual loss 2: 7.844297510194871e-07
# Total residual loss: 0.00032179716299451575 | Sqrt residual loss: 0.017938705722390223
#
# Test sample 184:
# Residual loss 1: 0.0005409000644144453 | Residual loss 2: 1.4634146057249663e-07
# Total residual loss: 0.0005410464058750178 | Sqrt residual loss: 0.023260404250034387
#
# Test sample 185:
# Residual loss 1: 0.0010544521226015901 | Residual loss 2: 4.808007123324173e-07
# Total residual loss: 0.0010549329233139225 | Sqrt residual loss: 0.032479730961230614
#
# Test sample 186:
# Residual loss 1: 0.0005031262948756065 | Residual loss 2: 6.82538559943669e-07
# Total residual loss: 0.0005038088334355502 | Sqrt residual loss: 0.02244568629905422
#
# Test sample 187:
# Residual loss 1: 0.0001902081818186449 | Residual loss 2: 2.5553784477062733e-07
# Total residual loss: 0.0001904637196634155 | Sqrt residual loss: 0.013800859381336204
#
# Test sample 188:
# Residual loss 1: 0.0005820908378051635 | Residual loss 2: 1.3132573551580462e-07
# Total residual loss: 0.0005822221635406793 | Sqrt residual loss: 0.02412928021182313
#
# Test sample 189:
# Residual loss 1: 0.0004016392677249099 | Residual loss 2: 1.2518380788087036e-07
# Total residual loss: 0.0004017644515327908 | Sqrt residual loss: 0.020044062750170955
#
# Test sample 190:
# Residual loss 1: 0.00036454933448503465 | Residual loss 2: 4.394765468427916e-06
# Total residual loss: 0.00036894409995346256 | Sqrt residual loss: 0.019207917637095975
#
# Test sample 191:
# Residual loss 1: 0.0003368789474264166 | Residual loss 2: 5.947989545632434e-08
# Total residual loss: 0.00033693842732187293 | Sqrt residual loss: 0.01835588263532628
#
# Test sample 192:
# Residual loss 1: 0.00028792556349461666 | Residual loss 2: 2.222030553350239e-07
# Total residual loss: 0.0002881477665499517 | Sqrt residual loss: 0.01697491580391348
#
# Test sample 193:
# Residual loss 1: 0.0005965221852233156 | Residual loss 2: 4.2869924058956565e-07
# Total residual loss: 0.0005969508844639052 | Sqrt residual loss: 0.024432578342530802
#
# Test sample 194:
# Residual loss 1: 0.0005994089144080618 | Residual loss 2: 3.856976885952749e-06
# Total residual loss: 0.0006032658912940146 | Sqrt residual loss: 0.024561471684205215
#
# Test sample 195:
# Residual loss 1: 0.00049683505630937 | Residual loss 2: 5.32892864056548e-07
# Total residual loss: 0.0004973679491734266 | Sqrt residual loss: 0.022301747670831238
#
# Test sample 196:
# Residual loss 1: 0.0002952374827230077 | Residual loss 2: 2.624621343560448e-08
# Total residual loss: 0.0002952637289364433 | Sqrt residual loss: 0.017183239768345297
#
# Test sample 197:
# Residual loss 1: 0.00048160211566359814 | Residual loss 2: 1.0470505796543852e-07
# Total residual loss: 0.00048170682072156356 | Sqrt residual loss: 0.021947820409361007
#
# Test sample 198:
# Residual loss 1: 0.0003401493520352866 | Residual loss 2: 3.693712121398222e-07
# Total residual loss: 0.0003405187232474264 | Sqrt residual loss: 0.018453149412699894
#
# Test sample 199:
# Residual loss 1: 0.0004293178488791295 | Residual loss 2: 1.662569704870829e-06
# Total residual loss: 0.00043098041858400033 | Sqrt residual loss: 0.020760067884860116
#
# Test sample 200:
# Residual loss 1: 0.001644620806900542 | Residual loss 2: 4.583444717005089e-06
# Total residual loss: 0.001649204251617547 | Sqrt residual loss: 0.040610395856449696
#
# Test sample 201:
# Residual loss 1: 0.0005016813196237371 | Residual loss 2: 3.1222300703101197e-07
# Total residual loss: 0.0005019935426307682 | Sqrt residual loss: 0.022405212398697947
#
# Test sample 202:
# Residual loss 1: 0.00025753272583226824 | Residual loss 2: 1.1631122563588685e-06
# Total residual loss: 0.0002586958380886271 | Sqrt residual loss: 0.016084024312609923
#
# Test sample 203:
# Residual loss 1: 0.00038677536212646153 | Residual loss 2: 1.5923038873296678e-08
# Total residual loss: 0.0003867912851653348 | Sqrt residual loss: 0.019667010071826748
#
# Test sample 204:
# Residual loss 1: 0.00030488363080692095 | Residual loss 2: 2.167616058893075e-08
# Total residual loss: 0.0003049053069675099 | Sqrt residual loss: 0.017461537932482063
#
# Test sample 205:
# Residual loss 1: 0.00048277938817822244 | Residual loss 2: 5.247593783128664e-07
# Total residual loss: 0.0004833041475565353 | Sqrt residual loss: 0.021984179483358828
#
# Test sample 206:
# Residual loss 1: 0.0003753738995108224 | Residual loss 2: 1.777564942046612e-07
# Total residual loss: 0.00037555165600502706 | Sqrt residual loss: 0.01937915519327473
#
# Test sample 207:
# Residual loss 1: 0.00021493288686416187 | Residual loss 2: 2.901275178141964e-07
# Total residual loss: 0.00021522301438197606 | Sqrt residual loss: 0.014670481054893056
#
# Test sample 208:
# Residual loss 1: 0.0004780169899825982 | Residual loss 2: 2.4225973555960554e-07
# Total residual loss: 0.0004782592497181578 | Sqrt residual loss: 0.021869139208440688
#
# Test sample 209:
# Residual loss 1: 0.0002756164374571786 | Residual loss 2: 2.3516979002758242e-07
# Total residual loss: 0.0002758516072472062 | Sqrt residual loss: 0.01660878102833577
#
# Test sample 210:
# Residual loss 1: 0.00023399390426022577 | Residual loss 2: 6.023072313477557e-08
# Total residual loss: 0.00023405413498336054 | Sqrt residual loss: 0.015298827895736344
#
# Test sample 211:
# Residual loss 1: 0.0005394152313726103 | Residual loss 2: 2.0102190973790993e-06
# Total residual loss: 0.0005414254504699894 | Sqrt residual loss: 0.023268550674031878
#
# Test sample 212:
# Residual loss 1: 0.0004035116459565037 | Residual loss 2: 2.1201205841706474e-06
# Total residual loss: 0.00040563176654067435 | Sqrt residual loss: 0.020140302046907695
#
# Test sample 213:
# Residual loss 1: 0.00034200802056614556 | Residual loss 2: 8.638527007566152e-07
# Total residual loss: 0.00034287187326690217 | Sqrt residual loss: 0.018516799757703872
#
# Test sample 214:
# Residual loss 1: 0.00036026406154381904 | Residual loss 2: 1.0039486984017643e-06
# Total residual loss: 0.0003612680102422208 | Sqrt residual loss: 0.019007051592559557
#
# Test sample 215:
# Residual loss 1: 0.0003803727063515236 | Residual loss 2: 5.340236625304619e-07
# Total residual loss: 0.000380906730014054 | Sqrt residual loss: 0.019516831966639822
#
# Test sample 216:
# Residual loss 1: 0.00026180707929629915 | Residual loss 2: 1.314949933068751e-07
# Total residual loss: 0.000261938574289606 | Sqrt residual loss: 0.016184516498481072
#
# Test sample 217:
# Residual loss 1: 0.00032436800794098913 | Residual loss 2: 2.2856164992945684e-06
# Total residual loss: 0.0003266536244402837 | Sqrt residual loss: 0.01807356147637437
#
# Test sample 218:
# Residual loss 1: 0.0005641716907709352 | Residual loss 2: 1.2181845259945315e-05
# Total residual loss: 0.0005763535360308805 | Sqrt residual loss: 0.0240073642041537
#
# Test sample 219:
# Residual loss 1: 0.00025817415236346273 | Residual loss 2: 2.1103600772199292e-06
# Total residual loss: 0.00026028451244068266 | Sqrt residual loss: 0.01613333544065463
#
# Test sample 220:
# Residual loss 1: 0.0004232574841843142 | Residual loss 2: 3.5633481460194748e-06
# Total residual loss: 0.0004268208323303337 | Sqrt residual loss: 0.02065964259928844
#
# Test sample 221:
# Residual loss 1: 0.0004852818808007664 | Residual loss 2: 2.2424193400491073e-07
# Total residual loss: 0.0004855061227347713 | Sqrt residual loss: 0.022034203474025814
#
# Test sample 222:
# Residual loss 1: 0.00028221571555051987 | Residual loss 2: 8.135092848452131e-10
# Total residual loss: 0.0002822165290598047 | Sqrt residual loss: 0.016799301445590074
#
# Test sample 223:
# Residual loss 1: 0.0006984671418556143 | Residual loss 2: 1.8339488518492126e-07
# Total residual loss: 0.0006986505367407993 | Sqrt residual loss: 0.02643199834936434
#
# Test sample 224:
# Residual loss 1: 0.0008780516565480974 | Residual loss 2: 1.7204915770209615e-07
# Total residual loss: 0.0008782237057057995 | Sqrt residual loss: 0.029634839390585525
#
# Test sample 225:
# Residual loss 1: 0.0004162224906015246 | Residual loss 2: 3.4301771751276795e-07
# Total residual loss: 0.00041656550831903734 | Sqrt residual loss: 0.020409936509431806
#
# Test sample 226:
# Residual loss 1: 0.0006264049665971302 | Residual loss 2: 9.311285416792296e-09
# Total residual loss: 0.000626414277882547 | Sqrt residual loss: 0.025028269574274346
#
# Test sample 227:
# Residual loss 1: 0.0007900256562807771 | Residual loss 2: 4.4480184610890434e-07
# Total residual loss: 0.000790470458126886 | Sqrt residual loss: 0.028115306473998927
#
# Test sample 228:
# Residual loss 1: 0.00048308363815440197 | Residual loss 2: 7.468554834477547e-07
# Total residual loss: 0.0004838304936378497 | Sqrt residual loss: 0.02199614724532116
#
# Test sample 229:
# Residual loss 1: 0.0002884106182066648 | Residual loss 2: 1.571273030077094e-06
# Total residual loss: 0.0002899818912367419 | Sqrt residual loss: 0.017028854666029124
#
# Test sample 230:
# Residual loss 1: 0.0006012462906422979 | Residual loss 2: 2.84198011984254e-06
# Total residual loss: 0.0006040882707621405 | Sqrt residual loss: 0.024578207232467963
#
# Test sample 231:
# Residual loss 1: 0.0006990042646237913 | Residual loss 2: 3.604327997643943e-08
# Total residual loss: 0.0006990403079037678 | Sqrt residual loss: 0.026439370414284978
#
# Test sample 232:
# Residual loss 1: 0.0002417426019644216 | Residual loss 2: 7.862660621565492e-07
# Total residual loss: 0.00024252886802657815 | Sqrt residual loss: 0.015573338371286298
#
# Test sample 233:
# Residual loss 1: 0.0009420977597930834 | Residual loss 2: 7.250601795898178e-07
# Total residual loss: 0.0009428228199726733 | Sqrt residual loss: 0.030705420042277116
#
# Test sample 234:
# Residual loss 1: 0.0002797233264963593 | Residual loss 2: 3.6888934519524556e-07
# Total residual loss: 0.00028009221584155455 | Sqrt residual loss: 0.016735955779146723
#
# Test sample 235:
# Residual loss 1: 0.00033629242009663833 | Residual loss 2: 2.0303765317053914e-06
# Total residual loss: 0.0003383227966283437 | Sqrt residual loss: 0.018393553126798086
#
# Test sample 236:
# Residual loss 1: 0.000565814749500566 | Residual loss 2: 1.2318758301372958e-07
# Total residual loss: 0.0005659379370835798 | Sqrt residual loss: 0.023789450121505115
#
# Test sample 237:
# Residual loss 1: 0.0002706743834146071 | Residual loss 2: 3.3546501207311904e-07
# Total residual loss: 0.0002710098484266802 | Sqrt residual loss: 0.016462376755094637
#
# Test sample 238:
# Residual loss 1: 0.00031107499350593594 | Residual loss 2: 4.2240857497853963e-07
# Total residual loss: 0.00031149740208091445 | Sqrt residual loss: 0.017649288996469926
#
# Test sample 239:
# Residual loss 1: 0.0003516309204411586 | Residual loss 2: 1.3078013724409312e-07
# Total residual loss: 0.00035176170057840266 | Sqrt residual loss: 0.018755311263170298
#
# Test sample 240:
# Residual loss 1: 0.0004134620573632127 | Residual loss 2: 9.895024062372159e-07
# Total residual loss: 0.00041445155976944996 | Sqrt residual loss: 0.020358083401181212
#
# Test sample 241:
# Residual loss 1: 0.002515954436154181 | Residual loss 2: 4.567951651578257e-07
# Total residual loss: 0.0025164112313193388 | Sqrt residual loss: 0.05016384386507217
#
# Test sample 242:
# Residual loss 1: 0.0003733066240467155 | Residual loss 2: 1.0988811336162826e-06
# Total residual loss: 0.0003744055051803318 | Sqrt residual loss: 0.019349560852389695
#
# Test sample 243:
# Residual loss 1: 0.00038064973431195477 | Residual loss 2: 5.634157958420026e-07
# Total residual loss: 0.0003812131501077968 | Sqrt residual loss: 0.019524680537919097
#
# Test sample 244:
# Residual loss 1: 0.0001757513986157656 | Residual loss 2: 4.1942489820583516e-08
# Total residual loss: 0.00017579334110558618 | Sqrt residual loss: 0.013258708123553599
#
# Test sample 245:
# Residual loss 1: 0.0001692922713933578 | Residual loss 2: 6.266022950160189e-06
# Total residual loss: 0.00017555829434351799 | Sqrt residual loss: 0.013249841295031348
#
# Test sample 246:
# Residual loss 1: 0.00031517679559990694 | Residual loss 2: 6.229621257617675e-07
# Total residual loss: 0.0003157997577256687 | Sqrt residual loss: 0.01777075568808678
#
# Test sample 247:
# Residual loss 1: 0.000609898408818956 | Residual loss 2: 4.474757731304871e-08
# Total residual loss: 0.000609943156396269 | Sqrt residual loss: 0.024697027278526237
#
# Test sample 248:
# Residual loss 1: 0.0003642289444115945 | Residual loss 2: 6.611083959401452e-07
# Total residual loss: 0.0003648900528075347 | Sqrt residual loss: 0.019102095508282194
#
# Test sample 249:
# Residual loss 1: 0.00038888916667691436 | Residual loss 2: 1.2645573118998788e-07
# Total residual loss: 0.0003890156224081044 | Sqrt residual loss: 0.019723478963106493
#
# Test sample 250:
# Residual loss 1: 0.0006030726240624434 | Residual loss 2: 3.69265822697062e-07
# Total residual loss: 0.0006034418898851404 | Sqrt residual loss: 0.02456505424144511
#
# Test sample 251:
# Residual loss 1: 0.00036599403549782 | Residual loss 2: 7.158028438477216e-07
# Total residual loss: 0.0003667098383416677 | Sqrt residual loss: 0.01914966940554504
#
# Test sample 252:
# Residual loss 1: 0.00023703222554482075 | Residual loss 2: 3.595233678468941e-07
# Total residual loss: 0.00023739174891266766 | Sqrt residual loss: 0.015407522478084128
#
# Test sample 253:
# Residual loss 1: 0.0003065514939048501 | Residual loss 2: 2.88055198493001e-07
# Total residual loss: 0.0003068395491033431 | Sqrt residual loss: 0.017516836161343266
#
# Test sample 254:
# Residual loss 1: 0.0007868489312702296 | Residual loss 2: 1.130164832200069e-06
# Total residual loss: 0.0007879790961024297 | Sqrt residual loss: 0.028070965357508276
#
# Test sample 255:
# Residual loss 1: 0.0002389164945395483 | Residual loss 2: 2.7171189589859495e-06
# Total residual loss: 0.00024163361349853425 | Sqrt residual loss: 0.015544568617318856
#
# Test sample 256:
# Residual loss 1: 0.0006243714273674474 | Residual loss 2: 9.47584745225936e-08
# Total residual loss: 0.00062446618584197 | Sqrt residual loss: 0.024989321436204907
#
# Test sample 257:
# Residual loss 1: 0.00030207567916664974 | Residual loss 2: 2.4499103773698547e-06
# Total residual loss: 0.0003045255895440196 | Sqrt residual loss: 0.017450661578978018
#
# Test sample 258:
# Residual loss 1: 0.0005209640983907796 | Residual loss 2: 6.995543343962655e-08
# Total residual loss: 0.0005210340538242193 | Sqrt residual loss: 0.02282617037140088
#
# Test sample 259:
# Residual loss 1: 0.0008091953325401154 | Residual loss 2: 2.0583024293009877e-06
# Total residual loss: 0.0008112536349694164 | Sqrt residual loss: 0.02848251454786632
#
# Test sample 260:
# Residual loss 1: 0.00021553513119857096 | Residual loss 2: 1.1777182622161028e-06
# ...
# Total residual loss: 0.0011760485948007382 | Sqrt residual loss: 0.03429356491822829
#
# Test sample 414:
# Residual loss 1: 0.0008177361768512702 | Residual loss 2: 1.4572524763651339e-06
# Total residual loss: 0.0008191934293276354 | Sqrt residual loss: 0.028621555326844756
#
# Test sample 415:
# Residual loss 1: 0.0006498408452717409 | Residual loss 2: 2.489574258622295e-08
# Total residual loss: 0.0006498657410143272 | Sqrt residual loss: 0.025492464396647242
#
# Test sample 416:
# Residual loss 1: 0.0004883589635078402 | Residual loss 2: 1.8830365680360878e-07
# Total residual loss: 0.0004885472671646438 | Sqrt residual loss: 0.02210310537378501
#
# Test sample 417:
# Residual loss 1: 0.0003364038850791262 | Residual loss 2: 1.740587376980707e-06
# Total residual loss: 0.0003381444724561069 | Sqrt residual loss: 0.018388705023902767
#
# Test sample 418:
# Residual loss 1: 0.000601346195694216 | Residual loss 2: 7.1676029933616856e-06
# Total residual loss: 0.0006085137986875778 | Sqrt residual loss: 0.024668072455860383
#
# Test sample 419:
# Residual loss 1: 0.0008381018142765907 | Residual loss 2: 6.849095574221663e-08
# Total residual loss: 0.0008381703052323329 | Sqrt residual loss: 0.028951171051139413
#
# Test sample 420:
# Residual loss 1: 0.0005606024957283526 | Residual loss 2: 6.399556009677805e-10
# Total residual loss: 0.0005606031356839536 | Sqrt residual loss: 0.023677059270187113
#
# Test sample 421:
# Residual loss 1: 0.0004737601577172099 | Residual loss 2: 3.2407785361465088e-06
# Total residual loss: 0.0004770009362533564 | Sqrt residual loss: 0.02184035110187921
#
# Test sample 422:
# Residual loss 1: 0.00022075972981961203 | Residual loss 2: 1.1527439961299042e-08
# Total residual loss: 0.00022077125725957332 | Sqrt residual loss: 0.014858373304624342
#
# Test sample 423:
# Residual loss 1: 0.0004335280900195267 | Residual loss 2: 3.423551757890358e-07
# Total residual loss: 0.0004338704451953157 | Sqrt residual loss: 0.02082955700909925
#
# Test sample 424:
# Residual loss 1: 0.0002713871712052694 | Residual loss 2: 1.9209135827737418e-06
# Total residual loss: 0.00027330808478804317 | Sqrt residual loss: 0.01653203208283976
#
# Test sample 425:
# Residual loss 1: 0.00038790647496282475 | Residual loss 2: 9.010752360858856e-07
# Total residual loss: 0.00038880755019891065 | Sqrt residual loss: 0.019718203523620265
#
# Test sample 426:
# Residual loss 1: 0.00047721870104827456 | Residual loss 2: 8.084463293437771e-10
# Total residual loss: 0.0004772195094946039 | Sqrt residual loss: 0.02184535441448831
#
# Test sample 427:
# Residual loss 1: 0.00038131076203416515 | Residual loss 2: 1.984909579109947e-07
# Total residual loss: 0.00038150925299207616 | Sqrt residual loss: 0.019532261850386815
#
# Test sample 428:
# Residual loss 1: 0.000200877350734797 | Residual loss 2: 1.249795169752846e-06
# Total residual loss: 0.00020212714590454983 | Sqrt residual loss: 0.014217142677224204
#
# Test sample 429:
# Residual loss 1: 0.00038467895915953506 | Residual loss 2: 1.3867492578251263e-07
# Total residual loss: 0.0003848176340853176 | Sqrt residual loss: 0.019616769206098072
#
# Test sample 430:
# Residual loss 1: 0.00030639416392493383 | Residual loss 2: 4.881568865215048e-06
# Total residual loss: 0.0003112757327901489 | Sqrt residual loss: 0.017643008042568843
#
# Test sample 431:
# Residual loss 1: 0.00035880014071092977 | Residual loss 2: 3.298580596662578e-06
# Total residual loss: 0.00036209872130759236 | Sqrt residual loss: 0.019028891751954248
#
# Test sample 432:
# Residual loss 1: 0.00015665154019801558 | Residual loss 2: 1.0041147412615751e-07
# Total residual loss: 0.00015675195167214173 | Sqrt residual loss: 0.012520061967583936
#
# Test sample 433:
# Residual loss 1: 0.0004346651538059957 | Residual loss 2: 5.846993869787078e-07
# Total residual loss: 0.0004352498531929744 | Sqrt residual loss: 0.020862642526606606
#
# Test sample 434:
# Residual loss 1: 0.00040287524002167974 | Residual loss 2: 1.7897742073370657e-06
# Total residual loss: 0.0004046650142290168 | Sqrt residual loss: 0.020116287287395177
#
# Test sample 435:
# Residual loss 1: 0.00046227105956923924 | Residual loss 2: 2.5834138127613957e-07
# Total residual loss: 0.0004625294009505154 | Sqrt residual loss: 0.021506496714958377
#
# Test sample 436:
# Residual loss 1: 0.0005751122357554037 | Residual loss 2: 5.990854241302045e-07
# Total residual loss: 0.0005757113211795339 | Sqrt residual loss: 0.02399398510417838
#
# Test sample 437:
# Residual loss 1: 0.001038536486541874 | Residual loss 2: 9.87786894586931e-06
# Total residual loss: 0.0010484143554877433 | Sqrt residual loss: 0.03237922722190484
#
# Test sample 438:
# Residual loss 1: 0.0002339586602262046 | Residual loss 2: 2.1502810561718282e-07
# Total residual loss: 0.0002341736883318218 | Sqrt residual loss: 0.015302734668412107
#
# Test sample 439:
# Residual loss 1: 0.0008228296597547727 | Residual loss 2: 3.2511490261517327e-06
# Total residual loss: 0.0008260808087809245 | Sqrt residual loss: 0.028741621540562468
#
# Test sample 440:
# Residual loss 1: 0.0002637430372909089 | Residual loss 2: 7.781682542572218e-07
# Total residual loss: 0.0002645212055451661 | Sqrt residual loss: 0.016264107892693225
#
# Test sample 441:
# Residual loss 1: 0.00040838813227712153 | Residual loss 2: 1.0366538222285805e-06
# Total residual loss: 0.0004094247860993501 | Sqrt residual loss: 0.020234247851090244
#
# Test sample 442:
# Residual loss 1: 0.00020003859854300806 | Residual loss 2: 2.0038534336397885e-06
# Total residual loss: 0.00020204245197664785 | Sqrt residual loss: 0.01421416378042155
#
# Test sample 443:
# Residual loss 1: 0.00025525453015066225 | Residual loss 2: 8.718937772003431e-07
# Total residual loss: 0.0002561264239278626 | Sqrt residual loss: 0.016003950260103365
#
# Test sample 444:
# Residual loss 1: 0.0004263457798317431 | Residual loss 2: 2.33016705262344e-06
# Total residual loss: 0.00042867594688436654 | Sqrt residual loss: 0.02070449098346459
#
# Test sample 445:
# Residual loss 1: 0.0005139577069454232 | Residual loss 2: 7.467590894104682e-09
# Total residual loss: 0.0005139651745363173 | Sqrt residual loss: 0.0226708000418229
#
# Test sample 446:
# Residual loss 1: 0.0003987472227528769 | Residual loss 2: 1.228627557577261e-06
# Total residual loss: 0.00039997585031045416 | Sqrt residual loss: 0.019999396248648462
#
# Test sample 447:
# Residual loss 1: 0.0005501739604470433 | Residual loss 2: 7.986566019766528e-08
# Total residual loss: 0.000550253826107241 | Sqrt residual loss: 0.023457489765685523
#
# Test sample 448:
# Residual loss 1: 0.0003295840840141541 | Residual loss 2: 1.4623867172812084e-07
# Total residual loss: 0.0003297303226858822 | Sqrt residual loss: 0.018158477983737573
#
# Test sample 449:
# Residual loss 1: 0.0012036822787479429 | Residual loss 2: 3.46768970739818e-07
# Total residual loss: 0.0012040290477186826 | Sqrt residual loss: 0.034699121713937985
#
# Test sample 450:
# Residual loss 1: 0.000513218136329175 | Residual loss 2: 3.7425923382099023e-06
# Total residual loss: 0.0005169607286673849 | Sqrt residual loss: 0.022736770409787423
#
# Test sample 451:
# Residual loss 1: 0.00048165950666578615 | Residual loss 2: 9.888218614651398e-07
# Total residual loss: 0.0004826483285272513 | Sqrt residual loss: 0.02196925871592511
#
# Test sample 452:
# Residual loss 1: 0.0009262246678167496 | Residual loss 2: 2.55690160435717e-06
# Total residual loss: 0.0009287815694211068 | Sqrt residual loss: 0.03047591786019097
#
# Test sample 453:
# Residual loss 1: 0.000272291982072585 | Residual loss 2: 1.1345356229106942e-06
# Total residual loss: 0.0002734265176954957 | Sqrt residual loss: 0.01653561361714453
#
# Test sample 454:
# Residual loss 1: 0.00025597462695435883 | Residual loss 2: 6.746719800143643e-08
# Total residual loss: 0.0002560420941523603 | Sqrt residual loss: 0.016001315388191068
#
# Test sample 455:
# Residual loss 1: 0.00041136436654622176 | Residual loss 2: 4.188100894455484e-09
# Total residual loss: 0.0004113685546471162 | Sqrt residual loss: 0.02028222262591347
#
# Test sample 456:
# Residual loss 1: 0.00038741374307642724 | Residual loss 2: 1.9753849275807245e-07
# Total residual loss: 0.0003876112815691853 | Sqrt residual loss: 0.01968784603681127
#
# Test sample 457:
# Residual loss 1: 0.0013307230006704429 | Residual loss 2: 1.0896416450951305e-05
# Total residual loss: 0.0013416194171213941 | Sqrt residual loss: 0.03662812330875545
#
# Test sample 458:
# Residual loss 1: 0.0007374548337925486 | Residual loss 2: 1.7932365541415397e-07
# Total residual loss: 0.0007376341574479627 | Sqrt residual loss: 0.02715942115450848
#
# Test sample 459:
# Residual loss 1: 0.0009364900081826713 | Residual loss 2: 3.1230298252620323e-06
# Total residual loss: 0.0009396130380079333 | Sqrt residual loss: 0.03065310812964867
#
# Test sample 460:
# Residual loss 1: 0.0002490665749509795 | Residual loss 2: 1.204515837485352e-06
# Total residual loss: 0.00025027109078846484 | Sqrt residual loss: 0.015819958621578784
#
# Test sample 461:
# Residual loss 1: 0.00012399442198150415 | Residual loss 2: 8.305975732577628e-08
# Total residual loss: 0.00012407748173882992 | Sqrt residual loss: 0.011139007215135015
#
# Test sample 462:
# Residual loss 1: 0.0005572430389613459 | Residual loss 2: 9.249348478409942e-06
# Total residual loss: 0.0005664923874397559 | Sqrt residual loss: 0.02380110055101982
#
# Test sample 463:
# Residual loss 1: 0.0006153748310041807 | Residual loss 2: 4.202924629423871e-08
# Total residual loss: 0.0006154168602504749 | Sqrt residual loss: 0.024807596825377403
#
# Test sample 464:
# Residual loss 1: 0.00018287919893018235 | Residual loss 2: 1.6517717213437792e-07
# Total residual loss: 0.00018304437610231673 | Sqrt residual loss: 0.013529389346985204
#
# Test sample 465:
# Residual loss 1: 0.0004968053692781764 | Residual loss 2: 4.825974566416153e-06
# Total residual loss: 0.0005016313438445926 | Sqrt residual loss: 0.02239712802670451
#
# Test sample 466:
# Residual loss 1: 0.00036435259111565097 | Residual loss 2: 1.445219220879344e-07
# Total residual loss: 0.0003644971130377389 | Sqrt residual loss: 0.019091807484828117
#
# Test sample 467:
# Residual loss 1: 0.00022210865181084558 | Residual loss 2: 5.8291065102575385e-08
# Total residual loss: 0.00022216694287594815 | Sqrt residual loss: 0.014905265609037235
#
# Test sample 468:
# Residual loss 1: 0.0002839930017519878 | Residual loss 2: 2.393118681061898e-06
# Total residual loss: 0.0002863861204330497 | Sqrt residual loss: 0.016922946564740127
#
# Test sample 469:
# Residual loss 1: 0.0004050577586998873 | Residual loss 2: 4.2321872060757216e-08
# Total residual loss: 0.0004051000805719481 | Sqrt residual loss: 0.02012709816570556
#
# Test sample 470:
# Residual loss 1: 0.0003368769391493747 | Residual loss 2: 3.1761262652545746e-07
# Total residual loss: 0.00033719455177590017 | Sqrt residual loss: 0.018362857941396273
#
# Test sample 471:
# Residual loss 1: 0.00041183073036566754 | Residual loss 2: 5.592536591359446e-07
# Total residual loss: 0.00041238998402480347 | Sqrt residual loss: 0.02030738742489549
#
# Test sample 472:
# Residual loss 1: 0.0005273047154898229 | Residual loss 2: 2.3722056680577513e-07
# Total residual loss: 0.0005275419360566287 | Sqrt residual loss: 0.022968281086242145
#
# Test sample 473:
# Residual loss 1: 0.0002539647284453042 | Residual loss 2: 7.420974219891546e-09
# Total residual loss: 0.0002539721494195241 | Sqrt residual loss: 0.015936503676136873
#
# Test sample 474:
# Residual loss 1: 0.0003746921020073353 | Residual loss 2: 3.6312604624217854e-06
# Total residual loss: 0.0003783233624697571 | Sqrt residual loss: 0.01945053630288268
#
# Test sample 475:
# Residual loss 1: 0.0006692462616590157 | Residual loss 2: 1.0670387716615705e-06
# Total residual loss: 0.0006703133004306773 | Sqrt residual loss: 0.025890409429568263
#
# Test sample 476:
# Residual loss 1: 0.00040308933043070133 | Residual loss 2: 3.5517205635724944e-08
# Total residual loss: 0.0004031248476363371 | Sqrt residual loss: 0.020077969210961975
#
# Test sample 477:
# Residual loss 1: 0.00021945362334052719 | Residual loss 2: 2.893541192130868e-07
# Total residual loss: 0.00021974297745974028 | Sqrt residual loss: 0.014823730214077032
#
# Test sample 478:
# Residual loss 1: 0.00028402272220709137 | Residual loss 2: 1.361790243969957e-07
# Total residual loss: 0.0002841589012314884 | Sqrt residual loss: 0.01685701341375418
#
# Test sample 479:
# Residual loss 1: 0.0004937268795948141 | Residual loss 2: 5.671195458150091e-06
# Total residual loss: 0.0004993980750529641 | Sqrt residual loss: 0.022347216270778875
#
# Test sample 480:
# Residual loss 1: 0.0004040697926881141 | Residual loss 2: 1.908580118330055e-07
# Total residual loss: 0.0004042606506999471 | Sqrt residual loss: 0.02010623412526441
#
# Test sample 481:
# Residual loss 1: 0.00036486189799714503 | Residual loss 2: 5.341504897832853e-07
# Total residual loss: 0.0003653960484869283 | Sqrt residual loss: 0.019115335427005414
#
# Test sample 482:
# Residual loss 1: 0.00022119210759662106 | Residual loss 2: 6.276965370673774e-06
# Total residual loss: 0.00022746907296729483 | Sqrt residual loss: 0.015082077873001944
#
# Test sample 483:
# Residual loss 1: 0.0003865265866255475 | Residual loss 2: 1.0859195465068152e-06
# Total residual loss: 0.0003876125061720543 | Sqrt residual loss: 0.019687877137265317
#
# Test sample 484:
# Residual loss 1: 0.00030075218994722364 | Residual loss 2: 6.038021895341198e-07
# Total residual loss: 0.00030135599213675774 | Sqrt residual loss: 0.017359608064030644
#
# Test sample 485:
# Residual loss 1: 0.0001710519421360656 | Residual loss 2: 2.0286210712361172e-10
# Total residual loss: 0.00017105214499817272 | Sqrt residual loss: 0.013078690492483287
#
# Test sample 486:
# Residual loss 1: 0.00048198906927932744 | Residual loss 2: 6.19446456574211e-06
# Total residual loss: 0.00048818353384506955 | Sqrt residual loss: 0.022094875737262466
#
# Test sample 487:
# Residual loss 1: 0.0004403899732545248 | Residual loss 2: 4.0445197294789435e-07
# Total residual loss: 0.0004407944252274727 | Sqrt residual loss: 0.020995104792009795
#
# Test sample 488:
# Residual loss 1: 0.0007354700588226137 | Residual loss 2: 1.4570325340280464e-06
# Total residual loss: 0.0007369270913566417 | Sqrt residual loss: 0.027146401075587197
#
# Test sample 489:
# Residual loss 1: 0.00021323440944124016 | Residual loss 2: 2.4275626150416228e-08
# Total residual loss: 0.0002132586850673906 | Sqrt residual loss: 0.014603379234526185
#
# Test sample 490:
# Residual loss 1: 0.0005908888479252634 | Residual loss 2: 1.5737234494790946e-06
# Total residual loss: 0.0005924625713747425 | Sqrt residual loss: 0.0243405540482287
#
# Test sample 491:
# Residual loss 1: 0.0004957618404625166 | Residual loss 2: 2.583050712909597e-07
# Total residual loss: 0.0004960201455338076 | Sqrt residual loss: 0.022271509727313225
#
# Test sample 492:
# Residual loss 1: 0.000593607661316701 | Residual loss 2: 1.5475683030176965e-06
# Total residual loss: 0.0005951552296197186 | Sqrt residual loss: 0.024395803524781032
#
# Test sample 493:
# Residual loss 1: 0.00034769442753913626 | Residual loss 2: 7.03989019894055e-08
# Total residual loss: 0.0003477648264411257 | Sqrt residual loss: 0.01864845372788655
#
# Test sample 494:
# Residual loss 1: 0.0002560422633361827 | Residual loss 2: 3.7220643930410364e-07
# Total residual loss: 0.00025641446977548685 | Sqrt residual loss: 0.01601294694225541
#
# Test sample 495:
# Residual loss 1: 0.0007707622950919398 | Residual loss 2: 1.0319230848997118e-07
# Total residual loss: 0.0007708654874004298 | Sqrt residual loss: 0.02776446447170249
#
# Test sample 496:
# Residual loss 1: 0.00048308155320618524 | Residual loss 2: 1.7582338665674215e-07
# Total residual loss: 0.000483257376592842 | Sqrt residual loss: 0.021983115716222804
#
# Test sample 497:
# Residual loss 1: 0.00022648419540989865 | Residual loss 2: 9.108468512379825e-09
# Total residual loss: 0.00022649330387841104 | Sqrt residual loss: 0.015049694477909213
#
# Test sample 498:
# Residual loss 1: 0.00041478881311202 | Residual loss 2: 3.981184739169508e-07
# Total residual loss: 0.000415186931585937 | Sqrt residual loss: 0.020376136326250297
#
# Test sample 499:
# Residual loss 1: 0.0005058610993911895 | Residual loss 2: 3.5649950786058343e-06
# Total residual loss: 0.0005094260944697954 | Sqrt residual loss: 0.02257046952258183

# %%
np.save(os.path.join(model_test_outputs_path, "residual_loss_dict.npy"), residual_loss_dict)

# %%
print(f'mean residual loss 1: {np.mean(residual_loss_dict["loss_1"]):.2e} (std: {np.std(residual_loss_dict["loss_1"]):.2e})')
print(f'mean residual loss 2: {np.mean(residual_loss_dict["loss_2"]):.2e} (std: {np.std(residual_loss_dict["loss_2"]):.2e})')
print(f'mean total residual loss: {np.mean(residual_loss_dict["total_loss"]):.2e} (std: {np.std(residual_loss_dict["total_loss"]):.2e})')
print(f'mean sqrt total residual loss: {np.mean(residual_loss_dict["sqrt_total_loss"]):.2e} (std: {np.std(residual_loss_dict["sqrt_total_loss"]):.2e})')
# Out:
# mean residual loss 1: 4.53e-04 (std: 2.67e-04)
# mean residual loss 2: 1.39e-06 (std: 2.02e-06)
# mean total residual loss: 4.55e-04 (std: 2.67e-04)
# mean sqrt total residual loss: 2.06e-02 (std: 5.41e-03)

# %%
ratio_list = []
for test_index in range(num_test):
    ratio = np.sqrt(sigma_u_error_dict['squared_hdiv_h1'])[test_index] / residual_loss_dict['sqrt_total_loss'][test_index]
    ratio_list.append(ratio)
    print(f'index: {test_index} | ratio: {ratio}')
# Out:
# index: 0 | ratio: 1.3708890062944254
# index: 1 | ratio: 1.0670771359216362
# index: 2 | ratio: 1.1741998391082769
# index: 3 | ratio: 1.5195683475077986
# index: 4 | ratio: 0.8916814223921812
# index: 5 | ratio: 0.4915188560380252
# index: 6 | ratio: 1.2713021694170392
# index: 7 | ratio: 1.2633398230188317
# index: 8 | ratio: 0.9184765891000786
# index: 9 | ratio: 1.0320472735013642
# index: 10 | ratio: 0.7423723856011656
# index: 11 | ratio: 0.7499395610689552
# index: 12 | ratio: 0.9439017758938948
# index: 13 | ratio: 1.0256466114900804
# index: 14 | ratio: 0.42878685137266737
# index: 15 | ratio: 0.6850822210075153
# index: 16 | ratio: 0.8617187844589346
# index: 17 | ratio: 1.2001160362278456
# index: 18 | ratio: 1.4190185133574187
# index: 19 | ratio: 1.137816777285812
# index: 20 | ratio: 1.052402666614741
# index: 21 | ratio: 0.8317225557028767
# index: 22 | ratio: 0.76196373022856
# index: 23 | ratio: 1.0862066360636926
# index: 24 | ratio: 0.6110373057537791
# index: 25 | ratio: 0.8817493061255182
# index: 26 | ratio: 1.2407624805084634
# index: 27 | ratio: 1.1601014968341303
# index: 28 | ratio: 1.4037370425684286
# index: 29 | ratio: 1.5263096727880165
# index: 30 | ratio: 0.7422017691503774
# index: 31 | ratio: 0.7718108812585761
# index: 32 | ratio: 0.5830002039336919
# index: 33 | ratio: 1.0860417255524064
# index: 34 | ratio: 0.7719803833480053
# index: 35 | ratio: 1.4374867203940997
# index: 36 | ratio: 0.8354025135297742
# index: 37 | ratio: 1.302465774274586
# index: 38 | ratio: 0.9065373838950607
# index: 39 | ratio: 1.0961170597155196
# index: 40 | ratio: 0.7465444897618501
# index: 41 | ratio: 1.1539903224665982
# index: 42 | ratio: 0.68335911874862
# index: 43 | ratio: 0.6243492875027732
# index: 44 | ratio: 0.9906089251388885
# index: 45 | ratio: 0.687982961940793
# index: 46 | ratio: 0.6847782391252293
# index: 47 | ratio: 0.7156386391196815
# index: 48 | ratio: 1.1057846197211383
# index: 49 | ratio: 1.0038124274228246
# index: 50 | ratio: 1.2398413328118891
# index: 51 | ratio: 1.1717547478428738
# index: 52 | ratio: 0.677401039922417
# index: 53 | ratio: 0.7453151561404491
# index: 54 | ratio: 1.1125537374604395
# index: 55 | ratio: 1.1674034913080968
# index: 56 | ratio: 1.5564557456609984
# index: 57 | ratio: 0.5607642419994364
# index: 58 | ratio: 1.1892011507715647
# index: 59 | ratio: 0.8212597463784865
# index: 60 | ratio: 0.9692740323703257
# index: 61 | ratio: 1.188608274654746
# index: 62 | ratio: 0.7530215393793588
# index: 63 | ratio: 1.5203309373413612
# index: 64 | ratio: 1.1442715004930575
# index: 65 | ratio: 0.962668873182736
# index: 66 | ratio: 1.4962838099242965
# index: 67 | ratio: 0.9643431783718424
# index: 68 | ratio: 1.300371315925704
# index: 69 | ratio: 1.2103403330913067
# index: 70 | ratio: 0.8901495595193902
# index: 71 | ratio: 1.191041028012812
# index: 72 | ratio: 1.1920665274703226
# index: 73 | ratio: 1.036821562663059
# index: 74 | ratio: 0.9490250698428054
# index: 75 | ratio: 0.8651320756395556
# index: 76 | ratio: 1.172651173341007
# index: 77 | ratio: 1.0287963901629937
# index: 78 | ratio: 1.3699562024419725
# index: 79 | ratio: 1.3348458862498358
# index: 80 | ratio: 0.6622204286012803
# index: 81 | ratio: 1.238512573099982
# index: 82 | ratio: 0.8523600789587328
# index: 83 | ratio: 1.2042607383692154
# index: 84 | ratio: 1.058930684248444
# index: 85 | ratio: 0.7755572804288998
# index: 86 | ratio: 1.121685429029301
# index: 87 | ratio: 1.0556648566705027
# index: 88 | ratio: 0.9886315834635551
# index: 89 | ratio: 1.252210067828071
# index: 90 | ratio: 1.3085523809852677
# index: 91 | ratio: 1.4854939174607797
# index: 92 | ratio: 0.7906861948546009
# index: 93 | ratio: 0.8896179835943829
# index: 94 | ratio: 1.0097315301125322
# index: 95 | ratio: 0.8612892477548458
# index: 96 | ratio: 1.0508245168409893
# index: 97 | ratio: 0.8848326787050971
# index: 98 | ratio: 0.7142619244359615
# index: 99 | ratio: 1.1050022897742868
# index: 100 | ratio: 1.2231645997446545
# index: 101 | ratio: 1.1216087498832683
# index: 102 | ratio: 0.7877131266841159
# index: 103 | ratio: 1.0952621449048558
# index: 104 | ratio: 0.9657846824444918
# index: 105 | ratio: 0.9874025188504615
# index: 106 | ratio: 0.9150072763290994
# index: 107 | ratio: 1.1682341911904763
# index: 108 | ratio: 0.40374406454536976
# index: 109 | ratio: 0.5875803881884424
# index: 110 | ratio: 1.105329742031962
# index: 111 | ratio: 0.8226274649960135
# index: 112 | ratio: 1.1870770532627446
# index: 113 | ratio: 1.0947984319790478
# index: 114 | ratio: 1.0283889053575244
# index: 115 | ratio: 0.707252556432222
# index: 116 | ratio: 0.5287837849462215
# index: 117 | ratio: 0.9169155966059594
# index: 118 | ratio: 0.3967926889886666
# index: 119 | ratio: 0.8289914252555668
# index: 120 | ratio: 0.8721322501616422
# index: 121 | ratio: 0.7413869829810724
# index: 122 | ratio: 0.6092012465776576
# index: 123 | ratio: 1.1074283851372237
# index: 124 | ratio: 0.5867321175730027
# index: 125 | ratio: 0.9886574646033315
# index: 126 | ratio: 1.0227404523430323
# index: 127 | ratio: 1.2041440916035193
# index: 128 | ratio: 0.6666807102651311
# index: 129 | ratio: 0.8704234705181545
# index: 130 | ratio: 1.1421437774070549
# index: 131 | ratio: 1.452127165505435
# index: 132 | ratio: 1.1169922417608946
# index: 133 | ratio: 1.1143880948572433
# index: 134 | ratio: 0.5575938820542098
# index: 135 | ratio: 1.2216711488143497
# index: 136 | ratio: 1.5807965936817008
# index: 137 | ratio: 1.1255709431344565
# index: 138 | ratio: 0.8911495228617334
# index: 139 | ratio: 0.7705211342335885
# index: 140 | ratio: 0.8489712030445119
# index: 141 | ratio: 0.7203480359534837
# index: 142 | ratio: 0.9425103566646774
# index: 143 | ratio: 0.9251506692342082
# index: 144 | ratio: 0.5724080253640347
# index: 145 | ratio: 0.7973310152787959
# index: 146 | ratio: 0.7677118518368511
# index: 147 | ratio: 0.7242326682685214
# index: 148 | ratio: 0.8968611098440454
# index: 149 | ratio: 1.2300717881042054
# index: 150 | ratio: 0.6907795745380528
# index: 151 | ratio: 0.9225063467579125
# index: 152 | ratio: 0.6346339528969811
# index: 153 | ratio: 1.1046014654997924
# index: 154 | ratio: 0.6319556792755977
# index: 155 | ratio: 1.1683146723362465
# index: 156 | ratio: 0.5956106040565387
# index: 157 | ratio: 0.6244428868033587
# index: 158 | ratio: 1.2106819989870499
# index: 159 | ratio: 1.2065902548056913
# index: 160 | ratio: 0.8795977374529328
# index: 161 | ratio: 0.8323661474112926
# index: 162 | ratio: 0.9159357784138986
# index: 163 | ratio: 0.6752584587697497
# index: 164 | ratio: 0.7327603602633811
# index: 165 | ratio: 0.5884028919782807
# index: 166 | ratio: 0.5440042453555258
# index: 167 | ratio: 1.2601845698383711
# index: 168 | ratio: 0.6719326243889846
# index: 169 | ratio: 1.170213553584085
# index: 170 | ratio: 0.715113987194467
# index: 171 | ratio: 0.995364205298572
# index: 172 | ratio: 0.8897151129628441
# index: 173 | ratio: 1.2328362297380444
# index: 174 | ratio: 0.5464359233090779
# index: 175 | ratio: 0.6558076895379443
# index: 176 | ratio: 1.0003333728114427
# index: 177 | ratio: 0.8538232294437611
# index: 178 | ratio: 0.6725346835350214
# index: 179 | ratio: 0.5524191920234813
# index: 180 | ratio: 0.9856770409213131
# index: 181 | ratio: 1.1456803660137493
# index: 182 | ratio: 1.0159806490919518
# index: 183 | ratio: 0.7971566461318595
# index: 184 | ratio: 0.9287637984605044
# index: 185 | ratio: 0.5608074667975316
# index: 186 | ratio: 0.9248218135711513
# index: 187 | ratio: 0.9934688620352138
# index: 188 | ratio: 0.361327297159153
# index: 189 | ratio: 1.0241501495693641
# index: 190 | ratio: 1.3155341976492445
# index: 191 | ratio: 0.6639930367157605
# index: 192 | ratio: 0.6923467774019262
# index: 193 | ratio: 0.6505550370985848
# index: 194 | ratio: 0.5639220478675334
# index: 195 | ratio: 0.7333176754847603
# index: 196 | ratio: 0.8182548254506025
# index: 197 | ratio: 0.8134851750756463
# index: 198 | ratio: 1.2928810557889063
# index: 199 | ratio: 1.1004132521614012
# index: 200 | ratio: 0.589142412250849
# index: 201 | ratio: 0.9418036454473964
# index: 202 | ratio: 0.8263091014720039
# index: 203 | ratio: 1.236732492223668
# index: 204 | ratio: 0.9867227543912008
# index: 205 | ratio: 0.8468106418928322
# index: 206 | ratio: 0.7926495483989514
# index: 207 | ratio: 0.8476625367462159
# index: 208 | ratio: 1.0226319081688593
# index: 209 | ratio: 1.1528719950603732
# index: 210 | ratio: 0.7109520113715843
# index: 211 | ratio: 1.2741673283378636
# index: 212 | ratio: 1.0139832933644095
# index: 213 | ratio: 1.276158468541199
# index: 214 | ratio: 0.7741669187325617
# index: 215 | ratio: 0.6098353713325559
# index: 216 | ratio: 0.7205737323222465
# index: 217 | ratio: 0.9730132051429107
# index: 218 | ratio: 0.6991287033601704
# index: 219 | ratio: 1.0616555380678598
# index: 220 | ratio: 0.8988028274394736
# index: 221 | ratio: 0.9516588335630757
# index: 222 | ratio: 1.263540163599065
# index: 223 | ratio: 0.9457975277721041
# index: 224 | ratio: 0.6751607427340446
# index: 225 | ratio: 0.9936383740518085
# index: 226 | ratio: 0.880364581595715
# index: 227 | ratio: 0.5625510341018217
# index: 228 | ratio: 0.8872069557969166
# index: 229 | ratio: 0.7285424681781258
# index: 230 | ratio: 1.4365929944275964
# index: 231 | ratio: 1.1340083950652942
# index: 232 | ratio: 1.313380706513959
# index: 233 | ratio: 0.3862905234702103
# index: 234 | ratio: 1.371278782716377
# index: 235 | ratio: 0.8640717918887418
# index: 236 | ratio: 1.0630680643598514
# index: 237 | ratio: 1.4393551331786802
# index: 238 | ratio: 0.4849275900504622
# index: 239 | ratio: 0.6940633281508852
# index: 240 | ratio: 1.5158525568946108
# index: 241 | ratio: 0.3304464792204841
# index: 242 | ratio: 0.964737753146896
# index: 243 | ratio: 0.8960170559310774
# index: 244 | ratio: 0.8199539710785663
# index: 245 | ratio: 1.2662097665728833
# index: 246 | ratio: 0.8082164925896697
# index: 247 | ratio: 0.9809065038120894
# index: 248 | ratio: 1.222700347344787
# index: 249 | ratio: 1.4733534691668757
# index: 250 | ratio: 0.7911846124576155
# index: 251 | ratio: 0.687775594130122
# index: 252 | ratio: 0.8276294346175035
# index: 253 | ratio: 0.6344819143237482
# index: 254 | ratio: 1.0094746732839084
# index: 255 | ratio: 0.5250664256920056
# index: 256 | ratio: 0.9929418156945776
# index: 257 | ratio: 1.109856690988822
# index: 258 | ratio: 1.051631145727678
# index: 259 | ratio: 0.6478890862083158
# index: 260 | ratio: 1.0902008067888043
# index: 261 | ratio: 1.3489181272296615
# index: 262 | ratio: 0.6585949458084679
# index: 263 | ratio: 1.0501709448561762
# index: 264 | ratio: 0.90731398618069
# index: 265 | ratio: 1.1131724839993757
# index: 266 | ratio: 0.6891368527172026
# index: 267 | ratio: 0.8886613299045204
# index: 268 | ratio: 1.1061915426873636
# index: 269 | ratio: 0.7198262838228244
# index: 270 | ratio: 1.142833956720644
# index: 271 | ratio: 0.7473098973754833
# index: 272 | ratio: 0.9429510794763908
# index: 273 | ratio: 1.4863673984803842
# index: 274 | ratio: 0.8713621294333912
# index: 275 | ratio: 1.0286024648954464
# index: 276 | ratio: 1.2644364079629686
# index: 277 | ratio: 0.7604508658495799
# index: 278 | ratio: 0.4815615318377373
# index: 279 | ratio: 0.49236088988067905
# index: 280 | ratio: 1.083535902485069
# index: 281 | ratio: 1.3128898194751317
# index: 282 | ratio: 0.885385383744129
# index: 283 | ratio: 0.7974487431837779
# index: 284 | ratio: 1.5363086378836066
# index: 285 | ratio: 1.048666492389026
# index: 286 | ratio: 0.7602979182575629
# index: 287 | ratio: 0.992366367372906
# index: 288 | ratio: 0.9492186417827981
# index: 289 | ratio: 1.3178024169369285
# index: 290 | ratio: 0.6715621131382528
# index: 291 | ratio: 0.9025310267405446
# index: 292 | ratio: 0.8454127292377347
# index: 293 | ratio: 1.3231392403159101
# index: 294 | ratio: 0.6759403965620976
# index: 295 | ratio: 1.1629006256505925
# index: 296 | ratio: 1.1442657163805527
# index: 297 | ratio: 0.8597695459281411
# index: 298 | ratio: 1.028715561414868
# index: 299 | ratio: 0.6840157367256023
# index: 300 | ratio: 1.0708974349695182
# index: 301 | ratio: 0.72265485981687
# index: 302 | ratio: 0.8033657570763548
# index: 303 | ratio: 0.6650409346519454
# index: 304 | ratio: 1.471116993626502
# index: 305 | ratio: 0.6713304107420605
# index: 306 | ratio: 1.091985786249082
# index: 307 | ratio: 1.0622094738098808
# index: 308 | ratio: 0.718561375773412
# index: 309 | ratio: 1.1212431221628265
# index: 310 | ratio: 1.036349945417661
# index: 311 | ratio: 1.1455086081729309
# index: 312 | ratio: 1.4385159464916986
# index: 313 | ratio: 1.0219352601514207
# index: 314 | ratio: 0.7302051939631247
# index: 315 | ratio: 0.8623314360992034
# index: 316 | ratio: 0.9706789851008479
# index: 317 | ratio: 1.1272955727706595
# index: 318 | ratio: 1.56270365274784
# index: 319 | ratio: 1.5133163884165712
# index: 320 | ratio: 0.8049825164393576
# index: 321 | ratio: 0.7025391861317789
# index: 322 | ratio: 1.1140082690089703
# index: 323 | ratio: 0.8051306677397976
# index: 324 | ratio: 0.835210574222014
# index: 325 | ratio: 0.7615222483071509
# index: 326 | ratio: 1.0095500197314398
# index: 327 | ratio: 0.5944677809238037
# index: 328 | ratio: 0.5767587470399367
# index: 329 | ratio: 0.6776000539871062
# index: 330 | ratio: 1.05939116563663
# index: 331 | ratio: 0.6291696992135932
# index: 332 | ratio: 0.7317836630362499
# index: 333 | ratio: 0.8720714728604946
# index: 334 | ratio: 1.3155642586252447
# index: 335 | ratio: 1.261505320643903
# index: 336 | ratio: 0.9619848156684915
# index: 337 | ratio: 0.5154881528317986
# index: 338 | ratio: 0.8517043559403298
# index: 339 | ratio: 0.5889133554077415
# index: 340 | ratio: 1.0157431695353079
# index: 341 | ratio: 0.6253868136667728
# index: 342 | ratio: 1.0146725652417123
# index: 343 | ratio: 0.7510199279322767
# index: 344 | ratio: 1.1889553814562859
# index: 345 | ratio: 0.6903707338539606
# index: 346 | ratio: 0.8996611494547934
# index: 347 | ratio: 1.3224461401772043
# index: 348 | ratio: 0.6383464133433786
# index: 349 | ratio: 0.5925152812803387
# index: 350 | ratio: 1.0906756058735603
# index: 351 | ratio: 1.0439176484004107
# index: 352 | ratio: 1.2266555813957136
# index: 353 | ratio: 0.6626820062712383
# index: 354 | ratio: 0.6525650789387101
# index: 355 | ratio: 1.593651395557201
# index: 356 | ratio: 1.269199154072052
# index: 357 | ratio: 0.8654796624997484
# index: 358 | ratio: 0.8299748016037498
# index: 359 | ratio: 0.8916265479867399
# index: 360 | ratio: 1.5197358797088019
# index: 361 | ratio: 0.7514364653430375
# index: 362 | ratio: 0.6350201857165796
# index: 363 | ratio: 1.4452690551178093
# index: 364 | ratio: 0.586753104290573
# index: 365 | ratio: 0.9421233345722936
# index: 366 | ratio: 0.8443460901944102
# index: 367 | ratio: 0.5835389998874956
# index: 368 | ratio: 0.6679780088411863
# index: 369 | ratio: 1.396135817104777
# index: 370 | ratio: 1.098662413618682
# index: 371 | ratio: 1.1353271284215178
# index: 372 | ratio: 1.2827528385569993
# index: 373 | ratio: 0.8891052562622813
# index: 374 | ratio: 1.110684742555102
# index: 375 | ratio: 1.4952506586635843
# index: 376 | ratio: 0.9352169865283884
# index: 377 | ratio: 0.8272097299276215
# index: 378 | ratio: 0.8975589005314479
# index: 379 | ratio: 0.9329930657902827
# index: 380 | ratio: 0.954720558142504
# index: 381 | ratio: 1.096917294310613
# index: 382 | ratio: 0.8939084343677339
# index: 383 | ratio: 1.1901882003979927
# index: 384 | ratio: 1.0317474702851592
# index: 385 | ratio: 0.613172821606581
# index: 386 | ratio: 1.1990791644371093
# index: 387 | ratio: 1.2200857664055733
# index: 388 | ratio: 1.0238431993539951
# index: 389 | ratio: 0.816370715849148
# index: 390 | ratio: 0.6417931994238253
# index: 391 | ratio: 0.7487153270950335
# index: 392 | ratio: 0.4350948168914673
# index: 393 | ratio: 1.6243588044019661
# index: 394 | ratio: 0.6923463918442535
# index: 395 | ratio: 0.7858741559781214
# index: 396 | ratio: 1.1534556683244006
# index: 397 | ratio: 0.9803096337479252
# index: 398 | ratio: 1.2329406374389336
# index: 399 | ratio: 0.9516239050822553
# index: 400 | ratio: 1.1968272499355166
# index: 401 | ratio: 0.8551644044634527
# index: 402 | ratio: 1.2818633488506392
# index: 403 | ratio: 1.3700016638872694
# index: 404 | ratio: 1.400270636513339
# index: 405 | ratio: 0.6520874635404618
# index: 406 | ratio: 0.9697201474189971
# index: 407 | ratio: 1.202792488777503
# index: 408 | ratio: 0.9263705635494579
# index: 409 | ratio: 0.952525530490794
# index: 410 | ratio: 0.8802727693704059
# index: 411 | ratio: 0.9394477639736761
# index: 412 | ratio: 1.126703766774857
# index: 413 | ratio: 0.8329787225285403
# index: 414 | ratio: 0.6474517408874558
# index: 415 | ratio: 0.6999694248065849
# index: 416 | ratio: 0.7784227945647004
# index: 417 | ratio: 1.243775842184285
# index: 418 | ratio: 0.3828518120558879
# index: 419 | ratio: 0.9157576992607734
# index: 420 | ratio: 1.1518178677903503
# index: 421 | ratio: 0.8920483537957966
# index: 422 | ratio: 1.0691673800947215
# index: 423 | ratio: 1.3093730023043104
# index: 424 | ratio: 1.2959824962349107
# index: 425 | ratio: 1.0592974706763583
# index: 426 | ratio: 1.084283863515781
# index: 427 | ratio: 0.9305749886093849
# index: 428 | ratio: 1.0612058477426884
# index: 429 | ratio: 1.0695431434354672
# index: 430 | ratio: 1.1365879701826016
# index: 431 | ratio: 1.1378630694184597
# index: 432 | ratio: 0.7819376911097835
# index: 433 | ratio: 0.7545206714716046
# index: 434 | ratio: 0.863831228848521
# index: 435 | ratio: 0.7590955350991554
# index: 436 | ratio: 1.4537644907289744
# index: 437 | ratio: 1.7228538463718022
# index: 438 | ratio: 0.5204585074967791
# index: 439 | ratio: 0.9643935933424983
# index: 440 | ratio: 0.836481738681759
# index: 441 | ratio: 0.684261120589776
# index: 442 | ratio: 1.2974415719098928
# index: 443 | ratio: 0.6717243909680705
# index: 444 | ratio: 0.7731622597686763
# index: 445 | ratio: 0.958047386853429
# index: 446 | ratio: 0.9376169364797096
# index: 447 | ratio: 1.2297048913563455
# index: 448 | ratio: 1.2042819232641513
# index: 449 | ratio: 0.8347171618132628
# index: 450 | ratio: 1.4801294049957567
# index: 451 | ratio: 0.913433184460207
# index: 452 | ratio: 0.7985196425554141
# index: 453 | ratio: 1.1273835624874637
# index: 454 | ratio: 0.8629736483890169
# index: 455 | ratio: 0.9055899403378105
# index: 456 | ratio: 1.0191668068441533
# index: 457 | ratio: 0.5679240312106063
# index: 458 | ratio: 0.7030153890252651
# index: 459 | ratio: 0.8474667932892199
# index: 460 | ratio: 1.2288085932955326
# index: 461 | ratio: 0.6365888668351122
# index: 462 | ratio: 0.9176013224390421
# index: 463 | ratio: 0.49738397767966824
# index: 464 | ratio: 0.5722098715866741
# index: 465 | ratio: 1.2809575744590957
# index: 466 | ratio: 0.6985081552739623
# index: 467 | ratio: 1.2303067681223865
# index: 468 | ratio: 1.5498755315331567
# index: 469 | ratio: 0.8916832268860057
# index: 470 | ratio: 0.9399792847609711
# index: 471 | ratio: 1.0266854891576878
# index: 472 | ratio: 0.951493482780986
# index: 473 | ratio: 0.7434778348511657
# index: 474 | ratio: 1.283818759737155
# index: 475 | ratio: 1.0620137367813742
# index: 476 | ratio: 0.6487122208086095
# index: 477 | ratio: 0.8456826543374789
# index: 478 | ratio: 1.0334459929562512
# index: 479 | ratio: 0.9088026143056691
# index: 480 | ratio: 0.4952528844005261
# index: 481 | ratio: 1.0123986614455212
# index: 482 | ratio: 0.9279087498790101
# index: 483 | ratio: 1.1893548708280013
# index: 484 | ratio: 1.1131436113991764
# index: 485 | ratio: 1.226660458108505
# index: 486 | ratio: 1.1490357308093706
# index: 487 | ratio: 0.5002148688459812
# index: 488 | ratio: 0.9934835519297815
# index: 489 | ratio: 0.7843703065937054
# index: 490 | ratio: 0.8898687573639315
# index: 491 | ratio: 0.7647972261995903
# index: 492 | ratio: 0.6557891001356763
# index: 493 | ratio: 0.8268531701435426
# index: 494 | ratio: 1.4279157666205338
# index: 495 | ratio: 0.7715771212929218
# index: 496 | ratio: 0.9016403210853879
# index: 497 | ratio: 1.3849787069645676
# index: 498 | ratio: 0.8367650918183714
# index: 499 | ratio: 1.339484302333536

# %%
plt.figure(figsize=(8, 6))  # Optional: bigger figure
plt.hist(ratio_list, bins=10)

plt.xlabel('Value', fontsize=25) 
plt.ylabel('Frequency', fontsize=25)
plt.title(fr'Error / $\sqrt{{\text{{Loss}}}}$ (# test = {num_test})', fontsize=25)

plt.xticks(fontsize=23)
plt.yticks(fontsize=23)

plt.savefig(os.path.join(model_test_outputs_path, 'ratio_histogram_hdiv_h1.png'),
            dpi=300, bbox_inches='tight')
plt.close()
