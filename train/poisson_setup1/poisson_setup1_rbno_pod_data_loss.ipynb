# %%
import os
import sys
import argparse

import numpy as np
import matplotlib.pyplot as plt

import torch

import dolfinx
import dolfinx.fem.petsc
import ufl
from mpi4py import MPI
import basix.ufl

repo_path = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(repo_path)

from data_generation.differential_equations import PoissonSetup1LeastSquares
from utils import load_yaml, load_pkl, load_npy, format_elapsed_time, timing
from utils import plot_real_valued_function, plot_block_sparsity, plot_block_submatrix_sparsity

from scifem import create_real_functionspace

import torch
import torch.nn as nn
import torch.nn.init as init
import numpy as np
from petsc4py import PETSc
import scifem


from utils import project, norm_L2, convert_petsc_mat_to_torch_sparse_coo_tensor, convert_weight_to_tensor
from utils import evaluate_expression, print_model_size
from typing import Optional
import pickle
import csv

from typing import Optional
from train.train_loss import SurrogateLoss
from models import ConvolutionalNN_129x129
from train.train_utils import BatchIndicesIterator, pretty_print_loss
from train.soap import SOAP
from utils.set_seed import set_seed
import time
from tqdm import tqdm
# Out:
# ----------------------------------------
# 2025-12-09 21:12:46 - Start Program
# ----------------------------------------

# %%
set_seed(2025)

# %%
mesh_config_path= repo_path + "/configs/poisson_setup1/config_data/config_mesh.yaml"
function_space_config_path= repo_path + "/configs/poisson_setup1/config_data/config_function_space.yaml"
output_reduced_basis_config_path= repo_path + "/configs/poisson_setup1/config_data/config_output_reduced_basis.yaml"
train_dataset_path = repo_path + "/results/poisson_setup1/train_dataset"
test_dataset_path = repo_path + "/results/poisson_setup1/test_dataset"
model_train_outputs_path = repo_path + "/results/poisson_setup1/model_train_outputs/rbno_pod_data_loss"
model_test_outputs_path = repo_path + "/results/poisson_setup1/model_test_outputs/rbno_pod_data_loss"

mesh_args = load_yaml(mesh_config_path)
function_space_args = load_yaml(function_space_config_path)
output_reduced_basis_args = load_yaml(output_reduced_basis_config_path)
poisson_least_squares = PoissonSetup1LeastSquares(mesh_args, function_space_args)

# %%
p_dof = load_npy(train_dataset_path+'/p_dof.npy')
p_vertex_values = load_npy(train_dataset_path+'/p_vertex_values.npy')
sigma_u_dof = load_npy(train_dataset_path+'/sigma_u_dof.npy')

# %%
print("p_dof shape: ", p_dof.shape)
print("p_vertex_values shape: ", p_vertex_values.shape)
print("sigma_u_dof shape: ", sigma_u_dof.shape)
# Out:
# p_dof shape:  (5000, 32768)
# p_vertex_values shape:  (5000, 16641)
# sigma_u_dof shape:  (5000, 230401)

# %%
mesh = poisson_least_squares.mesh
Vh = poisson_least_squares.Vh

# %%
torch_dtype = {
    'float16': torch.float16,
    'float32': torch.float32,
    'float64': torch.float64,
}

# %%
reference_loss_list = []
num_samples_for_reference_loss = 1
for i in range(num_samples_for_reference_loss):
    p_fc = dolfinx.fem.Function(Vh['p'])  
    p_fc.x.array[:] = p_dof[i]
    weight = poisson_least_squares.compute_weight(p_fc)
    weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float64'])
    
    y = sigma_u_dof[i]
    y = torch.tensor(y, dtype=torch_dtype['float64'])
    reference_loss = torch.dot(y, weight_tensor['A00'] @ y) + 2*torch.dot(y, weight_tensor['A01'])  + weight_tensor['A11']
    print(f'reference loss: {reference_loss.item()}')
    reference_loss_list.append(reference_loss.item())

print(f"reference loss mean: {np.mean(reference_loss_list):.2e}")
print(f"reference loss std: {np.std(reference_loss_list):.2e}")
# Out:
# reference loss: 0.00010073986411485158
# reference loss mean: 1.01e-04
# reference loss std: 0.00e+00

# %%
def compute_reduced_weight(weight: dict[torch.Tensor], pod_basis_dof: torch.Tensor)-> torch.Tensor:

    quadratic_weight = pod_basis_dof.T @ weight['A00'] @ pod_basis_dof
    linear_weight = pod_basis_dof.T @ weight['A01']
    bias = weight['A11']

    reduced_weight = {'quadratic': quadratic_weight, 'linear': linear_weight, 'bias': bias}

    return reduced_weight

def compute_reduced_weight_v2(weight,  pod_basis_dof_petsc, pod_basis_dof_petsc_T) -> dict[np.ndarray]:
    """
    Compute the reduced weight using the POD basis in PETSc format.
    """
    temp = weight['A00'].matMult(pod_basis_dof_petsc)
    quadratic_weight = pod_basis_dof_petsc_T.matMult(temp)
    linear_weight = pod_basis_dof_petsc_T.createVecLeft()
    pod_basis_dof_petsc_T.mult(weight['A01'], linear_weight)
    bias = weight['A11']

    def mat_to_numpy(mat: PETSc.Mat):
        m, n = mat.getSize()
        arr = np.zeros((m, n), dtype=float)
        for i in range(m):
            for j in range(n):
                arr[i, j] = mat.getValue(i, j)
        return arr

    quadratic_weight = mat_to_numpy(quadratic_weight)
    linear_weight = linear_weight.getArray(readonly=True)
    reduced_weight = {'quadratic': quadratic_weight, 'linear': linear_weight, 'bias': bias}

    return reduced_weight

num_basis = 128

pod_basis_dof = np.load(train_dataset_path + '/hdiv_h1_pod_basis_dof.npy')[:, :num_basis]
pod_basis_dof_tensor = torch.tensor(pod_basis_dof, dtype=torch_dtype['float64'])

import numpy as np
from petsc4py import PETSc

pod_basis_dof_petsc = PETSc.Mat().createDense(size=pod_basis_dof.shape, array=pod_basis_dof, comm=PETSc.COMM_SELF)
pod_basis_dof_petsc_T = PETSc.Mat().createDense(size=(pod_basis_dof.shape[1], pod_basis_dof.shape[0]), array=pod_basis_dof.T, comm=PETSc.COMM_SELF)
pod_basis_dof_petsc.assemblyBegin()
pod_basis_dof_petsc.assemblyEnd()
pod_basis_dof_petsc_T.assemblyBegin()
pod_basis_dof_petsc_T.assemblyEnd()

# %%
# %%time
weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float64'])
reduced_weight = compute_reduced_weight(weight_tensor, pod_basis_dof_tensor)
# Out:
# CPU times: user 1.29 s, sys: 2.21 s, total: 3.5 s
# Wall time: 3.49 s

# %%
# %%time
reduced_weight_v2 = compute_reduced_weight_v2(weight, pod_basis_dof_petsc, pod_basis_dof_petsc_T)
# Out:
# CPU times: user 391 ms, sys: 112 ms, total: 502 ms
# Wall time: 495 ms

# %%
# avg_compute_reduced_weight_time = 0
# for i in range(num_samples_for_reference_loss):
#     k_fc = dolfinx.fem.Function(Vh['k'])
#     k_fc.x.array[:] = k_dof[i]
#     weight = poisson_least_squares.compute_weight_with_auxiliary_variable(k_fc, aux_sigma_u)

#     start_time = time.time()
#     reduced_weight_v2 = compute_reduced_weight_v2(weight, pod_basis_dof_petsc, pod_basis_dof_petsc_T)
#     end_time = time.time()
#     avg_compute_reduced_weight_time += (end_time - start_time)
# avg_compute_reduced_weight_time /= num_samples_for_reference_loss
# print(avg_compute_reduced_weight_time)

# %%
# ## precision = float32
# reference_loss_list = []
# num_samples_for_reference_loss = 100
# aux_sigma_u = dolfinx.fem.Function(Vh['sigma_u'])
# aux_sigma_u.x.array[:] = aux_sigma_u_dof
# for i in range(num_samples_for_reference_loss):
#     k_fc = dolfinx.fem.Function(Vh['k'])  
#     k_fc.x.array[:] = k_dof[i]
#     weight = poisson_least_squares.compute_weight_with_auxiliary_variable(k_fc, aux_sigma_u)
#     weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float32'])
    
#     y = sigma_u_dof[i] - aux_sigma_u_dof
#     y = torch.tensor(y, dtype=torch_dtype['float32'])
#     reference_loss = torch.dot(y, weight_tensor['A00'] @ y) + 2*torch.dot(y, weight_tensor['A01'])  + weight_tensor['A11']
#     print(f'reference loss: {reference_loss.item()}')
#     reference_loss_list.append(reference_loss.item())


# print(f"reference loss mean: {np.mean(reference_loss_list):.2e}")
# print(f"reference loss std: {np.std(reference_loss_list):.2e}")

# %%
# # precision = float16
# reference_loss_list = []
# num_samples_for_reference_loss = 100
# aux_sigma_u = dolfinx.fem.Function(Vh['sigma_u'])
# aux_sigma_u.x.array[:] = aux_sigma_u_dof
# for i in range(num_samples_for_reference_loss):
#     k_fc = dolfinx.fem.Function(Vh['k'])  
#     k_fc.x.array[:] = k_dof[i]
#     weight = poisson_least_squares.compute_weight_with_auxiliary_variable(k_fc, aux_sigma_u)
#     weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float16'])
    
#     y = sigma_u_dof[i] - aux_sigma_u_dof
#     y = torch.tensor(y, dtype=torch_dtype['float16'])
#     reference_loss = torch.dot(y, weight_tensor['A00'] @ y) + 2*torch.dot(y, weight_tensor['A01'])  + weight_tensor['A11']
#     print(f'reference loss: {reference_loss.item()}')
#     reference_loss_list.append(reference_loss.item())

# print(f"reference loss mean: {np.mean(reference_loss_list):.2e}")
# print(f"reference loss std: {np.std(reference_loss_list):.2e}")

# %%
# fig = plot_block_sparsity(weight_tensor, highlight_box=(10000, 12000, 10000, 12000), box_color='red', box_linewidth=3, box_alpha=0.9)
# fig.savefig(os.path.join(train_dataset_path, 'sparsity_pattern_full.png'), dpi=300, bbox_inches='tight')

# %%
# fig = plot_block_submatrix_sparsity(weight_tensor, (10000, 12000), (10000, 12000), highlight_box=(0, 100, 0, 100), box_color='red', box_linewidth=2, box_alpha=0.5)
# fig.savefig(os.path.join(train_dataset_path, 'sparsity_pattern_10000-12000.png'), dpi=300, bbox_inches='tight')

# %%
# fig = plot_block_submatrix_sparsity(weight_tensor, (10000, 10100), (10000, 10100))
# fig.savefig(os.path.join(train_dataset_path, 'sparsity_pattern_10000-10100.png'), dpi=300, bbox_inches='tight')

# %%
# for i in range(10):
#     k_fc = dolfinx.fem.Function(Vh['k'])
#     k_fc.x.array[:] = k_dof[i]
#     weight = poisson_least_squares.compute_weight_with_auxiliary_variable(k_fc, aux_sigma_u)
#     weight_tensor = convert_weight_to_tensor(weight, dtype=torch_dtype['float64'])
    
#     y = sigma_u_dof[0] - aux_sigma_u_dof
#     y = torch.tensor(y, dtype=torch_dtype['float64'])
#     reference_loss = torch.dot(y, weight_tensor['A00'] @ y) + 2*torch.dot(y, weight_tensor['A01'])  + weight_tensor['A11']

#     if i == 0:
#         print(f'Correct reference loss: {reference_loss}')
#     else: 
#         print(f'Wrong reference loss: {reference_loss}')

# %%
pod_basis_dof = np.load(train_dataset_path+'/hdiv_h1_pod_basis_dof.npy')[:,:output_reduced_basis_args['num_basis']]
reference_reduced_minimizers = np.load(train_dataset_path+'/reference_reduced_minimizers.npy')[:,:output_reduced_basis_args['num_basis']]

# %%
# for i in range(10):
#     plt.plot(pod_basis_dof[:,i])

# %%
pod_basis_dof = torch.tensor(pod_basis_dof, dtype=torch_dtype['float64'])
reference_reduced_minimizers = torch.tensor(reference_reduced_minimizers, dtype=torch_dtype['float64'])

quadratic_weight = torch.tensor(np.load(train_dataset_path+'/hdiv_h1_quadratic_weight.npy'), dtype=torch_dtype['float64'])
linear_weight = torch.tensor(np.load(train_dataset_path+'/hdiv_h1_linear_weight.npy'), dtype=torch_dtype['float64'])
bias = torch.tensor(np.load(train_dataset_path+'/hdiv_h1_bias.npy'), dtype=torch_dtype['float64'])

# %%
reduced_weight_list = []
for i in range(len(quadratic_weight)):
    reduced_weight = {}
    reduced_weight['quadratic'] = quadratic_weight[i]
    reduced_weight['linear'] = linear_weight[i]
    reduced_weight['bias'] = bias[i]
    reduced_weight_list.append(reduced_weight)

# %%
surrogate_loss = SurrogateLoss(reduced_weight_list)

# %%
valid_start_index = 4500
reference_surrogate_loss_list = []
num_samples_for_reference_surrogate_loss = 500
for i in range(valid_start_index, valid_start_index + num_samples_for_reference_surrogate_loss):
    print(f'sample {i}:')
    reference_surrogate_loss = surrogate_loss(reference_reduced_minimizers[i], i, sub_dim=64)
    print(f'reference surrogate loss: {reference_surrogate_loss.item()}')
    reference_surrogate_loss_list.append(reference_surrogate_loss.item())
print("")
print("number of POD basi: 64")
print(f'mean reference surrogate loss: {np.mean(reference_surrogate_loss_list):.2e}')
print(f'std reference surrogate loss: {np.std(reference_surrogate_loss_list):.2e}')
# Out:
# sample 4500:
# reference surrogate loss: 0.00043160808264386397
# sample 4501:
# reference surrogate loss: 0.0008166741369290964
# sample 4502:
# reference surrogate loss: 0.00043653716075531257
# sample 4503:
# reference surrogate loss: 0.00027495829609969213
# sample 4504:
# reference surrogate loss: 0.00022582770016654763
# sample 4505:
# reference surrogate loss: 0.00018576886340060383
# sample 4506:
# reference surrogate loss: 0.00025749903907201777
# sample 4507:
# reference surrogate loss: 0.00023064808979356144
# sample 4508:
# reference surrogate loss: 0.00017224577095520388
# sample 4509:
# reference surrogate loss: 0.00014251010423005361
# sample 4510:
# reference surrogate loss: 0.00022094822162310734
# sample 4511:
# reference surrogate loss: 0.00016545408331958278
# sample 4512:
# reference surrogate loss: 0.0005317159920659176
# sample 4513:
# reference surrogate loss: 0.0003090513937227257
# sample 4514:
# reference surrogate loss: 9.764782060339705e-05
# sample 4515:
# reference surrogate loss: 0.00024325803515679034
# sample 4516:
# reference surrogate loss: 0.00013599188826907138
# sample 4517:
# reference surrogate loss: 0.00038302146549873406
# sample 4518:
# reference surrogate loss: 0.0004219192679000283
# sample 4519:
# reference surrogate loss: 0.0002812609963993573
# sample 4520:
# reference surrogate loss: 0.00037061132025684174
# sample 4521:
# reference surrogate loss: 0.00030554532843729554
# sample 4522:
# reference surrogate loss: 0.0003017966667218097
# sample 4523:
# reference surrogate loss: 0.0003392172821174988
# sample 4524:
# reference surrogate loss: 0.00039031777754905406
# sample 4525:
# reference surrogate loss: 0.0002566364128240295
# sample 4526:
# reference surrogate loss: 0.0001911935897693784
# sample 4527:
# reference surrogate loss: 0.0003676450374814344
# sample 4528:
# reference surrogate loss: 0.0005247374835251062
# sample 4529:
# reference surrogate loss: 0.00035792112106891594
# sample 4530:
# reference surrogate loss: 0.00025861663546100644
# sample 4531:
# reference surrogate loss: 0.00016243453543718367
# sample 4532:
# reference surrogate loss: 0.00036525723626001927
# sample 4533:
# reference surrogate loss: 0.0003197507163077429
# sample 4534:
# reference surrogate loss: 0.0002127133990974528
# sample 4535:
# reference surrogate loss: 0.0005912998669370673
# sample 4536:
# reference surrogate loss: 0.00012268376235535783
# sample 4537:
# reference surrogate loss: 0.0001587207430580051
# sample 4538:
# reference surrogate loss: 0.00011969556814017679
# sample 4539:
# reference surrogate loss: 0.0003460799033043749
# sample 4540:
# reference surrogate loss: 0.0008226692580981521
# sample 4541:
# reference surrogate loss: 0.00035240863431584835
# sample 4542:
# reference surrogate loss: 0.0005023504603065554
# sample 4543:
# reference surrogate loss: 0.00015935877075778926
# sample 4544:
# reference surrogate loss: 0.0002756682351183759
# sample 4545:
# reference surrogate loss: 0.00046123885228976924
# sample 4546:
# reference surrogate loss: 0.0006390945591236985
# sample 4547:
# reference surrogate loss: 0.00057073859562351
# sample 4548:
# reference surrogate loss: 0.00031649816746259773
# sample 4549:
# reference surrogate loss: 0.0002622403907126536
# sample 4550:
# reference surrogate loss: 0.00012551964574170071
# sample 4551:
# reference surrogate loss: 0.0006560895692566682
# sample 4552:
# reference surrogate loss: 0.0003398525867193136
# sample 4553:
# reference surrogate loss: 0.0011552890486794531
# sample 4554:
# reference surrogate loss: 0.00023354780077378123
# sample 4555:
# reference surrogate loss: 0.00019074597270307692
# sample 4556:
# reference surrogate loss: 0.00016366246616361657
# sample 4557:
# reference surrogate loss: 0.0004784491777380939
# sample 4558:
# reference surrogate loss: 0.0001619089920106287
# sample 4559:
# reference surrogate loss: 0.0006388879878942433
# sample 4560:
# reference surrogate loss: 0.00018636210942246656
# sample 4561:
# reference surrogate loss: 0.0007267224101836778
# sample 4562:
# reference surrogate loss: 0.0003821028083303979
# sample 4563:
# reference surrogate loss: 0.00022769683595047496
# sample 4564:
# reference surrogate loss: 0.00031155150142558874
# sample 4565:
# reference surrogate loss: 0.00022807435923111186
# sample 4566:
# reference surrogate loss: 0.00016453197660060148
# sample 4567:
# reference surrogate loss: 0.000404730535704223
# sample 4568:
# reference surrogate loss: 0.00029555934903080505
# sample 4569:
# reference surrogate loss: 0.0004952367636050781
# sample 4570:
# reference surrogate loss: 0.00038365391982941865
# sample 4571:
# reference surrogate loss: 0.0002195076637192539
# sample 4572:
# reference surrogate loss: 0.001642523744445068
# sample 4573:
# reference surrogate loss: 8.784052974819545e-05
# sample 4574:
# reference surrogate loss: 0.0002512725267562743
# sample 4575:
# reference surrogate loss: 0.00015191863694874463
# sample 4576:
# reference surrogate loss: 0.00028675773830899587
# sample 4577:
# reference surrogate loss: 0.00019965236051011637
# sample 4578:
# reference surrogate loss: 0.0002523145126207549
# sample 4579:
# reference surrogate loss: 0.0001881738481646078
# sample 4580:
# reference surrogate loss: 0.0002032817339501225
# sample 4581:
# reference surrogate loss: 0.0002226204356272632
# sample 4582:
# reference surrogate loss: 0.0005361862201944678
# sample 4583:
# reference surrogate loss: 0.00025047001268019287
# sample 4584:
# reference surrogate loss: 0.0006967087261215976
# sample 4585:
# reference surrogate loss: 0.0001916240541308678
# sample 4586:
# reference surrogate loss: 0.00021816695383036766
# sample 4587:
# reference surrogate loss: 0.0003443685478887737
# sample 4588:
# reference surrogate loss: 0.0006843254772017637
# sample 4589:
# reference surrogate loss: 0.00022772083194011472
# sample 4590:
# reference surrogate loss: 0.0005487278231290915
# sample 4591:
# reference surrogate loss: 0.0003484328750282817
# sample 4592:
# reference surrogate loss: 0.0007070352973421734
# sample 4593:
# reference surrogate loss: 0.0003877718976066369
# sample 4594:
# reference surrogate loss: 0.00033514616667429387
# sample 4595:
# reference surrogate loss: 0.0002661532371688313
# sample 4596:
# reference surrogate loss: 0.0008437891111001683
# sample 4597:
# reference surrogate loss: 0.0004133651944808747
# sample 4598:
# reference surrogate loss: 9.6728604696672e-05
# sample 4599:
# reference surrogate loss: 0.0001402246456478906
# sample 4600:
# reference surrogate loss: 0.00042810908972201744
# sample 4601:
# reference surrogate loss: 0.0002504420386599815
# sample 4602:
# reference surrogate loss: 0.0004620534325692205
# sample 4603:
# reference surrogate loss: 0.00016710891415550044
# sample 4604:
# reference surrogate loss: 0.0009552432660422383
# sample 4605:
# reference surrogate loss: 0.0002492926845174548
# sample 4606:
# reference surrogate loss: 0.00011944789637952091
# sample 4607:
# reference surrogate loss: 0.0007655740112904041
# sample 4608:
# reference surrogate loss: 0.00012220465402612568
# sample 4609:
# reference surrogate loss: 0.00042960566804794986
# sample 4610:
# reference surrogate loss: 0.00022640122046269084
# sample 4611:
# reference surrogate loss: 0.00021401659888309332
# sample 4612:
# reference surrogate loss: 0.0006854826681852444
# sample 4613:
# reference surrogate loss: 0.0004613464798839395
# sample 4614:
# reference surrogate loss: 0.00020319626263476387
# sample 4615:
# reference surrogate loss: 0.0005066530587725104
# sample 4616:
# reference surrogate loss: 0.0001932249726059876
# sample 4617:
# reference surrogate loss: 0.00016574212005293631
# sample 4618:
# reference surrogate loss: 0.0006749267024108718
# sample 4619:
# reference surrogate loss: 0.00034152917144969486
# sample 4620:
# reference surrogate loss: 0.0004284114044086351
# sample 4621:
# reference surrogate loss: 0.000128211892751251
# sample 4622:
# reference surrogate loss: 0.00045204294600620365
# sample 4623:
# reference surrogate loss: 0.0006086295733123137
# sample 4624:
# reference surrogate loss: 0.0006630031011680693
# sample 4625:
# reference surrogate loss: 0.00014268701728137323
# sample 4626:
# reference surrogate loss: 0.0002738851400689857
# sample 4627:
# reference surrogate loss: 0.0003734667830774807
# sample 4628:
# reference surrogate loss: 0.0004592762015382945
# sample 4629:
# reference surrogate loss: 0.00029080913257417684
# sample 4630:
# reference surrogate loss: 0.000174697543143143
# sample 4631:
# reference surrogate loss: 0.00038185127791656726
# sample 4632:
# reference surrogate loss: 0.00034912275976983764
# sample 4633:
# reference surrogate loss: 0.00016774710535671922
# sample 4634:
# reference surrogate loss: 0.0003620795511984909
# sample 4635:
# reference surrogate loss: 0.0009655612125103463
# sample 4636:
# reference surrogate loss: 0.0003307252483488732
# sample 4637:
# reference surrogate loss: 0.00025179671442732143
# sample 4638:
# reference surrogate loss: 0.00015961810128173326
# sample 4639:
# reference surrogate loss: 0.0005271900306538235
# sample 4640:
# reference surrogate loss: 0.0004927524114357595
# sample 4641:
# reference surrogate loss: 0.00011439745393015954
# sample 4642:
# reference surrogate loss: 0.00034726986163091667
# sample 4643:
# reference surrogate loss: 0.0003265641452152579
# sample 4644:
# reference surrogate loss: 0.0006169934800510646
# sample 4645:
# reference surrogate loss: 0.0003358837658171687
# sample 4646:
# reference surrogate loss: 0.00021445321841961906
# sample 4647:
# reference surrogate loss: 0.000970775645126043
# sample 4648:
# reference surrogate loss: 0.0001771594098938234
# sample 4649:
# reference surrogate loss: 0.0008545925412606348
# sample 4650:
# reference surrogate loss: 0.00022323609923025067
# sample 4651:
# reference surrogate loss: 0.0008056156194791164
# sample 4652:
# reference surrogate loss: 0.0008409077877191695
# sample 4653:
# reference surrogate loss: 0.0009877531406843332
# sample 4654:
# reference surrogate loss: 0.0001925723860776163
# sample 4655:
# reference surrogate loss: 0.00022100616932951844
# sample 4656:
# reference surrogate loss: 0.00035248163367063157
# sample 4657:
# reference surrogate loss: 0.0001894342803077098
# sample 4658:
# reference surrogate loss: 0.00045306477440765214
# sample 4659:
# reference surrogate loss: 0.00018429164015754118
# sample 4660:
# reference surrogate loss: 0.00029149920921045513
# sample 4661:
# reference surrogate loss: 0.000358888279645031
# sample 4662:
# reference surrogate loss: 0.000527427137228198
# sample 4663:
# reference surrogate loss: 0.00015808887297508178
# sample 4664:
# reference surrogate loss: 0.0002743104070148661
# sample 4665:
# reference surrogate loss: 0.0003089749242077833
# sample 4666:
# reference surrogate loss: 0.0001484192744445334
# sample 4667:
# reference surrogate loss: 0.00021746456149940308
# sample 4668:
# reference surrogate loss: 0.00022103583902266521
# sample 4669:
# reference surrogate loss: 0.0004219765694128963
# sample 4670:
# reference surrogate loss: 0.0006903007985847864
# sample 4671:
# reference surrogate loss: 0.00015615400243440547
# sample 4672:
# reference surrogate loss: 0.0006959393325520757
# sample 4673:
# reference surrogate loss: 0.00017596188863033824
# sample 4674:
# reference surrogate loss: 0.00035915264397634594
# sample 4675:
# reference surrogate loss: 0.00017625155573175455
# sample 4676:
# reference surrogate loss: 0.00023854898957131887
# sample 4677:
# reference surrogate loss: 0.00023591922877685967
# sample 4678:
# reference surrogate loss: 0.00025294943790288293
# sample 4679:
# reference surrogate loss: 0.00031673218353445165
# sample 4680:
# reference surrogate loss: 0.0002978131185227273
# sample 4681:
# reference surrogate loss: 0.0001341287217244691
# sample 4682:
# reference surrogate loss: 0.00039399813699203534
# sample 4683:
# reference surrogate loss: 0.000899974758850508
# sample 4684:
# reference surrogate loss: 0.0004032390007691067
# sample 4685:
# reference surrogate loss: 0.00045777980077832403
# sample 4686:
# reference surrogate loss: 0.0004158445069060157
# sample 4687:
# reference surrogate loss: 0.0016992766018673056
# sample 4688:
# reference surrogate loss: 0.000468226706912489
# sample 4689:
# reference surrogate loss: 0.00032290933435130675
# sample 4690:
# reference surrogate loss: 0.0003275730244578501
# sample 4691:
# reference surrogate loss: 0.00021886353930322677
# sample 4692:
# reference surrogate loss: 0.000373424490148766
# sample 4693:
# reference surrogate loss: 0.000285050196229264
# sample 4694:
# reference surrogate loss: 0.0005399096451161878
# sample 4695:
# reference surrogate loss: 0.000769127561802252
# sample 4696:
# reference surrogate loss: 0.0005565147831922967
# sample 4697:
# reference surrogate loss: 0.0004497507979539517
# sample 4698:
# reference surrogate loss: 0.0001800085123742079
# sample 4699:
# reference surrogate loss: 0.0003203775259101871
# sample 4700:
# reference surrogate loss: 0.00016257130830132915
# sample 4701:
# reference surrogate loss: 0.0002833938330744079
# sample 4702:
# reference surrogate loss: 0.0002349022678254098
# sample 4703:
# reference surrogate loss: 0.0008984850619622176
# sample 4704:
# reference surrogate loss: 0.00018828585619945493
# sample 4705:
# reference surrogate loss: 0.00038065639623119374
# sample 4706:
# reference surrogate loss: 0.00031224574711297137
# sample 4707:
# reference surrogate loss: 0.00015251227044354998
# sample 4708:
# reference surrogate loss: 0.0005483804803834147
# sample 4709:
# reference surrogate loss: 0.0005182511784826982
# sample 4710:
# reference surrogate loss: 0.000582584329106961
# sample 4711:
# reference surrogate loss: 0.0003106232228367034
# sample 4712:
# reference surrogate loss: 0.00016965704078497623
# sample 4713:
# reference surrogate loss: 0.00012410628087544673
# sample 4714:
# reference surrogate loss: 0.0004119349190059296
# sample 4715:
# reference surrogate loss: 0.00019673757986238272
# sample 4716:
# reference surrogate loss: 0.00020814143941660923
# sample 4717:
# reference surrogate loss: 0.00031463495979289213
# sample 4718:
# reference surrogate loss: 0.0001793047068514575
# sample 4719:
# reference surrogate loss: 0.0007424841697329931
# sample 4720:
# reference surrogate loss: 0.00015247021356179502
# sample 4721:
# reference surrogate loss: 0.0002433495367444305
# sample 4722:
# reference surrogate loss: 0.0005077972312772516
# sample 4723:
# reference surrogate loss: 0.00028900012855026525
# sample 4724:
# reference surrogate loss: 0.00040941899096491596
# sample 4725:
# reference surrogate loss: 0.0005541077132735772
# sample 4726:
# reference surrogate loss: 0.0004497488506018943
# sample 4727:
# reference surrogate loss: 0.0006665329352277816
# sample 4728:
# reference surrogate loss: 0.00016595420100973257
# sample 4729:
# reference surrogate loss: 0.0002542503151499176
# sample 4730:
# reference surrogate loss: 0.0002503043805359706
# sample 4731:
# reference surrogate loss: 0.0004528141707065281
# sample 4732:
# reference surrogate loss: 0.0004481213785281213
# sample 4733:
# reference surrogate loss: 0.00014472440313406665
# sample 4734:
# reference surrogate loss: 0.0001497748333956217
# sample 4735:
# reference surrogate loss: 0.0004763765533035702
# sample 4736:
# reference surrogate loss: 0.00028329287585182605
# sample 4737:
# reference surrogate loss: 0.0002484619954474798
# sample 4738:
# reference surrogate loss: 0.0002311402826622455
# sample 4739:
# reference surrogate loss: 0.0007620641669647821
# sample 4740:
# reference surrogate loss: 0.001299293137750901
# sample 4741:
# reference surrogate loss: 0.0002418165351072421
# sample 4742:
# reference surrogate loss: 0.000826247300278693
# sample 4743:
# reference surrogate loss: 0.00022103593354061424
# sample 4744:
# reference surrogate loss: 0.00015238577565357403
# sample 4745:
# reference surrogate loss: 0.00021365581260579525
# sample 4746:
# reference surrogate loss: 0.00033708284800471056
# sample 4747:
# reference surrogate loss: 0.0005890094657605704
# sample 4748:
# reference surrogate loss: 0.0002761233123993456
# sample 4749:
# reference surrogate loss: 0.0006605208045480371
# sample 4750:
# reference surrogate loss: 0.0006744118223249718
# sample 4751:
# reference surrogate loss: 0.00015897952096932677
# sample 4752:
# reference surrogate loss: 0.0003601807322608508
# sample 4753:
# reference surrogate loss: 0.00026050667265753447
# sample 4754:
# reference surrogate loss: 0.0002684717480585519
# sample 4755:
# reference surrogate loss: 0.0002021124935525087
# sample 4756:
# reference surrogate loss: 0.00022697439412189269
# sample 4757:
# reference surrogate loss: 0.00021177706013686404
# sample 4758:
# reference surrogate loss: 0.0012034464820602775
# sample 4759:
# reference surrogate loss: 0.00044352991872309566
# sample 4760:
# reference surrogate loss: 0.0005486881770604413
# sample 4761:
# reference surrogate loss: 0.0003525813658007415
# sample 4762:
# reference surrogate loss: 0.00016628642528648818
# sample 4763:
# reference surrogate loss: 0.00035531622527296136
# sample 4764:
# reference surrogate loss: 0.000830187014855932
# sample 4765:
# reference surrogate loss: 0.00014243455280094075
# sample 4766:
# reference surrogate loss: 0.0004036009461338974
# sample 4767:
# reference surrogate loss: 0.00020393925463380036
# sample 4768:
# reference surrogate loss: 0.00021599009115291778
# sample 4769:
# reference surrogate loss: 0.00015031701807277642
# sample 4770:
# reference surrogate loss: 0.00021201963318495665
# sample 4771:
# reference surrogate loss: 0.0003518386868941459
# sample 4772:
# reference surrogate loss: 0.00038671741156592887
# sample 4773:
# reference surrogate loss: 0.00028868816827998245
# sample 4774:
# reference surrogate loss: 0.000806304826355797
# sample 4775:
# reference surrogate loss: 0.0001767816116173826
# sample 4776:
# reference surrogate loss: 0.00027519964802147356
# sample 4777:
# reference surrogate loss: 0.0008946974342693981
# sample 4778:
# reference surrogate loss: 0.00026383368688454034
# sample 4779:
# reference surrogate loss: 0.0004381717149368747
# sample 4780:
# reference surrogate loss: 0.00014784504735088078
# sample 4781:
# reference surrogate loss: 0.0002850517879651182
# sample 4782:
# reference surrogate loss: 0.0002376767520000378
# sample 4783:
# reference surrogate loss: 0.0007369014186928702
# sample 4784:
# reference surrogate loss: 0.0004134941056788133
# sample 4785:
# reference surrogate loss: 0.0003475149448184389
# sample 4786:
# reference surrogate loss: 0.0004873306305561709
# sample 4787:
# reference surrogate loss: 0.00016023182311997175
# sample 4788:
# reference surrogate loss: 0.00018089100254781165
# sample 4789:
# reference surrogate loss: 0.00018763350393657952
# sample 4790:
# reference surrogate loss: 0.000282690073655667
# sample 4791:
# reference surrogate loss: 0.00036116452811341127
# sample 4792:
# reference surrogate loss: 0.00016888993857988588
# sample 4793:
# reference surrogate loss: 0.0002605028612170379
# sample 4794:
# reference surrogate loss: 0.0002543586160168587
# sample 4795:
# reference surrogate loss: 0.0002199076174878023
# sample 4796:
# reference surrogate loss: 0.00020356035321356103
# sample 4797:
# reference surrogate loss: 0.00015862532674604246
# sample 4798:
# reference surrogate loss: 0.00012701447564844592
# sample 4799:
# reference surrogate loss: 0.00021330005450637124
# sample 4800:
# reference surrogate loss: 0.00039085140394812257
# sample 4801:
# reference surrogate loss: 0.0003238656259565431
# sample 4802:
# reference surrogate loss: 0.00018071220906157315
# sample 4803:
# reference surrogate loss: 0.0003315514805943831
# sample 4804:
# reference surrogate loss: 0.00021122834374542876
# sample 4805:
# reference surrogate loss: 0.0012965773819477722
# sample 4806:
# reference surrogate loss: 0.00015637776327737107
# sample 4807:
# reference surrogate loss: 0.0003379121643432015
# sample 4808:
# reference surrogate loss: 0.00025105244969814144
# sample 4809:
# reference surrogate loss: 0.00035316332592083555
# sample 4810:
# reference surrogate loss: 0.0002009005287704202
# sample 4811:
# reference surrogate loss: 0.0004921420443984026
# sample 4812:
# reference surrogate loss: 0.0003030779769315206
# sample 4813:
# reference surrogate loss: 0.0002928793798631091
# sample 4814:
# reference surrogate loss: 0.0005188388393668752
# sample 4815:
# reference surrogate loss: 0.00032882670006606496
# sample 4816:
# reference surrogate loss: 0.0002714739312643655
# sample 4817:
# reference surrogate loss: 0.00027246720712925665
# sample 4818:
# reference surrogate loss: 0.00046233028291653433
# sample 4819:
# reference surrogate loss: 0.0005476822837913176
# sample 4820:
# reference surrogate loss: 0.00026741798374874115
# sample 4821:
# reference surrogate loss: 0.0005935041252904671
# sample 4822:
# reference surrogate loss: 0.00019666662550044123
# sample 4823:
# reference surrogate loss: 0.000407568667119218
# sample 4824:
# reference surrogate loss: 0.000150960785123333
# sample 4825:
# reference surrogate loss: 0.00026496985762913816
# sample 4826:
# reference surrogate loss: 0.0005321882402058442
# sample 4827:
# reference surrogate loss: 0.0008048300390135488
# sample 4828:
# reference surrogate loss: 0.0002286186603606133
# sample 4829:
# reference surrogate loss: 0.0005724139400895556
# sample 4830:
# reference surrogate loss: 0.0006176610086696677
# sample 4831:
# reference surrogate loss: 0.0002944007031389084
# sample 4832:
# reference surrogate loss: 0.0009095904614442318
# sample 4833:
# reference surrogate loss: 0.0004214450984052487
# sample 4834:
# reference surrogate loss: 0.0004561084802194859
# sample 4835:
# reference surrogate loss: 0.00017788926986184173
# sample 4836:
# reference surrogate loss: 0.000218442235210059
# sample 4837:
# reference surrogate loss: 0.0004879963204420523
# sample 4838:
# reference surrogate loss: 0.00036369256747748047
# sample 4839:
# reference surrogate loss: 0.000106287160182017
# sample 4840:
# reference surrogate loss: 0.00026434349828141634
# sample 4841:
# reference surrogate loss: 0.0004180705974914378
# sample 4842:
# reference surrogate loss: 0.0002469475436879254
# sample 4843:
# reference surrogate loss: 0.0007976445120649878
# sample 4844:
# reference surrogate loss: 0.00030447360086527375
# sample 4845:
# reference surrogate loss: 0.00022565670015262107
# sample 4846:
# reference surrogate loss: 0.00016887433488399495
# sample 4847:
# reference surrogate loss: 0.00021364491324105117
# sample 4848:
# reference surrogate loss: 0.000566421771703407
# sample 4849:
# reference surrogate loss: 0.0005063633660231659
# sample 4850:
# reference surrogate loss: 0.00015950407671860845
# sample 4851:
# reference surrogate loss: 0.0012443716817007733
# sample 4852:
# reference surrogate loss: 0.0002788613848927479
# sample 4853:
# reference surrogate loss: 0.00022952616529425818
# sample 4854:
# reference surrogate loss: 0.0002595641558644779
# sample 4855:
# reference surrogate loss: 0.0001731819581962668
# sample 4856:
# reference surrogate loss: 0.0005459080127705462
# sample 4857:
# reference surrogate loss: 0.0002554527470755019
# sample 4858:
# reference surrogate loss: 0.00033009527217386925
# sample 4859:
# reference surrogate loss: 0.0004787717339771458
# sample 4860:
# reference surrogate loss: 0.0005335744737420267
# sample 4861:
# reference surrogate loss: 0.0004211753913634375
# sample 4862:
# reference surrogate loss: 0.0003888730433234677
# sample 4863:
# reference surrogate loss: 0.00018287568435781942
# sample 4864:
# reference surrogate loss: 0.00030681227186457605
# sample 4865:
# reference surrogate loss: 0.0004300041251812381
# sample 4866:
# reference surrogate loss: 0.0002729390258495723
# sample 4867:
# reference surrogate loss: 0.0009906915256516768
# sample 4868:
# reference surrogate loss: 0.00033995566785671727
# sample 4869:
# reference surrogate loss: 0.00021387893353175258
# sample 4870:
# reference surrogate loss: 0.00025834958871251423
# sample 4871:
# reference surrogate loss: 0.00013086758982194802
# sample 4872:
# reference surrogate loss: 0.0003416834392326873
# sample 4873:
# reference surrogate loss: 0.0003891274703016201
# sample 4874:
# reference surrogate loss: 0.00042664832799022
# sample 4875:
# reference surrogate loss: 0.0006249708777350538
# sample 4876:
# reference surrogate loss: 0.0005886396658068005
# sample 4877:
# reference surrogate loss: 0.0003538700447816012
# sample 4878:
# reference surrogate loss: 0.0006716799918913274
# sample 4879:
# reference surrogate loss: 0.00024705740965336176
# sample 4880:
# reference surrogate loss: 0.00024342546203648396
# sample 4881:
# reference surrogate loss: 0.00047000265752972226
# sample 4882:
# reference surrogate loss: 0.00018962376600062392
# sample 4883:
# reference surrogate loss: 0.0002350011215961345
# sample 4884:
# reference surrogate loss: 0.0005290848019021688
# sample 4885:
# reference surrogate loss: 0.000497336050861108
# sample 4886:
# reference surrogate loss: 0.0003905419781433661
# sample 4887:
# reference surrogate loss: 0.00036315481820370366
# sample 4888:
# reference surrogate loss: 0.00015615184895234613
# sample 4889:
# reference surrogate loss: 0.00015920074928565953
# sample 4890:
# reference surrogate loss: 0.000582869615207704
# sample 4891:
# reference surrogate loss: 0.00038030537394084796
# sample 4892:
# reference surrogate loss: 0.00018605843698127345
# sample 4893:
# reference surrogate loss: 0.00015588248891007517
# sample 4894:
# reference surrogate loss: 0.0003176352568659002
# sample 4895:
# reference surrogate loss: 0.0002220751337085325
# sample 4896:
# reference surrogate loss: 0.0002269438461242057
# sample 4897:
# reference surrogate loss: 0.00018750347367579856
# sample 4898:
# reference surrogate loss: 0.0002702882387681793
# sample 4899:
# reference surrogate loss: 0.0002318443741000653
# sample 4900:
# reference surrogate loss: 0.00021142892969949756
# sample 4901:
# reference surrogate loss: 0.00024655074893753515
# sample 4902:
# reference surrogate loss: 0.00011345681410568353
# sample 4903:
# reference surrogate loss: 0.00020579704510925723
# sample 4904:
# reference surrogate loss: 0.00043586098868297896
# sample 4905:
# reference surrogate loss: 0.0002952151051245355
# sample 4906:
# reference surrogate loss: 0.0008452359500275008
# sample 4907:
# reference surrogate loss: 0.0006574826280068002
# sample 4908:
# reference surrogate loss: 0.00028501415323312074
# sample 4909:
# reference surrogate loss: 0.0007071367513982185
# sample 4910:
# reference surrogate loss: 0.0002510669514592667
# sample 4911:
# reference surrogate loss: 0.00031658069271167655
# sample 4912:
# reference surrogate loss: 0.0003301365401608969
# sample 4913:
# reference surrogate loss: 0.001233011483657842
# sample 4914:
# reference surrogate loss: 0.00014669773520004092
# sample 4915:
# reference surrogate loss: 0.0005465731194205237
# sample 4916:
# reference surrogate loss: 0.00016741585848967233
# sample 4917:
# reference surrogate loss: 0.000433019398105694
# sample 4918:
# reference surrogate loss: 0.00012833243770948854
# sample 4919:
# reference surrogate loss: 0.00031785096769376686
# sample 4920:
# reference surrogate loss: 0.00025852449754060203
# sample 4921:
# reference surrogate loss: 0.00020186499564500693
# sample 4922:
# reference surrogate loss: 0.00031455706419492024
# sample 4923:
# reference surrogate loss: 0.000186350191436091
# sample 4924:
# reference surrogate loss: 0.0008576843180438942
# sample 4925:
# reference surrogate loss: 0.00015653272895188586
# sample 4926:
# reference surrogate loss: 0.00022456345773291808
# sample 4927:
# reference surrogate loss: 0.00019482759830213858
# sample 4928:
# reference surrogate loss: 0.00036640627577866347
# sample 4929:
# reference surrogate loss: 0.00018145265761804197
# sample 4930:
# reference surrogate loss: 0.00015291194332767155
# sample 4931:
# reference surrogate loss: 0.000265980011424638
# sample 4932:
# reference surrogate loss: 0.0003438005535150168
# sample 4933:
# reference surrogate loss: 0.0005964088182444094
# sample 4934:
# reference surrogate loss: 0.0002915291820442256
# sample 4935:
# reference surrogate loss: 0.0005794241994103722
# sample 4936:
# reference surrogate loss: 0.00032311424978459513
# sample 4937:
# reference surrogate loss: 0.0003653081699861449
# sample 4938:
# reference surrogate loss: 0.00032571143952830894
# sample 4939:
# reference surrogate loss: 0.00021739530495024084
# sample 4940:
# reference surrogate loss: 0.0003481816883581512
# sample 4941:
# reference surrogate loss: 0.00020786120470472902
# sample 4942:
# reference surrogate loss: 0.0002639893309588359
# sample 4943:
# reference surrogate loss: 0.0003624125787913268
# sample 4944:
# reference surrogate loss: 0.0002054324433458099
# sample 4945:
# reference surrogate loss: 0.00037680149352947723
# sample 4946:
# reference surrogate loss: 0.0004634413857609321
# sample 4947:
# reference surrogate loss: 0.00016541248024104505
# sample 4948:
# reference surrogate loss: 0.0007761978422504701
# sample 4949:
# reference surrogate loss: 0.00019177097207889737
# sample 4950:
# reference surrogate loss: 0.0005992874389617597
# sample 4951:
# reference surrogate loss: 0.00042543437745767854
# sample 4952:
# reference surrogate loss: 0.00017218121514983586
# sample 4953:
# reference surrogate loss: 0.0005404237091399811
# sample 4954:
# reference surrogate loss: 0.0007979128590072104
# sample 4955:
# reference surrogate loss: 0.0005393665028496919
# sample 4956:
# reference surrogate loss: 0.000487862503810943
# sample 4957:
# reference surrogate loss: 0.00022391454081516216
# sample 4958:
# reference surrogate loss: 0.00014882270412064358
# sample 4959:
# reference surrogate loss: 0.00010110582979061533
# sample 4960:
# reference surrogate loss: 0.0004710732864061651
# sample 4961:
# reference surrogate loss: 0.0008925676297089069
# sample 4962:
# reference surrogate loss: 0.0006201124225717614
# sample 4963:
# reference surrogate loss: 0.00017484561137415255
# sample 4964:
# reference surrogate loss: 0.0005675635244142274
# sample 4965:
# reference surrogate loss: 0.0004482788866320142
# sample 4966:
# reference surrogate loss: 0.0001602862758103285
# sample 4967:
# reference surrogate loss: 0.0002443760028583153
# sample 4968:
# reference surrogate loss: 0.00041859458613746625
# sample 4969:
# reference surrogate loss: 0.00018419114653389634
# sample 4970:
# reference surrogate loss: 0.0006115700460607165
# sample 4971:
# reference surrogate loss: 0.00020101602328792545
# sample 4972:
# reference surrogate loss: 0.0002144026441837088
# sample 4973:
# reference surrogate loss: 0.000697066763602816
# sample 4974:
# reference surrogate loss: 0.00041573794767657546
# sample 4975:
# reference surrogate loss: 0.0002481819286055398
# sample 4976:
# reference surrogate loss: 0.0001572881944738036
# sample 4977:
# reference surrogate loss: 0.00018750534723110945
# sample 4978:
# reference surrogate loss: 0.00032571447296980693
# sample 4979:
# reference surrogate loss: 0.0003056441579603053
# sample 4980:
# reference surrogate loss: 0.0003341442531128447
# sample 4981:
# reference surrogate loss: 0.00046393158852708893
# sample 4982:
# reference surrogate loss: 0.0007125738574731422
# sample 4983:
# reference surrogate loss: 0.00010785707402738431
# sample 4984:
# reference surrogate loss: 0.0004302176393824464
# sample 4985:
# reference surrogate loss: 0.00019341267126948836
# sample 4986:
# reference surrogate loss: 0.00022106032422408717
# sample 4987:
# reference surrogate loss: 0.0005276662627884399
# sample 4988:
# reference surrogate loss: 0.00018461648993373103
# sample 4989:
# reference surrogate loss: 0.0001515586898388488
# sample 4990:
# reference surrogate loss: 0.00033588402850148746
# sample 4991:
# reference surrogate loss: 0.00017641684124547474
# sample 4992:
# reference surrogate loss: 0.0004334607850375871
# sample 4993:
# reference surrogate loss: 0.0005566573346422743
# sample 4994:
# reference surrogate loss: 0.0008100402950690366
# sample 4995:
# reference surrogate loss: 0.000740600840653638
# sample 4996:
# reference surrogate loss: 0.00016876360503736976
# sample 4997:
# reference surrogate loss: 0.0003629102889564084
# sample 4998:
# reference surrogate loss: 0.00043344952176860296
# sample 4999:
# reference surrogate loss: 0.000560257429176092
#
# number of POD basi: 64
# mean reference surrogate loss: 3.71e-04
# std reference surrogate loss: 2.31e-04

# %%
reference_surrogate_loss_list = []
for i in range(valid_start_index, valid_start_index + num_samples_for_reference_surrogate_loss):
    print(f'sample {i}:')
    reference_surrogate_loss = surrogate_loss(reference_reduced_minimizers[i], i, sub_dim=128)
    print(f'reference surrogate loss: {reference_surrogate_loss.item()}')
    reference_surrogate_loss_list.append(reference_surrogate_loss.item())
print("")
print("number of POD basi: 128")
print(f'mean reference surrogate loss: {np.mean(reference_surrogate_loss_list):.2e}')
print(f'std reference surrogate loss: {np.std(reference_surrogate_loss_list):.2e}')
# Out:
# sample 4500:
# reference surrogate loss: 0.00010218305421294538
# sample 4501:
# reference surrogate loss: 0.0001230687282425258
# sample 4502:
# reference surrogate loss: 0.00011238575568350839
# sample 4503:
# reference surrogate loss: 0.00012242223835334798
# sample 4504:
# reference surrogate loss: 6.425059196391025e-05
# sample 4505:
# reference surrogate loss: 7.004457719506085e-05
# sample 4506:
# reference surrogate loss: 9.061663736242842e-05
# sample 4507:
# reference surrogate loss: 9.046295523718051e-05
# sample 4508:
# reference surrogate loss: 8.838564563484752e-05
# sample 4509:
# reference surrogate loss: 8.526154847898759e-05
# sample 4510:
# reference surrogate loss: 0.00014081604340288045
# sample 4511:
# reference surrogate loss: 0.00012143582778989526
# sample 4512:
# reference surrogate loss: 8.094461445273815e-05
# sample 4513:
# reference surrogate loss: 8.15948096621888e-05
# sample 4514:
# reference surrogate loss: 7.603310732196e-05
# sample 4515:
# reference surrogate loss: 0.00010740180345325534
# sample 4516:
# reference surrogate loss: 8.733160486529279e-05
# sample 4517:
# reference surrogate loss: 0.00011853639230885449
# sample 4518:
# reference surrogate loss: 0.0001469538232030665
# sample 4519:
# reference surrogate loss: 0.00011793979490870576
# sample 4520:
# reference surrogate loss: 9.889297655374385e-05
# sample 4521:
# reference surrogate loss: 9.685635054035302e-05
# sample 4522:
# reference surrogate loss: 0.00015260216716894703
# sample 4523:
# reference surrogate loss: 0.00010263416259292946
# sample 4524:
# reference surrogate loss: 0.00013947233301370154
# sample 4525:
# reference surrogate loss: 0.00011873751584268177
# sample 4526:
# reference surrogate loss: 0.00014566840976315554
# sample 4527:
# reference surrogate loss: 0.00010237977995974923
# sample 4528:
# reference surrogate loss: 0.00013372374149245303
# sample 4529:
# reference surrogate loss: 0.00010362704507360654
# sample 4530:
# reference surrogate loss: 0.00012999797925394851
# sample 4531:
# reference surrogate loss: 9.131745750901032e-05
# sample 4532:
# reference surrogate loss: 0.00013848378900949143
# sample 4533:
# reference surrogate loss: 7.836358331103632e-05
# sample 4534:
# reference surrogate loss: 0.00012607182842350184
# sample 4535:
# reference surrogate loss: 0.00012723308821116497
# sample 4536:
# reference surrogate loss: 5.878260980352046e-05
# sample 4537:
# reference surrogate loss: 9.923203076933618e-05
# sample 4538:
# reference surrogate loss: 9.322858668370237e-05
# sample 4539:
# reference surrogate loss: 6.920022879230991e-05
# sample 4540:
# reference surrogate loss: 0.0001465053854174947
# sample 4541:
# reference surrogate loss: 0.0001767435877537693
# sample 4542:
# reference surrogate loss: 0.0001052683520830211
# sample 4543:
# reference surrogate loss: 0.00011395961227744777
# sample 4544:
# reference surrogate loss: 0.00011471276789043472
# sample 4545:
# reference surrogate loss: 0.0001488221786842825
# sample 4546:
# reference surrogate loss: 0.00010148021490619108
# sample 4547:
# reference surrogate loss: 0.00011987623500786526
# sample 4548:
# reference surrogate loss: 0.00010366070979639375
# sample 4549:
# reference surrogate loss: 0.00011403271244403435
# sample 4550:
# reference surrogate loss: 9.634718519335728e-05
# sample 4551:
# reference surrogate loss: 0.00012842601254869912
# sample 4552:
# reference surrogate loss: 0.00013965089472622871
# sample 4553:
# reference surrogate loss: 0.00012721041000918198
# sample 4554:
# reference surrogate loss: 5.0072712534987573e-05
# sample 4555:
# reference surrogate loss: 7.760110294818823e-05
# sample 4556:
# reference surrogate loss: 9.62670803681398e-05
# sample 4557:
# reference surrogate loss: 0.0001313704238870006
# sample 4558:
# reference surrogate loss: 0.00011262326160421665
# sample 4559:
# reference surrogate loss: 9.872922316422894e-05
# sample 4560:
# reference surrogate loss: 0.00010918169270235367
# sample 4561:
# reference surrogate loss: 0.00010923192973777418
# sample 4562:
# reference surrogate loss: 0.0001012222915566241
# sample 4563:
# reference surrogate loss: 7.641628525489885e-05
# sample 4564:
# reference surrogate loss: 7.219603324282176e-05
# sample 4565:
# reference surrogate loss: 0.00012636328666437713
# sample 4566:
# reference surrogate loss: 6.92650460500932e-05
# sample 4567:
# reference surrogate loss: 0.00014550965956594553
# sample 4568:
# reference surrogate loss: 9.445381271788733e-05
# sample 4569:
# reference surrogate loss: 0.00013094402271507377
# sample 4570:
# reference surrogate loss: 0.00012053843903303552
# sample 4571:
# reference surrogate loss: 0.00011386892573961305
# sample 4572:
# reference surrogate loss: 0.00017987390512952395
# sample 4573:
# reference surrogate loss: 5.768410380180278e-05
# sample 4574:
# reference surrogate loss: 0.00013286427476844054
# sample 4575:
# reference surrogate loss: 0.00010017969709785746
# sample 4576:
# reference surrogate loss: 8.426618882628745e-05
# sample 4577:
# reference surrogate loss: 9.561730363416565e-05
# sample 4578:
# reference surrogate loss: 0.00014993766446402823
# sample 4579:
# reference surrogate loss: 0.00011991244480791252
# sample 4580:
# reference surrogate loss: 9.539898812271908e-05
# sample 4581:
# reference surrogate loss: 8.233703789550795e-05
# sample 4582:
# reference surrogate loss: 0.00016528145921346216
# sample 4583:
# reference surrogate loss: 8.23279615089767e-05
# sample 4584:
# reference surrogate loss: 0.0001084362783612125
# sample 4585:
# reference surrogate loss: 0.00010584164441285182
# sample 4586:
# reference surrogate loss: 8.122001783461563e-05
# sample 4587:
# reference surrogate loss: 7.205369896090552e-05
# sample 4588:
# reference surrogate loss: 0.00016303426813824018
# sample 4589:
# reference surrogate loss: 6.954914571366544e-05
# sample 4590:
# reference surrogate loss: 8.970737691837982e-05
# sample 4591:
# reference surrogate loss: 0.00015874120981185236
# sample 4592:
# reference surrogate loss: 8.136824796323161e-05
# sample 4593:
# reference surrogate loss: 0.00010823036298446276
# sample 4594:
# reference surrogate loss: 9.743515543703118e-05
# sample 4595:
# reference surrogate loss: 0.00015175411129031424
# sample 4596:
# reference surrogate loss: 0.00011486553385919862
# sample 4597:
# reference surrogate loss: 0.00011141703199135655
# sample 4598:
# reference surrogate loss: 6.716041497489833e-05
# sample 4599:
# reference surrogate loss: 8.512557877060623e-05
# sample 4600:
# reference surrogate loss: 0.0001598416916537282
# sample 4601:
# reference surrogate loss: 9.989879413407898e-05
# sample 4602:
# reference surrogate loss: 0.00014179375635658964
# sample 4603:
# reference surrogate loss: 8.524849779956156e-05
# sample 4604:
# reference surrogate loss: 0.00013921639214165005
# sample 4605:
# reference surrogate loss: 8.166731807812688e-05
# sample 4606:
# reference surrogate loss: 8.163119561044319e-05
# sample 4607:
# reference surrogate loss: 0.00016721185586265896
# sample 4608:
# reference surrogate loss: 9.519345207786856e-05
# sample 4609:
# reference surrogate loss: 0.0001420105005944805
# sample 4610:
# reference surrogate loss: 0.00010129145334514256
# sample 4611:
# reference surrogate loss: 0.00011940131991483582
# sample 4612:
# reference surrogate loss: 8.362106205872522e-05
# sample 4613:
# reference surrogate loss: 0.00013623897841164023
# sample 4614:
# reference surrogate loss: 0.00011824532832371837
# sample 4615:
# reference surrogate loss: 9.27607607212888e-05
# sample 4616:
# reference surrogate loss: 0.00011592707083529774
# sample 4617:
# reference surrogate loss: 8.979781731643932e-05
# sample 4618:
# reference surrogate loss: 0.0001325803038172424
# sample 4619:
# reference surrogate loss: 0.000112163785179753
# sample 4620:
# reference surrogate loss: 0.00015025967677861907
# sample 4621:
# reference surrogate loss: 0.00010484763005380593
# sample 4622:
# reference surrogate loss: 0.00013838910192442988
# sample 4623:
# reference surrogate loss: 0.00012726103371618613
# sample 4624:
# reference surrogate loss: 0.00015744300544096035
# sample 4625:
# reference surrogate loss: 7.205262165888016e-05
# sample 4626:
# reference surrogate loss: 0.00014078314568921613
# sample 4627:
# reference surrogate loss: 0.00010364968967202515
# sample 4628:
# reference surrogate loss: 9.215591752798069e-05
# sample 4629:
# reference surrogate loss: 0.00010713810825246917
# sample 4630:
# reference surrogate loss: 0.00013249503802881257
# sample 4631:
# reference surrogate loss: 0.00010693306022413473
# sample 4632:
# reference surrogate loss: 0.0001157355090906087
# sample 4633:
# reference surrogate loss: 9.708206195457869e-05
# sample 4634:
# reference surrogate loss: 0.0001134516054350776
# sample 4635:
# reference surrogate loss: 0.0001163605495453357
# sample 4636:
# reference surrogate loss: 7.098164754415492e-05
# sample 4637:
# reference surrogate loss: 0.00010327561203160585
# sample 4638:
# reference surrogate loss: 0.00012067642953761393
# sample 4639:
# reference surrogate loss: 0.00014327810891501258
# sample 4640:
# reference surrogate loss: 0.0001646667243315747
# sample 4641:
# reference surrogate loss: 8.840598562565027e-05
# sample 4642:
# reference surrogate loss: 8.44170910556663e-05
# sample 4643:
# reference surrogate loss: 0.0001349911059014275
# sample 4644:
# reference surrogate loss: 6.39270964415406e-05
# sample 4645:
# reference surrogate loss: 0.00010766088271330077
# sample 4646:
# reference surrogate loss: 0.00011568840797959723
# sample 4647:
# reference surrogate loss: 0.00011139109632596345
# sample 4648:
# reference surrogate loss: 0.0001281723715214067
# sample 4649:
# reference surrogate loss: 0.00012498814886985343
# sample 4650:
# reference surrogate loss: 8.488015693131068e-05
# sample 4651:
# reference surrogate loss: 9.91827300027559e-05
# sample 4652:
# reference surrogate loss: 0.00010838929639334083
# sample 4653:
# reference surrogate loss: 0.00012856226596569265
# sample 4654:
# reference surrogate loss: 9.622383874341445e-05
# sample 4655:
# reference surrogate loss: 7.201833777736866e-05
# sample 4656:
# reference surrogate loss: 0.00015207527842542312
# sample 4657:
# reference surrogate loss: 0.00014677286746955787
# sample 4658:
# reference surrogate loss: 0.0001270377755240304
# sample 4659:
# reference surrogate loss: 0.0001066627119581387
# sample 4660:
# reference surrogate loss: 0.0001103657066543473
# sample 4661:
# reference surrogate loss: 0.00012980245407279156
# sample 4662:
# reference surrogate loss: 0.00011993785840025417
# sample 4663:
# reference surrogate loss: 0.0001280182474656666
# sample 4664:
# reference surrogate loss: 0.0001107709162446735
# sample 4665:
# reference surrogate loss: 0.00010815638570105257
# sample 4666:
# reference surrogate loss: 8.315240774248167e-05
# sample 4667:
# reference surrogate loss: 0.00010240473203393385
# sample 4668:
# reference surrogate loss: 0.0001141749483497545
# sample 4669:
# reference surrogate loss: 8.738032115562788e-05
# sample 4670:
# reference surrogate loss: 8.65033768475687e-05
# sample 4671:
# reference surrogate loss: 8.309298657538378e-05
# sample 4672:
# reference surrogate loss: 0.00012909849975817345
# sample 4673:
# reference surrogate loss: 0.00012023884887812919
# sample 4674:
# reference surrogate loss: 0.00012860618411081326
# sample 4675:
# reference surrogate loss: 0.00011444801784921133
# sample 4676:
# reference surrogate loss: 0.0001231866243072144
# sample 4677:
# reference surrogate loss: 8.73307552671232e-05
# sample 4678:
# reference surrogate loss: 0.00010938330065957125
# sample 4679:
# reference surrogate loss: 0.00013342950158778955
# sample 4680:
# reference surrogate loss: 0.00011221772094227589
# sample 4681:
# reference surrogate loss: 7.745709069850726e-05
# sample 4682:
# reference surrogate loss: 6.854138192302628e-05
# sample 4683:
# reference surrogate loss: 0.00012863269980112335
# sample 4684:
# reference surrogate loss: 0.0001450890764638224
# sample 4685:
# reference surrogate loss: 9.130855384720249e-05
# sample 4686:
# reference surrogate loss: 9.882495570390226e-05
# sample 4687:
# reference surrogate loss: 0.00011879851863216828
# sample 4688:
# reference surrogate loss: 0.00011002287961203727
# sample 4689:
# reference surrogate loss: 0.00012921985818103998
# sample 4690:
# reference surrogate loss: 0.00014791642278288997
# sample 4691:
# reference surrogate loss: 4.845149950627459e-05
# sample 4692:
# reference surrogate loss: 0.00010069018460501233
# sample 4693:
# reference surrogate loss: 0.00010109421555082321
# sample 4694:
# reference surrogate loss: 0.0001365429226505288
# sample 4695:
# reference surrogate loss: 9.822156198580068e-05
# sample 4696:
# reference surrogate loss: 9.132551998503047e-05
# sample 4697:
# reference surrogate loss: 0.00011150265042036978
# sample 4698:
# reference surrogate loss: 0.00010532303952293098
# sample 4699:
# reference surrogate loss: 0.0001312066315315441
# sample 4700:
# reference surrogate loss: 0.00013461919194557304
# sample 4701:
# reference surrogate loss: 0.00010899405252495775
# sample 4702:
# reference surrogate loss: 0.00011413938441817706
# sample 4703:
# reference surrogate loss: 0.00011158778889197585
# sample 4704:
# reference surrogate loss: 6.370984833625748e-05
# sample 4705:
# reference surrogate loss: 0.00010530993980339964
# sample 4706:
# reference surrogate loss: 0.00011551456272851368
# sample 4707:
# reference surrogate loss: 0.000103840353434137
# sample 4708:
# reference surrogate loss: 0.00017145661294182268
# sample 4709:
# reference surrogate loss: 0.0001487187412179125
# sample 4710:
# reference surrogate loss: 8.790523638291248e-05
# sample 4711:
# reference surrogate loss: 7.935629421007562e-05
# sample 4712:
# reference surrogate loss: 9.307571847338991e-05
# sample 4713:
# reference surrogate loss: 9.626945586194147e-05
# sample 4714:
# reference surrogate loss: 0.00010542293963711202
# sample 4715:
# reference surrogate loss: 0.00012236933473097622
# sample 4716:
# reference surrogate loss: 9.200493543470856e-05
# sample 4717:
# reference surrogate loss: 0.00010850112938531886
# sample 4718:
# reference surrogate loss: 9.109842943355595e-05
# sample 4719:
# reference surrogate loss: 0.0001400851362183264
# sample 4720:
# reference surrogate loss: 9.038985833864643e-05
# sample 4721:
# reference surrogate loss: 0.00010816327310414486
# sample 4722:
# reference surrogate loss: 0.00010296433499523694
# sample 4723:
# reference surrogate loss: 8.698397947792813e-05
# sample 4724:
# reference surrogate loss: 0.00013740342655887972
# sample 4725:
# reference surrogate loss: 0.0001515798006423985
# sample 4726:
# reference surrogate loss: 0.00014033188931250606
# sample 4727:
# reference surrogate loss: 0.0001722227590181813
# sample 4728:
# reference surrogate loss: 0.00010432762476542123
# sample 4729:
# reference surrogate loss: 0.00011518272128130391
# sample 4730:
# reference surrogate loss: 0.00013068728469090019
# sample 4731:
# reference surrogate loss: 0.00012779149994557315
# sample 4732:
# reference surrogate loss: 9.87135305721143e-05
# sample 4733:
# reference surrogate loss: 9.759231091233111e-05
# sample 4734:
# reference surrogate loss: 9.285817679094421e-05
# sample 4735:
# reference surrogate loss: 0.00012356551519476788
# sample 4736:
# reference surrogate loss: 7.999491921295565e-05
# sample 4737:
# reference surrogate loss: 0.00011898025971346371
# sample 4738:
# reference surrogate loss: 0.00010416640606170091
# sample 4739:
# reference surrogate loss: 0.00014093196668918395
# sample 4740:
# reference surrogate loss: 0.00012990514820399035
# sample 4741:
# reference surrogate loss: 0.00010092924097993006
# sample 4742:
# reference surrogate loss: 8.976380965264319e-05
# sample 4743:
# reference surrogate loss: 0.0001135048668570171
# sample 4744:
# reference surrogate loss: 7.499896888862878e-05
# sample 4745:
# reference surrogate loss: 0.00011587832163773015
# sample 4746:
# reference surrogate loss: 0.00010414732197627785
# sample 4747:
# reference surrogate loss: 9.95295784902428e-05
# sample 4748:
# reference surrogate loss: 9.249068460692733e-05
# sample 4749:
# reference surrogate loss: 0.00015353943297347072
# sample 4750:
# reference surrogate loss: 9.793397995450093e-05
# sample 4751:
# reference surrogate loss: 0.00012431959845859986
# sample 4752:
# reference surrogate loss: 0.00015350598069518995
# sample 4753:
# reference surrogate loss: 0.00012797707112177648
# sample 4754:
# reference surrogate loss: 9.9375963300119e-05
# sample 4755:
# reference surrogate loss: 0.00010261178866377563
# sample 4756:
# reference surrogate loss: 8.386683594374666e-05
# sample 4757:
# reference surrogate loss: 7.674798346046785e-05
# sample 4758:
# reference surrogate loss: 0.00012830024535293028
# sample 4759:
# reference surrogate loss: 0.00010943940933527685
# sample 4760:
# reference surrogate loss: 0.00012329247098663565
# sample 4761:
# reference surrogate loss: 0.00014327071145880943
# sample 4762:
# reference surrogate loss: 0.00011065828023171242
# sample 4763:
# reference surrogate loss: 0.00016334519303362605
# sample 4764:
# reference surrogate loss: 7.606614765021114e-05
# sample 4765:
# reference surrogate loss: 5.942328569963351e-05
# sample 4766:
# reference surrogate loss: 6.822035939824111e-05
# sample 4767:
# reference surrogate loss: 0.00010746345335355123
# sample 4768:
# reference surrogate loss: 9.334005785444077e-05
# sample 4769:
# reference surrogate loss: 0.00010198333750133237
# sample 4770:
# reference surrogate loss: 9.920514603112274e-05
# sample 4771:
# reference surrogate loss: 0.00011841646629640046
# sample 4772:
# reference surrogate loss: 9.772073967173611e-05
# sample 4773:
# reference surrogate loss: 9.440298403928793e-05
# sample 4774:
# reference surrogate loss: 0.00018015249521297072
# sample 4775:
# reference surrogate loss: 8.582775994869785e-05
# sample 4776:
# reference surrogate loss: 6.2650804001807e-05
# sample 4777:
# reference surrogate loss: 7.783401948713298e-05
# sample 4778:
# reference surrogate loss: 8.699803135980844e-05
# sample 4779:
# reference surrogate loss: 0.00011608754650849207
# sample 4780:
# reference surrogate loss: 7.274993588279877e-05
# sample 4781:
# reference surrogate loss: 8.813260325846173e-05
# sample 4782:
# reference surrogate loss: 0.00011994433399187265
# sample 4783:
# reference surrogate loss: 0.00014409816010263476
# sample 4784:
# reference surrogate loss: 0.00011454696149360011
# sample 4785:
# reference surrogate loss: 0.00013605317156439867
# sample 4786:
# reference surrogate loss: 0.0001452791861327185
# sample 4787:
# reference surrogate loss: 0.0001179268435487213
# sample 4788:
# reference surrogate loss: 9.05753508890772e-05
# sample 4789:
# reference surrogate loss: 0.00010308213428356083
# sample 4790:
# reference surrogate loss: 9.176782240039039e-05
# sample 4791:
# reference surrogate loss: 0.0001091614608890179
# sample 4792:
# reference surrogate loss: 0.00010499936696350964
# sample 4793:
# reference surrogate loss: 8.44300708995327e-05
# sample 4794:
# reference surrogate loss: 0.000173291238336315
# sample 4795:
# reference surrogate loss: 0.00011900035378786811
# sample 4796:
# reference surrogate loss: 0.00011049707601662462
# sample 4797:
# reference surrogate loss: 7.943110407371279e-05
# sample 4798:
# reference surrogate loss: 8.074335725893889e-05
# sample 4799:
# reference surrogate loss: 8.867234234832821e-05
# sample 4800:
# reference surrogate loss: 8.270284680578222e-05
# sample 4801:
# reference surrogate loss: 0.0001184009616148618
# sample 4802:
# reference surrogate loss: 8.193296176695064e-05
# sample 4803:
# reference surrogate loss: 0.000116375145112535
# sample 4804:
# reference surrogate loss: 0.00012165263750740785
# sample 4805:
# reference surrogate loss: 9.672905184876512e-05
# sample 4806:
# reference surrogate loss: 0.00011355746180430337
# sample 4807:
# reference surrogate loss: 8.685901154414921e-05
# sample 4808:
# reference surrogate loss: 7.987069369042032e-05
# sample 4809:
# reference surrogate loss: 0.00011618287848480513
# sample 4810:
# reference surrogate loss: 9.43995955386967e-05
# sample 4811:
# reference surrogate loss: 0.00016512057044448802
# sample 4812:
# reference surrogate loss: 0.0001351323041667296
# sample 4813:
# reference surrogate loss: 0.00010257586540585173
# sample 4814:
# reference surrogate loss: 0.00015037448106158813
# sample 4815:
# reference surrogate loss: 0.00010456705692485357
# sample 4816:
# reference surrogate loss: 0.00013629246731894362
# sample 4817:
# reference surrogate loss: 7.313126072805431e-05
# sample 4818:
# reference surrogate loss: 7.065771244185726e-05
# sample 4819:
# reference surrogate loss: 8.123466334097884e-05
# sample 4820:
# reference surrogate loss: 8.741081294116881e-05
# sample 4821:
# reference surrogate loss: 0.00012419177237976697
# sample 4822:
# reference surrogate loss: 0.00010997087345709922
# sample 4823:
# reference surrogate loss: 6.630177596234077e-05
# sample 4824:
# reference surrogate loss: 0.00011246331759218187
# sample 4825:
# reference surrogate loss: 9.908103457534345e-05
# sample 4826:
# reference surrogate loss: 8.055090822756128e-05
# sample 4827:
# reference surrogate loss: 0.00011663516515825201
# sample 4828:
# reference surrogate loss: 9.59106941564869e-05
# sample 4829:
# reference surrogate loss: 9.673236446872124e-05
# sample 4830:
# reference surrogate loss: 0.00011436878052273336
# sample 4831:
# reference surrogate loss: 0.0001098916285722229
# sample 4832:
# reference surrogate loss: 0.00010288530084978653
# sample 4833:
# reference surrogate loss: 0.00012579034292836688
# sample 4834:
# reference surrogate loss: 7.022229289188608e-05
# sample 4835:
# reference surrogate loss: 0.00011771117331682568
# sample 4836:
# reference surrogate loss: 6.536478400498424e-05
# sample 4837:
# reference surrogate loss: 0.00011797139571734228
# sample 4838:
# reference surrogate loss: 0.0001252031687151156
# sample 4839:
# reference surrogate loss: 8.328526890100107e-05
# sample 4840:
# reference surrogate loss: 9.629672291033842e-05
# sample 4841:
# reference surrogate loss: 0.00014678563250947185
# sample 4842:
# reference surrogate loss: 9.448810377676864e-05
# sample 4843:
# reference surrogate loss: 0.00011313227315135066
# sample 4844:
# reference surrogate loss: 0.00011317144376854493
# sample 4845:
# reference surrogate loss: 0.00012497811759804023
# sample 4846:
# reference surrogate loss: 0.00013056737620353864
# sample 4847:
# reference surrogate loss: 0.00012513982467732276
# sample 4848:
# reference surrogate loss: 6.341834840029037e-05
# sample 4849:
# reference surrogate loss: 6.123813270297873e-05
# sample 4850:
# reference surrogate loss: 8.08618043726117e-05
# sample 4851:
# reference surrogate loss: 0.00015658450466249363
# sample 4852:
# reference surrogate loss: 0.00010144247750099034
# sample 4853:
# reference surrogate loss: 9.633175053824772e-05
# sample 4854:
# reference surrogate loss: 8.186111510788407e-05
# sample 4855:
# reference surrogate loss: 8.188393627928114e-05
# sample 4856:
# reference surrogate loss: 9.987663689936532e-05
# sample 4857:
# reference surrogate loss: 0.0001360433558355023
# sample 4858:
# reference surrogate loss: 0.00010850531260664376
# sample 4859:
# reference surrogate loss: 0.00015072674882410375
# sample 4860:
# reference surrogate loss: 0.0001578805068875866
# sample 4861:
# reference surrogate loss: 8.360858167155705e-05
# sample 4862:
# reference surrogate loss: 9.950291795446375e-05
# sample 4863:
# reference surrogate loss: 6.518113215858712e-05
# sample 4864:
# reference surrogate loss: 0.0001223974752653234
# sample 4865:
# reference surrogate loss: 0.00013628614148086804
# sample 4866:
# reference surrogate loss: 7.281477487830479e-05
# sample 4867:
# reference surrogate loss: 0.00012242640054105358
# sample 4868:
# reference surrogate loss: 9.062656567548899e-05
# sample 4869:
# reference surrogate loss: 8.791241101335778e-05
# sample 4870:
# reference surrogate loss: 0.00016365005107887853
# sample 4871:
# reference surrogate loss: 6.830089789611193e-05
# sample 4872:
# reference surrogate loss: 0.00010542843257543844
# sample 4873:
# reference surrogate loss: 0.00014930647776112416
# sample 4874:
# reference surrogate loss: 6.396830065069636e-05
# sample 4875:
# reference surrogate loss: 7.109848098441063e-05
# sample 4876:
# reference surrogate loss: 0.00012111099410594406
# sample 4877:
# reference surrogate loss: 0.0001442953326060703
# sample 4878:
# reference surrogate loss: 0.00010283931499732724
# sample 4879:
# reference surrogate loss: 8.460454946890295e-05
# sample 4880:
# reference surrogate loss: 9.095905099187895e-05
# sample 4881:
# reference surrogate loss: 9.61721946102223e-05
# sample 4882:
# reference surrogate loss: 0.00011040619388813511
# sample 4883:
# reference surrogate loss: 7.995352465983707e-05
# sample 4884:
# reference surrogate loss: 0.00011012060690895886
# sample 4885:
# reference surrogate loss: 0.00014098965895636972
# sample 4886:
# reference surrogate loss: 8.302616373434546e-05
# sample 4887:
# reference surrogate loss: 0.00010409074853279243
# sample 4888:
# reference surrogate loss: 0.00012297736836641704
# sample 4889:
# reference surrogate loss: 0.00011155511517824124
# sample 4890:
# reference surrogate loss: 0.00010783561818139553
# sample 4891:
# reference surrogate loss: 9.152739399920229e-05
# sample 4892:
# reference surrogate loss: 7.794947051631418e-05
# sample 4893:
# reference surrogate loss: 0.0001222419004507369
# sample 4894:
# reference surrogate loss: 9.881736162409283e-05
# sample 4895:
# reference surrogate loss: 6.391706627284499e-05
# sample 4896:
# reference surrogate loss: 7.504640173849886e-05
# sample 4897:
# reference surrogate loss: 0.00011374351536375116
# sample 4898:
# reference surrogate loss: 0.00010871971815595849
# sample 4899:
# reference surrogate loss: 0.00011134503872800572
# sample 4900:
# reference surrogate loss: 8.451242076534804e-05
# sample 4901:
# reference surrogate loss: 0.00011675107475017654
# sample 4902:
# reference surrogate loss: 9.431582691554752e-05
# sample 4903:
# reference surrogate loss: 0.00011401910234964951
# sample 4904:
# reference surrogate loss: 0.00011459239758715434
# sample 4905:
# reference surrogate loss: 0.00010070429734421182
# sample 4906:
# reference surrogate loss: 0.00016532454961448728
# sample 4907:
# reference surrogate loss: 0.00010438482776820024
# sample 4908:
# reference surrogate loss: 8.068677646111411e-05
# sample 4909:
# reference surrogate loss: 0.00013274677854613337
# sample 4910:
# reference surrogate loss: 0.00015765266676925904
# sample 4911:
# reference surrogate loss: 0.00010872595239508343
# sample 4912:
# reference surrogate loss: 0.00011211007703026965
# sample 4913:
# reference surrogate loss: 0.00010815004780950765
# sample 4914:
# reference surrogate loss: 5.655355704337062e-05
# sample 4915:
# reference surrogate loss: 0.00017009976863446852
# sample 4916:
# reference surrogate loss: 0.00010742367954708065
# sample 4917:
# reference surrogate loss: 0.00012534595469082532
# sample 4918:
# reference surrogate loss: 8.939821761666522e-05
# sample 4919:
# reference surrogate loss: 9.498871899027428e-05
# sample 4920:
# reference surrogate loss: 0.00011264708750879926
# sample 4921:
# reference surrogate loss: 0.00014928417847270836
# sample 4922:
# reference surrogate loss: 0.00012920322603093837
# sample 4923:
# reference surrogate loss: 0.0001572284960513759
# sample 4924:
# reference surrogate loss: 0.000138544021588638
# sample 4925:
# reference surrogate loss: 0.00010592584732971311
# sample 4926:
# reference surrogate loss: 0.0001072036818592359
# sample 4927:
# reference surrogate loss: 0.0001163439818319123
# sample 4928:
# reference surrogate loss: 0.000109697193878322
# sample 4929:
# reference surrogate loss: 9.664696548394858e-05
# sample 4930:
# reference surrogate loss: 7.5808039580183e-05
# sample 4931:
# reference surrogate loss: 6.615044947966275e-05
# sample 4932:
# reference surrogate loss: 0.00012141318075253871
# sample 4933:
# reference surrogate loss: 0.000126670998620515
# sample 4934:
# reference surrogate loss: 9.51638290229706e-05
# sample 4935:
# reference surrogate loss: 0.00011510342521670047
# sample 4936:
# reference surrogate loss: 8.665842725785744e-05
# sample 4937:
# reference surrogate loss: 0.00012994952287859185
# sample 4938:
# reference surrogate loss: 7.787307598339233e-05
# sample 4939:
# reference surrogate loss: 0.0001314851861800026
# sample 4940:
# reference surrogate loss: 0.0001652791670618825
# sample 4941:
# reference surrogate loss: 0.00015174377587445775
# sample 4942:
# reference surrogate loss: 0.00012274841387038826
# sample 4943:
# reference surrogate loss: 7.97690363381065e-05
# sample 4944:
# reference surrogate loss: 0.00013646864322613972
# sample 4945:
# reference surrogate loss: 0.00010334988791771416
# sample 4946:
# reference surrogate loss: 7.210006675184566e-05
# sample 4947:
# reference surrogate loss: 7.344963319444453e-05
# sample 4948:
# reference surrogate loss: 7.845144403351156e-05
# sample 4949:
# reference surrogate loss: 9.851716309361436e-05
# sample 4950:
# reference surrogate loss: 9.796397027295178e-05
# sample 4951:
# reference surrogate loss: 0.00011906090509072875
# sample 4952:
# reference surrogate loss: 0.00010317464325648729
# sample 4953:
# reference surrogate loss: 0.00010732088004927753
# sample 4954:
# reference surrogate loss: 0.00013437614715172685
# sample 4955:
# reference surrogate loss: 9.079733206363017e-05
# sample 4956:
# reference surrogate loss: 0.00010992259340159016
# sample 4957:
# reference surrogate loss: 0.00015138199424180598
# sample 4958:
# reference surrogate loss: 7.231480492353448e-05
# sample 4959:
# reference surrogate loss: 7.575362295009214e-05
# sample 4960:
# reference surrogate loss: 8.608589064196259e-05
# sample 4961:
# reference surrogate loss: 0.00014025087926028412
# sample 4962:
# reference surrogate loss: 6.09424352984167e-05
# sample 4963:
# reference surrogate loss: 6.786864950591998e-05
# sample 4964:
# reference surrogate loss: 0.00010937572895031167
# sample 4965:
# reference surrogate loss: 9.188766024470496e-05
# sample 4966:
# reference surrogate loss: 8.308457195771446e-05
# sample 4967:
# reference surrogate loss: 9.92974052345108e-05
# sample 4968:
# reference surrogate loss: 9.534483527962045e-05
# sample 4969:
# reference surrogate loss: 0.00011032173548408686
# sample 4970:
# reference surrogate loss: 9.451176996466693e-05
# sample 4971:
# reference surrogate loss: 0.00014482704152984915
# sample 4972:
# reference surrogate loss: 7.690110401115113e-05
# sample 4973:
# reference surrogate loss: 0.00010672855925042413
# sample 4974:
# reference surrogate loss: 9.050740448546257e-05
# sample 4975:
# reference surrogate loss: 0.0001315088407178866
# sample 4976:
# reference surrogate loss: 0.0001190647341156037
# sample 4977:
# reference surrogate loss: 9.902525919325278e-05
# sample 4978:
# reference surrogate loss: 0.0001097133205603118
# sample 4979:
# reference surrogate loss: 0.00010870117683658975
# sample 4980:
# reference surrogate loss: 0.00013012208309848283
# sample 4981:
# reference surrogate loss: 0.00014247193616356846
# sample 4982:
# reference surrogate loss: 0.00010607560848407971
# sample 4983:
# reference surrogate loss: 8.49024773386109e-05
# sample 4984:
# reference surrogate loss: 0.00010418593458139114
# sample 4985:
# reference surrogate loss: 0.00012360147858547776
# sample 4986:
# reference surrogate loss: 0.00012231807129703398
# sample 4987:
# reference surrogate loss: 0.00012076811743977345
# sample 4988:
# reference surrogate loss: 0.0001340645856720002
# sample 4989:
# reference surrogate loss: 0.00012094462920653193
# sample 4990:
# reference surrogate loss: 9.256581918570816e-05
# sample 4991:
# reference surrogate loss: 9.614898168242014e-05
# sample 4992:
# reference surrogate loss: 0.00013024813238304844
# sample 4993:
# reference surrogate loss: 0.0001610956987381229
# sample 4994:
# reference surrogate loss: 0.0001391146629010631
# sample 4995:
# reference surrogate loss: 0.0001564062828365298
# sample 4996:
# reference surrogate loss: 9.221147484450576e-05
# sample 4997:
# reference surrogate loss: 0.00017619430075588305
# sample 4998:
# reference surrogate loss: 9.009144260785362e-05
# sample 4999:
# reference surrogate loss: 0.0001192334041404397
#
# number of POD basi: 128
# mean reference surrogate loss: 1.09e-04
# std reference surrogate loss: 2.58e-05

# %%
# reference_surrogate_loss_list = []
# for i in range(valid_start_index, valid_start_index + num_samples_for_reference_surrogate_loss):
#     print(f'sample {i}:')
#     reference_surrogate_loss = surrogate_loss(reference_reduced_minimizers[i], i, sub_dim=256)
#     print(f'reference surrogate loss: {reference_surrogate_loss.item()}')
#     reference_surrogate_loss_list.append(reference_surrogate_loss.item())
# print("")
# print("number of POD basi: 256")
# print(f'mean reference surrogate loss: {np.mean(reference_surrogate_loss_list):.2e}')
# print(f'std reference surrogate loss: {np.std(reference_surrogate_loss_list):.2e}')

# %%
# reference_surrogate_loss_list = []
# for i in range(valid_start_index, valid_start_index + num_samples_for_reference_surrogate_loss):
#     print(f'sample {i}:')
#     reference_surrogate_loss = surrogate_loss(reference_reduced_minimizers[i], i, sub_dim=512)
#     print(f'reference surrogate loss: {reference_surrogate_loss.item()}')
#     reference_surrogate_loss_list.append(reference_surrogate_loss.item())
# print("")
# print("number of POD basi: 512")
# print(f'mean reference surrogate loss: {np.mean(reference_surrogate_loss_list):.2e}')
# print(f'std reference surrogate loss: {np.std(reference_surrogate_loss_list):.2e}')

# %%
# fig, ax = plt.subplots(figsize=(8, 6))  # Fixed figure size
# cax = ax.imshow(surrogate_loss.reduced_weight_list[0]['quadratic'].numpy(),  cmap='turbo')
# ax.set_xlabel('column index', fontsize=15)   
# ax.set_ylabel('row index', fontsize=15)
# ax.set_title('Reduced quadratic weight matrix', fontsize=15)
# ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_aspect('equal')
# cbar = fig.colorbar(cax, ax=ax)
# cbar.ax.tick_params(labelsize=13)  # Increase colorbar tick label font size

# fig.savefig(os.path.join(train_dataset_path, 'reduced_quadratic_weight_matrix_full.png'), dpi=300, bbox_inches='tight')

# %%
# fig, ax = plt.subplots(figsize=(8, 6))  # Fixed figure size
# cax = ax.imshow(surrogate_loss.reduced_weight_list[0]['quadratic'][:64,:64].numpy(),  cmap='turbo')
# ax.set_xlabel('column index', fontsize=15)   
# ax.set_ylabel('row index', fontsize=15)
# ax.set_title('Reduced quadratic weight matrix [0:64, 0:64]', fontsize=15)
# ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_aspect('equal')
# cbar = fig.colorbar(cax, ax=ax)
# cbar.ax.tick_params(labelsize=13)  # Increase colorbar tick label font size
# fig.savefig(os.path.join(train_dataset_path, 'reduced_quadratic_weight_matrix_0-64.png'), dpi=300, bbox_inches='tight')

# %%
# fig, ax = plt.subplots(figsize=(8, 6))  # Fixed figure size
# cax = ax.imshow(surrogate_loss.reduced_weight_list[0]['quadratic'][:16,:16].numpy(),  cmap='turbo')
# ax.set_xlabel('column index', fontsize=15) 
# ax.set_ylabel('row index', fontsize=15)
# ax.set_title('Reduced quadratic weight matrix [0:16, 0:16]', fontsize=15)
# ax.tick_params(axis='both', which='major', labelsize=13)
# ax.set_aspect('equal')
# cbar = fig.colorbar(cax, ax=ax)
# cbar.ax.tick_params(labelsize=13)  # Increase colorbar tick label font size
# fig.savefig(os.path.join(train_dataset_path, 'reduced_quadratic_weight_matrix_0-16.png'), dpi=300, bbox_inches='tight')

# %%
num_p_fc = len(p_dof)
dolfinx_mesh_coords = mesh.geometry.x[:,:2]

num_x, num_y = mesh_args['num_x'], mesh_args['num_y']
x = np.linspace(0, mesh_args['upper_right_x'], num_x+1)
y = np.linspace(0, mesh_args['upper_right_y'], num_y+1)
image_mesh_coords = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
perm = [np.where((image_mesh_coords == row).all(axis=1))[0][0] for row in dolfinx_mesh_coords]

CG_element = basix.ufl.element('CG', 'triangle', 1)
Vh['CG1'] = dolfinx.fem.functionspace(mesh, CG_element)

# %%
# for i in range(3):
#     k = dolfinx.fem.Function(Vh['CG1'])
#     k.x.array[:] = k_dof[i]
#     k_vertex_values[i][perm] = k.x.array[:][scifem.vertex_to_dofmap(Vh['CG1'])]
#     plt.imshow(k_vertex_values[i].reshape(num_x+1, num_y+1).T, extent=[0, 1, 0, 1], origin='lower', cmap='turbo')
#     plt.colorbar()
#     plt.title('Random parameter function k')
#     plt.show()

# %%
# if not os.path.exists(os.path.join(train_dataset_path, 'k_vertex_values.npy')):
#     print('Computing k_vertex_values...')
#     k_vertex_values = np.zeros((num_k_fc, (mesh_args['num_x'] + 1) * (mesh_args['num_y'] + 1)))
#     for i in tqdm(range(num_k_fc)):
#         k_fc = dolfinx.fem.Function(Vh['k'])
#         k_fc.x.array[:] = k_dof[i]
#         k_vertex_values[i][perm] = evaluate_expression(mesh, k_fc, mesh.geometry.x)[1][:, 0]
#     np.save(os.path.join(train_dataset_path, 'k_vertex_values.npy'), k_vertex_values)
# else:
#     k_vertex_values = np.load(os.path.join(train_dataset_path, 'k_vertex_values.npy'))

# %%
# k_vertex_values = np.zeros((num_k_fc, (mesh_args['num_x'] + 1) * (mesh_args['num_y'] + 1)))

# for i in tqdm(range(num_k_fc)):
#     k = dolfinx.fem.Function(Vh['k'])
#     k.x.array[:] = k_dof[i]
#     k_vertex_values[i][perm] = evaluate_expression(mesh, k, mesh.geometry.x)[1][:, 0]

# %%
image_p_vertex_values = np.zeros((num_p_fc, 1, mesh_args['num_y']+1, mesh_args['num_x']+1))
for i in tqdm(range(num_p_fc)):
    image_p_vertex_values[i,0,:,:] = p_vertex_values[i].reshape(num_x+1, num_y+1).T
# Out:
# 100%|██████████| 5000/5000 [00:03<00:00, 1551.95it/s]

# %%
# for i in range(num_k_fc):
#     k = dolfinx.fem.Function(Vh['CG1'])
#     k.x.array[:] = k_dof[i]
#     k_vertex_values[i][perm] = k.x.array[:][scifem.vertex_to_dofmap(Vh['CG1'])]

# device = torch.device('cuda:3')

# image_k_vertex_values = np.zeros((num_k_fc, 1, num_x+1, num_y+1))
# for i in range(num_k_fc):
#     image_k_vertex_values[i,0,:,:] = k_vertex_values[i].reshape(num_x+1, num_y+1)

# k_vertex_values_tensor = torch.tensor(image_k_vertex_values, dtype=torch_dtype['float32']).to(device)

# %%
device = torch.device('cuda:3')
p_vertex_values_tensor = torch.tensor(image_p_vertex_values, dtype=torch_dtype['float32']).to(device)

# %%
x = mesh.geometry.x[:, 0]
y = mesh.geometry.x[:, 1]
p = dolfinx.fem.Function(Vh['p'])
p.x.array[:] = p_dof[0]
plt.tricontourf(x, y, evaluate_expression(mesh, p, mesh.geometry.x)[1][:, 0], cmap='turbo', levels=100)
plt.colorbar()
plt.title('Random parameter function p')
plt.show()

# %%
plt.imshow(p_vertex_values_tensor[0,0,:,:].cpu().numpy(), extent=[0, 1, 0, 1], origin='lower', cmap='turbo')
plt.colorbar()
plt.title('Random parameter function p')
plt.show()

# %%
surrogate_loss = SurrogateLoss(reduced_weight_list).astype(torch_dtype['float32']).to(device)
num_basis = output_reduced_basis_args['num_basis']
model = ConvolutionalNN_129x129(output_dim=num_basis, activation='leakyrelu', init_func='xavier_uniform')
model = model.to(device)

# %%
_, _ = print_model_size(model)
# Out:
# Total number of model parameters: 15117440 (~57.67 MiB)

# %%
iterations = 3000
num_train = 3000
num_valid = 500

batch_size = {
    'train': 1000,
    'valid': num_valid
}

# %%
data_loss = torch.nn.MSELoss(reduction='mean')
reference_reduced_minimizers = reference_reduced_minimizers.to(torch_dtype['float32']).to(device)
num_samples_for_data_loss = output_reduced_basis_args['num_evals']

# %%
loss_history = {
    'train_physical': [],
    'train_data': [],
    'train_total': [],
    'valid_physical': [],
    'valid_data': [],
    'valid_total': []
}
valid_start_index = 4500

train_batch_indices_iterator = BatchIndicesIterator(start=0, end=num_train, batch_size=batch_size['train'], shuffle=True)
valid_batch_indices_iterator = BatchIndicesIterator(start=valid_start_index, end=valid_start_index + num_valid, batch_size=batch_size['valid'], shuffle=False)
data_loss_indices = torch.arange(num_samples_for_data_loss, dtype=torch.int64).to(device)

print(f'num_training_samples: {num_train}')
optimizer = SOAP(params=model.parameters(), lr=5e-3, betas=(.95, .95), weight_decay=.01, precondition_frequency=5)
# optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.01)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.9)

best_valid_loss = float('inf')
best_model_path = os.path.join(model_train_outputs_path, f"best_model_params_{num_train}.pth")
best_model_iterations = []  

counter = 0
while counter < iterations:
    for batch_indices in train_batch_indices_iterator:
        model.train()
        loss = {'physical': torch.tensor(0.0).to(device),
                'data': torch.tensor(0.0).to(device),
                'total': torch.tensor(0.0).to(device)}

        input_ = p_vertex_values_tensor[batch_indices]
        output = model(input_)

        data_loss_batch_indices = []
        for j, index in enumerate(batch_indices):
            # loss['physical'] += (surrogate_loss(output[j], index))[0]
            if index in data_loss_indices:
                loss['data'] += data_loss(output[j], reference_reduced_minimizers[index])
                data_loss_batch_indices.append(index)

        # loss['physical'] /= len(batch_indices)
        loss['data'] /= len(data_loss_batch_indices) if len(data_loss_batch_indices) > 0 else 1
        loss['total'] = loss['physical'] + loss['data']

        optimizer.zero_grad()
        loss['total'].backward()
        optimizer.step()
        counter += 1

        print('')
        print(f'Iteration: {counter}')
        print(f'Train loss: physical {loss["physical"].item()} | data {loss["data"].item()} | total {loss["total"].item()}')

        loss_history['train_physical'].append(loss['physical'].item())
        loss_history['train_data'].append(loss['data'].item())
        loss_history['train_total'].append(loss['total'].item())

        with torch.no_grad():
            model.eval()
            valid_loss = {'physical': torch.tensor(0.0).to(device),
                          'data': torch.tensor(0.0).to(device),
                          'total': torch.tensor(0.0).to(device)}
            for valid_batch_indices in valid_batch_indices_iterator:
                valid_input = p_vertex_values_tensor[valid_batch_indices]
                valid_output = model(valid_input)
                for j, index in enumerate(valid_batch_indices):
                    # valid_loss['physical'] += (surrogate_loss(valid_output[j], index))[0]
                    valid_loss['data'] += data_loss(valid_output[j], reference_reduced_minimizers[index])
                # valid_loss['physical'] /= len(valid_batch_indices)
                valid_loss['data'] /= len(valid_batch_indices)
                valid_loss['total'] = valid_loss['physical'] + valid_loss['data']

            valid_physical_loss_value = valid_loss['physical'].item()
            valid_data_loss_value = valid_loss['data'].item()
            valid_total_loss_value = valid_loss['total'].item()
            print(f'Valid loss: physical {valid_loss["physical"].item()} | data {valid_loss["data"].item()} | total {valid_loss["total"].item()}')

            loss_history['valid_physical'].append(valid_loss['physical'].item())
            loss_history['valid_data'].append(valid_loss['data'].item())
            loss_history['valid_total'].append(valid_loss['total'].item())

            # Save best model
            if valid_total_loss_value < best_valid_loss:
                best_valid_loss = valid_total_loss_value
                torch.save(model.state_dict(), best_model_path)
                best_model_iterations.append(counter) 
                print(f"New best model saved at iteration {counter} with validation total loss {best_valid_loss:.6f}")

    lr_scheduler.step()

# Save training history and final model
loss_history = {key: np.array(value) for key, value in loss_history.items()}
np.save(os.path.join(model_train_outputs_path, f'loss_history_{num_train}.npy'), loss_history)
torch.save(model.state_dict(), os.path.join(model_train_outputs_path, f"latest_model_params_{num_train}.pth"))
# Out:
# num_training_samples: 3000
#
# Iteration: 1
# Train loss: physical 0.0 | data 0.017545700073242188 | total 0.017545700073242188
# Valid loss: physical 0.0 | data 0.017436577007174492 | total 0.017436577007174492
# New best model saved at iteration 1 with validation total loss 0.017437
#
# Iteration: 2
# Train loss: physical 0.0 | data 0.017626848071813583 | total 0.017626848071813583
# Valid loss: physical 0.0 | data 3.2486791610717773 | total 3.2486791610717773
#
# Iteration: 3
# Train loss: physical 0.0 | data 3.38458251953125 | total 3.38458251953125
# Valid loss: physical 0.0 | data 0.2912430465221405 | total 0.2912430465221405
#
# Iteration: 4
# Train loss: physical 0.0 | data 0.30552777647972107 | total 0.30552777647972107
# Valid loss: physical 0.0 | data 0.050584133714437485 | total 0.050584133714437485
#
# Iteration: 5
# Train loss: physical 0.0 | data 0.0511852465569973 | total 0.0511852465569973
# Valid loss: physical 0.0 | data 0.3850293755531311 | total 0.3850293755531311
#
# Iteration: 6
# Train loss: physical 0.0 | data 0.40224984288215637 | total 0.40224984288215637
# Valid loss: physical 0.0 | data 0.42222750186920166 | total 0.42222750186920166
#
# Iteration: 7
# Train loss: physical 0.0 | data 0.427147775888443 | total 0.427147775888443
# Valid loss: physical 0.0 | data 0.14522379636764526 | total 0.14522379636764526
#
# Iteration: 8
# Train loss: physical 0.0 | data 0.1590729057788849 | total 0.1590729057788849
# Valid loss: physical 0.0 | data 0.11564580351114273 | total 0.11564580351114273
#
# Iteration: 9
# Train loss: physical 0.0 | data 0.13039396703243256 | total 0.13039396703243256
# Valid loss: physical 0.0 | data 0.03406397998332977 | total 0.03406397998332977
#
# Iteration: 10
# Train loss: physical 0.0 | data 0.03581902012228966 | total 0.03581902012228966
# Valid loss: physical 0.0 | data 0.016332266852259636 | total 0.016332266852259636
# New best model saved at iteration 10 with validation total loss 0.016332
#
# Iteration: 11
# Train loss: physical 0.0 | data 0.0179815161973238 | total 0.0179815161973238
# Valid loss: physical 0.0 | data 0.015857307240366936 | total 0.015857307240366936
# New best model saved at iteration 11 with validation total loss 0.015857
#
# Iteration: 12
# Train loss: physical 0.0 | data 0.01572910137474537 | total 0.01572910137474537
# Valid loss: physical 0.0 | data 0.014140295796096325 | total 0.014140295796096325
# New best model saved at iteration 12 with validation total loss 0.014140
#
# Iteration: 13
# Train loss: physical 0.0 | data 0.015289722010493279 | total 0.015289722010493279
# Valid loss: physical 0.0 | data 0.012381752021610737 | total 0.012381752021610737
# New best model saved at iteration 13 with validation total loss 0.012382
#
# Iteration: 14
# Train loss: physical 0.0 | data 0.01263224147260189 | total 0.01263224147260189
# Valid loss: physical 0.0 | data 0.011998755857348442 | total 0.011998755857348442
# New best model saved at iteration 14 with validation total loss 0.011999
#
# Iteration: 15
# Train loss: physical 0.0 | data 0.01233446504920721 | total 0.01233446504920721
# Valid loss: physical 0.0 | data 0.01136288046836853 | total 0.01136288046836853
# New best model saved at iteration 15 with validation total loss 0.011363
#
# Iteration: 16
# Train loss: physical 0.0 | data 0.011509159579873085 | total 0.011509159579873085
# Valid loss: physical 0.0 | data 0.011206941679120064 | total 0.011206941679120064
# New best model saved at iteration 16 with validation total loss 0.011207
#
# Iteration: 17
# Train loss: physical 0.0 | data 0.011328570544719696 | total 0.011328570544719696
# Valid loss: physical 0.0 | data 0.01233945693820715 | total 0.01233945693820715
#
# Iteration: 18
# Train loss: physical 0.0 | data 0.012851299718022346 | total 0.012851299718022346
# Valid loss: physical 0.0 | data 0.013157598674297333 | total 0.013157598674297333
#
# Iteration: 19
# Train loss: physical 0.0 | data 0.01334313489496708 | total 0.01334313489496708
# Valid loss: physical 0.0 | data 0.011024262756109238 | total 0.011024262756109238
# New best model saved at iteration 19 with validation total loss 0.011024
#
# Iteration: 20
# Train loss: physical 0.0 | data 0.011132861487567425 | total 0.011132861487567425
# Valid loss: physical 0.0 | data 0.010844689793884754 | total 0.010844689793884754
# New best model saved at iteration 20 with validation total loss 0.010845
#
# Iteration: 21
# Train loss: physical 0.0 | data 0.011507838033139706 | total 0.011507838033139706
# Valid loss: physical 0.0 | data 0.010882636532187462 | total 0.010882636532187462
#
# Iteration: 22
# Train loss: physical 0.0 | data 0.010996880941092968 | total 0.010996880941092968
# Valid loss: physical 0.0 | data 0.011732760816812515 | total 0.011732760816812515
#
# Iteration: 23
# Train loss: physical 0.0 | data 0.013371845707297325 | total 0.013371845707297325
# Valid loss: physical 0.0 | data 0.010607603006064892 | total 0.010607603006064892
# New best model saved at iteration 23 with validation total loss 0.010608
#
# Iteration: 24
# Train loss: physical 0.0 | data 0.010951535776257515 | total 0.010951535776257515
# Valid loss: physical 0.0 | data 0.010355611331760883 | total 0.010355611331760883
# New best model saved at iteration 24 with validation total loss 0.010356
#
# Iteration: 25
# Train loss: physical 0.0 | data 0.01105528324842453 | total 0.01105528324842453
# Valid loss: physical 0.0 | data 0.009402226656675339 | total 0.009402226656675339
# New best model saved at iteration 25 with validation total loss 0.009402
#
# Iteration: 26
# Train loss: physical 0.0 | data 0.009787116199731827 | total 0.009787116199731827
# Valid loss: physical 0.0 | data 0.008651330135762691 | total 0.008651330135762691
# New best model saved at iteration 26 with validation total loss 0.008651
#
# Iteration: 27
# Train loss: physical 0.0 | data 0.009050966240465641 | total 0.009050966240465641
# Valid loss: physical 0.0 | data 0.008244568482041359 | total 0.008244568482041359
# New best model saved at iteration 27 with validation total loss 0.008245
#
# Iteration: 28
# Train loss: physical 0.0 | data 0.008688326925039291 | total 0.008688326925039291
# Valid loss: physical 0.0 | data 0.007735123857855797 | total 0.007735123857855797
# New best model saved at iteration 28 with validation total loss 0.007735
#
# Iteration: 29
# Train loss: physical 0.0 | data 0.008034138940274715 | total 0.008034138940274715
# Valid loss: physical 0.0 | data 0.007383960299193859 | total 0.007383960299193859
# New best model saved at iteration 29 with validation total loss 0.007384
#
# Iteration: 30
# Train loss: physical 0.0 | data 0.007768497336655855 | total 0.007768497336655855
# Valid loss: physical 0.0 | data 0.006877541542053223 | total 0.006877541542053223
# New best model saved at iteration 30 with validation total loss 0.006878
#
# Iteration: 31
# Train loss: physical 0.0 | data 0.006866941228508949 | total 0.006866941228508949
# Valid loss: physical 0.0 | data 0.006464872509241104 | total 0.006464872509241104
# New best model saved at iteration 31 with validation total loss 0.006465
#
# Iteration: 32
# Train loss: physical 0.0 | data 0.006907318718731403 | total 0.006907318718731403
# Valid loss: physical 0.0 | data 0.006033047568053007 | total 0.006033047568053007
# New best model saved at iteration 32 with validation total loss 0.006033
#
# Iteration: 33
# Train loss: physical 0.0 | data 0.0062258001416921616 | total 0.0062258001416921616
# Valid loss: physical 0.0 | data 0.005461909342557192 | total 0.005461909342557192
# New best model saved at iteration 33 with validation total loss 0.005462
#
# Iteration: 34
# Train loss: physical 0.0 | data 0.005570998415350914 | total 0.005570998415350914
# Valid loss: physical 0.0 | data 0.005093254614621401 | total 0.005093254614621401
# New best model saved at iteration 34 with validation total loss 0.005093
#
# Iteration: 35
# Train loss: physical 0.0 | data 0.005096656270325184 | total 0.005096656270325184
# Valid loss: physical 0.0 | data 0.004723810590803623 | total 0.004723810590803623
# New best model saved at iteration 35 with validation total loss 0.004724
#
# Iteration: 36
# Train loss: physical 0.0 | data 0.004864125046879053 | total 0.004864125046879053
# Valid loss: physical 0.0 | data 0.004485842306166887 | total 0.004485842306166887
# New best model saved at iteration 36 with validation total loss 0.004486
#
# Iteration: 37
# Train loss: physical 0.0 | data 0.004478698596358299 | total 0.004478698596358299
# Valid loss: physical 0.0 | data 0.004357357509434223 | total 0.004357357509434223
# New best model saved at iteration 37 with validation total loss 0.004357
#
# Iteration: 38
# Train loss: physical 0.0 | data 0.004280307795852423 | total 0.004280307795852423
# Valid loss: physical 0.0 | data 0.003840978257358074 | total 0.003840978257358074
# New best model saved at iteration 38 with validation total loss 0.003841
#
# Iteration: 39
# Train loss: physical 0.0 | data 0.003762289648875594 | total 0.003762289648875594
# Valid loss: physical 0.0 | data 0.003575056092813611 | total 0.003575056092813611
# New best model saved at iteration 39 with validation total loss 0.003575
#
# Iteration: 40
# Train loss: physical 0.0 | data 0.0035085943527519703 | total 0.0035085943527519703
# Valid loss: physical 0.0 | data 0.003278033109381795 | total 0.003278033109381795
# New best model saved at iteration 40 with validation total loss 0.003278
#
# Iteration: 41
# Train loss: physical 0.0 | data 0.0032586599700152874 | total 0.0032586599700152874
# Valid loss: physical 0.0 | data 0.0031861616298556328 | total 0.0031861616298556328
# New best model saved at iteration 41 with validation total loss 0.003186
#
# Iteration: 42
# Train loss: physical 0.0 | data 0.0030927767511457205 | total 0.0030927767511457205
# Valid loss: physical 0.0 | data 0.003351171500980854 | total 0.003351171500980854
#
# Iteration: 43
# Train loss: physical 0.0 | data 0.0034560479689389467 | total 0.0034560479689389467
# Valid loss: physical 0.0 | data 0.0032852287404239178 | total 0.0032852287404239178
#
# Iteration: 44
# Train loss: physical 0.0 | data 0.0033346351701766253 | total 0.0033346351701766253
# Valid loss: physical 0.0 | data 0.002668882953003049 | total 0.002668882953003049
# New best model saved at iteration 44 with validation total loss 0.002669
#
# Iteration: 45
# Train loss: physical 0.0 | data 0.00266373623162508 | total 0.00266373623162508
# Valid loss: physical 0.0 | data 0.0026769477408379316 | total 0.0026769477408379316
#
# Iteration: 46
# Train loss: physical 0.0 | data 0.0027118446305394173 | total 0.0027118446305394173
# Valid loss: physical 0.0 | data 0.002329082228243351 | total 0.002329082228243351
# New best model saved at iteration 46 with validation total loss 0.002329
#
# Iteration: 47
# Train loss: physical 0.0 | data 0.0023886754643172026 | total 0.0023886754643172026
# Valid loss: physical 0.0 | data 0.0023517829831689596 | total 0.0023517829831689596
#
# Iteration: 48
# Train loss: physical 0.0 | data 0.002380200196057558 | total 0.002380200196057558
# Valid loss: physical 0.0 | data 0.002126752631738782 | total 0.002126752631738782
# New best model saved at iteration 48 with validation total loss 0.002127
#
# Iteration: 49
# Train loss: physical 0.0 | data 0.0021136989817023277 | total 0.0021136989817023277
# Valid loss: physical 0.0 | data 0.001925944467075169 | total 0.001925944467075169
# New best model saved at iteration 49 with validation total loss 0.001926
#
# Iteration: 50
# Train loss: physical 0.0 | data 0.001899896888062358 | total 0.001899896888062358
# Valid loss: physical 0.0 | data 0.0020054420456290245 | total 0.0020054420456290245
#
# Iteration: 51
# Train loss: physical 0.0 | data 0.002037518657743931 | total 0.002037518657743931
# Valid loss: physical 0.0 | data 0.0016985902329906821 | total 0.0016985902329906821
# New best model saved at iteration 51 with validation total loss 0.001699
#
# Iteration: 52
# Train loss: physical 0.0 | data 0.0017215287080034614 | total 0.0017215287080034614
# Valid loss: physical 0.0 | data 0.0017768193501979113 | total 0.0017768193501979113
#
# Iteration: 53
# Train loss: physical 0.0 | data 0.0018859156407415867 | total 0.0018859156407415867
# Valid loss: physical 0.0 | data 0.0017301538027822971 | total 0.0017301538027822971
#
# Iteration: 54
# Train loss: physical 0.0 | data 0.001762131112627685 | total 0.001762131112627685
# Valid loss: physical 0.0 | data 0.0016102269291877747 | total 0.0016102269291877747
# New best model saved at iteration 54 with validation total loss 0.001610
#
# Iteration: 55
# Train loss: physical 0.0 | data 0.0016498297918587923 | total 0.0016498297918587923
# Valid loss: physical 0.0 | data 0.0013999497750774026 | total 0.0013999497750774026
# New best model saved at iteration 55 with validation total loss 0.001400
#
# Iteration: 56
# Train loss: physical 0.0 | data 0.0014070668257772923 | total 0.0014070668257772923
# Valid loss: physical 0.0 | data 0.0016315778484568 | total 0.0016315778484568
#
# Iteration: 57
# Train loss: physical 0.0 | data 0.0016371459932997823 | total 0.0016371459932997823
# Valid loss: physical 0.0 | data 0.001480513601563871 | total 0.001480513601563871
#
# Iteration: 58
# Train loss: physical 0.0 | data 0.00145726278424263 | total 0.00145726278424263
# Valid loss: physical 0.0 | data 0.0013140332885086536 | total 0.0013140332885086536
# New best model saved at iteration 58 with validation total loss 0.001314
#
# Iteration: 59
# Train loss: physical 0.0 | data 0.0013425294309854507 | total 0.0013425294309854507
# Valid loss: physical 0.0 | data 0.001431627431884408 | total 0.001431627431884408
#
# Iteration: 60
# Train loss: physical 0.0 | data 0.0014378776540979743 | total 0.0014378776540979743
# Valid loss: physical 0.0 | data 0.0013748463243246078 | total 0.0013748463243246078
#
# Iteration: 61
# Train loss: physical 0.0 | data 0.0013835764257237315 | total 0.0013835764257237315
# Valid loss: physical 0.0 | data 0.0012727596331387758 | total 0.0012727596331387758
# New best model saved at iteration 61 with validation total loss 0.001273
#
# Iteration: 62
# Train loss: physical 0.0 | data 0.0012625836534425616 | total 0.0012625836534425616
# Valid loss: physical 0.0 | data 0.0013848418602719903 | total 0.0013848418602719903
#
# Iteration: 63
# Train loss: physical 0.0 | data 0.0013680068077519536 | total 0.0013680068077519536
# Valid loss: physical 0.0 | data 0.0012216494651511312 | total 0.0012216494651511312
# New best model saved at iteration 63 with validation total loss 0.001222
#
# Iteration: 64
# Train loss: physical 0.0 | data 0.0011900058016180992 | total 0.0011900058016180992
# Valid loss: physical 0.0 | data 0.0011719450121745467 | total 0.0011719450121745467
# New best model saved at iteration 64 with validation total loss 0.001172
#
# Iteration: 65
# Train loss: physical 0.0 | data 0.001169911352917552 | total 0.001169911352917552
# Valid loss: physical 0.0 | data 0.0012148115783929825 | total 0.0012148115783929825
#
# Iteration: 66
# Train loss: physical 0.0 | data 0.0012229072162881494 | total 0.0012229072162881494
# Valid loss: physical 0.0 | data 0.0011253029806539416 | total 0.0011253029806539416
# New best model saved at iteration 66 with validation total loss 0.001125
#
# Iteration: 67
# Train loss: physical 0.0 | data 0.001083960640244186 | total 0.001083960640244186
# Valid loss: physical 0.0 | data 0.0011115281376987696 | total 0.0011115281376987696
# New best model saved at iteration 67 with validation total loss 0.001112
#
# Iteration: 68
# Train loss: physical 0.0 | data 0.001065078773535788 | total 0.001065078773535788
# Valid loss: physical 0.0 | data 0.0011972076026722789 | total 0.0011972076026722789
#
# Iteration: 69
# Train loss: physical 0.0 | data 0.0012235267786309123 | total 0.0012235267786309123
# Valid loss: physical 0.0 | data 0.0010539473732933402 | total 0.0010539473732933402
# New best model saved at iteration 69 with validation total loss 0.001054
#
# Iteration: 70
# Train loss: physical 0.0 | data 0.0010363089386373758 | total 0.0010363089386373758
# Valid loss: physical 0.0 | data 0.0010304086608812213 | total 0.0010304086608812213
# New best model saved at iteration 70 with validation total loss 0.001030
#
# Iteration: 71
# Train loss: physical 0.0 | data 0.0010096696205437183 | total 0.0010096696205437183
# Valid loss: physical 0.0 | data 0.0010395754361525178 | total 0.0010395754361525178
#
# Iteration: 72
# Train loss: physical 0.0 | data 0.0010595195926725864 | total 0.0010595195926725864
# Valid loss: physical 0.0 | data 0.0009703117539174855 | total 0.0009703117539174855
# New best model saved at iteration 72 with validation total loss 0.000970
#
# Iteration: 73
# Train loss: physical 0.0 | data 0.0009314928902313113 | total 0.0009314928902313113
# Valid loss: physical 0.0 | data 0.0009327764273621142 | total 0.0009327764273621142
# New best model saved at iteration 73 with validation total loss 0.000933
#
# Iteration: 74
# Train loss: physical 0.0 | data 0.0009042322635650635 | total 0.0009042322635650635
# Valid loss: physical 0.0 | data 0.0009520630119368434 | total 0.0009520630119368434
#
# Iteration: 75
# Train loss: physical 0.0 | data 0.0009628854459151626 | total 0.0009628854459151626
# Valid loss: physical 0.0 | data 0.0009131972910836339 | total 0.0009131972910836339
# New best model saved at iteration 75 with validation total loss 0.000913
#
# Iteration: 76
# Train loss: physical 0.0 | data 0.0008945681038312614 | total 0.0008945681038312614
# Valid loss: physical 0.0 | data 0.0008927498129196465 | total 0.0008927498129196465
# New best model saved at iteration 76 with validation total loss 0.000893
#
# Iteration: 77
# Train loss: physical 0.0 | data 0.0008927043527364731 | total 0.0008927043527364731
# Valid loss: physical 0.0 | data 0.000857885112054646 | total 0.000857885112054646
# New best model saved at iteration 77 with validation total loss 0.000858
#
# Iteration: 78
# Train loss: physical 0.0 | data 0.0008352045551873744 | total 0.0008352045551873744
# Valid loss: physical 0.0 | data 0.0008383709355257452 | total 0.0008383709355257452
# New best model saved at iteration 78 with validation total loss 0.000838
#
# Iteration: 79
# Train loss: physical 0.0 | data 0.0008066649315878749 | total 0.0008066649315878749
# Valid loss: physical 0.0 | data 0.0007969887810759246 | total 0.0007969887810759246
# New best model saved at iteration 79 with validation total loss 0.000797
#
# Iteration: 80
# Train loss: physical 0.0 | data 0.0007974180043675005 | total 0.0007974180043675005
# Valid loss: physical 0.0 | data 0.0008076564408838749 | total 0.0008076564408838749
#
# Iteration: 81
# Train loss: physical 0.0 | data 0.0007891064742580056 | total 0.0007891064742580056
# Valid loss: physical 0.0 | data 0.0007645344594493508 | total 0.0007645344594493508
# New best model saved at iteration 81 with validation total loss 0.000765
#
# Iteration: 82
# Train loss: physical 0.0 | data 0.0007610382745042443 | total 0.0007610382745042443
# Valid loss: physical 0.0 | data 0.0007595943752676249 | total 0.0007595943752676249
# New best model saved at iteration 82 with validation total loss 0.000760
#
# Iteration: 83
# Train loss: physical 0.0 | data 0.0007385725621134043 | total 0.0007385725621134043
# Valid loss: physical 0.0 | data 0.0007301898440346122 | total 0.0007301898440346122
# New best model saved at iteration 83 with validation total loss 0.000730
#
# Iteration: 84
# Train loss: physical 0.0 | data 0.0006987996748648584 | total 0.0006987996748648584
# Valid loss: physical 0.0 | data 0.0007150781457312405 | total 0.0007150781457312405
# New best model saved at iteration 84 with validation total loss 0.000715
#
# Iteration: 85
# Train loss: physical 0.0 | data 0.0006802609423175454 | total 0.0006802609423175454
# Valid loss: physical 0.0 | data 0.0007124681142158806 | total 0.0007124681142158806
# New best model saved at iteration 85 with validation total loss 0.000712
#
# Iteration: 86
# Train loss: physical 0.0 | data 0.0006964497151784599 | total 0.0006964497151784599
# Valid loss: physical 0.0 | data 0.0006910259835422039 | total 0.0006910259835422039
# New best model saved at iteration 86 with validation total loss 0.000691
#
# Iteration: 87
# Train loss: physical 0.0 | data 0.0006754939677193761 | total 0.0006754939677193761
# Valid loss: physical 0.0 | data 0.0006870471406728029 | total 0.0006870471406728029
# New best model saved at iteration 87 with validation total loss 0.000687
#
# Iteration: 88
# Train loss: physical 0.0 | data 0.0006752353510819376 | total 0.0006752353510819376
# Valid loss: physical 0.0 | data 0.0006608225521631539 | total 0.0006608225521631539
# New best model saved at iteration 88 with validation total loss 0.000661
#
# Iteration: 89
# Train loss: physical 0.0 | data 0.0006293253973126411 | total 0.0006293253973126411
# Valid loss: physical 0.0 | data 0.0006613375153392553 | total 0.0006613375153392553
#
# Iteration: 90
# Train loss: physical 0.0 | data 0.0006389739573933184 | total 0.0006389739573933184
# Valid loss: physical 0.0 | data 0.0006283774273470044 | total 0.0006283774273470044
# New best model saved at iteration 90 with validation total loss 0.000628
#
# Iteration: 91
# Train loss: physical 0.0 | data 0.0006070692325010896 | total 0.0006070692325010896
# Valid loss: physical 0.0 | data 0.0006384067237377167 | total 0.0006384067237377167
#
# Iteration: 92
# Train loss: physical 0.0 | data 0.0006175701855681837 | total 0.0006175701855681837
# Valid loss: physical 0.0 | data 0.0006081985775381327 | total 0.0006081985775381327
# New best model saved at iteration 92 with validation total loss 0.000608
#
# Iteration: 93
# Train loss: physical 0.0 | data 0.0006023320602253079 | total 0.0006023320602253079
# Valid loss: physical 0.0 | data 0.0006186045939102769 | total 0.0006186045939102769
#
# Iteration: 94
# Train loss: physical 0.0 | data 0.0005897808005101979 | total 0.0005897808005101979
# Valid loss: physical 0.0 | data 0.0005975221283733845 | total 0.0005975221283733845
# New best model saved at iteration 94 with validation total loss 0.000598
#
# Iteration: 95
# Train loss: physical 0.0 | data 0.0005799729842692614 | total 0.0005799729842692614
# Valid loss: physical 0.0 | data 0.000579306622967124 | total 0.000579306622967124
# New best model saved at iteration 95 with validation total loss 0.000579
#
# Iteration: 96
# Train loss: physical 0.0 | data 0.0005668463418260217 | total 0.0005668463418260217
# Valid loss: physical 0.0 | data 0.000605144421570003 | total 0.000605144421570003
#
# Iteration: 97
# Train loss: physical 0.0 | data 0.0005811839364469051 | total 0.0005811839364469051
# Valid loss: physical 0.0 | data 0.0005648944643326104 | total 0.0005648944643326104
# New best model saved at iteration 97 with validation total loss 0.000565
#
# Iteration: 98
# Train loss: physical 0.0 | data 0.000542839930858463 | total 0.000542839930858463
# Valid loss: physical 0.0 | data 0.0005790684372186661 | total 0.0005790684372186661
#
# Iteration: 99
# Train loss: physical 0.0 | data 0.0005644854390993714 | total 0.0005644854390993714
# Valid loss: physical 0.0 | data 0.0005448507727123797 | total 0.0005448507727123797
# New best model saved at iteration 99 with validation total loss 0.000545
#
# Iteration: 100
# Train loss: physical 0.0 | data 0.0005137398256920278 | total 0.0005137398256920278
# Valid loss: physical 0.0 | data 0.000556468206923455 | total 0.000556468206923455
#
# Iteration: 101
# Train loss: physical 0.0 | data 0.0005451955366879702 | total 0.0005451955366879702
# Valid loss: physical 0.0 | data 0.000542425608728081 | total 0.000542425608728081
# New best model saved at iteration 101 with validation total loss 0.000542
#
# Iteration: 102
# Train loss: physical 0.0 | data 0.0005340089555829763 | total 0.0005340089555829763
# Valid loss: physical 0.0 | data 0.0005430602468550205 | total 0.0005430602468550205
#
# Iteration: 103
# Train loss: physical 0.0 | data 0.0005260861362330616 | total 0.0005260861362330616
# Valid loss: physical 0.0 | data 0.0005396920023486018 | total 0.0005396920023486018
# New best model saved at iteration 103 with validation total loss 0.000540
#
# Iteration: 104
# Train loss: physical 0.0 | data 0.0005067365127615631 | total 0.0005067365127615631
# Valid loss: physical 0.0 | data 0.0005322374636307359 | total 0.0005322374636307359
# New best model saved at iteration 104 with validation total loss 0.000532
#
# Iteration: 105
# Train loss: physical 0.0 | data 0.0005156620754860342 | total 0.0005156620754860342
# Valid loss: physical 0.0 | data 0.0005223490879870951 | total 0.0005223490879870951
# New best model saved at iteration 105 with validation total loss 0.000522
#
# Iteration: 106
# Train loss: physical 0.0 | data 0.0004942783853039145 | total 0.0004942783853039145
# Valid loss: physical 0.0 | data 0.0005328953266143799 | total 0.0005328953266143799
#
# Iteration: 107
# Train loss: physical 0.0 | data 0.0005115367821417749 | total 0.0005115367821417749
# Valid loss: physical 0.0 | data 0.0005174779216758907 | total 0.0005174779216758907
# New best model saved at iteration 107 with validation total loss 0.000517
#
# Iteration: 108
# Train loss: physical 0.0 | data 0.0005061500705778599 | total 0.0005061500705778599
# Valid loss: physical 0.0 | data 0.0005231316899880767 | total 0.0005231316899880767
#
# Iteration: 109
# Train loss: physical 0.0 | data 0.0005008805892430246 | total 0.0005008805892430246
# Valid loss: physical 0.0 | data 0.0005123123410157859 | total 0.0005123123410157859
# New best model saved at iteration 109 with validation total loss 0.000512
#
# Iteration: 110
# Train loss: physical 0.0 | data 0.00048335822066292167 | total 0.00048335822066292167
# Valid loss: physical 0.0 | data 0.0005051398184150457 | total 0.0005051398184150457
# New best model saved at iteration 110 with validation total loss 0.000505
#
# Iteration: 111
# Train loss: physical 0.0 | data 0.0004888636758551002 | total 0.0004888636758551002
# Valid loss: physical 0.0 | data 0.0005213891272433102 | total 0.0005213891272433102
#
# Iteration: 112
# Train loss: physical 0.0 | data 0.0005124422023072839 | total 0.0005124422023072839
# Valid loss: physical 0.0 | data 0.0005098616820760071 | total 0.0005098616820760071
#
# Iteration: 113
# Train loss: physical 0.0 | data 0.0004734006361104548 | total 0.0004734006361104548
# Valid loss: physical 0.0 | data 0.0004978386568836868 | total 0.0004978386568836868
# New best model saved at iteration 113 with validation total loss 0.000498
#
# Iteration: 114
# Train loss: physical 0.0 | data 0.0004804248455911875 | total 0.0004804248455911875
# Valid loss: physical 0.0 | data 0.0004946784465573728 | total 0.0004946784465573728
# New best model saved at iteration 114 with validation total loss 0.000495
#
# Iteration: 115
# Train loss: physical 0.0 | data 0.0004690911155194044 | total 0.0004690911155194044
# Valid loss: physical 0.0 | data 0.0004935441538691521 | total 0.0004935441538691521
# New best model saved at iteration 115 with validation total loss 0.000494
#
# Iteration: 116
# Train loss: physical 0.0 | data 0.00047471318976022303 | total 0.00047471318976022303
# Valid loss: physical 0.0 | data 0.0004706261388491839 | total 0.0004706261388491839
# New best model saved at iteration 116 with validation total loss 0.000471
#
# Iteration: 117
# Train loss: physical 0.0 | data 0.0004598735540639609 | total 0.0004598735540639609
# Valid loss: physical 0.0 | data 0.00047809205716475844 | total 0.00047809205716475844
#
# Iteration: 118
# Train loss: physical 0.0 | data 0.00046712023322470486 | total 0.00046712023322470486
# Valid loss: physical 0.0 | data 0.0004654590447898954 | total 0.0004654590447898954
# New best model saved at iteration 118 with validation total loss 0.000465
#
# Iteration: 119
# Train loss: physical 0.0 | data 0.0004482311487663537 | total 0.0004482311487663537
# Valid loss: physical 0.0 | data 0.00045888422755524516 | total 0.00045888422755524516
# New best model saved at iteration 119 with validation total loss 0.000459
#
# Iteration: 120
# Train loss: physical 0.0 | data 0.0004306971386540681 | total 0.0004306971386540681
# Valid loss: physical 0.0 | data 0.00045148414210416377 | total 0.00045148414210416377
# New best model saved at iteration 120 with validation total loss 0.000451
#
# Iteration: 121
# Train loss: physical 0.0 | data 0.0004344356420915574 | total 0.0004344356420915574
# Valid loss: physical 0.0 | data 0.0004590050084516406 | total 0.0004590050084516406
#
# Iteration: 122
# Train loss: physical 0.0 | data 0.00043383592856116593 | total 0.00043383592856116593
# Valid loss: physical 0.0 | data 0.00043686418212018907 | total 0.00043686418212018907
# New best model saved at iteration 122 with validation total loss 0.000437
#
# Iteration: 123
# Train loss: physical 0.0 | data 0.00041452195728197694 | total 0.00041452195728197694
# Valid loss: physical 0.0 | data 0.0004323912435211241 | total 0.0004323912435211241
# New best model saved at iteration 123 with validation total loss 0.000432
#
# Iteration: 124
# Train loss: physical 0.0 | data 0.0004049293929710984 | total 0.0004049293929710984
# Valid loss: physical 0.0 | data 0.0004424680373631418 | total 0.0004424680373631418
#
# Iteration: 125
# Train loss: physical 0.0 | data 0.0004241126880515367 | total 0.0004241126880515367
# Valid loss: physical 0.0 | data 0.00041697881533764303 | total 0.00041697881533764303
# New best model saved at iteration 125 with validation total loss 0.000417
#
# Iteration: 126
# Train loss: physical 0.0 | data 0.0003969542740378529 | total 0.0003969542740378529
# Valid loss: physical 0.0 | data 0.0004277277912478894 | total 0.0004277277912478894
#
# Iteration: 127
# Train loss: physical 0.0 | data 0.0004108761204406619 | total 0.0004108761204406619
# Valid loss: physical 0.0 | data 0.000434620538726449 | total 0.000434620538726449
#
# Iteration: 128
# Train loss: physical 0.0 | data 0.0004065408429596573 | total 0.0004065408429596573
# Valid loss: physical 0.0 | data 0.00040272288606502116 | total 0.00040272288606502116
# New best model saved at iteration 128 with validation total loss 0.000403
#
# Iteration: 129
# Train loss: physical 0.0 | data 0.0003854145761579275 | total 0.0003854145761579275
# Valid loss: physical 0.0 | data 0.00040605664253234863 | total 0.00040605664253234863
#
# Iteration: 130
# Train loss: physical 0.0 | data 0.00038469763239845634 | total 0.00038469763239845634
# Valid loss: physical 0.0 | data 0.00040359501144848764 | total 0.00040359501144848764
#
# Iteration: 131
# Train loss: physical 0.0 | data 0.00037566618993878365 | total 0.00037566618993878365
# Valid loss: physical 0.0 | data 0.0003909558872692287 | total 0.0003909558872692287
# New best model saved at iteration 131 with validation total loss 0.000391
#
# Iteration: 132
# Train loss: physical 0.0 | data 0.0003838751290459186 | total 0.0003838751290459186
# Valid loss: physical 0.0 | data 0.0003804191655945033 | total 0.0003804191655945033
# New best model saved at iteration 132 with validation total loss 0.000380
#
# Iteration: 133
# Train loss: physical 0.0 | data 0.0003663525858428329 | total 0.0003663525858428329
# Valid loss: physical 0.0 | data 0.0003782847197726369 | total 0.0003782847197726369
# New best model saved at iteration 133 with validation total loss 0.000378
#
# Iteration: 134
# Train loss: physical 0.0 | data 0.00035730787203647196 | total 0.00035730787203647196
# Valid loss: physical 0.0 | data 0.0003746053553186357 | total 0.0003746053553186357
# New best model saved at iteration 134 with validation total loss 0.000375
#
# Iteration: 135
# Train loss: physical 0.0 | data 0.00035014707827940583 | total 0.00035014707827940583
# Valid loss: physical 0.0 | data 0.00036679930053651333 | total 0.00036679930053651333
# New best model saved at iteration 135 with validation total loss 0.000367
#
# Iteration: 136
# Train loss: physical 0.0 | data 0.0003424045571591705 | total 0.0003424045571591705
# Valid loss: physical 0.0 | data 0.0003601814096327871 | total 0.0003601814096327871
# New best model saved at iteration 136 with validation total loss 0.000360
#
# Iteration: 137
# Train loss: physical 0.0 | data 0.0003353185602463782 | total 0.0003353185602463782
# Valid loss: physical 0.0 | data 0.00035672722151502967 | total 0.00035672722151502967
# New best model saved at iteration 137 with validation total loss 0.000357
#
# Iteration: 138
# Train loss: physical 0.0 | data 0.0003414258826524019 | total 0.0003414258826524019
# Valid loss: physical 0.0 | data 0.0003537369193509221 | total 0.0003537369193509221
# New best model saved at iteration 138 with validation total loss 0.000354
#
# Iteration: 139
# Train loss: physical 0.0 | data 0.000319835206028074 | total 0.000319835206028074
# Valid loss: physical 0.0 | data 0.0003484619955997914 | total 0.0003484619955997914
# New best model saved at iteration 139 with validation total loss 0.000348
#
# Iteration: 140
# Train loss: physical 0.0 | data 0.000331718212692067 | total 0.000331718212692067
# Valid loss: physical 0.0 | data 0.00034322126884944737 | total 0.00034322126884944737
# New best model saved at iteration 140 with validation total loss 0.000343
#
# Iteration: 141
# Train loss: physical 0.0 | data 0.0003269258013460785 | total 0.0003269258013460785
# Valid loss: physical 0.0 | data 0.000334965530782938 | total 0.000334965530782938
# New best model saved at iteration 141 with validation total loss 0.000335
#
# Iteration: 142
# Train loss: physical 0.0 | data 0.0003032134263776243 | total 0.0003032134263776243
# Valid loss: physical 0.0 | data 0.0003297094372101128 | total 0.0003297094372101128
# New best model saved at iteration 142 with validation total loss 0.000330
#
# Iteration: 143
# Train loss: physical 0.0 | data 0.0003076612192671746 | total 0.0003076612192671746
# Valid loss: physical 0.0 | data 0.00033488034387119114 | total 0.00033488034387119114
#
# Iteration: 144
# Train loss: physical 0.0 | data 0.00032656113035045564 | total 0.00032656113035045564
# Valid loss: physical 0.0 | data 0.00031946535455062985 | total 0.00031946535455062985
# New best model saved at iteration 144 with validation total loss 0.000319
#
# Iteration: 145
# Train loss: physical 0.0 | data 0.0002811028389260173 | total 0.0002811028389260173
# Valid loss: physical 0.0 | data 0.0003033149987459183 | total 0.0003033149987459183
# New best model saved at iteration 145 with validation total loss 0.000303
#
# Iteration: 146
# Train loss: physical 0.0 | data 0.0002843964903149754 | total 0.0002843964903149754
# Valid loss: physical 0.0 | data 0.00030627756495960057 | total 0.00030627756495960057
#
# Iteration: 147
# Train loss: physical 0.0 | data 0.00028616967028938234 | total 0.00028616967028938234
# Valid loss: physical 0.0 | data 0.00029335732688196003 | total 0.00029335732688196003
# New best model saved at iteration 147 with validation total loss 0.000293
#
# Iteration: 148
# Train loss: physical 0.0 | data 0.00026757162413559854 | total 0.00026757162413559854
# Valid loss: physical 0.0 | data 0.00029997393721714616 | total 0.00029997393721714616
#
# Iteration: 149
# Train loss: physical 0.0 | data 0.0002660376485437155 | total 0.0002660376485437155
# Valid loss: physical 0.0 | data 0.0002780956856440753 | total 0.0002780956856440753
# New best model saved at iteration 149 with validation total loss 0.000278
#
# Iteration: 150
# Train loss: physical 0.0 | data 0.0002541209105402231 | total 0.0002541209105402231
# Valid loss: physical 0.0 | data 0.0002785277902148664 | total 0.0002785277902148664
#
# Iteration: 151
# Train loss: physical 0.0 | data 0.00025009139790199697 | total 0.00025009139790199697
# Valid loss: physical 0.0 | data 0.0002664439962245524 | total 0.0002664439962245524
# New best model saved at iteration 151 with validation total loss 0.000266
#
# Iteration: 152
# Train loss: physical 0.0 | data 0.00024499380378983915 | total 0.00024499380378983915
# Valid loss: physical 0.0 | data 0.0002650597016327083 | total 0.0002650597016327083
# New best model saved at iteration 152 with validation total loss 0.000265
#
# Iteration: 153
# Train loss: physical 0.0 | data 0.00023364050139207393 | total 0.00023364050139207393
# Valid loss: physical 0.0 | data 0.0002565553004387766 | total 0.0002565553004387766
# New best model saved at iteration 153 with validation total loss 0.000257
#
# Iteration: 154
# Train loss: physical 0.0 | data 0.00022247449669521302 | total 0.00022247449669521302
# Valid loss: physical 0.0 | data 0.0002542317961342633 | total 0.0002542317961342633
# New best model saved at iteration 154 with validation total loss 0.000254
#
# Iteration: 155
# Train loss: physical 0.0 | data 0.0002257303276564926 | total 0.0002257303276564926
# Valid loss: physical 0.0 | data 0.0002468841557856649 | total 0.0002468841557856649
# New best model saved at iteration 155 with validation total loss 0.000247
#
# Iteration: 156
# Train loss: physical 0.0 | data 0.00021784020646009594 | total 0.00021784020646009594
# Valid loss: physical 0.0 | data 0.00024843294522725046 | total 0.00024843294522725046
#
# Iteration: 157
# Train loss: physical 0.0 | data 0.00022025058569852263 | total 0.00022025058569852263
# Valid loss: physical 0.0 | data 0.000271109223831445 | total 0.000271109223831445
#
# Iteration: 158
# Train loss: physical 0.0 | data 0.0002317556063644588 | total 0.0002317556063644588
# Valid loss: physical 0.0 | data 0.00027783476980403066 | total 0.00027783476980403066
#
# Iteration: 159
# Train loss: physical 0.0 | data 0.00024522378225810826 | total 0.00024522378225810826
# Valid loss: physical 0.0 | data 0.00029803920187987387 | total 0.00029803920187987387
#
# Iteration: 160
# Train loss: physical 0.0 | data 0.0002587395429145545 | total 0.0002587395429145545
# Valid loss: physical 0.0 | data 0.0003220990765839815 | total 0.0003220990765839815
#
# Iteration: 161
# Train loss: physical 0.0 | data 0.00028045036015100777 | total 0.00028045036015100777
# Valid loss: physical 0.0 | data 0.00024714702158235013 | total 0.00024714702158235013
#
# Iteration: 162
# Train loss: physical 0.0 | data 0.00021948957873973995 | total 0.00021948957873973995
# Valid loss: physical 0.0 | data 0.00023998096003197134 | total 0.00023998096003197134
# New best model saved at iteration 162 with validation total loss 0.000240
#
# Iteration: 163
# Train loss: physical 0.0 | data 0.00020397976913955063 | total 0.00020397976913955063
# Valid loss: physical 0.0 | data 0.000251012243097648 | total 0.000251012243097648
#
# Iteration: 164
# Train loss: physical 0.0 | data 0.0002207373036071658 | total 0.0002207373036071658
# Valid loss: physical 0.0 | data 0.00022510552662424743 | total 0.00022510552662424743
# New best model saved at iteration 164 with validation total loss 0.000225
#
# Iteration: 165
# Train loss: physical 0.0 | data 0.00019747497572097927 | total 0.00019747497572097927
# Valid loss: physical 0.0 | data 0.00021802725677844137 | total 0.00021802725677844137
# New best model saved at iteration 165 with validation total loss 0.000218
#
# Iteration: 166
# Train loss: physical 0.0 | data 0.00018850318156182766 | total 0.00018850318156182766
# Valid loss: physical 0.0 | data 0.0002382359089097008 | total 0.0002382359089097008
#
# Iteration: 167
# Train loss: physical 0.0 | data 0.00021297522471286356 | total 0.00021297522471286356
# Valid loss: physical 0.0 | data 0.0002133713278453797 | total 0.0002133713278453797
# New best model saved at iteration 167 with validation total loss 0.000213
#
# Iteration: 168
# Train loss: physical 0.0 | data 0.00018834373622667044 | total 0.00018834373622667044
# Valid loss: physical 0.0 | data 0.0002038261154666543 | total 0.0002038261154666543
# New best model saved at iteration 168 with validation total loss 0.000204
#
# Iteration: 169
# Train loss: physical 0.0 | data 0.0001810919784475118 | total 0.0001810919784475118
# Valid loss: physical 0.0 | data 0.00020641191804315895 | total 0.00020641191804315895
#
# Iteration: 170
# Train loss: physical 0.0 | data 0.00017485585703980178 | total 0.00017485585703980178
# Valid loss: physical 0.0 | data 0.0002102449507219717 | total 0.0002102449507219717
#
# Iteration: 171
# Train loss: physical 0.0 | data 0.0001778920559445396 | total 0.0001778920559445396
# Valid loss: physical 0.0 | data 0.0002045725123025477 | total 0.0002045725123025477
#
# Iteration: 172
# Train loss: physical 0.0 | data 0.00017800452769733965 | total 0.00017800452769733965
# Valid loss: physical 0.0 | data 0.00018756010103970766 | total 0.00018756010103970766
# New best model saved at iteration 172 with validation total loss 0.000188
#
# Iteration: 173
# Train loss: physical 0.0 | data 0.0001545925479149446 | total 0.0001545925479149446
# Valid loss: physical 0.0 | data 0.00020268924708943814 | total 0.00020268924708943814
#
# Iteration: 174
# Train loss: physical 0.0 | data 0.000165991805261001 | total 0.000165991805261001
# Valid loss: physical 0.0 | data 0.0001790984533727169 | total 0.0001790984533727169
# New best model saved at iteration 174 with validation total loss 0.000179
#
# Iteration: 175
# Train loss: physical 0.0 | data 0.0001459158374927938 | total 0.0001459158374927938
# Valid loss: physical 0.0 | data 0.00018167095549870282 | total 0.00018167095549870282
#
# Iteration: 176
# Train loss: physical 0.0 | data 0.00015935239207465202 | total 0.00015935239207465202
# Valid loss: physical 0.0 | data 0.00018210787675343454 | total 0.00018210787675343454
#
# Iteration: 177
# Train loss: physical 0.0 | data 0.000160973533638753 | total 0.000160973533638753
# Valid loss: physical 0.0 | data 0.0001842228084569797 | total 0.0001842228084569797
#
# Iteration: 178
# Train loss: physical 0.0 | data 0.00016000344476196915 | total 0.00016000344476196915
# Valid loss: physical 0.0 | data 0.0001722738379612565 | total 0.0001722738379612565
# New best model saved at iteration 178 with validation total loss 0.000172
#
# Iteration: 179
# Train loss: physical 0.0 | data 0.00014024133270140737 | total 0.00014024133270140737
# Valid loss: physical 0.0 | data 0.0001546508865430951 | total 0.0001546508865430951
# New best model saved at iteration 179 with validation total loss 0.000155
#
# Iteration: 180
# Train loss: physical 0.0 | data 0.00012522476026788354 | total 0.00012522476026788354
# Valid loss: physical 0.0 | data 0.0001902441872516647 | total 0.0001902441872516647
#
# Iteration: 181
# Train loss: physical 0.0 | data 0.00016543031961191446 | total 0.00016543031961191446
# Valid loss: physical 0.0 | data 0.00018735925550572574 | total 0.00018735925550572574
#
# Iteration: 182
# Train loss: physical 0.0 | data 0.00014976790407672524 | total 0.00014976790407672524
# Valid loss: physical 0.0 | data 0.00015225810057017952 | total 0.00015225810057017952
# New best model saved at iteration 182 with validation total loss 0.000152
#
# Iteration: 183
# Train loss: physical 0.0 | data 0.00012210296699777246 | total 0.00012210296699777246
# Valid loss: physical 0.0 | data 0.0001456563186366111 | total 0.0001456563186366111
# New best model saved at iteration 183 with validation total loss 0.000146
#
# Iteration: 184
# Train loss: physical 0.0 | data 0.00012951612006872892 | total 0.00012951612006872892
# Valid loss: physical 0.0 | data 0.00018266114057041705 | total 0.00018266114057041705
#
# Iteration: 185
# Train loss: physical 0.0 | data 0.00015972212713677436 | total 0.00015972212713677436
# Valid loss: physical 0.0 | data 0.00014483416453003883 | total 0.00014483416453003883
# New best model saved at iteration 185 with validation total loss 0.000145
#
# Iteration: 186
# Train loss: physical 0.0 | data 0.00011936752707697451 | total 0.00011936752707697451
# Valid loss: physical 0.0 | data 0.00015521002933382988 | total 0.00015521002933382988
#
# Iteration: 187
# Train loss: physical 0.0 | data 0.00012963353947270662 | total 0.00012963353947270662
# Valid loss: physical 0.0 | data 0.0001548741856822744 | total 0.0001548741856822744
#
# Iteration: 188
# Train loss: physical 0.0 | data 0.00013102139928378165 | total 0.00013102139928378165
# Valid loss: physical 0.0 | data 0.00013418494199868292 | total 0.00013418494199868292
# New best model saved at iteration 188 with validation total loss 0.000134
#
# Iteration: 189
# Train loss: physical 0.0 | data 0.00010549754370003939 | total 0.00010549754370003939
# Valid loss: physical 0.0 | data 0.0001517709024483338 | total 0.0001517709024483338
#
# Iteration: 190
# Train loss: physical 0.0 | data 0.0001237082906300202 | total 0.0001237082906300202
# Valid loss: physical 0.0 | data 0.0001615141809452325 | total 0.0001615141809452325
#
# Iteration: 191
# Train loss: physical 0.0 | data 0.0001463233056711033 | total 0.0001463233056711033
# Valid loss: physical 0.0 | data 0.00011910387547686696 | total 0.00011910387547686696
# New best model saved at iteration 191 with validation total loss 0.000119
#
# Iteration: 192
# Train loss: physical 0.0 | data 9.558434976497665e-05 | total 9.558434976497665e-05
# Valid loss: physical 0.0 | data 0.00013380637392401695 | total 0.00013380637392401695
#
# Iteration: 193
# Train loss: physical 0.0 | data 0.00010430540714878589 | total 0.00010430540714878589
# Valid loss: physical 0.0 | data 0.0001283297169720754 | total 0.0001283297169720754
#
# Iteration: 194
# Train loss: physical 0.0 | data 0.0001046830220730044 | total 0.0001046830220730044
# Valid loss: physical 0.0 | data 0.00013101143122185022 | total 0.00013101143122185022
#
# Iteration: 195
# Train loss: physical 0.0 | data 0.000109726024675183 | total 0.000109726024675183
# Valid loss: physical 0.0 | data 0.00013552540622185916 | total 0.00013552540622185916
#
# Iteration: 196
# Train loss: physical 0.0 | data 0.0001108127471525222 | total 0.0001108127471525222
# Valid loss: physical 0.0 | data 0.00011684757191687822 | total 0.00011684757191687822
# New best model saved at iteration 196 with validation total loss 0.000117
#
# Iteration: 197
# Train loss: physical 0.0 | data 9.418721310794353e-05 | total 9.418721310794353e-05
# Valid loss: physical 0.0 | data 0.0001488256675656885 | total 0.0001488256675656885
#
# Iteration: 198
# Train loss: physical 0.0 | data 0.0001223167055286467 | total 0.0001223167055286467
# Valid loss: physical 0.0 | data 0.0001363287738058716 | total 0.0001363287738058716
#
# Iteration: 199
# Train loss: physical 0.0 | data 0.00011540847481228411 | total 0.00011540847481228411
# Valid loss: physical 0.0 | data 0.00015066241030581295 | total 0.00015066241030581295
#
# Iteration: 200
# Train loss: physical 0.0 | data 0.00012818071991205215 | total 0.00012818071991205215
# Valid loss: physical 0.0 | data 0.00010991894669132307 | total 0.00010991894669132307
# New best model saved at iteration 200 with validation total loss 0.000110
#
# Iteration: 201
# Train loss: physical 0.0 | data 8.313464786624536e-05 | total 8.313464786624536e-05
# Valid loss: physical 0.0 | data 0.0001225609885295853 | total 0.0001225609885295853
#
# Iteration: 202
# Train loss: physical 0.0 | data 0.00010491108696442097 | total 0.00010491108696442097
# Valid loss: physical 0.0 | data 0.00012667565897572786 | total 0.00012667565897572786
#
# Iteration: 203
# Train loss: physical 0.0 | data 0.00010166095307795331 | total 0.00010166095307795331
# Valid loss: physical 0.0 | data 0.00011406432167859748 | total 0.00011406432167859748
#
# Iteration: 204
# Train loss: physical 0.0 | data 9.047536877915263e-05 | total 9.047536877915263e-05
# Valid loss: physical 0.0 | data 0.0001264771563000977 | total 0.0001264771563000977
#
# Iteration: 205
# Train loss: physical 0.0 | data 9.486845374340191e-05 | total 9.486845374340191e-05
# Valid loss: physical 0.0 | data 0.00012067706120433286 | total 0.00012067706120433286
#
# Iteration: 206
# Train loss: physical 0.0 | data 9.499712905380875e-05 | total 9.499712905380875e-05
# Valid loss: physical 0.0 | data 0.00010376963473390788 | total 0.00010376963473390788
# New best model saved at iteration 206 with validation total loss 0.000104
#
# Iteration: 207
# Train loss: physical 0.0 | data 8.456697833025828e-05 | total 8.456697833025828e-05
# Valid loss: physical 0.0 | data 0.00010607481090119109 | total 0.00010607481090119109
#
# Iteration: 208
# Train loss: physical 0.0 | data 9.04876651475206e-05 | total 9.04876651475206e-05
# Valid loss: physical 0.0 | data 8.741547935642302e-05 | total 8.741547935642302e-05
# New best model saved at iteration 208 with validation total loss 0.000087
#
# Iteration: 209
# Train loss: physical 0.0 | data 6.134410068625584e-05 | total 6.134410068625584e-05
# Valid loss: physical 0.0 | data 9.793740173336118e-05 | total 9.793740173336118e-05
#
# Iteration: 210
# Train loss: physical 0.0 | data 8.073275967035443e-05 | total 8.073275967035443e-05
# Valid loss: physical 0.0 | data 9.505952766630799e-05 | total 9.505952766630799e-05
#
# Iteration: 211
# Train loss: physical 0.0 | data 8.135368261719123e-05 | total 8.135368261719123e-05
# Valid loss: physical 0.0 | data 9.754131315276027e-05 | total 9.754131315276027e-05
#
# Iteration: 212
# Train loss: physical 0.0 | data 7.853413262637332e-05 | total 7.853413262637332e-05
# Valid loss: physical 0.0 | data 9.27708824747242e-05 | total 9.27708824747242e-05
#
# Iteration: 213
# Train loss: physical 0.0 | data 7.093167369021103e-05 | total 7.093167369021103e-05
# Valid loss: physical 0.0 | data 0.0001131210956373252 | total 0.0001131210956373252
#
# Iteration: 214
# ...
# Valid loss: physical 0.0 | data 4.853259270021226e-06 | total 4.853259270021226e-06
#
# Iteration: 2916
# Train loss: physical 0.0 | data 2.755267303200526e-08 | total 2.755267303200526e-08
# Valid loss: physical 0.0 | data 4.844351224164711e-06 | total 4.844351224164711e-06
#
# Iteration: 2917
# Train loss: physical 0.0 | data 1.7383802841663965e-08 | total 1.7383802841663965e-08
# Valid loss: physical 0.0 | data 4.8475826588401105e-06 | total 4.8475826588401105e-06
#
# Iteration: 2918
# Train loss: physical 0.0 | data 2.0868748507041346e-08 | total 2.0868748507041346e-08
# Valid loss: physical 0.0 | data 4.8311171667592134e-06 | total 4.8311171667592134e-06
#
# Iteration: 2919
# Train loss: physical 0.0 | data 1.9014379404325155e-08 | total 1.9014379404325155e-08
# Valid loss: physical 0.0 | data 4.809618985746056e-06 | total 4.809618985746056e-06
#
# Iteration: 2920
# Train loss: physical 0.0 | data 1.6646179545887207e-08 | total 1.6646179545887207e-08
# Valid loss: physical 0.0 | data 4.840361725655384e-06 | total 4.840361725655384e-06
#
# Iteration: 2921
# Train loss: physical 0.0 | data 1.8143561320016488e-08 | total 1.8143561320016488e-08
# Valid loss: physical 0.0 | data 4.877168066741433e-06 | total 4.877168066741433e-06
#
# Iteration: 2922
# Train loss: physical 0.0 | data 1.7098068738619077e-08 | total 1.7098068738619077e-08
# Valid loss: physical 0.0 | data 4.8563742893747985e-06 | total 4.8563742893747985e-06
#
# Iteration: 2923
# Train loss: physical 0.0 | data 1.5659415097957208e-08 | total 1.5659415097957208e-08
# Valid loss: physical 0.0 | data 4.827206794288941e-06 | total 4.827206794288941e-06
#
# Iteration: 2924
# Train loss: physical 0.0 | data 1.7303330324125454e-08 | total 1.7303330324125454e-08
# Valid loss: physical 0.0 | data 4.83558369523962e-06 | total 4.83558369523962e-06
#
# Iteration: 2925
# Train loss: physical 0.0 | data 1.5822859467107264e-08 | total 1.5822859467107264e-08
# Valid loss: physical 0.0 | data 4.8651900215190835e-06 | total 4.8651900215190835e-06
#
# Iteration: 2926
# Train loss: physical 0.0 | data 1.4389719638074894e-08 | total 1.4389719638074894e-08
# Valid loss: physical 0.0 | data 4.8553688429819886e-06 | total 4.8553688429819886e-06
#
# Iteration: 2927
# Train loss: physical 0.0 | data 1.686795592092949e-08 | total 1.686795592092949e-08
# Valid loss: physical 0.0 | data 4.828671990253497e-06 | total 4.828671990253497e-06
#
# Iteration: 2928
# Train loss: physical 0.0 | data 1.4353592980853591e-08 | total 1.4353592980853591e-08
# Valid loss: physical 0.0 | data 4.831375463254517e-06 | total 4.831375463254517e-06
#
# Iteration: 2929
# Train loss: physical 0.0 | data 1.1743648720141664e-08 | total 1.1743648720141664e-08
# Valid loss: physical 0.0 | data 4.827099019166781e-06 | total 4.827099019166781e-06
#
# Iteration: 2930
# Train loss: physical 0.0 | data 1.3812001320445688e-08 | total 1.3812001320445688e-08
# Valid loss: physical 0.0 | data 4.8249207793560345e-06 | total 4.8249207793560345e-06
#
# Iteration: 2931
# Train loss: physical 0.0 | data 1.567868679330786e-08 | total 1.567868679330786e-08
# Valid loss: physical 0.0 | data 4.834941137232818e-06 | total 4.834941137232818e-06
#
# Iteration: 2932
# Train loss: physical 0.0 | data 1.2139831362389941e-08 | total 1.2139831362389941e-08
# Valid loss: physical 0.0 | data 4.841964255319908e-06 | total 4.841964255319908e-06
#
# Iteration: 2933
# Train loss: physical 0.0 | data 1.1053901793900422e-08 | total 1.1053901793900422e-08
# Valid loss: physical 0.0 | data 4.850878212891985e-06 | total 4.850878212891985e-06
#
# Iteration: 2934
# Train loss: physical 0.0 | data 1.3953138200406556e-08 | total 1.3953138200406556e-08
# Valid loss: physical 0.0 | data 4.863186859438429e-06 | total 4.863186859438429e-06
#
# Iteration: 2935
# Train loss: physical 0.0 | data 1.4222668376362435e-08 | total 1.4222668376362435e-08
# Valid loss: physical 0.0 | data 4.868837550020544e-06 | total 4.868837550020544e-06
#
# Iteration: 2936
# Train loss: physical 0.0 | data 1.060623056048371e-08 | total 1.060623056048371e-08
# Valid loss: physical 0.0 | data 4.863284175371518e-06 | total 4.863284175371518e-06
#
# Iteration: 2937
# Train loss: physical 0.0 | data 1.241164060417077e-08 | total 1.241164060417077e-08
# Valid loss: physical 0.0 | data 4.8898791646934114e-06 | total 4.8898791646934114e-06
#
# Iteration: 2938
# Train loss: physical 0.0 | data 1.726869136575715e-08 | total 1.726869136575715e-08
# Valid loss: physical 0.0 | data 4.852808160649147e-06 | total 4.852808160649147e-06
#
# Iteration: 2939
# Train loss: physical 0.0 | data 1.565647878010168e-08 | total 1.565647878010168e-08
# Valid loss: physical 0.0 | data 4.845485818805173e-06 | total 4.845485818805173e-06
#
# Iteration: 2940
# Train loss: physical 0.0 | data 1.0478774292721482e-08 | total 1.0478774292721482e-08
# Valid loss: physical 0.0 | data 4.847260242968332e-06 | total 4.847260242968332e-06
#
# Iteration: 2941
# Train loss: physical 0.0 | data 1.6508575839679906e-08 | total 1.6508575839679906e-08
# Valid loss: physical 0.0 | data 4.7925059334374964e-06 | total 4.7925059334374964e-06
#
# Iteration: 2942
# Train loss: physical 0.0 | data 1.9624813774044014e-08 | total 1.9624813774044014e-08
# Valid loss: physical 0.0 | data 4.810741302208044e-06 | total 4.810741302208044e-06
#
# Iteration: 2943
# Train loss: physical 0.0 | data 1.1973356528471868e-08 | total 1.1973356528471868e-08
# Valid loss: physical 0.0 | data 4.853913196711801e-06 | total 4.853913196711801e-06
#
# Iteration: 2944
# Train loss: physical 0.0 | data 1.6934558644265962e-08 | total 1.6934558644265962e-08
# Valid loss: physical 0.0 | data 4.827634256798774e-06 | total 4.827634256798774e-06
#
# Iteration: 2945
# Train loss: physical 0.0 | data 1.8366893783650085e-08 | total 1.8366893783650085e-08
# Valid loss: physical 0.0 | data 4.841665941057727e-06 | total 4.841665941057727e-06
#
# Iteration: 2946
# Train loss: physical 0.0 | data 1.3055968750563807e-08 | total 1.3055968750563807e-08
# Valid loss: physical 0.0 | data 4.87706392959808e-06 | total 4.87706392959808e-06
#
# Iteration: 2947
# Train loss: physical 0.0 | data 2.0246766041509545e-08 | total 2.0246766041509545e-08
# Valid loss: physical 0.0 | data 4.861454726778902e-06 | total 4.861454726778902e-06
#
# Iteration: 2948
# Train loss: physical 0.0 | data 1.7576434530042206e-08 | total 1.7576434530042206e-08
# Valid loss: physical 0.0 | data 4.812459792447044e-06 | total 4.812459792447044e-06
#
# Iteration: 2949
# Train loss: physical 0.0 | data 1.229924251333614e-08 | total 1.229924251333614e-08
# Valid loss: physical 0.0 | data 4.817368790099863e-06 | total 4.817368790099863e-06
#
# Iteration: 2950
# Train loss: physical 0.0 | data 1.6327907914615025e-08 | total 1.6327907914615025e-08
# Valid loss: physical 0.0 | data 4.838044787902618e-06 | total 4.838044787902618e-06
#
# Iteration: 2951
# Train loss: physical 0.0 | data 1.640069235975261e-08 | total 1.640069235975261e-08
# Valid loss: physical 0.0 | data 4.818842626264086e-06 | total 4.818842626264086e-06
#
# Iteration: 2952
# Train loss: physical 0.0 | data 1.4037458306859207e-08 | total 1.4037458306859207e-08
# Valid loss: physical 0.0 | data 4.835930667468347e-06 | total 4.835930667468347e-06
#
# Iteration: 2953
# Train loss: physical 0.0 | data 1.587461895269371e-08 | total 1.587461895269371e-08
# Valid loss: physical 0.0 | data 4.853516202274477e-06 | total 4.853516202274477e-06
#
# Iteration: 2954
# Train loss: physical 0.0 | data 1.2906038016069488e-08 | total 1.2906038016069488e-08
# Valid loss: physical 0.0 | data 4.846388037549332e-06 | total 4.846388037549332e-06
#
# Iteration: 2955
# Train loss: physical 0.0 | data 1.3596164194495941e-08 | total 1.3596164194495941e-08
# Valid loss: physical 0.0 | data 4.842317139264196e-06 | total 4.842317139264196e-06
#
# Iteration: 2956
# Train loss: physical 0.0 | data 1.554819206717184e-08 | total 1.554819206717184e-08
# Valid loss: physical 0.0 | data 4.840710516873514e-06 | total 4.840710516873514e-06
#
# Iteration: 2957
# Train loss: physical 0.0 | data 1.2612030531045093e-08 | total 1.2612030531045093e-08
# Valid loss: physical 0.0 | data 4.827533757634228e-06 | total 4.827533757634228e-06
#
# Iteration: 2958
# Train loss: physical 0.0 | data 1.3030260426205587e-08 | total 1.3030260426205587e-08
# Valid loss: physical 0.0 | data 4.827854354516603e-06 | total 4.827854354516603e-06
#
# Iteration: 2959
# Train loss: physical 0.0 | data 1.5145610987588043e-08 | total 1.5145610987588043e-08
# Valid loss: physical 0.0 | data 4.820417416340206e-06 | total 4.820417416340206e-06
#
# Iteration: 2960
# Train loss: physical 0.0 | data 1.3736150883403297e-08 | total 1.3736150883403297e-08
# Valid loss: physical 0.0 | data 4.82216364616761e-06 | total 4.82216364616761e-06
#
# Iteration: 2961
# Train loss: physical 0.0 | data 1.4094204914272268e-08 | total 1.4094204914272268e-08
# Valid loss: physical 0.0 | data 4.818198704015231e-06 | total 4.818198704015231e-06
#
# Iteration: 2962
# Train loss: physical 0.0 | data 1.4590296082417353e-08 | total 1.4590296082417353e-08
# Valid loss: physical 0.0 | data 4.814393378183013e-06 | total 4.814393378183013e-06
#
# Iteration: 2963
# Train loss: physical 0.0 | data 1.2323908116229632e-08 | total 1.2323908116229632e-08
# Valid loss: physical 0.0 | data 4.846940555580659e-06 | total 4.846940555580659e-06
#
# Iteration: 2964
# Train loss: physical 0.0 | data 1.3160536660450362e-08 | total 1.3160536660450362e-08
# Valid loss: physical 0.0 | data 4.838069344259566e-06 | total 4.838069344259566e-06
#
# Iteration: 2965
# Train loss: physical 0.0 | data 1.2631570456278496e-08 | total 1.2631570456278496e-08
# Valid loss: physical 0.0 | data 4.824682946491521e-06 | total 4.824682946491521e-06
#
# Iteration: 2966
# Train loss: physical 0.0 | data 1.2270729321528506e-08 | total 1.2270729321528506e-08
# Valid loss: physical 0.0 | data 4.8220049393421505e-06 | total 4.8220049393421505e-06
#
# Iteration: 2967
# Train loss: physical 0.0 | data 1.1817877343389682e-08 | total 1.1817877343389682e-08
# Valid loss: physical 0.0 | data 4.812292445421917e-06 | total 4.812292445421917e-06
#
# Iteration: 2968
# Train loss: physical 0.0 | data 1.1080699025001195e-08 | total 1.1080699025001195e-08
# Valid loss: physical 0.0 | data 4.814635758521035e-06 | total 4.814635758521035e-06
#
# Iteration: 2969
# Train loss: physical 0.0 | data 1.294874163448867e-08 | total 1.294874163448867e-08
# Valid loss: physical 0.0 | data 4.838069344259566e-06 | total 4.838069344259566e-06
#
# Iteration: 2970
# Train loss: physical 0.0 | data 1.1821183143467806e-08 | total 1.1821183143467806e-08
# Valid loss: physical 0.0 | data 4.831755632039858e-06 | total 4.831755632039858e-06
#
# Iteration: 2971
# Train loss: physical 0.0 | data 1.3866978676446706e-08 | total 1.3866978676446706e-08
# Valid loss: physical 0.0 | data 4.816406999452738e-06 | total 4.816406999452738e-06
#
# Iteration: 2972
# Train loss: physical 0.0 | data 2.1071230094094062e-08 | total 2.1071230094094062e-08
# Valid loss: physical 0.0 | data 4.839845132664777e-06 | total 4.839845132664777e-06
#
# Iteration: 2973
# Train loss: physical 0.0 | data 2.1011310025187413e-08 | total 2.1011310025187413e-08
# Valid loss: physical 0.0 | data 4.823653398489114e-06 | total 4.823653398489114e-06
#
# Iteration: 2974
# Train loss: physical 0.0 | data 1.3232624773706902e-08 | total 1.3232624773706902e-08
# Valid loss: physical 0.0 | data 4.818729848921066e-06 | total 4.818729848921066e-06
#
# Iteration: 2975
# Train loss: physical 0.0 | data 1.2085648926074555e-08 | total 1.2085648926074555e-08
# Valid loss: physical 0.0 | data 4.835514118894935e-06 | total 4.835514118894935e-06
#
# Iteration: 2976
# Train loss: physical 0.0 | data 1.546902517191029e-08 | total 1.546902517191029e-08
# Valid loss: physical 0.0 | data 4.844027898798231e-06 | total 4.844027898798231e-06
#
# Iteration: 2977
# Train loss: physical 0.0 | data 1.291618900722824e-08 | total 1.291618900722824e-08
# Valid loss: physical 0.0 | data 4.844609065912664e-06 | total 4.844609065912664e-06
#
# Iteration: 2978
# Train loss: physical 0.0 | data 1.1701979829581433e-08 | total 1.1701979829581433e-08
# Valid loss: physical 0.0 | data 4.8672850425646175e-06 | total 4.8672850425646175e-06
#
# Iteration: 2979
# Train loss: physical 0.0 | data 1.621922862682368e-08 | total 1.621922862682368e-08
# Valid loss: physical 0.0 | data 4.871074452239554e-06 | total 4.871074452239554e-06
#
# Iteration: 2980
# Train loss: physical 0.0 | data 1.774699676104774e-08 | total 1.774699676104774e-08
# Valid loss: physical 0.0 | data 4.876792445429601e-06 | total 4.876792445429601e-06
#
# Iteration: 2981
# Train loss: physical 0.0 | data 1.44004230762107e-08 | total 1.44004230762107e-08
# Valid loss: physical 0.0 | data 4.885242105956422e-06 | total 4.885242105956422e-06
#
# Iteration: 2982
# Train loss: physical 0.0 | data 1.4317628860283094e-08 | total 1.4317628860283094e-08
# Valid loss: physical 0.0 | data 4.892167908110423e-06 | total 4.892167908110423e-06
#
# Iteration: 2983
# Train loss: physical 0.0 | data 1.333203147879658e-08 | total 1.333203147879658e-08
# Valid loss: physical 0.0 | data 4.8790566324896645e-06 | total 4.8790566324896645e-06
#
# Iteration: 2984
# Train loss: physical 0.0 | data 1.1275204769845004e-08 | total 1.1275204769845004e-08
# Valid loss: physical 0.0 | data 4.866546532866778e-06 | total 4.866546532866778e-06
#
# Iteration: 2985
# Train loss: physical 0.0 | data 1.292196483149155e-08 | total 1.292196483149155e-08
# Valid loss: physical 0.0 | data 4.868239102506777e-06 | total 4.868239102506777e-06
#
# Iteration: 2986
# Train loss: physical 0.0 | data 1.4265220116271848e-08 | total 1.4265220116271848e-08
# Valid loss: physical 0.0 | data 4.8492252062715124e-06 | total 4.8492252062715124e-06
#
# Iteration: 2987
# Train loss: physical 0.0 | data 1.2461266685193095e-08 | total 1.2461266685193095e-08
# Valid loss: physical 0.0 | data 4.836251264350722e-06 | total 4.836251264350722e-06
#
# Iteration: 2988
# Train loss: physical 0.0 | data 1.1155199430845641e-08 | total 1.1155199430845641e-08
# Valid loss: physical 0.0 | data 4.8398364924651105e-06 | total 4.8398364924651105e-06
#
# Iteration: 2989
# Train loss: physical 0.0 | data 1.198413102088125e-08 | total 1.198413102088125e-08
# Valid loss: physical 0.0 | data 4.824401457881322e-06 | total 4.824401457881322e-06
#
# Iteration: 2990
# Train loss: physical 0.0 | data 1.2761065981692354e-08 | total 1.2761065981692354e-08
# Valid loss: physical 0.0 | data 4.842503130930709e-06 | total 4.842503130930709e-06
#
# Iteration: 2991
# Train loss: physical 0.0 | data 1.2403122973125846e-08 | total 1.2403122973125846e-08
# Valid loss: physical 0.0 | data 4.83988242194755e-06 | total 4.83988242194755e-06
#
# Iteration: 2992
# Train loss: physical 0.0 | data 1.0809492856367342e-08 | total 1.0809492856367342e-08
# Valid loss: physical 0.0 | data 4.8229903768515214e-06 | total 4.8229903768515214e-06
#
# Iteration: 2993
# Train loss: physical 0.0 | data 1.0749133139142941e-08 | total 1.0749133139142941e-08
# Valid loss: physical 0.0 | data 4.831525075132959e-06 | total 4.831525075132959e-06
#
# Iteration: 2994
# Train loss: physical 0.0 | data 1.2657494607992703e-08 | total 1.2657494607992703e-08
# Valid loss: physical 0.0 | data 4.838384938921081e-06 | total 4.838384938921081e-06
#
# Iteration: 2995
# Train loss: physical 0.0 | data 1.3472869042630009e-08 | total 1.3472869042630009e-08
# Valid loss: physical 0.0 | data 4.856581199419452e-06 | total 4.856581199419452e-06
#
# Iteration: 2996
# Train loss: physical 0.0 | data 1.3976666046744413e-08 | total 1.3976666046744413e-08
# Valid loss: physical 0.0 | data 4.841870122618275e-06 | total 4.841870122618275e-06
#
# Iteration: 2997
# Train loss: physical 0.0 | data 1.258647763791032e-08 | total 1.258647763791032e-08
# Valid loss: physical 0.0 | data 4.862641162617365e-06 | total 4.862641162617365e-06
#
# Iteration: 2998
# Train loss: physical 0.0 | data 1.174730357433873e-08 | total 1.174730357433873e-08
# Valid loss: physical 0.0 | data 4.845220246352255e-06 | total 4.845220246352255e-06
#
# Iteration: 2999
# Train loss: physical 0.0 | data 1.1696957180618028e-08 | total 1.1696957180618028e-08
# Valid loss: physical 0.0 | data 4.8255774345307145e-06 | total 4.8255774345307145e-06
#
# Iteration: 3000
# Train loss: physical 0.0 | data 1.0445545761683661e-08 | total 1.0445545761683661e-08
# Valid loss: physical 0.0 | data 4.828927558264695e-06 | total 4.828927558264695e-06

# %%
counter_indices = np.arange(1, len(loss_history['train_physical'])+1)
# plt.loglog(counter_indices, loss_history['train_physical'], label='Training Loss (Residual)', color='blue')
plt.loglog(counter_indices, loss_history['train_data'], label='Training Loss (Data)', color='red')
# plt.loglog(counter_indices, loss_history['valid_physical'], label='Validation Loss (Residual)', color='orange')
plt.loglog(counter_indices, loss_history['valid_data'], label='Validation Loss (Data)', color='green')
# plt.plot(counter_indices[-1], loss_history['train_physical'][-1], 'bo', markersize=5, label='Final training loss (Residual)')  # blue dot on last point
# plt.plot(best_model_iterations[-1], loss_history['valid_physical'][best_model_iterations[-1]-1], 'go', markersize=5, label='Lowest validation loss (Residual)')  # red dot for best model iteration
# plt.plot(best_model_iterations, [loss_history['valid_physical'][i-1] for i in best_model_iterations], 'gx', markersize=2, label='Best model saved (Residual)')  # green dots for best model iterations
plt.plot(counter_indices[-1], loss_history['train_data'][-1], 'bo', markersize=5, label='Final training loss (Data)')  # blue dot on last point
plt.plot(best_model_iterations[-1], loss_history['valid_data'][best_model_iterations[-1]-1], 'go', markersize=5, label='Lowest validation loss (Data)')  # red dot for best model iteration
plt.plot(best_model_iterations, [loss_history['valid_data'][i-1] for i in best_model_iterations], 'gx', markersize=2, label='Best model saved (Data)')  # green dots for best model iterations

# # Annotate the last value
# plt.annotate(f'{loss_history['train_physical'][-1]:.2e}',
#              xy=(counter_indices[-1], loss_history['train_physical'][-1]),
#              xytext=(-20, 20),
#              textcoords='offset points',
#              color='red',
#              fontsize=8,
#              arrowprops=dict(arrowstyle='->', color='red', lw=0.5))

# plt.annotate(f'{loss_history['valid_physical'][best_model_iterations[-1]-1]:.2e}',
#                 xy=(best_model_iterations[-1], loss_history['valid_physical'][best_model_iterations[-1]-1]),
#                 xytext=(-40, 30),
#                 textcoords='offset points',
#                 color='red',
#                 fontsize=8,
#                 arrowprops=dict(arrowstyle='->', color='red', lw=0.5))

# Annotate the last value
plt.annotate(f'{loss_history['train_data'][-1]:.2e}',
             xy=(counter_indices[-1], loss_history['train_data'][-1]),
             xytext=(-20, 30),
             textcoords='offset points',
             color='red',
             fontsize=8,
             arrowprops=dict(arrowstyle='->', color='red', lw=0.5))

plt.annotate(f'{loss_history['valid_data'][best_model_iterations[-1]-1]:.2e}',
                xy=(best_model_iterations[-1], loss_history['valid_data'][best_model_iterations[-1]-1]),
                xytext=(-20, 30),
                textcoords='offset points',
                color='red',
                fontsize=8,
                arrowprops=dict(arrowstyle='->', color='red', lw=0.5))


plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title(f'Loss history (num_train: {num_train} | num_valid: {num_valid})')
plt.legend()
plt.savefig(os.path.join(model_train_outputs_path, f'loss_history_{num_train}.png'), dpi=300, bbox_inches='tight')
plt.show()
plt.close()

# %%
model = ConvolutionalNN_129x129(output_dim=num_basis, activation='leakyrelu', init_func='xavier_uniform')
model.load_state_dict(torch.load(os.path.join(model_train_outputs_path, f"best_model_params_{num_train}.pth")))
model = model.to(device)

# %%
num_test = 500

test_p_dof = load_npy(test_dataset_path+'/p_dof.npy')[:num_test]
test_sigma_u_dof = load_npy(test_dataset_path+'/sigma_u_dof.npy')[:num_test]
test_p_vertex_values = load_npy(test_dataset_path+'/p_vertex_values.npy')[:num_test]

# %%
test_image_p_vertex_values = np.zeros((num_test, 1, mesh_args['num_y']+1, mesh_args['num_x']+1))
for i in tqdm(range(num_test)):
    test_image_p_vertex_values[i,0,:,:] = test_p_vertex_values[i].reshape(num_x+1, num_y+1).T
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 47473.73it/s]

# %%
test_p_vertex_values_tensor = torch.tensor(test_image_p_vertex_values, dtype=torch_dtype['float32']).to(device)

# %%
test_pod_coeff_pred  = model(test_p_vertex_values_tensor)
test_pod_coeff_pred = test_pod_coeff_pred.cpu().detach()
test_pred = test_pod_coeff_pred.to(torch.float64) @ pod_basis_dof.T
test_pred = test_pred.numpy()

# %%
np.save(os.path.join(model_test_outputs_path, "test_pred_sigma_u_dof.npy"), test_pred)

# %%
compute_squared_L2_norm = poisson_least_squares.compute_squared_L2_norm
compute_squared_hdiv_h1_norm = poisson_least_squares.compute_squared_hdiv_h1_norm

# %%
sigma_u_norm_dict = {
    'squared_L2': np.zeros(num_test),
    'avg_squared_L2': 0.0,
    'squared_hdiv_h1': np.zeros(num_test),
    'avg_squared_hdiv_h1': 0.0
}

# %%
for i in tqdm(range(num_test)):
    sigma_u_label_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_label_fc.x.array[:] = test_sigma_u_dof[i] 
    sigma_u_norm_dict['squared_L2'][i] = compute_squared_L2_norm(sigma_u_label_fc)
sigma_u_norm_dict['avg_squared_L2'] = np.mean(sigma_u_norm_dict['squared_L2'])
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 176.19it/s]

# %%
for i in tqdm(range(num_test)):
    sigma_u_label_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_label_fc.x.array[:] = test_sigma_u_dof[i]
    sigma_label_fc = sigma_u_label_fc.sub(0).collapse()
    u_label_fc = sigma_u_label_fc.sub(1).collapse()
    sigma_u_norm_dict['squared_hdiv_h1'][i] = compute_squared_hdiv_h1_norm(sigma_label_fc, u_label_fc)
sigma_u_norm_dict['avg_squared_hdiv_h1'] = np.mean(sigma_u_norm_dict['squared_hdiv_h1'])
# Out:
# 100%|██████████| 500/500 [00:07<00:00, 69.08it/s]

# %%
print(f"Average squared L2 norm of sigma_u: {sigma_u_norm_dict['avg_squared_L2']:.2e}")
print(f"Average squared H(div)xH1 norm of sigma_u: {sigma_u_norm_dict['avg_squared_hdiv_h1']:.2e}")
# Out:
# Average squared L2 norm of sigma_u: 2.54e-01
# Average squared H(div)xH1 norm of sigma_u: 1.43e+00

# %%
sigma_u_error_dict = {
    'squared_L2': np.zeros(num_test),
    'relative_squared_L2': np.zeros(num_test),
    'squared_hdiv_h1': np.zeros(num_test),
    'relative_squared_hdiv_h1': np.zeros(num_test)
}

# %%
for i in tqdm(range(num_test)):
    sigma_u_label_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_label_fc.x.array[:] = test_sigma_u_dof[i]
    sigma_label_fc = sigma_u_label_fc.sub(0).collapse()
    u_label_fc = sigma_u_label_fc.sub(1).collapse()

    sigma_u_pred_fc = dolfinx.fem.Function(Vh['sigma_u'])
    sigma_u_pred_fc.x.array[:] = test_pred[i]
    sigma_pred_fc = sigma_u_pred_fc.sub(0).collapse()
    u_pred_fc = sigma_u_pred_fc.sub(1).collapse()

    sigma_u_error_dict['squared_L2'][i] = compute_squared_L2_norm(sigma_u_label_fc - sigma_u_pred_fc)
    sigma_u_error_dict['relative_squared_L2'][i] = sigma_u_error_dict['squared_L2'][i] / sigma_u_norm_dict['avg_squared_L2']

    sigma_u_error_dict['squared_hdiv_h1'][i] = compute_squared_hdiv_h1_norm(sigma_label_fc - sigma_pred_fc, u_label_fc - u_pred_fc)
    sigma_u_error_dict['relative_squared_hdiv_h1'][i] = sigma_u_error_dict['squared_hdiv_h1'][i] / sigma_u_norm_dict['avg_squared_hdiv_h1']
# Out:
# 100%|██████████| 500/500 [00:18<00:00, 27.29it/s]

# %%
sigma_u_error_dict['bochner_L2'] = np.sqrt(np.mean(sigma_u_error_dict['squared_L2']))
sigma_u_error_dict['relative_bochner_L2'] = np.sqrt(np.mean(sigma_u_error_dict['relative_squared_L2']))
sigma_u_error_dict['bochner_hdiv_h1'] = np.sqrt(np.mean(sigma_u_error_dict['squared_hdiv_h1']))
sigma_u_error_dict['relative_bochner_hdiv_h1'] = np.sqrt(np.mean(sigma_u_error_dict['relative_squared_hdiv_h1']))

sigma_u_error_dict['std_L2'] = np.std(np.sqrt(sigma_u_error_dict['squared_L2']))
sigma_u_error_dict['std_relative_L2'] = np.std(np.sqrt(sigma_u_error_dict['relative_squared_L2']))
sigma_u_error_dict['std_hdiv_h1'] = np.std(np.sqrt(sigma_u_error_dict['squared_hdiv_h1']))
sigma_u_error_dict['std_relative_hdiv_h1'] = np.std(np.sqrt(sigma_u_error_dict['relative_squared_hdiv_h1']))

# %%
print(f'sigma_u relative Bochner L2 error (std): {sigma_u_error_dict["relative_bochner_L2"]:.2e} ({sigma_u_error_dict["std_relative_L2"]:.2e})')
print(f'sigma_u relative Bochner H(div) x H1 error (std): {sigma_u_error_dict["relative_bochner_hdiv_h1"]:.2e} ({sigma_u_error_dict["std_relative_hdiv_h1"]:.2e})')
# Out:
# sigma_u relative Bochner L2 error (std): 3.25e-02 (1.98e-02)
# sigma_u relative Bochner H(div) x H1 error (std): 2.01e-02 (1.25e-02)

# %%
np.save(os.path.join(model_test_outputs_path, "sigma_u_error_dict.npy"), sigma_u_error_dict)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
def plot_ref_pred_diff(x, y, ref_f_grid_evals, pred_f_grid_evals, diff_f_grid_evals, variable_name, 
                        levels=100, 
                        ref_pred_format='%.3f',
                        ref_pred_colorbar_pad=0.02, 
                        diff_colorbar_pad=0.01,
                        tick_labelsize=15,  # NEW: control tick font size
                        colorbar_labelsize=15):  # NEW: control colorbar tick font size

    vmin = min(ref_f_grid_evals.min(), pred_f_grid_evals.min())
    vmax = max(ref_f_grid_evals.max(), pred_f_grid_evals.max())

    fig, axs = plt.subplots(1, 3, figsize=(18, 5), constrained_layout=True)

    # Reference
    cf0 = axs[0].tricontourf(x, y, ref_f_grid_evals, levels=levels, cmap='turbo', vmin=vmin, vmax=vmax)
    axs[0].set_title(fr'Reference {variable_name}', fontsize=18)
    axs[0].tick_params(axis='both', which='major', labelsize=tick_labelsize)
    axs[0].set_xticklabels([])
    axs[0].set_yticklabels([])


    # Prediction
    cf1 = axs[1].tricontourf(x, y, pred_f_grid_evals, levels=levels, cmap='turbo', vmin=vmin, vmax=vmax)
    axs[1].set_title(fr'Prediction {variable_name}', fontsize=18)
    axs[1].tick_params(axis='both', which='major', labelsize=tick_labelsize)
    axs[1].set_xticklabels([])
    axs[1].set_yticklabels([])

    # Shared colorbar for first two subplots
    cbar_shared = fig.colorbar(cf1, ax=[axs[0], axs[1]], format=ref_pred_format, pad=ref_pred_colorbar_pad)
    cbar_shared.ax.tick_params(labelsize=colorbar_labelsize)  # Increase colorbar ticks
    cbar_shared.locator = ticker.MaxNLocator(nbins=5)
    cbar_shared.update_ticks()

    # Difference plot (independent colorbar)
    cf2 = axs[2].tricontourf(x, y, diff_f_grid_evals, levels=levels, cmap='turbo')
    axs[2].set_title(fr'Difference {variable_name}', fontsize=18)
    axs[2].tick_params(axis='both', which='major', labelsize=tick_labelsize)
    axs[2].set_xticklabels([])
    axs[2].set_yticklabels([])

    cbar_diff = fig.colorbar(cf2, ax=axs[2], pad=diff_colorbar_pad)
    cbar_diff.ax.tick_params(labelsize=colorbar_labelsize)  # Increase colorbar ticks
    cbar_diff.formatter = ticker.ScalarFormatter(useMathText=True)
    cbar_diff.formatter.set_scientific(True)
    cbar_diff.formatter.set_powerlimits((-2, 2))
    cbar_diff.locator = ticker.MaxNLocator(nbins=5)
    cbar_diff.update_ticks()

    cbar_diff.ax.yaxis.get_offset_text().set_fontsize(colorbar_labelsize)

    # Remove ticks on x and y axes if needed
    for ax in axs:
        ax.tick_params(left=False, bottom=False)

    return fig

# %%
for i in range(3):
    # plt.figure(figsize=(6, 5))  # Optional: larger figure size
    img = plt.imshow(test_p_vertex_values_tensor[i,0,:,:].cpu().numpy(),
                     extent=[0, 1, 0, 1], origin='lower', cmap='turbo')

    cbar = plt.colorbar()
    cbar.ax.tick_params(labelsize=16)  # Increase colorbar tick labels

    plt.title('parameter (setup 1)', fontsize=20)
    # plt.xticks(fontsize=16)
    # plt.yticks(fontsize=16)

    plt.savefig(os.path.join(model_test_outputs_path, f'test_p_{i}.png'),
                dpi=300, bbox_inches='tight')
    plt.close()

# %%
for test_sample_index in range(3):
    pred_sigma_u_fc = dolfinx.fem.Function(Vh['sigma_u'])
    pred_sigma_u_fc.x.array[:] = test_pred[test_sample_index]
    pred_sigma_fc = pred_sigma_u_fc.sub(0).collapse()
    pred_u_fc = pred_sigma_u_fc.sub(1).collapse()

    ref_sigma_u_fc = dolfinx.fem.Function(Vh['sigma_u'])
    ref_sigma_u_fc.x.array[:] = test_sigma_u_dof[test_sample_index]
    ref_sigma_fc = ref_sigma_u_fc.sub(0).collapse()
    ref_u_fc = ref_sigma_u_fc.sub(1).collapse()


    pred_sigma_grid_evals = evaluate_expression(mesh, pred_sigma_fc, mesh.geometry.x)[1]
    pred_u_grid_evals = evaluate_expression(mesh, pred_u_fc, mesh.geometry.x)[1]


    ref_sigma_grid_evals = evaluate_expression(mesh, ref_sigma_fc, mesh.geometry.x)[1]
    ref_u_grid_evals = evaluate_expression(mesh, ref_u_fc, mesh.geometry.x)[1]


    diff_sigma_grid_evals = pred_sigma_grid_evals - ref_sigma_grid_evals
    diff_u_grid_evals = pred_u_grid_evals - ref_u_grid_evals

    x = mesh.geometry.x[:, 0]
    y = mesh.geometry.x[:, 1]


    fig = plot_ref_pred_diff(x, y, ref_u_grid_evals[:,0], pred_u_grid_evals[:,0], diff_u_grid_evals[:,0], r'$u^{\circ}$',
                            levels=100,
                            ref_pred_format='%.3f',
                            ref_pred_colorbar_pad=0.01,
                            diff_colorbar_pad=-0.01)
    fig.savefig(os.path.join(model_test_outputs_path, f'u_ref_pred_diff_{test_sample_index}.png'), dpi=300, bbox_inches='tight')


    fig = plot_ref_pred_diff(x, y, ref_sigma_grid_evals[:,0], pred_sigma_grid_evals[:, 0], diff_sigma_grid_evals[:, 0], r'$\sigma_1^{\circ}$', 
                            levels=100,
                            ref_pred_format='%.1f',
                            ref_pred_colorbar_pad=0.01, 
                            diff_colorbar_pad=-0.01)
    fig.savefig(os.path.join(model_test_outputs_path, f'sigma_1_ref_pred_diff_{test_sample_index}.png'), dpi=300, bbox_inches='tight')


    fig = plot_ref_pred_diff(x, y, ref_sigma_grid_evals[:,1], pred_sigma_grid_evals[:, 1], diff_sigma_grid_evals[:, 1], r'$\sigma_2^{\circ}$', 
                            levels=100,
                            ref_pred_format='%.1f',
                            ref_pred_colorbar_pad=0.01, 
                            diff_colorbar_pad=-0.01)
    fig.savefig(os.path.join(model_test_outputs_path, f'sigma_2_ref_pred_diff_{test_sample_index}.png'), dpi=300, bbox_inches='tight')

# %%
compute_physical_loss_1 = poisson_least_squares.compute_physical_loss_1
compute_physical_loss_2 = poisson_least_squares.compute_physical_loss_2

# %%
residual_loss_dict = {
    'loss_1': np.zeros(num_test),
    'loss_2': np.zeros(num_test),
    'total_loss': np.zeros(num_test),
    'sqrt_total_loss': np.zeros(num_test)
}
for test_index in range(num_test): 
    pred_fc = dolfinx.fem.Function(Vh['sigma_u'])
    pred_fc.x.array[:] = test_pred[test_index]
    pred_sigma_fc = pred_fc.sub(0).collapse()
    pred_u_fc = pred_fc.sub(1).collapse()

    p_fc = dolfinx.fem.Function(Vh['p'])
    p_fc.x.array[:] = test_p_dof[test_index]

    residual_loss_1 = compute_physical_loss_1(pred_sigma_fc, pred_u_fc, p_fc)
    residual_loss_2 = compute_physical_loss_2(pred_sigma_fc, pred_u_fc, p_fc)

    residual_loss = residual_loss_1 + residual_loss_2

    sqrt_residual_loss = np.sqrt(residual_loss)

    residual_loss_dict['loss_1'][test_index] = residual_loss_1
    residual_loss_dict['loss_2'][test_index] = residual_loss_2
    residual_loss_dict['total_loss'][test_index] = residual_loss
    residual_loss_dict['sqrt_total_loss'][test_index] = sqrt_residual_loss
    print(f'Test sample {test_index}:')
    print(f'Residual loss 1: {residual_loss_1} | Residual loss 2: {residual_loss_2}')
    print(f'Total residual loss: {residual_loss} | Sqrt residual loss: {sqrt_residual_loss}')

    print("")
# Out:
# Test sample 0:
# Residual loss 1: 0.0005556774644494385 | Residual loss 2: 2.9867704915655556e-06
# Total residual loss: 0.0005586642349410041 | Sqrt residual loss: 0.023636079094067276
#
# Test sample 1:
# Residual loss 1: 0.0018435760512649408 | Residual loss 2: 3.062457797913293e-06
# Total residual loss: 0.0018466385090628542 | Sqrt residual loss: 0.04297253202992412
#
# Test sample 2:
# Residual loss 1: 0.0007144804716937157 | Residual loss 2: 1.46503223143153e-05
# Total residual loss: 0.000729130794008031 | Sqrt residual loss: 0.027002422002628413
#
# Test sample 3:
# Residual loss 1: 0.0015580588846832147 | Residual loss 2: 8.967179856285639e-07
# Total residual loss: 0.0015589556026688433 | Sqrt residual loss: 0.03948361182400672
#
# Test sample 4:
# Residual loss 1: 0.0006058625572988025 | Residual loss 2: 2.5677301757899534e-06
# Total residual loss: 0.0006084302874745924 | Sqrt residual loss: 0.024666379699392296
#
# Test sample 5:
# Residual loss 1: 0.005759027763799538 | Residual loss 2: 6.747229228306495e-10
# Total residual loss: 0.005759028438522461 | Sqrt residual loss: 0.0758882628508682
#
# Test sample 6:
# Residual loss 1: 0.00042053997853593543 | Residual loss 2: 6.7516664837627004e-09
# Total residual loss: 0.0004205467302024192 | Sqrt residual loss: 0.02050723604492861
#
# Test sample 7:
# Residual loss 1: 0.0007964477188915569 | Residual loss 2: 2.2368225798063213e-06
# Total residual loss: 0.0007986845414713632 | Sqrt residual loss: 0.02826100743907342
#
# Test sample 8:
# Residual loss 1: 0.003055692386544121 | Residual loss 2: 1.2083019220551111e-05
# Total residual loss: 0.003067775405764672 | Sqrt residual loss: 0.055387502252445646
#
# Test sample 9:
# Residual loss 1: 0.007099465755871788 | Residual loss 2: 1.7595520592224203e-05
# Total residual loss: 0.007117061276464012 | Sqrt residual loss: 0.08436267703471727
#
# Test sample 10:
# Residual loss 1: 0.002700754328744396 | Residual loss 2: 7.075753190895426e-08
# Total residual loss: 0.0027008250862763047 | Sqrt residual loss: 0.051969463017009374
#
# Test sample 11:
# Residual loss 1: 0.0022178477001329774 | Residual loss 2: 1.0853162378952402e-05
# Total residual loss: 0.0022287008625119296 | Sqrt residual loss: 0.047209118425489895
#
# Test sample 12:
# Residual loss 1: 0.00018850215225418753 | Residual loss 2: 1.262047105808066e-08
# Total residual loss: 0.0001885147727252456 | Sqrt residual loss: 0.013730068198127991
#
# Test sample 13:
# Residual loss 1: 0.0013600473686294823 | Residual loss 2: 8.68146965818408e-07
# Total residual loss: 0.0013609155155953007 | Sqrt residual loss: 0.036890588441976645
#
# Test sample 14:
# Residual loss 1: 0.006000072402982891 | Residual loss 2: 1.8774086234325048e-06
# Total residual loss: 0.006001949811606324 | Sqrt residual loss: 0.0774722518816016
#
# Test sample 15:
# Residual loss 1: 0.001635821756944627 | Residual loss 2: 2.821535808163052e-07
# Total residual loss: 0.0016361039105254433 | Sqrt residual loss: 0.04044878132311829
#
# Test sample 16:
# Residual loss 1: 0.0020583067548350918 | Residual loss 2: 1.3417602395111267e-06
# Total residual loss: 0.002059648515074603 | Sqrt residual loss: 0.04538335063737144
#
# Test sample 17:
# Residual loss 1: 0.0006724789866247911 | Residual loss 2: 8.057205725430393e-08
# Total residual loss: 0.0006725595586820454 | Sqrt residual loss: 0.02593375327024697
#
# Test sample 18:
# Residual loss 1: 0.0006740525235316462 | Residual loss 2: 1.754581859452133e-06
# Total residual loss: 0.0006758071053910982 | Sqrt residual loss: 0.025996290223628028
#
# Test sample 19:
# Residual loss 1: 0.0003617109897344173 | Residual loss 2: 4.109764314506796e-06
# Total residual loss: 0.0003658207540489241 | Sqrt residual loss: 0.019126441228020544
#
# Test sample 20:
# Residual loss 1: 0.0015702249017461828 | Residual loss 2: 4.236390577393219e-06
# Total residual loss: 0.001574461292323576 | Sqrt residual loss: 0.0396794820067447
#
# Test sample 21:
# Residual loss 1: 0.0013592775480904384 | Residual loss 2: 1.2583346637400263e-05
# Total residual loss: 0.0013718608947278386 | Sqrt residual loss: 0.03703864056263187
#
# Test sample 22:
# Residual loss 1: 0.001268949001986717 | Residual loss 2: 1.1482896606262616e-05
# Total residual loss: 0.0012804318985929796 | Sqrt residual loss: 0.035783123097250465
#
# Test sample 23:
# Residual loss 1: 0.0007699748718281886 | Residual loss 2: 5.111148120806857e-06
# Total residual loss: 0.0007750860199489955 | Sqrt residual loss: 0.027840366735174225
#
# Test sample 24:
# Residual loss 1: 0.0020824015509160626 | Residual loss 2: 5.330310755314413e-07
# Total residual loss: 0.002082934581991594 | Sqrt residual loss: 0.04563917814763533
#
# Test sample 25:
# Residual loss 1: 0.0014624464488232612 | Residual loss 2: 4.553519144256393e-07
# Total residual loss: 0.0014629018007376868 | Sqrt residual loss: 0.03824789929836261
#
# Test sample 26:
# Residual loss 1: 0.0006558324331720557 | Residual loss 2: 1.6898247217932992e-06
# Total residual loss: 0.000657522257893849 | Sqrt residual loss: 0.02564219682269538
#
# Test sample 27:
# Residual loss 1: 0.0010222628887342957 | Residual loss 2: 4.548533579998889e-06
# Total residual loss: 0.0010268114223142945 | Sqrt residual loss: 0.03204389836324997
#
# Test sample 28:
# Residual loss 1: 0.0005401262227358198 | Residual loss 2: 5.781390721292469e-06
# Total residual loss: 0.0005459076134571124 | Sqrt residual loss: 0.023364665917943537
#
# Test sample 29:
# Residual loss 1: 0.0016238765141686634 | Residual loss 2: 6.65229600584104e-06
# Total residual loss: 0.0016305288101745043 | Sqrt residual loss: 0.0403798069605899
#
# Test sample 30:
# Residual loss 1: 0.0033184611172421222 | Residual loss 2: 4.8519600926912944e-08
# Total residual loss: 0.003318509636843049 | Sqrt residual loss: 0.057606506896730414
#
# Test sample 31:
# Residual loss 1: 0.001388838129476212 | Residual loss 2: 5.063047397747768e-06
# Total residual loss: 0.0013939011768739598 | Sqrt residual loss: 0.03733498596322168
#
# Test sample 32:
# Residual loss 1: 0.002824961807728675 | Residual loss 2: 1.0088522407630249e-05
# Total residual loss: 0.0028350503301363054 | Sqrt residual loss: 0.05324519067611934
#
# Test sample 33:
# Residual loss 1: 0.00417615231922717 | Residual loss 2: 9.581547863051036e-06
# Total residual loss: 0.0041857338670902204 | Sqrt residual loss: 0.06469724775514195
#
# Test sample 34:
# Residual loss 1: 0.0060938172399543685 | Residual loss 2: 1.1907291021860906e-05
# Total residual loss: 0.006105724530976229 | Sqrt residual loss: 0.07813913571940906
#
# Test sample 35:
# Residual loss 1: 0.0003978149106124092 | Residual loss 2: 5.381303563115588e-09
# Total residual loss: 0.0003978202919159723 | Sqrt residual loss: 0.01994543285857623
#
# Test sample 36:
# Residual loss 1: 0.0015108200140278479 | Residual loss 2: 9.373078045660518e-07
# Total residual loss: 0.0015117573218324139 | Sqrt residual loss: 0.038881323560707316
#
# Test sample 37:
# Residual loss 1: 0.0006442062717585945 | Residual loss 2: 1.2350147409679022e-05
# Total residual loss: 0.0006565564191682735 | Sqrt residual loss: 0.02562335690670279
#
# Test sample 38:
# Residual loss 1: 0.0037727013135839833 | Residual loss 2: 4.283838997187206e-06
# Total residual loss: 0.0037769851525811704 | Sqrt residual loss: 0.06145718145653257
#
# Test sample 39:
# Residual loss 1: 0.00032146153733309506 | Residual loss 2: 3.547372691867587e-07
# Total residual loss: 0.00032181627460228183 | Sqrt residual loss: 0.01793923840641742
#
# Test sample 40:
# Residual loss 1: 0.0009589449857985896 | Residual loss 2: 2.353184681591509e-06
# Total residual loss: 0.000961298170480181 | Sqrt residual loss: 0.03100480882831212
#
# Test sample 41:
# Residual loss 1: 0.0019476169168462089 | Residual loss 2: 8.116789131197833e-06
# Total residual loss: 0.0019557337059774066 | Sqrt residual loss: 0.04422367811452827
#
# Test sample 42:
# Residual loss 1: 0.002467684084733076 | Residual loss 2: 8.050568170031632e-06
# Total residual loss: 0.0024757346529031077 | Sqrt residual loss: 0.04975675484698643
#
# Test sample 43:
# Residual loss 1: 0.0018628103191636158 | Residual loss 2: 9.522846055268436e-06
# Total residual loss: 0.0018723331652188843 | Sqrt residual loss: 0.043270465276200626
#
# Test sample 44:
# Residual loss 1: 0.0010289291948630261 | Residual loss 2: 1.5928048461104756e-06
# Total residual loss: 0.0010305219997091366 | Sqrt residual loss: 0.0321017444963531
#
# Test sample 45:
# Residual loss 1: 0.002956614401182683 | Residual loss 2: 1.8141289348909465e-05
# Total residual loss: 0.0029747556905315928 | Sqrt residual loss: 0.05454132094597263
#
# Test sample 46:
# Residual loss 1: 0.000807259603970977 | Residual loss 2: 2.4042420400270514e-07
# Total residual loss: 0.0008075000281749798 | Sqrt residual loss: 0.028416544972515216
#
# Test sample 47:
# Residual loss 1: 0.0036926653985383255 | Residual loss 2: 1.798030329689959e-06
# Total residual loss: 0.0036944634288680156 | Sqrt residual loss: 0.060782097930788925
#
# Test sample 48:
# Residual loss 1: 0.0003674031124691646 | Residual loss 2: 5.7343849028566546e-06
# Total residual loss: 0.0003731374973720213 | Sqrt residual loss: 0.019316767259870925
#
# Test sample 49:
# Residual loss 1: 0.001298673170494526 | Residual loss 2: 8.949351111291458e-08
# Total residual loss: 0.0012987626640056388 | Sqrt residual loss: 0.036038349906809534
#
# Test sample 50:
# Residual loss 1: 0.0005514750640718488 | Residual loss 2: 1.1180320677935264e-06
# Total residual loss: 0.0005525930961396423 | Sqrt residual loss: 0.02350729878441252
#
# Test sample 51:
# Residual loss 1: 0.0005505079474882385 | Residual loss 2: 9.150232968677579e-07
# Total residual loss: 0.0005514229707851063 | Sqrt residual loss: 0.023482397040870982
#
# Test sample 52:
# Residual loss 1: 0.0011480946206147392 | Residual loss 2: 4.9711771451240595e-08
# Total residual loss: 0.0011481443323861904 | Sqrt residual loss: 0.0338842785430971
#
# Test sample 53:
# Residual loss 1: 0.0012069399257457019 | Residual loss 2: 7.056152169915572e-10
# Total residual loss: 0.001206940631360919 | Sqrt residual loss: 0.03474105109752609
#
# Test sample 54:
# Residual loss 1: 0.0015180641309543706 | Residual loss 2: 1.335090524098128e-05
# Total residual loss: 0.0015314150361953518 | Sqrt residual loss: 0.03913329830458138
#
# Test sample 55:
# Residual loss 1: 0.00044379432109687594 | Residual loss 2: 1.163554568185959e-06
# Total residual loss: 0.0004449578756650619 | Sqrt residual loss: 0.02109402464360611
#
# Test sample 56:
# Residual loss 1: 0.0017830908889969995 | Residual loss 2: 1.6767131446714733e-06
# Total residual loss: 0.001784767602141671 | Sqrt residual loss: 0.042246509940368694
#
# Test sample 57:
# Residual loss 1: 0.0030234011484788583 | Residual loss 2: 9.83702560369369e-07
# Total residual loss: 0.0030243848510392276 | Sqrt residual loss: 0.05499440745238762
#
# Test sample 58:
# Residual loss 1: 0.0008817576173182782 | Residual loss 2: 1.561084179451746e-07
# Total residual loss: 0.0008819137257362234 | Sqrt residual loss: 0.029697032271528808
#
# Test sample 59:
# Residual loss 1: 0.002458776802237365 | Residual loss 2: 1.5319870898634585e-07
# Total residual loss: 0.0024589300009463513 | Sqrt residual loss: 0.04958759926580789
# Test sample 60:
# Residual loss 1: 0.0027066589671546817 | Residual loss 2: 1.3630846908718983e-05
# Total residual loss: 0.0027202898140634008 | Sqrt residual loss: 0.052156397633113055
#
# Test sample 61:
# Residual loss 1: 0.001355441581125543 | Residual loss 2: 1.3185107714766261e-07
# Total residual loss: 0.0013555734322026906 | Sqrt residual loss: 0.036818112827828244
#
# Test sample 62:
# Residual loss 1: 0.008249282693366526 | Residual loss 2: 2.0355877901663475e-06
# Total residual loss: 0.008251318281156692 | Sqrt residual loss: 0.09083676723197877
#
# Test sample 63:
# Residual loss 1: 0.0004585082153881312 | Residual loss 2: 2.3528017528068257e-06
# Total residual loss: 0.00046086101714093805 | Sqrt residual loss: 0.021467673771066533
#
# Test sample 64:
# Residual loss 1: 0.0007308752392202951 | Residual loss 2: 3.1015962629858657e-06
# Total residual loss: 0.000733976835483281 | Sqrt residual loss: 0.027092006855958105
#
# Test sample 65:
# Residual loss 1: 0.0004993418436606882 | Residual loss 2: 5.555664929284327e-06
# Total residual loss: 0.0005048975085899726 | Sqrt residual loss: 0.022469924534585614
#
# Test sample 66:
# Residual loss 1: 0.00037307671678780675 | Residual loss 2: 1.1192629157421752e-06
# Total residual loss: 0.00037419597970354894 | Sqrt residual loss: 0.019344145876816297
#
# Test sample 67:
# Residual loss 1: 0.005751231283103411 | Residual loss 2: 6.91281247045363e-06
# Total residual loss: 0.0057581440955738646 | Sqrt residual loss: 0.07588243601502172
#
# Test sample 68:
# Residual loss 1: 0.0016160195740788591 | Residual loss 2: 2.4787162585790756e-05
# Total residual loss: 0.00164080673666465 | Sqrt residual loss: 0.040506872709018774
#
# Test sample 69:
# Residual loss 1: 0.000535020830338826 | Residual loss 2: 2.688100494174088e-07
# Total residual loss: 0.0005352896403882434 | Sqrt residual loss: 0.023136327288233182
#
# Test sample 70:
# Residual loss 1: 0.0007969287356711895 | Residual loss 2: 6.741877222639974e-06
# Total residual loss: 0.0008036706128938295 | Sqrt residual loss: 0.028349084868718944
#
# Test sample 71:
# Residual loss 1: 0.0006151765169461287 | Residual loss 2: 2.397513901367424e-07
# Total residual loss: 0.0006154162683362655 | Sqrt residual loss: 0.024807584895274782
#
# Test sample 72:
# Residual loss 1: 0.0013255652528661819 | Residual loss 2: 1.795429737924474e-06
# Total residual loss: 0.0013273606826041064 | Sqrt residual loss: 0.03643296148550247
#
# Test sample 73:
# Residual loss 1: 0.00040769792143313704 | Residual loss 2: 6.193379620999276e-06
# Total residual loss: 0.0004138913010541363 | Sqrt residual loss: 0.020344318643152844
#
# Test sample 74:
# Residual loss 1: 0.0007201659554650013 | Residual loss 2: 2.0179247754860177e-06
# Total residual loss: 0.0007221838802404873 | Sqrt residual loss: 0.02687347912423115
#
# Test sample 75:
# Residual loss 1: 0.0006874954725990257 | Residual loss 2: 4.65058899888774e-07
# Total residual loss: 0.0006879605314989145 | Sqrt residual loss: 0.026229001725168927
#
# Test sample 76:
# Residual loss 1: 0.0005786187630499269 | Residual loss 2: 1.3883980658002106e-07
# Total residual loss: 0.0005787576028565069 | Sqrt residual loss: 0.02405738146300438
#
# Test sample 77:
# Residual loss 1: 0.0011359476042454434 | Residual loss 2: 1.4828929968015041e-05
# Total residual loss: 0.0011507765342134585 | Sqrt residual loss: 0.033923097355834986
#
# Test sample 78:
# Residual loss 1: 0.0026098861405067144 | Residual loss 2: 1.0820211721109476e-07
# Total residual loss: 0.0026099943426239254 | Sqrt residual loss: 0.05108810372898886
#
# Test sample 79:
# Residual loss 1: 0.0011011284413724597 | Residual loss 2: 2.992788439543582e-06
# Total residual loss: 0.0011041212298120032 | Sqrt residual loss: 0.033228319695885966
#
# Test sample 80:
# Residual loss 1: 0.0013585174886963185 | Residual loss 2: 1.2565840979189941e-07
# Total residual loss: 0.0013586431471061104 | Sqrt residual loss: 0.036859776818452254
#
# Test sample 81:
# Residual loss 1: 0.0012186427734724168 | Residual loss 2: 1.956945615034383e-05
# Total residual loss: 0.0012382122296227607 | Sqrt residual loss: 0.03518823993357384
#
# Test sample 82:
# Residual loss 1: 0.001076365098432108 | Residual loss 2: 3.7503220242995856e-06
# Total residual loss: 0.0010801154204564077 | Sqrt residual loss: 0.03286510946971587
#
# Test sample 83:
# Residual loss 1: 0.0021836944366422366 | Residual loss 2: 1.2798798314215213e-06
# Total residual loss: 0.002184974316473658 | Sqrt residual loss: 0.046743708843796916
#
# Test sample 84:
# Residual loss 1: 0.00028332118942124367 | Residual loss 2: 1.6355744598170427e-06
# Total residual loss: 0.00028495676388106073 | Sqrt residual loss: 0.016880662424237407
#
# Test sample 85:
# Residual loss 1: 0.0035147106175443077 | Residual loss 2: 1.6667438569344486e-06
# Total residual loss: 0.003516377361401242 | Sqrt residual loss: 0.05929905025716046
#
# Test sample 86:
# Residual loss 1: 0.0020777577366582005 | Residual loss 2: 3.542741570691814e-06
# Total residual loss: 0.002081300478228892 | Sqrt residual loss: 0.04562127221186288
#
# Test sample 87:
# Residual loss 1: 0.0019076225013265424 | Residual loss 2: 5.080551365957541e-06
# Total residual loss: 0.0019127030526925 | Sqrt residual loss: 0.04373446069968738
#
# Test sample 88:
# Residual loss 1: 0.0004952115326510856 | Residual loss 2: 4.6873609098205265e-07
# Total residual loss: 0.0004956802687420676 | Sqrt residual loss: 0.022263878115505117
#
# Test sample 89:
# Residual loss 1: 0.00046856506757057755 | Residual loss 2: 4.0368635843040496e-06
# Total residual loss: 0.0004726019311548816 | Sqrt residual loss: 0.021739409632160703
#
# Test sample 90:
# Residual loss 1: 0.0005561479776635952 | Residual loss 2: 1.154711612851328e-06
# Total residual loss: 0.0005573026892764464 | Sqrt residual loss: 0.023607259249570807
#
# Test sample 91:
# Residual loss 1: 0.0006137697352151844 | Residual loss 2: 4.636467922129313e-07
# Total residual loss: 0.0006142333820073973 | Sqrt residual loss: 0.02478373220496456
#
# Test sample 92:
# Residual loss 1: 0.0011069618914771836 | Residual loss 2: 1.9349016756040342e-05
# Total residual loss: 0.001126310908233224 | Sqrt residual loss: 0.03356055583915773
#
# Test sample 93:
# Residual loss 1: 0.0002567993554361671 | Residual loss 2: 7.435409832517507e-07
# Total residual loss: 0.0002575428964194188 | Sqrt residual loss: 0.01604814308321741
#
# Test sample 94:
# Residual loss 1: 0.0020263445315594187 | Residual loss 2: 8.649267451158073e-06
# Total residual loss: 0.0020349937990105766 | Sqrt residual loss: 0.045110905544120665
#
# Test sample 95:
# Residual loss 1: 0.0017963805423972126 | Residual loss 2: 4.5943481277162224e-08
# Total residual loss: 0.0017964264858784898 | Sqrt residual loss: 0.04238427168040628
#
# Test sample 96:
# Residual loss 1: 0.0006505548231125871 | Residual loss 2: 7.607414380805381e-07
# Total residual loss: 0.0006513155645506677 | Sqrt residual loss: 0.02552088487005628
#
# Test sample 97:
# Residual loss 1: 0.0016576355627261133 | Residual loss 2: 1.4339865493669047e-08
# Total residual loss: 0.001657649902591607 | Sqrt residual loss: 0.04071424692403885
#
# Test sample 98:
# Residual loss 1: 0.001192596680837697 | Residual loss 2: 3.972377379901922e-07
# Total residual loss: 0.0011929939185756871 | Sqrt residual loss: 0.03453974404328566
#
# Test sample 99:
# Residual loss 1: 0.004461882352222666 | Residual loss 2: 6.621348133815399e-07
# Total residual loss: 0.0044625444870360475 | Sqrt residual loss: 0.06680227905570324
#
# Test sample 100:
# Residual loss 1: 0.0002824909952541737 | Residual loss 2: 5.53678116068188e-07
# Total residual loss: 0.0002830446733702419 | Sqrt residual loss: 0.016823931566974527
#
# Test sample 101:
# Residual loss 1: 0.0024492099601054625 | Residual loss 2: 4.445491953796351e-09
# Total residual loss: 0.0024492144055974162 | Sqrt residual loss: 0.04948953834496152
#
# Test sample 102:
# Residual loss 1: 0.0017239153069346905 | Residual loss 2: 5.755525373894082e-08
# Total residual loss: 0.0017239728621884294 | Sqrt residual loss: 0.041520752187170565
#
# Test sample 103:
# Residual loss 1: 0.0028317852961159675 | Residual loss 2: 5.712553839393635e-06
# Total residual loss: 0.0028374978499553613 | Sqrt residual loss: 0.053268169200333525
#
# Test sample 104:
# Residual loss 1: 0.0027388604546186718 | Residual loss 2: 2.2979005241223714e-07
# Total residual loss: 0.002739090244671084 | Sqrt residual loss: 0.052336318600672366
#
# Test sample 105:
# Residual loss 1: 0.006634602727562844 | Residual loss 2: 4.886299522017859e-06
# Total residual loss: 0.006639489027084862 | Sqrt residual loss: 0.08148305975529431
#
# Test sample 106:
# Residual loss 1: 0.0009775280086399658 | Residual loss 2: 8.500285024918013e-08
# Total residual loss: 0.000977613011490215 | Sqrt residual loss: 0.031266803666032364
#
# Test sample 107:
# Residual loss 1: 0.00031187678021135347 | Residual loss 2: 1.0476801264851344e-06
# Total residual loss: 0.0003129244603378386 | Sqrt residual loss: 0.017689671007054895
#
# Test sample 108:
# Residual loss 1: 0.0034031312075447633 | Residual loss 2: 3.5124201051134186e-09
# Total residual loss: 0.0034031347199648685 | Sqrt residual loss: 0.05833639275756488
#
# Test sample 109:
# Residual loss 1: 0.0025176589967428075 | Residual loss 2: 4.795164402261151e-07
# Total residual loss: 0.0025181385131830335 | Sqrt residual loss: 0.05018105731431965
#
# Test sample 110:
# Residual loss 1: 0.0018634248885349707 | Residual loss 2: 2.4169392857063983e-05
# Total residual loss: 0.0018875942813920347 | Sqrt residual loss: 0.043446453035800685
#
# Test sample 111:
# Residual loss 1: 0.001606463048934802 | Residual loss 2: 7.341914533756265e-06
# Total residual loss: 0.0016138049634685583 | Sqrt residual loss: 0.04017219141979385
#
# Test sample 112:
# Residual loss 1: 0.0010127372265643384 | Residual loss 2: 4.8139121093430714e-09
# Total residual loss: 0.0010127420404764478 | Sqrt residual loss: 0.03182360822528532
#
# Test sample 113:
# Residual loss 1: 0.002003917485799558 | Residual loss 2: 2.344893220126752e-05
# Total residual loss: 0.002027366418000826 | Sqrt residual loss: 0.04502628585616213
#
# Test sample 114:
# Residual loss 1: 0.0010533350360920491 | Residual loss 2: 2.0103759025801226e-06
# Total residual loss: 0.0010553454119946292 | Sqrt residual loss: 0.032486080280554455
#
# Test sample 115:
# Residual loss 1: 0.005278523890188163 | Residual loss 2: 2.7027206567141133e-05
# Total residual loss: 0.005305551096755304 | Sqrt residual loss: 0.07283921400423884
#
# Test sample 116:
# Residual loss 1: 0.0029695995481450912 | Residual loss 2: 2.0887550289659366e-06
# Total residual loss: 0.002971688303174057 | Sqrt residual loss: 0.05451319384492214
#
# Test sample 117:
# Residual loss 1: 0.0051051968512579645 | Residual loss 2: 3.659974939217392e-06
# Total residual loss: 0.005108856826197182 | Sqrt residual loss: 0.07147626757321049
#
# Test sample 118:
# Residual loss 1: 0.00426903355942014 | Residual loss 2: 1.7136419428194643e-05
# Total residual loss: 0.004286169978848334 | Sqrt residual loss: 0.06546884739208668
#
# Test sample 119:
# Residual loss 1: 0.0017414295153514161 | Residual loss 2: 4.265420734978245e-06
# Total residual loss: 0.0017456949360863943 | Sqrt residual loss: 0.04178151428666024
#
# Test sample 120:
# Residual loss 1: 0.0015659511169215602 | Residual loss 2: 8.031322758342112e-05
# Total residual loss: 0.0016462643445049813 | Sqrt residual loss: 0.04057418322659104
#
# Test sample 121:
# Residual loss 1: 0.005347759895172818 | Residual loss 2: 2.9600914290954233e-06
# Total residual loss: 0.005350719986601914 | Sqrt residual loss: 0.07314861575314952
#
# Test sample 122:
# Residual loss 1: 0.0003454851816412943 | Residual loss 2: 2.1708683110652094e-07
# Total residual loss: 0.00034570226847240086 | Sqrt residual loss: 0.018593070442301907
#
# Test sample 123:
# Residual loss 1: 0.0005567904817943856 | Residual loss 2: 1.2565186271748057e-06
# Total residual loss: 0.0005580470004215603 | Sqrt residual loss: 0.023623018444338572
#
# Test sample 124:
# Residual loss 1: 0.009994143465094838 | Residual loss 2: 1.871339362704941e-05
# Total residual loss: 0.010012856858721888 | Sqrt residual loss: 0.1000642636445294
#
# Test sample 125:
# Residual loss 1: 0.0007020506455914859 | Residual loss 2: 1.3613229405307464e-06
# Total residual loss: 0.0007034119685320167 | Sqrt residual loss: 0.026521914873025604
#
# Test sample 126:
# Residual loss 1: 0.0005597411547239482 | Residual loss 2: 1.2910778747430436e-06
# Total residual loss: 0.0005610322325986912 | Sqrt residual loss: 0.023686118985572355
#
# Test sample 127:
# Residual loss 1: 0.0004868146930755627 | Residual loss 2: 8.786206883175135e-06
# Total residual loss: 0.0004956008999587379 | Sqrt residual loss: 0.02226209558776392
#
# Test sample 128:
# Residual loss 1: 0.0024233792896058096 | Residual loss 2: 5.91423736755222e-06
# Total residual loss: 0.002429293526973362 | Sqrt residual loss: 0.04928786389136135
#
# Test sample 129:
# Residual loss 1: 0.004365413195476883 | Residual loss 2: 7.4437157535676225e-06
# Total residual loss: 0.004372856911230451 | Sqrt residual loss: 0.06612758056386496
#
# Test sample 130:
# Residual loss 1: 0.0022863737560313772 | Residual loss 2: 3.0036420226579796e-05
# Total residual loss: 0.002316410176257957 | Sqrt residual loss: 0.04812909905927969
#
# Test sample 131:
# Residual loss 1: 0.0005025947412513123 | Residual loss 2: 1.538246965770058e-05
# Total residual loss: 0.0005179772109090129 | Sqrt residual loss: 0.02275911270038911
#
# Test sample 132:
# Residual loss 1: 0.0002416399540120407 | Residual loss 2: 7.00866296810062e-06
# Total residual loss: 0.0002486486169801413 | Sqrt residual loss: 0.015768595910230603
#
# Test sample 133:
# Residual loss 1: 0.0013311799869233246 | Residual loss 2: 6.965131766753222e-06
# Total residual loss: 0.0013381451186900777 | Sqrt residual loss: 0.036580665913704714
#
# Test sample 134:
# Residual loss 1: 0.0018584698071658105 | Residual loss 2: 9.10527771309615e-06
# Total residual loss: 0.0018675750848789066 | Sqrt residual loss: 0.04321544960866318
#
# Test sample 135:
# Residual loss 1: 0.0018539564372946832 | Residual loss 2: 1.5116355845820814e-06
# Total residual loss: 0.0018554680728792652 | Sqrt residual loss: 0.04307514449052104
#
# Test sample 136:
# Residual loss 1: 0.0006408610232605655 | Residual loss 2: 3.0157344279448977e-06
# Total residual loss: 0.0006438767576885104 | Sqrt residual loss: 0.025374726751011732
#
# Test sample 137:
# Residual loss 1: 0.0007082593654809227 | Residual loss 2: 4.597545313366078e-08
# Total residual loss: 0.0007083053409340564 | Sqrt residual loss: 0.026614006480311383
#
# Test sample 138:
# Residual loss 1: 0.0013491011079294376 | Residual loss 2: 3.616413464509739e-07
# Total residual loss: 0.0013494627492758886 | Sqrt residual loss: 0.03673503435789721
#
# Test sample 139:
# Residual loss 1: 0.005277938703478269 | Residual loss 2: 6.87406212152275e-08
# Total residual loss: 0.005278007444099484 | Sqrt residual loss: 0.07264989638051443
#
# Test sample 140:
# Residual loss 1: 0.00039955712729053216 | Residual loss 2: 4.5565838465094467e-07
# Total residual loss: 0.0004000127856751831 | Sqrt residual loss: 0.020000319639325345
#
# Test sample 141:
# Residual loss 1: 0.0020981521149089043 | Residual loss 2: 2.9994197962544507e-05
# Total residual loss: 0.002128146312871449 | Sqrt residual loss: 0.04613183621829342
#
# Test sample 142:
# Residual loss 1: 0.00039459690000068616 | Residual loss 2: 2.577222017639395e-08
# Total residual loss: 0.00039462267222086254 | Sqrt residual loss: 0.019865111935774803
#
# Test sample 143:
# Residual loss 1: 0.0012112650581345313 | Residual loss 2: 6.203698775200082e-07
# Total residual loss: 0.0012118854280120514 | Sqrt residual loss: 0.034812144834986125
#
# Test sample 144:
# Residual loss 1: 0.0022120159751747655 | Residual loss 2: 4.581275021197148e-06
# Total residual loss: 0.0022165972501959627 | Sqrt residual loss: 0.04708075243871919
#
# Test sample 145:
# Residual loss 1: 0.0006229909955149824 | Residual loss 2: 1.2437929224217054e-07
# Total residual loss: 0.0006231153748072246 | Sqrt residual loss: 0.024962279038726103
#
# Test sample 146:
# Residual loss 1: 0.0005169580949999158 | Residual loss 2: 1.3459218111771742e-06
# Total residual loss: 0.0005183040168110929 | Sqrt residual loss: 0.022766291239705534
#
# Test sample 147:
# Residual loss 1: 0.0025141941590350807 | Residual loss 2: 1.4081183393219168e-06
# Total residual loss: 0.0025156022773744026 | Sqrt residual loss: 0.05015578009935049
#
# Test sample 148:
# Residual loss 1: 0.0005050961301396821 | Residual loss 2: 9.546148555535479e-06
# Total residual loss: 0.0005146422786952177 | Sqrt residual loss: 0.022685728524674223
#
# Test sample 149:
# Residual loss 1: 0.00028195645291285873 | Residual loss 2: 2.214376729641962e-06
# Total residual loss: 0.0002841708296425007 | Sqrt residual loss: 0.016857367221559262
#
# Test sample 150:
# Residual loss 1: 0.0019075980563441504 | Residual loss 2: 4.290724371185617e-06
# Total residual loss: 0.001911888780715336 | Sqrt residual loss: 0.043725150436737616
#
# Test sample 151:
# Residual loss 1: 0.0008000152708235935 | Residual loss 2: 6.401051445173246e-07
# Total residual loss: 0.0008006553759681109 | Sqrt residual loss: 0.028295854395443
#
# Test sample 152:
# Residual loss 1: 0.0013806553576730719 | Residual loss 2: 3.855895362144223e-05
# Total residual loss: 0.001419214311294514 | Sqrt residual loss: 0.03767246091370345
#
# Test sample 153:
# Residual loss 1: 0.0017519788881238075 | Residual loss 2: 1.4413597098936783e-05
# Total residual loss: 0.0017663924852227442 | Sqrt residual loss: 0.04202847231607097
#
# Test sample 154:
# Residual loss 1: 0.003730055613026542 | Residual loss 2: 7.432465813846877e-06
# Total residual loss: 0.0037374880788403893 | Sqrt residual loss: 0.06113499880461591
#
# Test sample 155:
# Residual loss 1: 0.000658489338613766 | Residual loss 2: 4.1271039470185054e-07
# Total residual loss: 0.0006589020490084678 | Sqrt residual loss: 0.02566908742064018
#
# Test sample 156:
# Residual loss 1: 0.0030495632807827355 | Residual loss 2: 5.6882310387827e-06
# Total residual loss: 0.003055251511821518 | Sqrt residual loss: 0.055274329591787165
#
# Test sample 157:
# Residual loss 1: 0.003131653161209509 | Residual loss 2: 1.2257666329535215e-05
# Total residual loss: 0.0031439108275390444 | Sqrt residual loss: 0.05607058790077953
#
# Test sample 158:
# Residual loss 1: 0.00036216246631178543 | Residual loss 2: 4.881990330506897e-08
# Total residual loss: 0.0003622112862150905 | Sqrt residual loss: 0.019031849258941982
#
# Test sample 159:
# Residual loss 1: 0.0003790473161900832 | Residual loss 2: 1.7050435820790857e-06
# Total residual loss: 0.0003807523597721623 | Sqrt residual loss: 0.019512876768230828
#
# Test sample 160:
# Residual loss 1: 0.0005895407846827222 | Residual loss 2: 5.345707994008694e-07
# Total residual loss: 0.000590075355482123 | Sqrt residual loss: 0.024291466721507844
#
# Test sample 161:
# Residual loss 1: 0.0032131978528190837 | Residual loss 2: 8.089739662452704e-06
# Total residual loss: 0.0032212875924815363 | Sqrt residual loss: 0.05675638812047095
#
# Test sample 162:
# Residual loss 1: 0.0049075431093157 | Residual loss 2: 3.6864351345069986e-07
# Total residual loss: 0.004907911752829151 | Sqrt residual loss: 0.07005648972671376
#
# Test sample 163:
# Residual loss 1: 0.003987041803104847 | Residual loss 2: 2.5610124805574287e-06
# Total residual loss: 0.003989602815585404 | Sqrt residual loss: 0.06316330276026899
#
# Test sample 164:
# Residual loss 1: 0.002368534234693588 | Residual loss 2: 5.4295949601669206e-06
# Total residual loss: 0.002373963829653755 | Sqrt residual loss: 0.04872333968083217
#
# Test sample 165:
# Residual loss 1: 0.001084783638361832 | Residual loss 2: 1.7358641863414424e-06
# Total residual loss: 0.0010865195025481734 | Sqrt residual loss: 0.03296239527929021
#
# Test sample 166:
# Residual loss 1: 0.006642279966080344 | Residual loss 2: 5.124610988613853e-07
# Total residual loss: 0.006642792427179206 | Sqrt residual loss: 0.08150332770616919
#
# Test sample 167:
# Residual loss 1: 0.0009891762251700036 | Residual loss 2: 1.6680093356721287e-06
# Total residual loss: 0.0009908442345056758 | Sqrt residual loss: 0.03147767835317077
#
# Test sample 168:
# Residual loss 1: 0.0012006460637352953 | Residual loss 2: 7.448113284245365e-06
# Total residual loss: 0.0012080941770195408 | Sqrt residual loss: 0.034757649187186705
#
# Test sample 169:
# Residual loss 1: 0.0013330735372919476 | Residual loss 2: 2.4422995789944918e-05
# Total residual loss: 0.0013574965330818926 | Sqrt residual loss: 0.03684421980557999
#
# Test sample 170:
# Residual loss 1: 0.0008016914829110206 | Residual loss 2: 5.462092132333412e-06
# Total residual loss: 0.000807153575043354 | Sqrt residual loss: 0.02841044834287826
#
# Test sample 171:
# Residual loss 1: 0.0009633906990616747 | Residual loss 2: 3.526665746887597e-07
# Total residual loss: 0.0009637433656363635 | Sqrt residual loss: 0.03104421629927809
#
# Test sample 172:
# Residual loss 1: 0.0006558416848880457 | Residual loss 2: 5.881752539801007e-06
# Total residual loss: 0.0006617234374278467 | Sqrt residual loss: 0.025723985644294057
#
# Test sample 173:
# Residual loss 1: 0.0004137421885909527 | Residual loss 2: 1.0822853657435489e-05
# Total residual loss: 0.0004245650422483882 | Sqrt residual loss: 0.020604976152579942
#
# Test sample 174:
# Residual loss 1: 0.0011782057333252667 | Residual loss 2: 8.929437809247959e-06
# Total residual loss: 0.0011871351711345147 | Sqrt residual loss: 0.03445482798004533
#
# Test sample 175:
# Residual loss 1: 0.0005676845104951534 | Residual loss 2: 7.1830631089100415e-06
# Total residual loss: 0.0005748675736040634 | Sqrt residual loss: 0.023976396176324404
#
# Test sample 176:
# Residual loss 1: 0.0008396314450827906 | Residual loss 2: 8.80195061838941e-07
# Total residual loss: 0.0008405116401446295 | Sqrt residual loss: 0.02899157877978758
#
# Test sample 177:
# Residual loss 1: 0.0034681659268318565 | Residual loss 2: 3.971508185662017e-06
# Total residual loss: 0.0034721374350175187 | Sqrt residual loss: 0.05892484565119809
#
# Test sample 178:
# Residual loss 1: 0.004651953579857433 | Residual loss 2: 4.801427335387788e-07
# Total residual loss: 0.004652433722590972 | Sqrt residual loss: 0.06820875107045263
#
# Test sample 179:
# Residual loss 1: 0.0009049632526428349 | Residual loss 2: 3.207588152878351e-07
# Total residual loss: 0.0009052840114581227 | Sqrt residual loss: 0.030087937972850892
#
# Test sample 180:
# Residual loss 1: 0.0018008837641230993 | Residual loss 2: 1.1839726297434905e-07
# Total residual loss: 0.0018010021613860737 | Sqrt residual loss: 0.04243821581294475
#
# Test sample 181:
# Residual loss 1: 0.002286748549891742 | Residual loss 2: 2.907557756105458e-06
# Total residual loss: 0.0022896561076478474 | Sqrt residual loss: 0.047850351175804835
#
# Test sample 182:
# Residual loss 1: 0.0009702391991876161 | Residual loss 2: 2.1178467221567898e-06
# Total residual loss: 0.0009723570459097728 | Sqrt residual loss: 0.031182640136937938
#
# Test sample 183:
# Residual loss 1: 0.0009719785323573128 | Residual loss 2: 9.586865317593811e-07
# Total residual loss: 0.0009729372188890722 | Sqrt residual loss: 0.03119194156972394
#
# Test sample 184:
# Residual loss 1: 0.0022782391364732516 | Residual loss 2: 8.281718031631978e-06
# Total residual loss: 0.0022865208545048837 | Sqrt residual loss: 0.047817578927679766
#
# Test sample 185:
# Residual loss 1: 0.0051689261994879365 | Residual loss 2: 2.3178308326924974e-06
# Total residual loss: 0.005171244030320629 | Sqrt residual loss: 0.07191136231723488
#
# Test sample 186:
# Residual loss 1: 0.0030596303268719477 | Residual loss 2: 8.559232244086743e-07
# Total residual loss: 0.0030604862500963562 | Sqrt residual loss: 0.05532166167150401
#
# Test sample 187:
# Residual loss 1: 0.000797350871989904 | Residual loss 2: 6.2171084602796834e-06
# Total residual loss: 0.0008035679804501836 | Sqrt residual loss: 0.028347274656484768
#
# Test sample 188:
# Residual loss 1: 0.0014613172427627237 | Residual loss 2: 1.3535055370923094e-08
# Total residual loss: 0.0014613307778180947 | Sqrt residual loss: 0.03822735640634982
#
# Test sample 189:
# Residual loss 1: 0.003280354177074018 | Residual loss 2: 3.7106656892732527e-06
# Total residual loss: 0.003284064842763291 | Sqrt residual loss: 0.05730676088179554
#
# Test sample 190:
# Residual loss 1: 0.0008299946540771833 | Residual loss 2: 1.3211282253552165e-05
# Total residual loss: 0.0008432059363307355 | Sqrt residual loss: 0.029038008477351464
#
# Test sample 191:
# Residual loss 1: 0.0019764702681245045 | Residual loss 2: 1.4078590248096486e-07
# Total residual loss: 0.0019766110540269857 | Sqrt residual loss: 0.044459094165614596
#
# Test sample 192:
# Residual loss 1: 0.001490904472498053 | Residual loss 2: 8.433939796892494e-06
# Total residual loss: 0.0014993384122949454 | Sqrt residual loss: 0.03872129145954387
#
# Test sample 193:
# Residual loss 1: 0.0014803227710264847 | Residual loss 2: 3.601897379300702e-06
# Total residual loss: 0.0014839246684057853 | Sqrt residual loss: 0.03852174280073249
#
# Test sample 194:
# Residual loss 1: 0.0024496751199132487 | Residual loss 2: 2.556515995333539e-05
# Total residual loss: 0.002475240279866584 | Sqrt residual loss: 0.049751786700244084
#
# Test sample 195:
# Residual loss 1: 0.0015466089353682502 | Residual loss 2: 2.3438193785652625e-07
# Total residual loss: 0.0015468433173061067 | Sqrt residual loss: 0.03932992902747355
#
# Test sample 196:
# Residual loss 1: 0.0006784931958535407 | Residual loss 2: 1.6139565798291443e-06
# Total residual loss: 0.0006801071524333699 | Sqrt residual loss: 0.026078864094000908
#
# Test sample 197:
# Residual loss 1: 0.00405075508995182 | Residual loss 2: 4.674760980213139e-08
# Total residual loss: 0.004050801837561622 | Sqrt residual loss: 0.06364590982586094
#
# Test sample 198:
# Residual loss 1: 0.5538016713850068 | Residual loss 2: 0.002188779446452248
# Total residual loss: 0.555990450831459 | Sqrt residual loss: 0.7456476720485748
#
# Test sample 199:
# Residual loss 1: 0.0015721578227698184 | Residual loss 2: 1.3611340668617727e-06
# Total residual loss: 0.0015735189568366803 | Sqrt residual loss: 0.03966760588738222
#
# Test sample 200:
# Residual loss 1: 0.0030246940433646206 | Residual loss 2: 3.3761743016593514e-06
# Total residual loss: 0.00302807021766628 | Sqrt residual loss: 0.05502790399121413
#
# Test sample 201:
# Residual loss 1: 0.0015600059779719642 | Residual loss 2: 8.189893786864738e-08
# Total residual loss: 0.0015600878769098329 | Sqrt residual loss: 0.03949794775567248
#
# Test sample 202:
# Residual loss 1: 0.0005060481084746059 | Residual loss 2: 1.0911627805073526e-07
# Total residual loss: 0.0005061572247526566 | Sqrt residual loss: 0.022497938233372778
#
# Test sample 203:
# Residual loss 1: 0.0005627119551678032 | Residual loss 2: 1.8818971827964383e-07
# Total residual loss: 0.0005629001448860828 | Sqrt residual loss: 0.02372551674645007
#
# Test sample 204:
# Residual loss 1: 0.0006774351131903571 | Residual loss 2: 9.643905972238037e-09
# Total residual loss: 0.0006774447570963293 | Sqrt residual loss: 0.026027768961175472
#
# Test sample 205:
# Residual loss 1: 0.0025028689272457026 | Residual loss 2: 7.525840100697875e-06
# Total residual loss: 0.0025103947673464004 | Sqrt residual loss: 0.05010383984632715
#
# Test sample 206:
# Residual loss 1: 0.0020635964176725975 | Residual loss 2: 4.473777795583383e-06
# Total residual loss: 0.0020680701954681807 | Sqrt residual loss: 0.045476039795349164
#
# Test sample 207:
# Residual loss 1: 0.0005918573796707051 | Residual loss 2: 6.600911080721511e-06
# Total residual loss: 0.0005984582907514267 | Sqrt residual loss: 0.024463407177893817
#
# Test sample 208:
# Residual loss 1: 0.0028360890329343267 | Residual loss 2: 1.1834305856656881e-06
# Total residual loss: 0.0028372724635199924 | Sqrt residual loss: 0.05326605357561223
#
# Test sample 209:
# Residual loss 1: 0.0005678633286674471 | Residual loss 2: 1.5800481815062857e-06
# Total residual loss: 0.0005694433768489534 | Sqrt residual loss: 0.023863012736219068
#
# Test sample 210:
# Residual loss 1: 0.0005620393754667499 | Residual loss 2: 1.2651540562830824e-05
# Total residual loss: 0.0005746909160295807 | Sqrt residual loss: 0.023972711903945718
#
# Test sample 211:
# Residual loss 1: 0.0051631074385138885 | Residual loss 2: 2.9238882093174116e-06
# Total residual loss: 0.0051660313267232055 | Sqrt residual loss: 0.07187510922929582
#
# Test sample 212:
# Residual loss 1: 0.0015678119523236903 | Residual loss 2: 2.0460381270850135e-07
# Total residual loss: 0.0015680165561363989 | Sqrt residual loss: 0.03959818879868622
#
# Test sample 213:
# Residual loss 1: 0.0005930143429201322 | Residual loss 2: 6.180792025613913e-06
# Total residual loss: 0.000599195134945746 | Sqrt residual loss: 0.024478462675293685
#
# Test sample 214:
# Residual loss 1: 0.0006540891227690763 | Residual loss 2: 1.722600104199421e-07
# Total residual loss: 0.0006542613827794963 | Sqrt residual loss: 0.025578533632315523
#
# Test sample 215:
# Residual loss 1: 0.0025245236076475693 | Residual loss 2: 1.3476156088406413e-06
# Total residual loss: 0.0025258712232564097 | Sqrt residual loss: 0.05025804635335928
#
# Test sample 216:
# Residual loss 1: 0.00037648187965957263 | Residual loss 2: 1.4430989251225434e-06
# Total residual loss: 0.0003779249785846952 | Sqrt residual loss: 0.019440292656868495
#
# Test sample 217:
# Residual loss 1: 0.001574839509440596 | Residual loss 2: 1.396304662264316e-08
# Total residual loss: 0.0015748534724872186 | Sqrt residual loss: 0.03968442354989195
#
# Test sample 218:
# Residual loss 1: 0.0018465155963589748 | Residual loss 2: 1.598164432998079e-06
# Total residual loss: 0.0018481137607919728 | Sqrt residual loss: 0.04298969365780562
#
# Test sample 219:
# Residual loss 1: 0.0009531479383075228 | Residual loss 2: 4.388013987450466e-06
# Total residual loss: 0.0009575359522949733 | Sqrt residual loss: 0.03094407782266218
#
# Test sample 220:
# Residual loss 1: 0.0015911629972503003 | Residual loss 2: 2.5627050525833475e-06
# Total residual loss: 0.0015937257023028836 | Sqrt residual loss: 0.039921494239355364
#
# Test sample 221:
# Residual loss 1: 0.0014333377007003164 | Residual loss 2: 6.661986915940803e-07
# Total residual loss: 0.0014340038993919104 | Sqrt residual loss: 0.037868243943862914
#
# Test sample 222:
# Residual loss 1: 0.0007590755788760394 | Residual loss 2: 5.445653289768297e-06
# Total residual loss: 0.0007645212321658077 | Sqrt residual loss: 0.02764997707351324
#
# Test sample 223:
# Residual loss 1: 0.0019365577916708773 | Residual loss 2: 7.651478592520941e-07
# Total residual loss: 0.0019373229395301295 | Sqrt residual loss: 0.04401503083641007
#
# Test sample 224:
# Residual loss 1: 0.0030979595525187113 | Residual loss 2: 2.0891724449655073e-06
# Total residual loss: 0.003100048724963677 | Sqrt residual loss: 0.05567808118967173
#
# Test sample 225:
# Residual loss 1: 0.03596241330203278 | Residual loss 2: 4.467705051712236e-06
# Total residual loss: 0.03596688100708449 | Sqrt residual loss: 0.18964936331842638
#
# Test sample 226:
# Residual loss 1: 0.002235022507185987 | Residual loss 2: 2.891179767402558e-05
# Total residual loss: 0.0022639343048600127 | Sqrt residual loss: 0.047580818665298445
#
# Test sample 227:
# Residual loss 1: 0.0027192864606763157 | Residual loss 2: 3.025662578867342e-06
# Total residual loss: 0.002722312123255183 | Sqrt residual loss: 0.05217578100282911
#
# Test sample 228:
# Residual loss 1: 0.0015837664868723678 | Residual loss 2: 4.003071084605664e-07
# Total residual loss: 0.0015841667939808285 | Sqrt residual loss: 0.039801592857332084
#
# Test sample 229:
# Residual loss 1: 0.00037266873378095873 | Residual loss 2: 1.1069694376195565e-07
# Total residual loss: 0.0003727794307247207 | Sqrt residual loss: 0.019307496749312706
#
# Test sample 230:
# Residual loss 1: 0.0009648892886903164 | Residual loss 2: 1.9924849327968526e-06
# Total residual loss: 0.0009668817736231132 | Sqrt residual loss: 0.031094722600838766
#
# Test sample 231:
# Residual loss 1: 0.00386612095389243 | Residual loss 2: 2.8770766550528325e-06
# Total residual loss: 0.0038689980305474827 | Sqrt residual loss: 0.06220127032904941
#
# Test sample 232:
# Residual loss 1: 0.0009601873054154155 | Residual loss 2: 1.0857064489366985e-05
# Total residual loss: 0.0009710443699047825 | Sqrt residual loss: 0.031161584842635693
#
# Test sample 233:
# Residual loss 1: 0.002610769371945678 | Residual loss 2: 2.2690833095924893e-06
# Total residual loss: 0.0026130384552552704 | Sqrt residual loss: 0.051117887820754784
#
# Test sample 234:
# Residual loss 1: 0.0013967756741443344 | Residual loss 2: 2.884767683604917e-06
# Total residual loss: 0.0013996604418279393 | Sqrt residual loss: 0.03741203605563241
#
# Test sample 235:
# Residual loss 1: 0.0010019492797413575 | Residual loss 2: 8.410903884261082e-07
# Total residual loss: 0.0010027903701297835 | Sqrt residual loss: 0.0316668654926531
#
# Test sample 236:
# Residual loss 1: 0.0013388560202576704 | Residual loss 2: 2.8356308087436237e-06
# Total residual loss: 0.001341691651066414 | Sqrt residual loss: 0.036629109340337695
#
# Test sample 237:
# Residual loss 1: 0.00034309552310835613 | Residual loss 2: 1.20640856924369e-08
# Total residual loss: 0.0003431075871940486 | Sqrt residual loss: 0.018523163530942778
#
# Test sample 238:
# Residual loss 1: 0.0003910648505163934 | Residual loss 2: 1.100780523911906e-05
# Total residual loss: 0.00040207265575551245 | Sqrt residual loss: 0.020051749443764564
#
# Test sample 239:
# Residual loss 1: 0.0017381422241486684 | Residual loss 2: 7.67541362876271e-07
# Total residual loss: 0.0017389097655115446 | Sqrt residual loss: 0.041700236995867834
#
# Test sample 240:
# Residual loss 1: 0.0009570359800988973 | Residual loss 2: 4.886730618761856e-06
# Total residual loss: 0.0009619227107176591 | Sqrt residual loss: 0.031014878860277033
#
# Test sample 241:
# Residual loss 1: 0.011002257972761154 | Residual loss 2: 2.570499940718191e-07
# Total residual loss: 0.011002515022755226 | Sqrt residual loss: 0.10489287403229652
#
# Test sample 242:
# Residual loss 1: 0.0015273907525028513 | Residual loss 2: 5.267334283352848e-06
# Total residual loss: 0.0015326580867862042 | Sqrt residual loss: 0.03914917734494818
#
# Test sample 243:
# Residual loss 1: 0.0008995829361974237 | Residual loss 2: 5.083829065233602e-07
# Total residual loss: 0.0009000913191039471 | Sqrt residual loss: 0.030001521946460434
#
# Test sample 244:
# Residual loss 1: 0.0002831085590693163 | Residual loss 2: 7.664582731982143e-06
# Total residual loss: 0.00029077314180129843 | Sqrt residual loss: 0.01705207148123941
#
# Test sample 245:
# Residual loss 1: 0.0003535374827544298 | Residual loss 2: 1.7257038784794009e-06
# Total residual loss: 0.0003552631866329092 | Sqrt residual loss: 0.018848426635475684
#
# Test sample 246:
# Residual loss 1: 0.0014846256551220211 | Residual loss 2: 5.860293692423042e-06
# Total residual loss: 0.0014904859488144443 | Sqrt residual loss: 0.03860681220736108
#
# Test sample 247:
# Residual loss 1: 0.0016748602388925607 | Residual loss 2: 4.608322811956682e-07
# Total residual loss: 0.0016753210711737564 | Sqrt residual loss: 0.04093068618009911
#
# Test sample 248:
# Residual loss 1: 0.0008884386320397749 | Residual loss 2: 1.8371727983619117e-08
# Total residual loss: 0.0008884570037677585 | Sqrt residual loss: 0.02980699588633109
#
# Test sample 249:
# Residual loss 1: 0.0026415140362502426 | Residual loss 2: 9.981027981024871e-05
# Total residual loss: 0.0027413243160604914 | Sqrt residual loss: 0.05235765766399879
#
# Test sample 250:
# Residual loss 1: 0.0029880133186700785 | Residual loss 2: 1.1090556219113496e-06
# Total residual loss: 0.0029891223742919896 | Sqrt residual loss: 0.05467286689292953
#
# Test sample 251:
# Residual loss 1: 0.004214243920734176 | Residual loss 2: 5.3511701881459035e-06
# Total residual loss: 0.004219595090922321 | Sqrt residual loss: 0.06495841047102616
#
# Test sample 252:
# Residual loss 1: 0.001250698189235764 | Residual loss 2: 2.7881445475751387e-06
# Total residual loss: 0.0012534863337833391 | Sqrt residual loss: 0.03540460893419583
#
# Test sample 253:
# Residual loss 1: 0.0014829118346740943 | Residual loss 2: 9.206039096174972e-06
# Total residual loss: 0.0014921178737702693 | Sqrt residual loss: 0.038627941619639394
#
# Test sample 254:
# Residual loss 1: 0.002948317753855731 | Residual loss 2: 2.394975869792942e-06
# Total residual loss: 0.0029507127297255242 | Sqrt residual loss: 0.05432046326869391
#
# Test sample 255:
# Residual loss 1: 0.0016148098211218257 | Residual loss 2: 2.2124367927036665e-06
# Total residual loss: 0.0016170222579145294 | Sqrt residual loss: 0.0402122152823558
#
# Test sample 256:
# Residual loss 1: 0.0019329514022996565 | Residual loss 2: 1.0187930621843173e-05
# Total residual loss: 0.0019431393329214996 | Sqrt residual loss: 0.044081054126705044
#
# Test sample 257:
# Residual loss 1: 0.0007704966343345715 | Residual loss 2: 1.5610599548629622e-06
# Total residual loss: 0.0007720576942894345 | Sqrt residual loss: 0.027785926190959237
#
# Test sample 258:
# Residual loss 1: 0.005664144101936236 | Residual loss 2: 5.003067582292173e-06
# Total residual loss: 0.005669147169518528 | Sqrt residual loss: 0.07529373924516253
#
# Test sample 259:
# Residual loss 1: 0.003978599446984567 | Residual loss 2: 1.8463271736876686e-06
# Total residual loss: 0.003980445774158254 | Sqrt residual loss: 0.0630907740811464
#
# Test sample 260:
# Residual loss 1: 0.00111322196411576 | Residual loss 2: 7.010763725323473e-06
# Total residual loss: 0.0011202327278410835 | Sqrt residual loss: 0.03346987791792918
#
# Test sample 261:
# Residual loss 1: 0.0007995396565060606 | Residual loss 2: 3.412484427983911e-07
# Total residual loss: 0.000799880904948859 | Sqrt residual loss: 0.028282165846145145
#
# Test sample 262:
# ...
#
# Test sample 413:
# Residual loss 1: 0.012852803047431128 | Residual loss 2: 2.069295077306414e-08
# Total residual loss: 0.012852823740381901 | Sqrt residual loss: 0.11337029478828174
#
# Test sample 414:
# Residual loss 1: 0.003525858060525742 | Residual loss 2: 1.0224440294102714e-07
# Total residual loss: 0.0035259603049286833 | Sqrt residual loss: 0.059379797110875036
#
# Test sample 415:
# Residual loss 1: 0.0017685027312967355 | Residual loss 2: 3.7165916688550675e-09
# Total residual loss: 0.0017685064478884043 | Sqrt residual loss: 0.042053613969412956
#
# Test sample 416:
# Residual loss 1: 0.000755440570637674 | Residual loss 2: 5.777474983210078e-07
# Total residual loss: 0.000756018318135995 | Sqrt residual loss: 0.0274957872797997
#
# Test sample 417:
# Residual loss 1: 0.0005412671956459151 | Residual loss 2: 3.6321911610649058e-06
# Total residual loss: 0.00054489938680698 | Sqrt residual loss: 0.023343080062557725
#
# Test sample 418:
# Residual loss 1: 0.002826161028776345 | Residual loss 2: 1.969041879504618e-06
# Total residual loss: 0.0028281300706558495 | Sqrt residual loss: 0.05318016613979172
#
# Test sample 419:
# Residual loss 1: 0.0030911794067737916 | Residual loss 2: 8.628341691390424e-06
# Total residual loss: 0.003099807748465182 | Sqrt residual loss: 0.05567591713178313
#
# Test sample 420:
# Residual loss 1: 0.002789439746158017 | Residual loss 2: 2.660546565583378e-06
# Total residual loss: 0.0027921002927236006 | Sqrt residual loss: 0.05284032827986216
#
# Test sample 421:
# Residual loss 1: 0.002228185564292145 | Residual loss 2: 3.014442581469875e-07
# Total residual loss: 0.002228487008550292 | Sqrt residual loss: 0.047206853406579555
#
# Test sample 422:
# Residual loss 1: 0.0010378404203570724 | Residual loss 2: 1.0779051343743162e-06
# Total residual loss: 0.0010389183254914467 | Sqrt residual loss: 0.03223225597893276
#
# Test sample 423:
# Residual loss 1: 0.0017411059451741785 | Residual loss 2: 1.0645667666091146e-05
# Total residual loss: 0.0017517516128402696 | Sqrt residual loss: 0.04185393186834744
#
# Test sample 424:
# Residual loss 1: 0.001431919441420548 | Residual loss 2: 2.912829727909865e-06
# Total residual loss: 0.0014348322711484579 | Sqrt residual loss: 0.03787917991652483
#
# Test sample 425:
# Residual loss 1: 0.0020638580793671366 | Residual loss 2: 4.1773530795274134e-07
# Total residual loss: 0.0020642758146750895 | Sqrt residual loss: 0.04543430218100735
#
# Test sample 426:
# Residual loss 1: 0.0009481927948631897 | Residual loss 2: 1.029619982573198e-07
# Total residual loss: 0.000948295756861447 | Sqrt residual loss: 0.030794411130291924
#
# Test sample 427:
# Residual loss 1: 0.0010940357233850445 | Residual loss 2: 1.0076906869019374e-05
# Total residual loss: 0.001104112630254064 | Sqrt residual loss: 0.03322819029459871
#
# Test sample 428:
# Residual loss 1: 0.0005439551668178262 | Residual loss 2: 6.173477454397456e-06
# Total residual loss: 0.0005501286442722237 | Sqrt residual loss: 0.02345482134385644
#
# Test sample 429:
# Residual loss 1: 0.0007556164285520804 | Residual loss 2: 2.1543189622135635e-06
# Total residual loss: 0.000757770747514294 | Sqrt residual loss: 0.027527636068400314
#
# Test sample 430:
# Residual loss 1: 0.0012478206576154933 | Residual loss 2: 1.7221674533307877e-06
# Total residual loss: 0.001249542825068824 | Sqrt residual loss: 0.035348873038172295
#
# Test sample 431:
# Residual loss 1: 0.002129576485808283 | Residual loss 2: 4.2007957062416805e-05
# Total residual loss: 0.0021715844428707 | Sqrt residual loss: 0.046600262261823164
#
# Test sample 432:
# Residual loss 1: 0.000493716595234123 | Residual loss 2: 1.731119854298106e-06
# Total residual loss: 0.0004954477150884211 | Sqrt residual loss: 0.022258654835556013
#
# Test sample 433:
# Residual loss 1: 0.0009633505506010439 | Residual loss 2: 1.033027942561273e-05
# Total residual loss: 0.0009736808300266567 | Sqrt residual loss: 0.03120385921687663
#
# Test sample 434:
# Residual loss 1: 0.003189274994533076 | Residual loss 2: 1.6028872951281996e-09
# Total residual loss: 0.003189276597420371 | Sqrt residual loss: 0.05647368057263818
#
# Test sample 435:
# Residual loss 1: 0.0021922733196548627 | Residual loss 2: 3.7733652766707044e-07
# Total residual loss: 0.0021926506561825297 | Sqrt residual loss: 0.0468257477909593
#
# Test sample 436:
# Residual loss 1: 0.000545169792220052 | Residual loss 2: 1.3824954292764275e-05
# Total residual loss: 0.0005589947465128162 | Sqrt residual loss: 0.02364306973539638
#
# Test sample 437:
# Residual loss 1: 0.0017985062022644847 | Residual loss 2: 5.493962735929174e-06
# Total residual loss: 0.001804000165000414 | Sqrt residual loss: 0.04247352310558207
#
# Test sample 438:
# Residual loss 1: 0.0008525766918200427 | Residual loss 2: 5.36338837964766e-06
# Total residual loss: 0.0008579400801996904 | Sqrt residual loss: 0.029290614199768677
#
# Test sample 439:
# Residual loss 1: 0.0027147329735921415 | Residual loss 2: 2.460987360598532e-05
# Total residual loss: 0.002739342847198127 | Sqrt residual loss: 0.05233873180731576
#
# Test sample 440:
# Residual loss 1: 0.00046780621791049545 | Residual loss 2: 2.299478700358344e-05
# Total residual loss: 0.0004908010049140789 | Sqrt residual loss: 0.022154029089853585
#
# Test sample 441:
# Residual loss 1: 0.003363570919048652 | Residual loss 2: 5.706995008996005e-06
# Total residual loss: 0.003369277914057648 | Sqrt residual loss: 0.05804548142670236
#
# Test sample 442:
# Residual loss 1: 0.0005799682834463394 | Residual loss 2: 1.4665297586286369e-05
# Total residual loss: 0.0005946335810326258 | Sqrt residual loss: 0.02438510982203332
#
# Test sample 443:
# Residual loss 1: 0.002916371708281556 | Residual loss 2: 4.201762405882037e-06
# Total residual loss: 0.002920573470687438 | Sqrt residual loss: 0.054042330359519455
#
# Test sample 444:
# Residual loss 1: 0.0017941059184417097 | Residual loss 2: 5.68371737238263e-06
# Total residual loss: 0.0017997896358140923 | Sqrt residual loss: 0.04242392763304798
#
# Test sample 445:
# Residual loss 1: 0.0009072589634208535 | Residual loss 2: 6.681549325564646e-08
# Total residual loss: 0.0009073257789141092 | Sqrt residual loss: 0.030121848862812342
#
# Test sample 446:
# Residual loss 1: 0.0006757123901131003 | Residual loss 2: 7.896097474749593e-07
# Total residual loss: 0.0006765019998605753 | Sqrt residual loss: 0.026009652051893647
#
# Test sample 447:
# Residual loss 1: 0.0020615683313745838 | Residual loss 2: 2.5115997912455303e-06
# Total residual loss: 0.0020640799311658293 | Sqrt residual loss: 0.045432146451228006
#
# Test sample 448:
# Residual loss 1: 0.0035215545877938233 | Residual loss 2: 7.26826584905619e-06
# Total residual loss: 0.0035288228536428795 | Sqrt residual loss: 0.0594038959466707
#
# Test sample 449:
# Residual loss 1: 0.005100701563621574 | Residual loss 2: 4.881764367974825e-06
# Total residual loss: 0.005105583327989549 | Sqrt residual loss: 0.07145336470726588
#
# Test sample 450:
# Residual loss 1: 0.0008111278402620205 | Residual loss 2: 3.658221456695407e-06
# Total residual loss: 0.0008147860617187159 | Sqrt residual loss: 0.028544457635742808
#
# Test sample 451:
# Residual loss 1: 0.0017021813627177305 | Residual loss 2: 7.559560687132042e-06
# Total residual loss: 0.0017097409234048625 | Sqrt residual loss: 0.041349013572331596
#
# Test sample 452:
# Residual loss 1: 0.005205818836868897 | Residual loss 2: 3.080671631444616e-06
# Total residual loss: 0.005208899508500342 | Sqrt residual loss: 0.07217270611872845
#
# Test sample 453:
# Residual loss 1: 0.032170799137599106 | Residual loss 2: 4.480273859140997e-06
# Total residual loss: 0.032175279411458244 | Sqrt residual loss: 0.17937468999682826
#
# Test sample 454:
# Residual loss 1: 0.00037206716104427184 | Residual loss 2: 3.2401183246044813e-06
# Total residual loss: 0.0003753072793688763 | Sqrt residual loss: 0.019372849025604787
#
# Test sample 455:
# Residual loss 1: 0.003065115474764353 | Residual loss 2: 6.096496181463352e-08
# Total residual loss: 0.0030651764397261676 | Sqrt residual loss: 0.055364035616329195
#
# Test sample 456:
# Residual loss 1: 0.0004991118914800445 | Residual loss 2: 2.0363553995072816e-07
# Total residual loss: 0.0004993155270199952 | Sqrt residual loss: 0.022345369252263325
#
# Test sample 457:
# Residual loss 1: 0.0023010297904382626 | Residual loss 2: 9.357552193949148e-06
# Total residual loss: 0.0023103873426322118 | Sqrt residual loss: 0.04806648876953893
#
# Test sample 458:
# Residual loss 1: 0.005162089178818112 | Residual loss 2: 1.215207310679578e-05
# Total residual loss: 0.005174241251924908 | Sqrt residual loss: 0.07193219899269664
#
# Test sample 459:
# Residual loss 1: 0.010023358819537507 | Residual loss 2: 2.6612469675652332e-05
# Total residual loss: 0.01004997128921316 | Sqrt residual loss: 0.10024954508232524
#
# Test sample 460:
# Residual loss 1: 0.0006120085649710451 | Residual loss 2: 1.2980183164757176e-07
# Total residual loss: 0.0006121383668026927 | Sqrt residual loss: 0.024741430168902782
#
# Test sample 461:
# Residual loss 1: 0.00016963141189020676 | Residual loss 2: 1.2109401112202408e-05
# Total residual loss: 0.00018174081300240916 | Sqrt residual loss: 0.013481128031526485
#
# Test sample 462:
# Residual loss 1: 0.001387458245611484 | Residual loss 2: 2.0332006346929263e-05
# Total residual loss: 0.0014077902519584132 | Sqrt residual loss: 0.037520531072446364
#
# Test sample 463:
# Residual loss 1: 0.0057436394544821525 | Residual loss 2: 1.1740901239986368e-06
# Total residual loss: 0.0057448135446061515 | Sqrt residual loss: 0.07579454825121759
#
# Test sample 464:
# Residual loss 1: 0.0005305460305278526 | Residual loss 2: 5.702708595222026e-06
# Total residual loss: 0.0005362487391230746 | Sqrt residual loss: 0.023157045129356953
#
# Test sample 465:
# Residual loss 1: 0.001980197558160347 | Residual loss 2: 1.7323093227505336e-05
# Total residual loss: 0.001997520651387852 | Sqrt residual loss: 0.044693630993552676
#
# Test sample 466:
# Residual loss 1: 0.002310886215066319 | Residual loss 2: 1.7713372705740078e-05
# Total residual loss: 0.002328599587772059 | Sqrt residual loss: 0.04825556535542879
#
# Test sample 467:
# Residual loss 1: 0.00046619478382031607 | Residual loss 2: 9.383537892033836e-07
# Total residual loss: 0.00046713313760951943 | Sqrt residual loss: 0.02161326300236777
#
# Test sample 468:
# Residual loss 1: 0.0008296694971006162 | Residual loss 2: 1.8909711786902664e-05
# Total residual loss: 0.0008485792088875188 | Sqrt residual loss: 0.02913038291693947
#
# Test sample 469:
# Residual loss 1: 0.003703158051236414 | Residual loss 2: 4.2936990491933915e-06
# Total residual loss: 0.0037074517502856076 | Sqrt residual loss: 0.06088884750334504
#
# Test sample 470:
# Residual loss 1: 0.0013936621223168304 | Residual loss 2: 4.997659534240462e-06
# Total residual loss: 0.0013986597818510709 | Sqrt residual loss: 0.03739866016117517
#
# Test sample 471:
# Residual loss 1: 0.0017645240133373563 | Residual loss 2: 8.930083315968324e-07
# Total residual loss: 0.0017654170216689531 | Sqrt residual loss: 0.04201686591916338
#
# Test sample 472:
# Residual loss 1: 0.00988672530375248 | Residual loss 2: 4.248271445097398e-06
# Total residual loss: 0.009890973575197578 | Sqrt residual loss: 0.09945337387538734
#
# Test sample 473:
# Residual loss 1: 0.00046592473923133174 | Residual loss 2: 3.4137813605009307e-07
# Total residual loss: 0.00046626611736738183 | Sqrt residual loss: 0.021593196089680237
#
# Test sample 474:
# Residual loss 1: 0.0007475542710292147 | Residual loss 2: 5.44864610707861e-06
# Total residual loss: 0.0007530029171362932 | Sqrt residual loss: 0.027440898621151115
#
# Test sample 475:
# Residual loss 1: 0.0015495507861959569 | Residual loss 2: 1.55795350553762e-06
# Total residual loss: 0.0015511087397014945 | Sqrt residual loss: 0.03938411786115686
#
# Test sample 476:
# Residual loss 1: 0.0020475501054558294 | Residual loss 2: 3.404271488432075e-07
# Total residual loss: 0.0020478905326046727 | Sqrt residual loss: 0.045253624524502704
#
# Test sample 477:
# Residual loss 1: 0.000522949162051382 | Residual loss 2: 1.6490138070650689e-06
# Total residual loss: 0.000524598175858447 | Sqrt residual loss: 0.022904108274683976
#
# Test sample 478:
# Residual loss 1: 0.0015373999925511832 | Residual loss 2: 2.3723494154284703e-06
# Total residual loss: 0.0015397723419666117 | Sqrt residual loss: 0.0392399330015561
#
# Test sample 479:
# Residual loss 1: 0.001698140323713323 | Residual loss 2: 8.596943062399893e-10
# Total residual loss: 0.0016981411834076292 | Sqrt residual loss: 0.04120850862877264
#
# Test sample 480:
# Residual loss 1: 0.0010276045465151392 | Residual loss 2: 2.3286902219160462e-05
# Total residual loss: 0.0010508914487342997 | Sqrt residual loss: 0.03241745592631075
#
# Test sample 481:
# Residual loss 1: 0.001744547691317919 | Residual loss 2: 2.252710049321626e-07
# Total residual loss: 0.0017447729623228513 | Sqrt residual loss: 0.04177047955581611
#
# Test sample 482:
# Residual loss 1: 0.0005191906582311175 | Residual loss 2: 1.563623197272394e-06
# Total residual loss: 0.0005207542814283899 | Sqrt residual loss: 0.02282004122319655
#
# Test sample 483:
# Residual loss 1: 0.008138095283125358 | Residual loss 2: 3.7322617802880075e-05
# Total residual loss: 0.008175417900928237 | Sqrt residual loss: 0.09041801756800598
#
# Test sample 484:
# Residual loss 1: 0.0008912548872212875 | Residual loss 2: 2.82094364044282e-06
# Total residual loss: 0.0008940758308617304 | Sqrt residual loss: 0.02990110083026594
#
# Test sample 485:
# Residual loss 1: 0.00046996886567221937 | Residual loss 2: 2.8237169130830516e-08
# Total residual loss: 0.0004699971028413502 | Sqrt residual loss: 0.021679416570594103
#
# Test sample 486:
# Residual loss 1: 0.0042173469572629576 | Residual loss 2: 7.665677194369078e-06
# Total residual loss: 0.004225012634457326 | Sqrt residual loss: 0.06500009718806062
#
# Test sample 487:
# Residual loss 1: 0.0012655397564803746 | Residual loss 2: 1.970435704564876e-06
# Total residual loss: 0.0012675101921849395 | Sqrt residual loss: 0.03560210937830706
#
# Test sample 488:
# Residual loss 1: 0.0037757466031399234 | Residual loss 2: 1.064440293970269e-05
# Total residual loss: 0.003786391006079626 | Sqrt residual loss: 0.061533657506113074
#
# Test sample 489:
# Residual loss 1: 0.0002608197321238499 | Residual loss 2: 4.46024549995172e-08
# Total residual loss: 0.0002608643345788494 | Sqrt residual loss: 0.016151295136268465
#
# Test sample 490:
# Residual loss 1: 0.0024767881240071064 | Residual loss 2: 1.0912613651449579e-05
# Total residual loss: 0.002487700737658556 | Sqrt residual loss: 0.049876855731476856
#
# Test sample 491:
# Residual loss 1: 0.005865101923291947 | Residual loss 2: 6.442875123017733e-07
# Total residual loss: 0.005865746210804249 | Sqrt residual loss: 0.07658815972984498
#
# Test sample 492:
# Residual loss 1: 0.0010183528471159344 | Residual loss 2: 1.2050875420270554e-05
# Total residual loss: 0.001030403722536205 | Sqrt residual loss: 0.032099902220041186
#
# Test sample 493:
# Residual loss 1: 0.0006392949443165719 | Residual loss 2: 5.970557086438724e-06
# Total residual loss: 0.0006452655014030106 | Sqrt residual loss: 0.025402076714375353
#
# Test sample 494:
# Residual loss 1: 0.0003310848148375192 | Residual loss 2: 1.619178446339721e-07
# Total residual loss: 0.0003312467326821532 | Sqrt residual loss: 0.01820018496285555
#
# Test sample 495:
# Residual loss 1: 0.0015292375640769103 | Residual loss 2: 5.323498765367839e-06
# Total residual loss: 0.001534561062842278 | Sqrt residual loss: 0.03917347396954064
#
# Test sample 496:
# Residual loss 1: 0.0016477746312751247 | Residual loss 2: 1.3351931169107344e-07
# Total residual loss: 0.0016479081505868158 | Sqrt residual loss: 0.040594434970655964
#
# Test sample 497:
# Residual loss 1: 0.0006134502729757832 | Residual loss 2: 2.428099785426837e-09
# Total residual loss: 0.0006134527010755687 | Sqrt residual loss: 0.02476797733113402
#
# Test sample 498:
# Residual loss 1: 0.002162915460454328 | Residual loss 2: 3.260092803010738e-06
# Total residual loss: 0.0021661755532573386 | Sqrt residual loss: 0.046542191109329376
#
# Test sample 499:
# Residual loss 1: 0.0016053007816600965 | Residual loss 2: 5.617171530114244e-07
# Total residual loss: 0.001605862498813108 | Sqrt residual loss: 0.04007321423111837

# %%
np.save(os.path.join(model_test_outputs_path, "residual_loss_dict.npy"), residual_loss_dict)

# %%
print(f'mean residual loss 1: {np.mean(residual_loss_dict["loss_1"]):.2e} (std: {np.std(residual_loss_dict["loss_1"]):.2e})')
print(f'mean residual loss 2: {np.mean(residual_loss_dict["loss_2"]):.2e} (std: {np.std(residual_loss_dict["loss_2"]):.2e})')
print(f'mean total residual loss: {np.mean(residual_loss_dict["total_loss"]):.2e} (std: {np.std(residual_loss_dict["total_loss"]):.2e})')
print(f'mean sqrt total residual loss: {np.mean(residual_loss_dict["sqrt_total_loss"]):.2e} (std: {np.std(residual_loss_dict["sqrt_total_loss"]):.2e})')
# Out:
# mean residual loss 1: 3.26e-03 (std: 2.49e-02)
# mean residual loss 2: 1.10e-05 (std: 9.85e-05)
# mean total residual loss: 3.27e-03 (std: 2.50e-02)
# mean sqrt total residual loss: 4.28e-02 (std: 3.79e-02)

# %%
ratio_list = []
for test_index in range(num_test):
    ratio = np.sqrt(sigma_u_error_dict['squared_hdiv_h1'])[test_index] / residual_loss_dict['sqrt_total_loss'][test_index]
    ratio_list.append(ratio)
    print(f'index: {test_index} | ratio: {ratio}')
# Out:
# index: 0 | ratio: 0.6873702722373611
# index: 1 | ratio: 0.37889964191837217
# index: 2 | ratio: 0.8040519146162168
# index: 3 | ratio: 0.8694248583248384
# index: 4 | ratio: 0.4555899085538825
# index: 5 | ratio: 0.2644773449008006
# index: 6 | ratio: 0.6028783616012228
# index: 7 | ratio: 0.5779618686055245
# index: 8 | ratio: 0.45444136867610524
# index: 9 | ratio: 0.4322700147398439
# index: 10 | ratio: 0.3503573352904855
# index: 11 | ratio: 0.3312361464999338
# index: 12 | ratio: 0.6816863528022828
# index: 13 | ratio: 0.5379076052874364
# index: 14 | ratio: 0.25147923199190203
# index: 15 | ratio: 0.39172415641722164
# index: 16 | ratio: 0.40759797334588765
# index: 17 | ratio: 0.715007906587518
# index: 18 | ratio: 0.766992207453515
# index: 19 | ratio: 0.6240714292809603
# index: 20 | ratio: 0.39213376389549454
# index: 21 | ratio: 0.4866576611767886
# index: 22 | ratio: 0.5939423468282375
# index: 23 | ratio: 0.43093545285058493
# index: 24 | ratio: 0.30236951136564577
# index: 25 | ratio: 0.4056274386389509
# index: 26 | ratio: 0.606612008979567
# index: 27 | ratio: 0.5550745279659481
# index: 28 | ratio: 0.8944929994299705
# index: 29 | ratio: 0.6202138930417094
# index: 30 | ratio: 0.3374742527986813
# index: 31 | ratio: 0.3956753742837457
# index: 32 | ratio: 0.31210858982125644
# index: 33 | ratio: 0.324423285774843
# index: 34 | ratio: 0.28477068143731266
# index: 35 | ratio: 0.6880804648441547
# index: 36 | ratio: 0.39453808596852
# index: 37 | ratio: 0.8133286333836276
# index: 38 | ratio: 0.3226292364837322
# index: 39 | ratio: 0.570137467855423
# index: 40 | ratio: 0.40421479094742696
# index: 41 | ratio: 0.3394243694084027
# index: 42 | ratio: 0.4177762714682089
# index: 43 | ratio: 0.40364529381494096
# index: 44 | ratio: 0.5041829878920651
# index: 45 | ratio: 0.36000265608550874
# index: 46 | ratio: 0.4170281092174842
# index: 47 | ratio: 0.40981957512828804
# index: 48 | ratio: 0.6590054290100051
# index: 49 | ratio: 0.42759477624101555
# index: 50 | ratio: 0.6067732140478308
# index: 51 | ratio: 0.4580803350653532
# index: 52 | ratio: 0.43768596852776825
# index: 53 | ratio: 0.5538540852854343
# index: 54 | ratio: 0.5514645196022117
# index: 55 | ratio: 0.5911636891574307
# index: 56 | ratio: 0.7612294488334322
# index: 57 | ratio: 0.3164066959331144
# index: 58 | ratio: 0.5621276810840408
# index: 59 | ratio: 0.3347093204304541
# index: 60 | ratio: 0.36211296585231484
# index: 61 | ratio: 0.4684789966198505
# index: 62 | ratio: 0.3052805996293506
# index: 63 | ratio: 0.8511661131719676
# index: 64 | ratio: 0.4466103728582091
# index: 65 | ratio: 0.7593764688893605
# index: 66 | ratio: 0.6305973504030914
# index: 67 | ratio: 0.420002388250247
# index: 68 | ratio: 0.5171915114913248
# index: 69 | ratio: 0.5992605293419315
# index: 70 | ratio: 0.40196122621327135
# index: 71 | ratio: 0.4846934344750766
# index: 72 | ratio: 0.4512601128439953
# index: 73 | ratio: 0.662700172596966
# index: 74 | ratio: 0.4789080653400915
# index: 75 | ratio: 0.506694219999726
# index: 76 | ratio: 0.5076761258944724
# index: 77 | ratio: 0.51741108824185
# index: 78 | ratio: 0.45832399049027667
# index: 79 | ratio: 0.539061179798387
# index: 80 | ratio: 0.3564693334776575
# index: 81 | ratio: 0.44479552909108255
# index: 82 | ratio: 0.44102720219096236
# index: 83 | ratio: 0.3634423251398585
# index: 84 | ratio: 0.7302583873965336
# index: 85 | ratio: 0.31464683370011465
# index: 86 | ratio: 0.36989522154021304
# index: 87 | ratio: 0.4671277170882464
# index: 88 | ratio: 0.6299067272073239
# index: 89 | ratio: 0.6847988862253965
# index: 90 | ratio: 0.5642247976015299
# index: 91 | ratio: 0.6725812897727493
# index: 92 | ratio: 0.4945750795611918
# index: 93 | ratio: 0.6303710749061485
# index: 94 | ratio: 0.48608380719481364
# index: 95 | ratio: 0.49402878110263887
# index: 96 | ratio: 0.5526139738423347
# index: 97 | ratio: 0.4093904167217734
# index: 98 | ratio: 0.421885967672468
# index: 99 | ratio: 0.3817092330551056
# index: 100 | ratio: 0.6697630724834771
# index: 101 | ratio: 0.2930534714854828
# index: 102 | ratio: 0.41566472205555144
# index: 103 | ratio: 0.3769497987242538
# index: 104 | ratio: 0.342300715429803
# index: 105 | ratio: 0.3553407836197145
# index: 106 | ratio: 0.575585906308259
# index: 107 | ratio: 0.6778492940569452
# index: 108 | ratio: 0.3098795502078815
# index: 109 | ratio: 0.33031359289885776
# index: 110 | ratio: 0.49721245889636334
# index: 111 | ratio: 0.41875613097133807
# index: 112 | ratio: 0.6777521086682633
# index: 113 | ratio: 0.5516717071562763
# index: 114 | ratio: 0.5957611159574312
# index: 115 | ratio: 0.2893407038028104
# index: 116 | ratio: 0.3583675372750697
# index: 117 | ratio: 0.3780321629151812
# index: 118 | ratio: 0.31249080865779333
# index: 119 | ratio: 0.41869540189441407
# index: 120 | ratio: 0.4715780813110297
# index: 121 | ratio: 0.3423011629946809
# index: 122 | ratio: 0.5282463580927215
# index: 123 | ratio: 0.5559634295237382
# index: 124 | ratio: 0.35455234280518566
# index: 125 | ratio: 0.4595000288240636
# index: 126 | ratio: 0.6335995187217759
# index: 127 | ratio: 0.7399490681546068
# index: 128 | ratio: 0.3557109256996751
# index: 129 | ratio: 0.3972140657130297
# index: 130 | ratio: 0.3561622613292243
# index: 131 | ratio: 0.8787323018110068
# index: 132 | ratio: 0.6246513437018194
# index: 133 | ratio: 0.40638504757585886
# index: 134 | ratio: 0.33091612858172764
# index: 135 | ratio: 0.44759541656699336
# index: 136 | ratio: 0.7036192567437847
# index: 137 | ratio: 0.5250510815897916
# index: 138 | ratio: 0.46619702581956296
# index: 139 | ratio: 0.2828836861554154
# index: 140 | ratio: 0.586417972749672
# index: 141 | ratio: 0.43633715199972173
# index: 142 | ratio: 0.6535809227861724
# index: 143 | ratio: 0.5044479067716642
# index: 144 | ratio: 0.39910968092268
# index: 145 | ratio: 0.436601307038865
# index: 146 | ratio: 0.4328574440347588
# index: 147 | ratio: 0.34129412049176233
# index: 148 | ratio: 0.5623158762080265
# index: 149 | ratio: 0.7838032706414652
# index: 150 | ratio: 0.34793398997799707
# index: 151 | ratio: 0.6320577412977184
# index: 152 | ratio: 0.4304085794278775
# index: 153 | ratio: 0.4110292058166148
# index: 154 | ratio: 0.3593549006841977
# index: 155 | ratio: 0.654959758802981
# index: 156 | ratio: 0.3937138050406281
# index: 157 | ratio: 0.3586123246291802
# index: 158 | ratio: 0.5937393928710294
# index: 159 | ratio: 0.5779268882559977
# index: 160 | ratio: 0.46229842734877175
# index: 161 | ratio: 0.345964072138336
# index: 162 | ratio: 0.415688934951113
# index: 163 | ratio: 0.2864392406724413
# index: 164 | ratio: 0.3318432531587654
# index: 165 | ratio: 0.3734210007162908
# index: 166 | ratio: 0.30680392712313476
# index: 167 | ratio: 0.585926290572858
# index: 168 | ratio: 0.3440943737372656
# index: 169 | ratio: 0.5182352759238205
# index: 170 | ratio: 0.508205033147752
# index: 171 | ratio: 0.5467670430712201
# index: 172 | ratio: 0.6090702946526737
# index: 173 | ratio: 0.9336851661069785
# index: 174 | ratio: 0.3863036511541602
# index: 175 | ratio: 0.4670977532302095
# index: 176 | ratio: 0.3970192987924954
# index: 177 | ratio: 0.32202270486206597
# index: 178 | ratio: 0.37283530605279686
# index: 179 | ratio: 0.44238275386634857
# index: 180 | ratio: 0.45033721941064925
# index: 181 | ratio: 0.39944039455220876
# index: 182 | ratio: 0.4630115810086889
# index: 183 | ratio: 0.5522943326608859
# index: 184 | ratio: 0.3647403326076882
# index: 185 | ratio: 0.28063808208027
# index: 186 | ratio: 0.364309989566127
# index: 187 | ratio: 0.45297406517731137
# index: 188 | ratio: 0.3311738463462511
# index: 189 | ratio: 0.39084637523435706
# index: 190 | ratio: 0.513309573437917
# index: 191 | ratio: 0.33840578431417645
# index: 192 | ratio: 0.35059819706880163
# index: 193 | ratio: 0.42096725891534514
# index: 194 | ratio: 0.40125948500517344
# index: 195 | ratio: 0.43203167059249986
# index: 196 | ratio: 0.4222205676884003
# index: 197 | ratio: 0.3341729143242704
# index: 198 | ratio: 0.4082997161378265
# index: 199 | ratio: 0.3917259984159375
# index: 200 | ratio: 0.3205187638152784
# index: 201 | ratio: 0.514007630457151
# index: 202 | ratio: 0.5488369508946328
# index: 203 | ratio: 0.7371181074027756
# index: 204 | ratio: 0.6291359687508595
# index: 205 | ratio: 0.41758641211462566
# index: 206 | ratio: 0.31450565709797584
# index: 207 | ratio: 0.4602418398793051
# index: 208 | ratio: 0.3901013894339492
# index: 209 | ratio: 0.6110280416492602
# index: 210 | ratio: 0.4663583003358578
# index: 211 | ratio: 0.3274705081811027
# index: 212 | ratio: 0.3431986291590913
# index: 213 | ratio: 0.6491578911617116
# index: 214 | ratio: 0.4761799528771433
# index: 215 | ratio: 0.32250763024692025
# index: 216 | ratio: 0.5142223874306796
# index: 217 | ratio: 0.4842378292043293
# index: 218 | ratio: 0.35910812601092845
# index: 219 | ratio: 0.5494626969980967
# index: 220 | ratio: 0.4637732865317188
# index: 221 | ratio: 0.4475263093866469
# index: 222 | ratio: 0.4998690797673063
# index: 223 | ratio: 0.4302861510404912
# index: 224 | ratio: 0.33941848500966315
# index: 225 | ratio: 0.4300017072169246
# index: 226 | ratio: 0.4417930687151805
# index: 227 | ratio: 0.28452162740201686
# index: 228 | ratio: 0.3915521361077035
# index: 229 | ratio: 0.6709165996078671
# index: 230 | ratio: 0.9259908278370862
# index: 231 | ratio: 0.44451645787648797
# index: 232 | ratio: 0.5188018447379248
# index: 233 | ratio: 0.31583943460563113
# index: 234 | ratio: 0.638897918580499
# index: 235 | ratio: 0.4561179413293551
# index: 236 | ratio: 0.507830304659649
# index: 237 | ratio: 0.7671825881636847
# index: 238 | ratio: 0.5795531497189332
# index: 239 | ratio: 0.33065218048784784
# index: 240 | ratio: 0.700783181631211
# index: 241 | ratio: 0.2287134547210347
# index: 242 | ratio: 0.42134342440066197
# index: 243 | ratio: 0.5626380753584482
# index: 244 | ratio: 0.6315923649146732
# index: 245 | ratio: 0.6053195159241437
# index: 246 | ratio: 0.38797488831693044
# index: 247 | ratio: 0.5319647741992583
# index: 248 | ratio: 0.6463789598527523
# index: 249 | ratio: 0.667026193503304
# index: 250 | ratio: 0.40801839310658083
# index: 251 | ratio: 0.2515391422299058
# index: 252 | ratio: 0.35971052922490565
# index: 253 | ratio: 0.3852725571128708
# index: 254 | ratio: 0.3548341917310352
# index: 255 | ratio: 0.38983585198520304
# index: 256 | ratio: 0.4311241587555115
# index: 257 | ratio: 0.5510868291580223
# index: 258 | ratio: 0.34214286120265264
# index: 259 | ratio: 0.344592430026361
# index: 260 | ratio: 0.5127406089986838
# index: 261 | ratio: 0.5637308967829142
# index: 262 | ratio: 0.5140030841877419
# index: 263 | ratio: 0.328256197638748
# index: 264 | ratio: 0.33294165206160725
# index: 265 | ratio: 0.4245865560904991
# index: 266 | ratio: 0.30170839886980294
# index: 267 | ratio: 0.5251626491726054
# index: 268 | ratio: 0.40083687687166514
# index: 269 | ratio: 0.4216736939914866
# index: 270 | ratio: 0.38855795305462393
# index: 271 | ratio: 0.4070726951247443
# index: 272 | ratio: 0.31414355129626337
# index: 273 | ratio: 0.6099829119599918
# index: 274 | ratio: 0.4355668025162249
# index: 275 | ratio: 0.42778287834301715
# index: 276 | ratio: 0.42577856805769465
# index: 277 | ratio: 0.37659634394012675
# index: 278 | ratio: 0.38208798755746565
# index: 279 | ratio: 0.35441197042917644
# index: 280 | ratio: 0.548894086059778
# index: 281 | ratio: 0.9185920607191922
# index: 282 | ratio: 0.3720509041013879
# index: 283 | ratio: 0.37704623498607004
# index: 284 | ratio: 0.5135422967512101
# index: 285 | ratio: 0.503323732210591
# index: 286 | ratio: 0.4908554292168214
# index: 287 | ratio: 0.3465196949111103
# index: 288 | ratio: 0.3720925964916644
# index: 289 | ratio: 0.5889387773486939
# index: 290 | ratio: 0.5080190728197307
# index: 291 | ratio: 0.5278715418074164
# index: 292 | ratio: 0.3995875227238023
# index: 293 | ratio: 0.7740860346334972
# index: 294 | ratio: 0.4658408620445233
# index: 295 | ratio: 0.4387981856982644
# index: 296 | ratio: 0.4887543804495663
# index: 297 | ratio: 0.4563547041051655
# index: 298 | ratio: 0.34613338794164383
# index: 299 | ratio: 0.3183271419785622
# index: 300 | ratio: 0.5212417436246621
# index: 301 | ratio: 0.514907292705582
# index: 302 | ratio: 0.3191069715655749
# index: 303 | ratio: 0.47119382419223416
# index: 304 | ratio: 0.6218335708474942
# index: 305 | ratio: 0.43975707646649015
# index: 306 | ratio: 0.3494433942449668
# index: 307 | ratio: 0.47049914464150716
# index: 308 | ratio: 0.5074326913636821
# index: 309 | ratio: 0.558391544711067
# index: 310 | ratio: 0.46321918213171653
# index: 311 | ratio: 0.6604639504360402
# index: 312 | ratio: 0.8766922887043861
# index: 313 | ratio: 0.42715565447411724
# index: 314 | ratio: 0.39083570012786994
# index: 315 | ratio: 0.4806181524223323
# index: 316 | ratio: 0.4459527905572374
# index: 317 | ratio: 0.6317369352749402
# index: 318 | ratio: 0.875410767485027
# index: 319 | ratio: 0.5444989049902554
# index: 320 | ratio: 0.5180340796313871
# index: 321 | ratio: 0.4319376938253468
# index: 322 | ratio: 0.34376084650842376
# index: 323 | ratio: 0.5114959333060058
# index: 324 | ratio: 0.49819489907527
# index: 325 | ratio: 0.4645535711403447
# index: 326 | ratio: 0.32189468353699574
# index: 327 | ratio: 0.5161389561274138
# index: 328 | ratio: 0.4709778065963674
# index: 329 | ratio: 0.30342224379361166
# index: 330 | ratio: 0.4204906148597877
# index: 331 | ratio: 0.3741788177960548
# index: 332 | ratio: 0.5597871162109144
# index: 333 | ratio: 0.5345826559833773
# index: 334 | ratio: 0.658877757999258
# index: 335 | ratio: 0.6875445091700068
# index: 336 | ratio: 0.4587892032351011
# index: 337 | ratio: 0.26815395418475896
# index: 338 | ratio: 0.6372645865036802
# index: 339 | ratio: 0.32205053341185974
# index: 340 | ratio: 0.4525763590225962
# index: 341 | ratio: 0.33559791792773946
# index: 342 | ratio: 0.5937406522206833
# index: 343 | ratio: 0.4001231868917339
# index: 344 | ratio: 0.6619520196627637
# index: 345 | ratio: 0.39245268232112257
# index: 346 | ratio: 0.47562228338459067
# index: 347 | ratio: 0.6017807634996681
# index: 348 | ratio: 0.3544052857020443
# index: 349 | ratio: 0.6177290203866618
# index: 350 | ratio: 0.6865693755013419
# index: 351 | ratio: 0.4128904578885313
# index: 352 | ratio: 0.4929791409123267
# index: 353 | ratio: 0.2700593404623579
# index: 354 | ratio: 0.37336937336460463
# index: 355 | ratio: 0.7203132302563192
# index: 356 | ratio: 0.5527140306886251
# index: 357 | ratio: 0.5950203372887566
# index: 358 | ratio: 0.6057530077089216
# index: 359 | ratio: 0.41771978612897703
# index: 360 | ratio: 0.5611779904369758
# index: 361 | ratio: 0.43550782833752033
# index: 362 | ratio: 0.6327692817529965
# index: 363 | ratio: 0.4713290785044626
# index: 364 | ratio: 0.36041831777220257
# index: 365 | ratio: 0.38767136993469753
# index: 366 | ratio: 0.5381236595222635
# index: 367 | ratio: 0.30056814763510914
# index: 368 | ratio: 0.32595760264918233
# index: 369 | ratio: 0.7271005293828108
# index: 370 | ratio: 0.4514550449464299
# index: 371 | ratio: 0.457316379194366
# index: 372 | ratio: 0.6472187849029868
# index: 373 | ratio: 0.5229485960123915
# index: 374 | ratio: 0.7020564849339516
# index: 375 | ratio: 0.545757809440768
# index: 376 | ratio: 0.34500805231858295
# index: 377 | ratio: 0.4143183778221579
# index: 378 | ratio: 0.46187314041887384
# index: 379 | ratio: 0.37970082707082425
# index: 380 | ratio: 0.48114946827514093
# index: 381 | ratio: 0.40490882369563314
# index: 382 | ratio: 0.4402087404166972
# index: 383 | ratio: 0.5331835391228272
# index: 384 | ratio: 0.38207950255636736
# index: 385 | ratio: 0.4039611903511591
# index: 386 | ratio: 0.4898413084687388
# index: 387 | ratio: 0.6131064388328253
# index: 388 | ratio: 0.6339359611655241
# index: 389 | ratio: 0.4298979847466426
# index: 390 | ratio: 0.3562377630182868
# index: 391 | ratio: 0.38028769493461456
# index: 392 | ratio: 0.3292171903016466
# index: 393 | ratio: 0.7451661190899593
# index: 394 | ratio: 0.5212381531106202
# index: 395 | ratio: 0.4125511152030935
# index: 396 | ratio: 0.4708578666532836
# index: 397 | ratio: 0.3815372989595247
# index: 398 | ratio: 0.6755356875209404
# index: 399 | ratio: 0.5144716556551711
# index: 400 | ratio: 0.406485546259094
# index: 401 | ratio: 0.35691829066390357
# index: 402 | ratio: 0.40512244889639154
# index: 403 | ratio: 0.3346828676226834
# index: 404 | ratio: 0.8111358788872669
# index: 405 | ratio: 0.34245464522553576
# index: 406 | ratio: 0.3001202239548843
# index: 407 | ratio: 0.7155168318233084
# index: 408 | ratio: 0.39737723671665315
# index: 409 | ratio: 0.5752040216871269
# index: 410 | ratio: 0.42884951743137506
# index: 411 | ratio: 0.28648471741317905
# index: 412 | ratio: 0.47860345859090897
# index: 413 | ratio: 0.25359676229094213
# index: 414 | ratio: 0.33768076511719836
# index: 415 | ratio: 0.4503347621025174
# index: 416 | ratio: 0.635519758994727
# index: 417 | ratio: 0.5733454415384036
# index: 418 | ratio: 0.32511083571142596
# index: 419 | ratio: 0.40206633943192427
# index: 420 | ratio: 0.48119471064131725
# index: 421 | ratio: 0.3930251765136998
# index: 422 | ratio: 0.41378668589990386
# index: 423 | ratio: 0.41486229360726434
# index: 424 | ratio: 0.5854973775507113
# index: 425 | ratio: 0.33426233845948683
# index: 426 | ratio: 0.5095664196783458
# index: 427 | ratio: 0.4258012510695151
# index: 428 | ratio: 0.621364236225329
# index: 429 | ratio: 0.5279465690753955
# index: 430 | ratio: 0.5119701348283818
# index: 431 | ratio: 0.4353876372824625
# index: 432 | ratio: 0.5035118981717444
# index: 433 | ratio: 0.42809681387247484
# index: 434 | ratio: 0.3695608434111085
# index: 435 | ratio: 0.3799268629504708
# index: 436 | ratio: 0.8497413826530754
# index: 437 | ratio: 0.8286315847278256
# index: 438 | ratio: 0.39651733973092723
# index: 439 | ratio: 0.43225116132916663
# index: 440 | ratio: 0.660799907934699
# index: 441 | ratio: 0.31084990830419074
# index: 442 | ratio: 0.5241067918204819
# index: 443 | ratio: 0.31620161976690786
# index: 444 | ratio: 0.38756670887222916
# index: 445 | ratio: 0.4383177175618091
# index: 446 | ratio: 0.5759340188229296
# index: 447 | ratio: 0.38680679501381815
# index: 448 | ratio: 0.35880234678860035
# index: 449 | ratio: 0.4069977652923017
# index: 450 | ratio: 1.111391478107896
# index: 451 | ratio: 0.4245844767920518
# index: 452 | ratio: 0.3114474715318382
# index: 453 | ratio: 0.4860258837973337
# index: 454 | ratio: 0.6171926358560766
# index: 455 | ratio: 0.29645444232606544
# index: 456 | ratio: 0.8692408806722377
# index: 457 | ratio: 0.3769585475775533
# index: 458 | ratio: 0.3569308219409082
# index: 459 | ratio: 0.28605216699542046
# index: 460 | ratio: 0.6156585104542199
# index: 461 | ratio: 0.7348536301633787
# index: 462 | ratio: 0.5813840790980449
# index: 463 | ratio: 0.24274586368751622
# index: 464 | ratio: 0.4350658956716612
# index: 465 | ratio: 0.4613241508121885
# index: 466 | ratio: 0.31558317192255597
# index: 467 | ratio: 0.600138980389247
# index: 468 | ratio: 0.5345928951850489
# index: 469 | ratio: 0.3597153474110783
# index: 470 | ratio: 0.42147437006232147
# index: 471 | ratio: 0.401456944830685
# index: 472 | ratio: 0.3802795077644779
# index: 473 | ratio: 0.4799272570106798
# index: 474 | ratio: 0.7855897644529956
# index: 475 | ratio: 0.6713416711766172
# index: 476 | ratio: 0.3979793108569543
# index: 477 | ratio: 0.5018764095636818
# index: 478 | ratio: 0.398215962156214
# index: 479 | ratio: 0.41799433514499706
# index: 480 | ratio: 0.45273464541224157
# index: 481 | ratio: 0.39702942261706303
# index: 482 | ratio: 0.5288241144289013
# index: 483 | ratio: 0.5247552774257974
# index: 484 | ratio: 0.4434134440021822
# index: 485 | ratio: 0.6623126494862542
# index: 486 | ratio: 0.3440980106230884
# index: 487 | ratio: 0.37967348219678265
# index: 488 | ratio: 0.39590672147318984
# index: 489 | ratio: 0.604333526763394
# index: 490 | ratio: 0.46127042408712693
# index: 491 | ratio: 0.28822239949508266
# index: 492 | ratio: 0.46861659481939805
# index: 493 | ratio: 0.531950814767015
# index: 494 | ratio: 0.7715799903086399
# index: 495 | ratio: 0.5573710145607935
# index: 496 | ratio: 0.3655997965282913
# index: 497 | ratio: 0.6589747057740132
# index: 498 | ratio: 0.4570693832944305
# index: 499 | ratio: 0.6325264191853041

# %%
plt.figure(figsize=(8, 6))  # Optional: bigger figure
plt.hist(ratio_list, bins=10)

plt.xlabel('Value', fontsize=25) 
plt.ylabel('Frequency', fontsize=25)
plt.title(fr'Error / $\sqrt{{\text{{Loss}}}}$ (# test = {num_test})', fontsize=25)

plt.xticks(fontsize=23)
plt.yticks(fontsize=23)

plt.savefig(os.path.join(model_test_outputs_path, 'ratio_histogram_hdiv_h1.png'),
            dpi=300, bbox_inches='tight')
plt.close()
